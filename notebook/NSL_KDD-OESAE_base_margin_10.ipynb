# %%
import os
import pathlib
import sys

default_dir_path = str(pathlib.Path(os.getcwd()).parent.absolute())

sys.path.append(default_dir_path)

from properties import ApplicationProperties
# Out:
# [2020-12-17 15:32:48,023][INFO][properties.py:22] Complete to apply the random seed, RANDOM_SEED : 777

# %%
from torch import optim
from torch.nn import functional as F
import torch

from dataset.factory import DatasetFactory
from dataset.nsl_kdd_dataset import NSLKDDDataFrameFactory, NSLKDDDataset
from domain.criterion import Criterion
from domain.hyperparameters import Hyperparameters
from domain.metadata import ModelFileMetadata
from logger import logger
from model.factory import ModelFactory
from trainer.base import TrainerBase
from trainer.factory import TrainerFactory

# %%
from sklearn import preprocessing
from sklearn.metrics import roc_curve, auc
from sklearn.model_selection import train_test_split
from torch import nn, optim
from torch.utils.data import Dataset, DataLoader
import numpy as np
import pandas as pd
import tqdm.notebook as tqdm

# %%
device = "cpu"
data_name = "nsl_kdd_outlier"
model_name = "oesae_margin10"
n_epoch = 1000

# %%
dataset_factory = DatasetFactory.create(data_name=data_name)
# Out:
# [2020-12-17 15:32:49,787][INFO][nsl_kdd_dataset.py:98] Success to load dataset dataframe : train
# [2020-12-17 15:32:49,884][INFO][nsl_kdd_dataset.py:98] Success to load dataset dataframe : test
# [2020-12-17 15:32:50,317][INFO][nsl_kdd_dataset.py:110] Success to load dataset dataframe : entire
# [2020-12-17 15:32:51,374][INFO][nsl_kdd_dataset.py:164] Entire data size : 148517
# [2020-12-17 15:32:51,375][INFO][nsl_kdd_dataset.py:165] Normal data size : 77054
# [2020-12-17 15:32:51,376][INFO][nsl_kdd_dataset.py:166] Abnormal data size : 7146
# [2020-12-17 15:32:51,377][INFO][nsl_kdd_dataset.py:167] Outlier data size : 7146
# [2020-12-17 15:32:51,378][INFO][nsl_kdd_dataset.py:168] Normal test data size : 7146
# [2020-12-17 15:32:51,379][INFO][nsl_kdd_dataset.py:169] Training data size : 69908
# [2020-12-17 15:32:51,380][INFO][nsl_kdd_dataset.py:170] Test data size : 14292
# [2020-12-17 15:32:52,561][INFO][factory.py:109] Success to fit data with scaling
# [2020-12-17 15:32:52,969][INFO][factory.py:118] Success to transform data with scaling
# [2020-12-17 15:32:52,986][INFO][factory.py:153] Data selected : 'nsl_kdd_outlier'

# %%
train_dataloader, outlier_dataloader = dataset_factory.train_dataloader
val_dataloader = dataset_factory.val_dataloader

# %%
class AE(nn.Module):
    
    def __init__(self, input_size):  # 117
        super(AE, self).__init__()
        self.encoder_1 = nn.Sequential(
            nn.Linear(in_features=input_size, out_features=64, bias=True),
            nn.Tanh(),
            nn.Linear(in_features=64, out_features=32, bias=True),
            nn.Tanh(),
            nn.Linear(in_features=32, out_features=16, bias=True),
            nn.Tanh()
        )
        self.decoder_1 = nn.Sequential(
            nn.Linear(in_features=16, out_features=32, bias=True),
            nn.Tanh(),
            nn.Linear(in_features=32, out_features=64, bias=True),
            nn.Tanh(),
            nn.Linear(in_features=64, out_features=input_size, bias=True),
            nn.Tanh()
        )
        
        self.he_init_weight()
        
    def forward(self, x):
        z = self.encoder_1(x)
        x_hat = self.decoder_1(z)
        return x_hat, z
    
    def he_init_weight(self):
        for module in self.modules():
            if isinstance(module, nn.Conv2d):
                nn.init.kaiming_normal_(module.weight.data)
            elif isinstance(module, nn.Linear):
                nn.init.kaiming_normal_(module.weight.data)
            elif isinstance(module, nn.ConvTranspose2d):
                nn.init.kaiming_normal_(module.weight.data)

# %%
from copy import deepcopy
import pickle
import time

from sklearn.metrics import roc_curve, auc
import torch

from domain.criterion import Criterion
from trainer.base import TrainerBase

time.time()


class OESAETrainer(TrainerBase):

    def __init__(self, model, model_file_metadata, train_loader, outlier_loader, val_loader, test_loader, hyperparameters,
                 tqdm_env='script'):
        super(OESAETrainer, self).__init__(model, model_file_metadata, train_loader, val_loader, test_loader,
                                        hyperparameters, tqdm_env)
        self.outlier_loader = outlier_loader

    def train(self):
        self.model.train()

        train_result_dict_list = list()
        val_result_dict_list = list()

        best_loss = 999999
        best_auc = 0
        best_loss_epoch = 0
        best_auc_epoch = 0

        # Set hyperparameters
        optimizer_cls = self.hyperparameters.optimizer_cls
        lr = self.hyperparameters.lr
        weight_decay = self.hyperparameters.weight_decay
        n_epoch = self.hyperparameters.n_epoch
        train_criterion = self.hyperparameters.train_criterion
        val_criterion = self.hyperparameters.val_criterion
        lambda_ = self.hyperparameters.lambda_
        margin = self.hyperparameters.margin
        device = self.hyperparameters.device

        optimizer = optimizer_cls(self.model.parameters(), lr=lr, weight_decay=weight_decay)

        for epoch in self.tqdm.tqdm(range(n_epoch)):
            total_loss = 0
            n_batch = 0

            for i, ((data_batch, label_batch, abnormal_label_batch), (outlier_data_batch, outlier_label_batch, outlier_abnormal_label_batch)) in enumerate(zip(self.train_loader, self.outlier_loader)):
                entire_data_batch = torch.cat([data_batch, outlier_data_batch], dim=0)
                entire_data_batch = entire_data_batch.to(device)

                # Optimization
                optimizer.zero_grad()
                pred_data_batch, latent_data_batch = self.model(entire_data_batch)

                in_pred_data_batch = pred_data_batch[:len(data_batch)]
                out_pred_data_batch = pred_data_batch[len(data_batch):]

                in_latent_data_batch = latent_data_batch[:len(data_batch)]
                out_latent_data_batch = latent_data_batch[len(data_batch):]

                if in_latent_data_batch.shape != out_latent_data_batch.shape:
                    continue

                mse_loss = val_criterion(data_batch, in_pred_data_batch, in_latent_data_batch, lambda_)
                triple_margin_loss = train_criterion(
                    anchor=torch.zeros(size=in_latent_data_batch.shape),
                    positive=in_latent_data_batch,
                    negative=out_latent_data_batch,
                    margin=margin
                )
                loss = mse_loss + triple_margin_loss

                loss.backward()
                optimizer.step()

                total_loss += loss.item()
                n_batch += 1

            current_loss = total_loss / n_batch

            train_result_dict = dict(
                loss=current_loss
            )
            val_result_dict = self.validate()

            # Early stopping
            if val_result_dict['loss'] < best_loss:
                best_loss = val_result_dict['loss']
                best_loss_epoch = epoch
                # self.best_model_state_dict = deepcopy(self.model.state_dict())

            if best_auc < val_result_dict['auc']:
                best_auc = val_result_dict['auc']
                best_auc_epoch = epoch
                self.best_model = deepcopy(self.model.state_dict())

            # Print
            print(
                f"[Epoch {epoch}] "
                f"Train - loss : {round(train_result_dict['loss'], 7)} | "
                f"Val - AUC : {round(val_result_dict['auc'], 7)} | "
                f"Best AUC : {round(best_auc, 7)} (epoch : {best_auc_epoch})"
            )

            # Save Model & Record dictW
            record_dict = dict(
                train_result_dict=train_result_dict,
                val_result_dict=val_result_dict
            )

            self.save_model(epoch=epoch)
            self.save_record(record=record_dict, epoch=epoch)

            train_result_dict_list.append(train_result_dict)
            val_result_dict_list.append(val_result_dict)

        # Save last result
        entire_record_dict = dict(
            train_result_dict_list=train_result_dict_list,
            val_result_dict_list=val_result_dict_list
        )
        torch.save(self.best_model, self.model_file_metadata.get_best_model_file_path())

        # Save entire_record_dict
        with open(self.model_file_metadata.get_entire_record_file_path(), "wb") as f:
            pickle.dump(entire_record_dict, f, protocol=pickle.HIGHEST_PROTOCOL)

        # Load best model
        self.load_best_model()

        return entire_record_dict

    def validate(self):
        self.model.eval()

        total_loss = 0
        n_batch = 0

        latent_data_list = list()
        reconstructino_error_list = list()
        abnormal_label_list = list()

        # Set hyperparameters
        device = self.hyperparameters.device
        val_criterion = self.hyperparameters.val_criterion
        lambda_ = self.hyperparameters.lambda_

        for i, (data_batch, label_batch, abnormal_label_batch) in enumerate(self.val_loader):
            data_batch = data_batch.to(device)
            abnormal_label_batch = abnormal_label_batch.to(device)

            with torch.no_grad():
                pred_data_batch, latent_data_batch = self.model(data_batch)
                loss = val_criterion(data_batch, pred_data_batch, latent_data_batch, lambda_).item()
                reconstruction_error_batch = Criterion.reconstruction_error(x=data_batch, x_hat=pred_data_batch)

            latent_data_list.append(latent_data_batch)
            reconstructino_error_list.append(reconstruction_error_batch)
            abnormal_label_list.append(abnormal_label_batch)

            total_loss += loss
            n_batch += 1

        latent_data_list = torch.cat(latent_data_list).cpu().numpy()
        reconstruction_error_list = torch.cat(reconstructino_error_list).cpu().numpy()
        abnormal_label_list = torch.cat(abnormal_label_list).cpu().numpy()

        fpr, tpr, thresholds = roc_curve(abnormal_label_list, reconstruction_error_list)
        auc_value = auc(fpr, tpr)

        current_loss = total_loss / n_batch

        return dict(loss=current_loss, auc=auc_value, latent_data_list=latent_data_list)

# %%
ae_model = AE(input_size=118)

# %%
ae_model.to(device)
# Out:
# AE(
#   (encoder_1): Sequential(
#     (0): Linear(in_features=118, out_features=64, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=64, out_features=32, bias=True)
#     (3): Tanh()
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): Tanh()
#   )
#   (decoder_1): Sequential(
#     (0): Linear(in_features=16, out_features=32, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=32, out_features=64, bias=True)
#     (3): Tanh()
#     (4): Linear(in_features=64, out_features=118, bias=True)
#     (5): Tanh()
#   )
# )

# %%
trainer = OESAETrainer(
    model=ae_model,
    model_file_metadata=ModelFileMetadata(model_name=model_name),
    train_loader=train_dataloader,
    val_loader=val_dataloader,
    outlier_loader=outlier_dataloader,
    test_loader=dataset_factory.test_dataloader,
    hyperparameters=Hyperparameters(
        optimizer_cls=optim.Adadelta,
        train_criterion=Criterion.triple_margin_loss,
        val_criterion=Criterion.sae_loss,
        lambda_=10,
        margin=10,
        n_epoch=n_epoch,
        lr=1e-3,
        weight_decay=0,
        device=device
    ),
    tqdm_env="jupyter"
)
# Out:
# [2020-12-17 15:32:53,287][INFO][base.py:40] Model set to 'cpu'

# %%
# Adadelta (tanh, lambda 10)
result_dict = trainer.train()
# Out:
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# [Epoch 0] Train - loss : 12.1296645 | Val - AUC : 0.964658 | Best AUC : 0.964658 (epoch : 0)
# [Epoch 1] Train - loss : 11.9199084 | Val - AUC : 0.9648235 | Best AUC : 0.9648235 (epoch : 1)
# [Epoch 2] Train - loss : 11.7962563 | Val - AUC : 0.9648382 | Best AUC : 0.9648382 (epoch : 2)
# [Epoch 3] Train - loss : 11.5936894 | Val - AUC : 0.9647908 | Best AUC : 0.9648382 (epoch : 2)
# [Epoch 4] Train - loss : 11.5308041 | Val - AUC : 0.9647526 | Best AUC : 0.9648382 (epoch : 2)
# [Epoch 5] Train - loss : 11.1514366 | Val - AUC : 0.9647387 | Best AUC : 0.9648382 (epoch : 2)
# [Epoch 6] Train - loss : 11.0388145 | Val - AUC : 0.9647631 | Best AUC : 0.9648382 (epoch : 2)
# [Epoch 7] Train - loss : 10.9881693 | Val - AUC : 0.9648276 | Best AUC : 0.9648382 (epoch : 2)
# [Epoch 8] Train - loss : 10.6853726 | Val - AUC : 0.9648951 | Best AUC : 0.9648951 (epoch : 8)
# [Epoch 9] Train - loss : 10.552234 | Val - AUC : 0.9649618 | Best AUC : 0.9649618 (epoch : 9)
# [Epoch 10] Train - loss : 10.6946409 | Val - AUC : 0.9650325 | Best AUC : 0.9650325 (epoch : 10)
# [Epoch 11] Train - loss : 10.5062184 | Val - AUC : 0.9651067 | Best AUC : 0.9651067 (epoch : 11)
# [Epoch 12] Train - loss : 10.3303113 | Val - AUC : 0.9651916 | Best AUC : 0.9651916 (epoch : 12)
# [Epoch 13] Train - loss : 10.3112212 | Val - AUC : 0.9652512 | Best AUC : 0.9652512 (epoch : 13)
# [Epoch 14] Train - loss : 10.1403966 | Val - AUC : 0.9653135 | Best AUC : 0.9653135 (epoch : 14)
# [Epoch 15] Train - loss : 10.0803963 | Val - AUC : 0.9653655 | Best AUC : 0.9653655 (epoch : 15)
# [Epoch 16] Train - loss : 10.0272669 | Val - AUC : 0.9654231 | Best AUC : 0.9654231 (epoch : 16)
# [Epoch 17] Train - loss : 10.0071761 | Val - AUC : 0.9654681 | Best AUC : 0.9654681 (epoch : 17)
# [Epoch 18] Train - loss : 10.0267045 | Val - AUC : 0.9655216 | Best AUC : 0.9655216 (epoch : 18)
# [Epoch 19] Train - loss : 9.8421091 | Val - AUC : 0.9655653 | Best AUC : 0.9655653 (epoch : 19)
# [Epoch 20] Train - loss : 9.8600098 | Val - AUC : 0.9656134 | Best AUC : 0.9656134 (epoch : 20)
# [Epoch 21] Train - loss : 9.7999095 | Val - AUC : 0.9656467 | Best AUC : 0.9656467 (epoch : 21)
# [Epoch 22] Train - loss : 9.6990587 | Val - AUC : 0.965691 | Best AUC : 0.965691 (epoch : 22)
# [Epoch 23] Train - loss : 9.8556117 | Val - AUC : 0.9657239 | Best AUC : 0.9657239 (epoch : 23)
# [Epoch 24] Train - loss : 9.8933836 | Val - AUC : 0.9657489 | Best AUC : 0.9657489 (epoch : 24)
# [Epoch 25] Train - loss : 9.5409235 | Val - AUC : 0.9657888 | Best AUC : 0.9657888 (epoch : 25)
# [Epoch 26] Train - loss : 9.5621916 | Val - AUC : 0.9658187 | Best AUC : 0.9658187 (epoch : 26)
# [Epoch 27] Train - loss : 9.6426239 | Val - AUC : 0.9658499 | Best AUC : 0.9658499 (epoch : 27)
# [Epoch 28] Train - loss : 9.6805662 | Val - AUC : 0.9658817 | Best AUC : 0.9658817 (epoch : 28)
# [Epoch 29] Train - loss : 9.6052975 | Val - AUC : 0.9659054 | Best AUC : 0.9659054 (epoch : 29)
# [Epoch 30] Train - loss : 9.5809052 | Val - AUC : 0.965928 | Best AUC : 0.965928 (epoch : 30)
# [Epoch 31] Train - loss : 9.4757141 | Val - AUC : 0.9659584 | Best AUC : 0.9659584 (epoch : 31)
# [Epoch 32] Train - loss : 9.3256651 | Val - AUC : 0.9659689 | Best AUC : 0.9659689 (epoch : 32)
# [Epoch 33] Train - loss : 9.4439574 | Val - AUC : 0.9659965 | Best AUC : 0.9659965 (epoch : 33)
# [Epoch 34] Train - loss : 9.4710706 | Val - AUC : 0.9660188 | Best AUC : 0.9660188 (epoch : 34)
# [Epoch 35] Train - loss : 9.2043656 | Val - AUC : 0.9660305 | Best AUC : 0.9660305 (epoch : 35)
# [Epoch 36] Train - loss : 9.3957471 | Val - AUC : 0.96605 | Best AUC : 0.96605 (epoch : 36)
# [Epoch 37] Train - loss : 9.3549246 | Val - AUC : 0.9660701 | Best AUC : 0.9660701 (epoch : 37)
# [Epoch 38] Train - loss : 9.2701755 | Val - AUC : 0.9660777 | Best AUC : 0.9660777 (epoch : 38)
# [Epoch 39] Train - loss : 9.4060693 | Val - AUC : 0.9660951 | Best AUC : 0.9660951 (epoch : 39)
# [Epoch 40] Train - loss : 9.1426029 | Val - AUC : 0.9661112 | Best AUC : 0.9661112 (epoch : 40)
# [Epoch 41] Train - loss : 9.1494952 | Val - AUC : 0.9661165 | Best AUC : 0.9661165 (epoch : 41)
# [Epoch 42] Train - loss : 9.3320082 | Val - AUC : 0.9661122 | Best AUC : 0.9661165 (epoch : 41)
# [Epoch 43] Train - loss : 9.184714 | Val - AUC : 0.96612 | Best AUC : 0.96612 (epoch : 43)
# [Epoch 44] Train - loss : 9.1633087 | Val - AUC : 0.9661269 | Best AUC : 0.9661269 (epoch : 44)
# [Epoch 45] Train - loss : 9.1200606 | Val - AUC : 0.966141 | Best AUC : 0.966141 (epoch : 45)
# [Epoch 46] Train - loss : 9.2045431 | Val - AUC : 0.9661421 | Best AUC : 0.9661421 (epoch : 46)
# [Epoch 47] Train - loss : 9.2074601 | Val - AUC : 0.96615 | Best AUC : 0.96615 (epoch : 47)
# [Epoch 48] Train - loss : 9.3911869 | Val - AUC : 0.966159 | Best AUC : 0.966159 (epoch : 48)
# [Epoch 49] Train - loss : 9.065487 | Val - AUC : 0.9661671 | Best AUC : 0.9661671 (epoch : 49)
# [Epoch 50] Train - loss : 9.1303616 | Val - AUC : 0.9661705 | Best AUC : 0.9661705 (epoch : 50)
# [Epoch 51] Train - loss : 9.1419639 | Val - AUC : 0.9661729 | Best AUC : 0.9661729 (epoch : 51)
# [Epoch 52] Train - loss : 9.0314267 | Val - AUC : 0.96617 | Best AUC : 0.9661729 (epoch : 51)
# [Epoch 53] Train - loss : 9.1543062 | Val - AUC : 0.9661684 | Best AUC : 0.9661729 (epoch : 51)
# [Epoch 54] Train - loss : 9.1656465 | Val - AUC : 0.9661808 | Best AUC : 0.9661808 (epoch : 54)
# [Epoch 55] Train - loss : 8.9641241 | Val - AUC : 0.9661806 | Best AUC : 0.9661808 (epoch : 54)
# [Epoch 56] Train - loss : 8.8540582 | Val - AUC : 0.9661784 | Best AUC : 0.9661808 (epoch : 54)
# [Epoch 57] Train - loss : 8.9507887 | Val - AUC : 0.9661836 | Best AUC : 0.9661836 (epoch : 57)
# [Epoch 58] Train - loss : 8.981871 | Val - AUC : 0.9661826 | Best AUC : 0.9661836 (epoch : 57)
# [Epoch 59] Train - loss : 8.9077073 | Val - AUC : 0.9661925 | Best AUC : 0.9661925 (epoch : 59)
# [Epoch 60] Train - loss : 8.8470928 | Val - AUC : 0.9661915 | Best AUC : 0.9661925 (epoch : 59)
# [Epoch 61] Train - loss : 8.8921193 | Val - AUC : 0.9661895 | Best AUC : 0.9661925 (epoch : 59)
# [Epoch 62] Train - loss : 8.9364723 | Val - AUC : 0.9661934 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 63] Train - loss : 8.9594847 | Val - AUC : 0.9661834 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 64] Train - loss : 8.9380773 | Val - AUC : 0.9661881 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 65] Train - loss : 8.8812316 | Val - AUC : 0.9661847 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 66] Train - loss : 8.7926563 | Val - AUC : 0.9661879 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 67] Train - loss : 8.9591808 | Val - AUC : 0.9661811 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 68] Train - loss : 8.8037695 | Val - AUC : 0.9661722 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 69] Train - loss : 8.7707746 | Val - AUC : 0.9661676 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 70] Train - loss : 8.8140026 | Val - AUC : 0.9661546 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 71] Train - loss : 8.894447 | Val - AUC : 0.9661571 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 72] Train - loss : 8.6455751 | Val - AUC : 0.9661539 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 73] Train - loss : 8.847045 | Val - AUC : 0.9661515 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 74] Train - loss : 8.7405781 | Val - AUC : 0.9661468 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 75] Train - loss : 8.939077 | Val - AUC : 0.9661366 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 76] Train - loss : 8.8149457 | Val - AUC : 0.9661355 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 77] Train - loss : 8.8792332 | Val - AUC : 0.9661245 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 78] Train - loss : 8.8145158 | Val - AUC : 0.9661191 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 79] Train - loss : 8.7643357 | Val - AUC : 0.9661201 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 80] Train - loss : 8.7421516 | Val - AUC : 0.9661088 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 81] Train - loss : 8.8361823 | Val - AUC : 0.966109 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 82] Train - loss : 8.7667292 | Val - AUC : 0.9661035 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 83] Train - loss : 8.6342755 | Val - AUC : 0.9660938 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 84] Train - loss : 8.8192411 | Val - AUC : 0.966085 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 85] Train - loss : 8.5921036 | Val - AUC : 0.9660694 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 86] Train - loss : 8.843691 | Val - AUC : 0.9660621 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 87] Train - loss : 8.8339826 | Val - AUC : 0.9660476 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 88] Train - loss : 8.717738 | Val - AUC : 0.9660393 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 89] Train - loss : 8.6119078 | Val - AUC : 0.9660292 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 90] Train - loss : 8.7852069 | Val - AUC : 0.9660161 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 91] Train - loss : 8.722748 | Val - AUC : 0.9660025 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 92] Train - loss : 8.7505972 | Val - AUC : 0.9659941 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 93] Train - loss : 8.6775952 | Val - AUC : 0.9659788 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 94] Train - loss : 8.6897909 | Val - AUC : 0.9659765 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 95] Train - loss : 8.634444 | Val - AUC : 0.9659692 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 96] Train - loss : 8.4885587 | Val - AUC : 0.9659567 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 97] Train - loss : 8.5375814 | Val - AUC : 0.965942 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 98] Train - loss : 8.5196816 | Val - AUC : 0.9659267 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 99] Train - loss : 8.5383444 | Val - AUC : 0.9659187 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 100] Train - loss : 8.4138816 | Val - AUC : 0.9659022 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 101] Train - loss : 8.8982996 | Val - AUC : 0.9658838 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 102] Train - loss : 8.5153739 | Val - AUC : 0.9658793 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 103] Train - loss : 8.5102395 | Val - AUC : 0.9658679 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 104] Train - loss : 8.4767169 | Val - AUC : 0.9658604 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 105] Train - loss : 8.5017497 | Val - AUC : 0.9658468 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 106] Train - loss : 8.515905 | Val - AUC : 0.9658421 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 107] Train - loss : 8.3612387 | Val - AUC : 0.9658258 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 108] Train - loss : 8.5900759 | Val - AUC : 0.9658173 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 109] Train - loss : 8.3626313 | Val - AUC : 0.9657944 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 110] Train - loss : 8.4541634 | Val - AUC : 0.9657917 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 111] Train - loss : 8.585904 | Val - AUC : 0.9657756 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 112] Train - loss : 8.5030494 | Val - AUC : 0.9657584 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 113] Train - loss : 8.4301636 | Val - AUC : 0.9657453 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 114] Train - loss : 8.4068359 | Val - AUC : 0.965732 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 115] Train - loss : 8.4204321 | Val - AUC : 0.9657147 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 116] Train - loss : 8.5984933 | Val - AUC : 0.9657119 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 117] Train - loss : 8.4726218 | Val - AUC : 0.965702 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 118] Train - loss : 8.5004505 | Val - AUC : 0.9656831 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 119] Train - loss : 8.4852494 | Val - AUC : 0.9656721 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 120] Train - loss : 8.3075343 | Val - AUC : 0.9656586 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 121] Train - loss : 8.4381282 | Val - AUC : 0.965646 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 122] Train - loss : 8.4070336 | Val - AUC : 0.9656378 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 123] Train - loss : 8.4040396 | Val - AUC : 0.9656193 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 124] Train - loss : 8.4467098 | Val - AUC : 0.965613 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 125] Train - loss : 8.3824921 | Val - AUC : 0.9655944 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 126] Train - loss : 8.4816679 | Val - AUC : 0.9655875 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 127] Train - loss : 8.2788203 | Val - AUC : 0.9655797 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 128] Train - loss : 8.2940587 | Val - AUC : 0.965569 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 129] Train - loss : 8.3924667 | Val - AUC : 0.9655546 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 130] Train - loss : 8.5069273 | Val - AUC : 0.9655412 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 131] Train - loss : 8.4533374 | Val - AUC : 0.9655301 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 132] Train - loss : 8.2647461 | Val - AUC : 0.9655233 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 133] Train - loss : 8.3909595 | Val - AUC : 0.9655152 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 134] Train - loss : 8.3761437 | Val - AUC : 0.9655023 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 135] Train - loss : 8.3946807 | Val - AUC : 0.9654968 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 136] Train - loss : 8.246148 | Val - AUC : 0.9654747 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 137] Train - loss : 8.36834 | Val - AUC : 0.9654635 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 138] Train - loss : 8.4579147 | Val - AUC : 0.9654542 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 139] Train - loss : 8.3647685 | Val - AUC : 0.9654404 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 140] Train - loss : 8.408796 | Val - AUC : 0.9654272 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 141] Train - loss : 8.4470283 | Val - AUC : 0.9654102 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 142] Train - loss : 8.1662967 | Val - AUC : 0.9654032 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 143] Train - loss : 8.239178 | Val - AUC : 0.9653877 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 144] Train - loss : 8.3534461 | Val - AUC : 0.965376 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 145] Train - loss : 8.2764914 | Val - AUC : 0.9653663 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 146] Train - loss : 8.4454148 | Val - AUC : 0.9653488 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 147] Train - loss : 8.2387578 | Val - AUC : 0.965337 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 148] Train - loss : 8.3904157 | Val - AUC : 0.9653268 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 149] Train - loss : 8.2661637 | Val - AUC : 0.9653101 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 150] Train - loss : 8.2540798 | Val - AUC : 0.965304 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 151] Train - loss : 8.1060987 | Val - AUC : 0.9652892 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 152] Train - loss : 8.226622 | Val - AUC : 0.9652759 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 153] Train - loss : 8.2469369 | Val - AUC : 0.9652696 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 154] Train - loss : 8.4170585 | Val - AUC : 0.9652537 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 155] Train - loss : 8.2798639 | Val - AUC : 0.9652473 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 156] Train - loss : 8.2665339 | Val - AUC : 0.965236 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 157] Train - loss : 8.2778707 | Val - AUC : 0.96522 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 158] Train - loss : 8.2669111 | Val - AUC : 0.9652092 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 159] Train - loss : 8.2464358 | Val - AUC : 0.9652049 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 160] Train - loss : 8.2889289 | Val - AUC : 0.9651893 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 161] Train - loss : 8.1690426 | Val - AUC : 0.9651818 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 162] Train - loss : 8.253588 | Val - AUC : 0.9651766 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 163] Train - loss : 8.3534869 | Val - AUC : 0.9651617 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 164] Train - loss : 8.1539445 | Val - AUC : 0.9651489 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 165] Train - loss : 8.1654781 | Val - AUC : 0.9651324 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 166] Train - loss : 8.154166 | Val - AUC : 0.9651199 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 167] Train - loss : 8.1434962 | Val - AUC : 0.9651141 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 168] Train - loss : 8.1714443 | Val - AUC : 0.9651019 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 169] Train - loss : 8.2617815 | Val - AUC : 0.9650897 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 170] Train - loss : 8.2081998 | Val - AUC : 0.9650837 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 171] Train - loss : 8.2903833 | Val - AUC : 0.9650658 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 172] Train - loss : 8.2209035 | Val - AUC : 0.9650504 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 173] Train - loss : 8.1604824 | Val - AUC : 0.9650412 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 174] Train - loss : 8.2399723 | Val - AUC : 0.965025 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 175] Train - loss : 8.097083 | Val - AUC : 0.9650178 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 176] Train - loss : 8.1109432 | Val - AUC : 0.9650072 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 177] Train - loss : 8.1436786 | Val - AUC : 0.9649996 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 178] Train - loss : 8.0220642 | Val - AUC : 0.9649891 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 179] Train - loss : 8.1324782 | Val - AUC : 0.9649785 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 180] Train - loss : 8.1379888 | Val - AUC : 0.9649615 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 181] Train - loss : 8.2035118 | Val - AUC : 0.9649639 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 182] Train - loss : 8.2328015 | Val - AUC : 0.9649525 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 183] Train - loss : 8.1883992 | Val - AUC : 0.9649495 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 184] Train - loss : 8.1741279 | Val - AUC : 0.9649371 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 185] Train - loss : 8.3226123 | Val - AUC : 0.9649335 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 186] Train - loss : 8.3981212 | Val - AUC : 0.9649212 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 187] Train - loss : 8.0742224 | Val - AUC : 0.9649143 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 188] Train - loss : 8.0983286 | Val - AUC : 0.9649131 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 189] Train - loss : 8.1220146 | Val - AUC : 0.9649052 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 190] Train - loss : 8.2233785 | Val - AUC : 0.9648977 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 191] Train - loss : 8.3746543 | Val - AUC : 0.9648907 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 192] Train - loss : 8.1750179 | Val - AUC : 0.9648882 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 193] Train - loss : 8.1602497 | Val - AUC : 0.9648793 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 194] Train - loss : 8.1674808 | Val - AUC : 0.964866 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 195] Train - loss : 8.1094577 | Val - AUC : 0.9648637 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 196] Train - loss : 8.0415587 | Val - AUC : 0.9648538 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 197] Train - loss : 8.334062 | Val - AUC : 0.9648517 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 198] Train - loss : 7.9762572 | Val - AUC : 0.9648478 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 199] Train - loss : 7.9868804 | Val - AUC : 0.9648381 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 200] Train - loss : 8.2900952 | Val - AUC : 0.964839 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 201] Train - loss : 8.1232167 | Val - AUC : 0.964834 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 202] Train - loss : 8.0233288 | Val - AUC : 0.964831 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 203] Train - loss : 8.0804271 | Val - AUC : 0.9648267 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 204] Train - loss : 8.0630117 | Val - AUC : 0.9648248 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 205] Train - loss : 8.1452559 | Val - AUC : 0.9648267 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 206] Train - loss : 8.0156566 | Val - AUC : 0.9648194 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 207] Train - loss : 7.9752074 | Val - AUC : 0.9648162 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 208] Train - loss : 7.9736965 | Val - AUC : 0.9648034 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 209] Train - loss : 8.1958396 | Val - AUC : 0.9647966 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 210] Train - loss : 8.3114067 | Val - AUC : 0.9647908 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 211] Train - loss : 8.0508036 | Val - AUC : 0.9647958 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 212] Train - loss : 8.0738006 | Val - AUC : 0.9647904 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 213] Train - loss : 8.1178547 | Val - AUC : 0.9647822 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 214] Train - loss : 8.2366657 | Val - AUC : 0.9647789 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 215] Train - loss : 7.9613606 | Val - AUC : 0.9647701 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 216] Train - loss : 8.3256057 | Val - AUC : 0.9647636 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 217] Train - loss : 8.0477711 | Val - AUC : 0.96476 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 218] Train - loss : 8.0435392 | Val - AUC : 0.9647522 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 219] Train - loss : 8.0394789 | Val - AUC : 0.9647467 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 220] Train - loss : 8.1083669 | Val - AUC : 0.9647321 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 221] Train - loss : 7.964215 | Val - AUC : 0.9647231 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 222] Train - loss : 8.0241549 | Val - AUC : 0.9647295 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 223] Train - loss : 7.9215756 | Val - AUC : 0.9647188 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 224] Train - loss : 8.2303423 | Val - AUC : 0.9647182 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 225] Train - loss : 8.076605 | Val - AUC : 0.9647167 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 226] Train - loss : 8.0167736 | Val - AUC : 0.9647037 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 227] Train - loss : 8.0251265 | Val - AUC : 0.964703 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 228] Train - loss : 8.3067051 | Val - AUC : 0.9646946 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 229] Train - loss : 7.8636733 | Val - AUC : 0.9646939 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 230] Train - loss : 8.112426 | Val - AUC : 0.9646932 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 231] Train - loss : 8.0410883 | Val - AUC : 0.9646921 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 232] Train - loss : 8.160316 | Val - AUC : 0.9646846 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 233] Train - loss : 8.0107857 | Val - AUC : 0.9646795 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 234] Train - loss : 7.989339 | Val - AUC : 0.9646814 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 235] Train - loss : 7.9738287 | Val - AUC : 0.964675 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 236] Train - loss : 7.9688195 | Val - AUC : 0.9646701 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 237] Train - loss : 8.1225832 | Val - AUC : 0.9646621 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 238] Train - loss : 7.9732058 | Val - AUC : 0.9646644 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 239] Train - loss : 8.0062516 | Val - AUC : 0.9646555 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 240] Train - loss : 8.2083575 | Val - AUC : 0.9646535 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 241] Train - loss : 8.0020907 | Val - AUC : 0.9646498 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 242] Train - loss : 7.9367845 | Val - AUC : 0.9646416 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 243] Train - loss : 8.0105667 | Val - AUC : 0.9646426 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 244] Train - loss : 8.0418587 | Val - AUC : 0.9646394 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 245] Train - loss : 8.0903147 | Val - AUC : 0.9646318 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 246] Train - loss : 8.0578027 | Val - AUC : 0.9646298 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 247] Train - loss : 8.051687 | Val - AUC : 0.964627 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 248] Train - loss : 7.9322624 | Val - AUC : 0.9646246 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 249] Train - loss : 7.9459162 | Val - AUC : 0.9646274 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 250] Train - loss : 8.0013888 | Val - AUC : 0.9646229 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 251] Train - loss : 8.0284328 | Val - AUC : 0.9646213 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 252] Train - loss : 7.9238711 | Val - AUC : 0.9646142 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 253] Train - loss : 7.8693332 | Val - AUC : 0.9646136 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 254] Train - loss : 8.2098585 | Val - AUC : 0.9646051 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 255] Train - loss : 8.1311953 | Val - AUC : 0.9645959 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 256] Train - loss : 7.8830355 | Val - AUC : 0.9645934 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 257] Train - loss : 7.8503183 | Val - AUC : 0.9645922 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 258] Train - loss : 8.0756186 | Val - AUC : 0.964592 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 259] Train - loss : 7.9749044 | Val - AUC : 0.9645853 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 260] Train - loss : 7.8184664 | Val - AUC : 0.9645788 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 261] Train - loss : 7.8977471 | Val - AUC : 0.9645758 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 262] Train - loss : 7.9117423 | Val - AUC : 0.9645706 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 263] Train - loss : 7.8708968 | Val - AUC : 0.9645699 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 264] Train - loss : 7.9846542 | Val - AUC : 0.9645667 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 265] Train - loss : 7.8588171 | Val - AUC : 0.9645595 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 266] Train - loss : 7.8001209 | Val - AUC : 0.9645505 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 267] Train - loss : 7.8275638 | Val - AUC : 0.9645426 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 268] Train - loss : 7.942099 | Val - AUC : 0.964545 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 269] Train - loss : 7.8600183 | Val - AUC : 0.9645438 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 270] Train - loss : 7.9706948 | Val - AUC : 0.9645359 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 271] Train - loss : 8.0722115 | Val - AUC : 0.9645322 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 272] Train - loss : 7.8327109 | Val - AUC : 0.9645239 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 273] Train - loss : 7.9140732 | Val - AUC : 0.9645263 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 274] Train - loss : 7.8923331 | Val - AUC : 0.9645188 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 275] Train - loss : 7.9508642 | Val - AUC : 0.9645158 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 276] Train - loss : 7.9644678 | Val - AUC : 0.9645151 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 277] Train - loss : 8.013805 | Val - AUC : 0.9645072 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 278] Train - loss : 7.9526218 | Val - AUC : 0.964511 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 279] Train - loss : 8.1714617 | Val - AUC : 0.9645015 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 280] Train - loss : 8.0026159 | Val - AUC : 0.9644952 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 281] Train - loss : 7.7913098 | Val - AUC : 0.9645007 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 282] Train - loss : 7.9020077 | Val - AUC : 0.9644938 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 283] Train - loss : 7.8291094 | Val - AUC : 0.9644859 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 284] Train - loss : 7.9756907 | Val - AUC : 0.9644785 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 285] Train - loss : 7.8876117 | Val - AUC : 0.9644771 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 286] Train - loss : 7.8042737 | Val - AUC : 0.9644676 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 287] Train - loss : 7.9980015 | Val - AUC : 0.9644641 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 288] Train - loss : 7.9323838 | Val - AUC : 0.9644645 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 289] Train - loss : 8.1721675 | Val - AUC : 0.9644503 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 290] Train - loss : 8.0311228 | Val - AUC : 0.9644467 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 291] Train - loss : 7.880377 | Val - AUC : 0.9644438 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 292] Train - loss : 7.857242 | Val - AUC : 0.9644391 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 293] Train - loss : 7.981547 | Val - AUC : 0.9644396 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 294] Train - loss : 8.1527682 | Val - AUC : 0.964434 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 295] Train - loss : 7.8728811 | Val - AUC : 0.9644367 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 296] Train - loss : 7.8949998 | Val - AUC : 0.9644315 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 297] Train - loss : 7.8092766 | Val - AUC : 0.9644255 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 298] Train - loss : 7.825592 | Val - AUC : 0.9644216 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 299] Train - loss : 7.7880988 | Val - AUC : 0.9644122 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 300] Train - loss : 7.7314894 | Val - AUC : 0.9644132 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 301] Train - loss : 7.8128867 | Val - AUC : 0.9644081 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 302] Train - loss : 7.8153406 | Val - AUC : 0.9644044 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 303] Train - loss : 7.9529064 | Val - AUC : 0.9644017 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 304] Train - loss : 7.7966881 | Val - AUC : 0.9644036 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 305] Train - loss : 7.7924102 | Val - AUC : 0.9643978 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 306] Train - loss : 7.7659363 | Val - AUC : 0.9643937 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 307] Train - loss : 7.7722505 | Val - AUC : 0.9643946 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 308] Train - loss : 7.9869616 | Val - AUC : 0.9643866 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 309] Train - loss : 7.8818757 | Val - AUC : 0.9643789 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 310] Train - loss : 7.8075908 | Val - AUC : 0.9643815 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 311] Train - loss : 7.7916004 | Val - AUC : 0.9643813 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 312] Train - loss : 7.9111432 | Val - AUC : 0.9643707 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 313] Train - loss : 7.7254977 | Val - AUC : 0.9643659 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 314] Train - loss : 7.7593895 | Val - AUC : 0.9643683 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 315] Train - loss : 7.7478525 | Val - AUC : 0.964367 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 316] Train - loss : 7.8152397 | Val - AUC : 0.96437 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 317] Train - loss : 7.7212818 | Val - AUC : 0.9643707 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 318] Train - loss : 7.9411372 | Val - AUC : 0.9643624 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 319] Train - loss : 7.8085782 | Val - AUC : 0.9643608 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 320] Train - loss : 7.8950623 | Val - AUC : 0.964359 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 321] Train - loss : 7.8187152 | Val - AUC : 0.9643517 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 322] Train - loss : 7.9610986 | Val - AUC : 0.9643498 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 323] Train - loss : 8.0171777 | Val - AUC : 0.9643512 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 324] Train - loss : 7.7008286 | Val - AUC : 0.964341 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 325] Train - loss : 7.9080264 | Val - AUC : 0.9643415 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 326] Train - loss : 7.7716249 | Val - AUC : 0.9643416 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 327] Train - loss : 8.0199279 | Val - AUC : 0.9643336 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 328] Train - loss : 7.7747081 | Val - AUC : 0.9643319 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 329] Train - loss : 7.7646458 | Val - AUC : 0.9643266 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 330] Train - loss : 7.8803505 | Val - AUC : 0.9643266 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 331] Train - loss : 7.8058885 | Val - AUC : 0.9643241 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 332] Train - loss : 7.8020581 | Val - AUC : 0.9643156 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 333] Train - loss : 7.7757988 | Val - AUC : 0.9643134 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 334] Train - loss : 7.852389 | Val - AUC : 0.964308 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 335] Train - loss : 7.9256516 | Val - AUC : 0.9643055 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 336] Train - loss : 7.7048492 | Val - AUC : 0.9642999 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 337] Train - loss : 7.8034509 | Val - AUC : 0.9642991 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 338] Train - loss : 7.7157989 | Val - AUC : 0.9642995 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 339] Train - loss : 7.7215728 | Val - AUC : 0.9642925 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 340] Train - loss : 7.7373121 | Val - AUC : 0.9642897 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 341] Train - loss : 7.7542927 | Val - AUC : 0.9642934 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 342] Train - loss : 7.6918785 | Val - AUC : 0.964292 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 343] Train - loss : 7.7774769 | Val - AUC : 0.9642881 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 344] Train - loss : 7.7252919 | Val - AUC : 0.9642776 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 345] Train - loss : 7.8600501 | Val - AUC : 0.964274 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 346] Train - loss : 7.7964125 | Val - AUC : 0.9642787 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 347] Train - loss : 7.7061342 | Val - AUC : 0.9642773 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 348] Train - loss : 7.9309735 | Val - AUC : 0.9642726 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 349] Train - loss : 7.7840092 | Val - AUC : 0.9642639 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 350] Train - loss : 7.7923062 | Val - AUC : 0.9642673 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 351] Train - loss : 7.714259 | Val - AUC : 0.9642679 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 352] Train - loss : 7.6990816 | Val - AUC : 0.9642654 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 353] Train - loss : 7.7842126 | Val - AUC : 0.9642613 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 354] Train - loss : 7.8057082 | Val - AUC : 0.9642472 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 355] Train - loss : 7.740561 | Val - AUC : 0.9642535 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 356] Train - loss : 7.7172748 | Val - AUC : 0.9642479 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 357] Train - loss : 7.7033152 | Val - AUC : 0.9642412 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 358] Train - loss : 7.9188271 | Val - AUC : 0.9642315 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 359] Train - loss : 7.6785466 | Val - AUC : 0.9642331 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 360] Train - loss : 7.9836252 | Val - AUC : 0.9642353 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 361] Train - loss : 7.7122755 | Val - AUC : 0.9642369 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 362] Train - loss : 7.768125 | Val - AUC : 0.9642323 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 363] Train - loss : 7.789468 | Val - AUC : 0.9642301 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 364] Train - loss : 7.7582728 | Val - AUC : 0.9642361 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 365] Train - loss : 7.7735879 | Val - AUC : 0.9642361 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 366] Train - loss : 7.7647246 | Val - AUC : 0.9642305 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 367] Train - loss : 7.6232614 | Val - AUC : 0.9642243 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 368] Train - loss : 7.6327615 | Val - AUC : 0.9642177 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 369] Train - loss : 7.7070245 | Val - AUC : 0.9642215 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 370] Train - loss : 7.6572835 | Val - AUC : 0.9642208 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 371] Train - loss : 7.7483668 | Val - AUC : 0.9642257 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 372] Train - loss : 7.7051425 | Val - AUC : 0.9642227 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 373] Train - loss : 7.5677722 | Val - AUC : 0.9642213 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 374] Train - loss : 7.6955701 | Val - AUC : 0.9642125 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 375] Train - loss : 7.8252736 | Val - AUC : 0.9642132 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 376] Train - loss : 7.6260067 | Val - AUC : 0.9642137 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 377] Train - loss : 7.7554097 | Val - AUC : 0.9642102 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 378] Train - loss : 7.7546764 | Val - AUC : 0.9642082 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 379] Train - loss : 7.7653131 | Val - AUC : 0.9642135 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 380] Train - loss : 7.8173205 | Val - AUC : 0.9642236 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 381] Train - loss : 7.7925383 | Val - AUC : 0.9642161 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 382] Train - loss : 7.7745583 | Val - AUC : 0.9642066 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 383] Train - loss : 7.7057367 | Val - AUC : 0.9642101 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 384] Train - loss : 7.7187206 | Val - AUC : 0.9642096 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 385] Train - loss : 7.7455849 | Val - AUC : 0.9642033 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 386] Train - loss : 7.8069905 | Val - AUC : 0.9642051 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 387] Train - loss : 7.7843458 | Val - AUC : 0.9642054 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 388] Train - loss : 7.8363654 | Val - AUC : 0.9642087 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 389] Train - loss : 7.8584035 | Val - AUC : 0.9642062 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 390] Train - loss : 7.6244214 | Val - AUC : 0.9641993 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 391] Train - loss : 7.8499424 | Val - AUC : 0.964207 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 392] Train - loss : 7.7296721 | Val - AUC : 0.9642016 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 393] Train - loss : 7.6608892 | Val - AUC : 0.9642 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 394] Train - loss : 7.7232331 | Val - AUC : 0.9641972 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 395] Train - loss : 7.7738632 | Val - AUC : 0.9641974 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 396] Train - loss : 7.692 | Val - AUC : 0.9641901 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 397] Train - loss : 7.9092092 | Val - AUC : 0.9641928 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 398] Train - loss : 7.6694388 | Val - AUC : 0.9642007 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 399] Train - loss : 7.7226098 | Val - AUC : 0.9641962 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 400] Train - loss : 7.8365803 | Val - AUC : 0.9641982 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 401] Train - loss : 7.6405653 | Val - AUC : 0.9641926 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 402] Train - loss : 7.5786165 | Val - AUC : 0.9641987 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 403] Train - loss : 7.7483822 | Val - AUC : 0.964199 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 404] Train - loss : 7.7100981 | Val - AUC : 0.9641944 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 405] Train - loss : 7.7502147 | Val - AUC : 0.9641917 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 406] Train - loss : 7.7246498 | Val - AUC : 0.9641942 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 407] Train - loss : 7.9171399 | Val - AUC : 0.9641956 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 408] Train - loss : 7.5902693 | Val - AUC : 0.9641883 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 409] Train - loss : 7.6937853 | Val - AUC : 0.9641845 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 410] Train - loss : 7.7184514 | Val - AUC : 0.9641834 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 411] Train - loss : 7.6471485 | Val - AUC : 0.9641841 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 412] Train - loss : 7.7540613 | Val - AUC : 0.9641818 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 413] Train - loss : 7.6876829 | Val - AUC : 0.9641815 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 414] Train - loss : 7.6690283 | Val - AUC : 0.9641837 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 415] Train - loss : 7.6820824 | Val - AUC : 0.9641861 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 416] Train - loss : 7.639834 | Val - AUC : 0.9641832 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 417] Train - loss : 7.7842311 | Val - AUC : 0.9641844 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 418] Train - loss : 7.6785319 | Val - AUC : 0.9641835 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 419] Train - loss : 7.6627078 | Val - AUC : 0.964177 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 420] Train - loss : 7.8722872 | Val - AUC : 0.9641796 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 421] Train - loss : 7.7283102 | Val - AUC : 0.9641745 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 422] Train - loss : 7.7435867 | Val - AUC : 0.964173 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 423] Train - loss : 7.6897412 | Val - AUC : 0.9641686 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 424] Train - loss : 7.7189901 | Val - AUC : 0.964167 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 425] Train - loss : 7.6729502 | Val - AUC : 0.9641777 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 426] Train - loss : 7.7316455 | Val - AUC : 0.9641715 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 427] Train - loss : 7.8351935 | Val - AUC : 0.9641707 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 428] Train - loss : 7.631947 | Val - AUC : 0.9641722 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 429] Train - loss : 7.740166 | Val - AUC : 0.9641753 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 430] Train - loss : 7.5507935 | Val - AUC : 0.9641802 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 431] Train - loss : 7.6630337 | Val - AUC : 0.9641631 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 432] Train - loss : 7.680565 | Val - AUC : 0.964167 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 433] Train - loss : 7.8104211 | Val - AUC : 0.9641614 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 434] Train - loss : 7.8011777 | Val - AUC : 0.9641548 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 435] Train - loss : 7.600731 | Val - AUC : 0.9641653 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 436] Train - loss : 7.725363 | Val - AUC : 0.9641616 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 437] Train - loss : 7.7474309 | Val - AUC : 0.9641596 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 438] Train - loss : 7.6938738 | Val - AUC : 0.9641589 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 439] Train - loss : 7.7487033 | Val - AUC : 0.9641802 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 440] Train - loss : 7.6220315 | Val - AUC : 0.9641703 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 441] Train - loss : 7.6004745 | Val - AUC : 0.964166 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 442] Train - loss : 7.6583901 | Val - AUC : 0.9641696 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 443] Train - loss : 7.6324363 | Val - AUC : 0.9641689 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 444] Train - loss : 7.7986425 | Val - AUC : 0.9641645 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 445] Train - loss : 7.7514557 | Val - AUC : 0.9641666 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 446] Train - loss : 7.7923403 | Val - AUC : 0.9641764 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 447] Train - loss : 7.5173776 | Val - AUC : 0.9641777 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 448] Train - loss : 7.7261477 | Val - AUC : 0.9641779 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 449] Train - loss : 7.6518776 | Val - AUC : 0.964183 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 450] Train - loss : 7.5586801 | Val - AUC : 0.9641655 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 451] Train - loss : 7.4870081 | Val - AUC : 0.9641707 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 452] Train - loss : 7.7189687 | Val - AUC : 0.9641755 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 453] Train - loss : 7.686208 | Val - AUC : 0.9641758 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 454] Train - loss : 7.6370191 | Val - AUC : 0.9641755 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 455] Train - loss : 7.7375615 | Val - AUC : 0.9641806 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 456] Train - loss : 7.5826978 | Val - AUC : 0.964181 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 457] Train - loss : 7.6791818 | Val - AUC : 0.964176 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 458] Train - loss : 7.6730444 | Val - AUC : 0.9641791 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 459] Train - loss : 7.7812799 | Val - AUC : 0.9641848 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 460] Train - loss : 7.6358887 | Val - AUC : 0.9641805 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 461] Train - loss : 7.5919192 | Val - AUC : 0.9641706 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 462] Train - loss : 7.5587563 | Val - AUC : 0.9641691 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 463] Train - loss : 7.7319551 | Val - AUC : 0.9641731 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 464] Train - loss : 7.659581 | Val - AUC : 0.9641808 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 465] Train - loss : 7.6462285 | Val - AUC : 0.9641756 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 466] Train - loss : 7.7990538 | Val - AUC : 0.9641754 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 467] Train - loss : 7.8356441 | Val - AUC : 0.96417 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 468] Train - loss : 7.4887612 | Val - AUC : 0.9641702 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 469] Train - loss : 7.5565007 | Val - AUC : 0.9641661 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 470] Train - loss : 7.6351865 | Val - AUC : 0.964163 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 471] Train - loss : 7.6471532 | Val - AUC : 0.9641646 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 472] Train - loss : 7.6766404 | Val - AUC : 0.9641631 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 473] Train - loss : 7.7227776 | Val - AUC : 0.964159 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 474] Train - loss : 7.7203545 | Val - AUC : 0.9641592 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 475] Train - loss : 7.6189566 | Val - AUC : 0.964155 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 476] Train - loss : 7.6020523 | Val - AUC : 0.9641644 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 477] Train - loss : 7.6249713 | Val - AUC : 0.9641569 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 478] Train - loss : 7.5032379 | Val - AUC : 0.964156 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 479] Train - loss : 7.7508012 | Val - AUC : 0.9641591 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 480] Train - loss : 7.765683 | Val - AUC : 0.9641575 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 481] Train - loss : 7.6745674 | Val - AUC : 0.9641627 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 482] Train - loss : 7.6659323 | Val - AUC : 0.9641649 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 483] Train - loss : 7.6018974 | Val - AUC : 0.964168 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 484] Train - loss : 7.6064212 | Val - AUC : 0.9641673 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 485] Train - loss : 7.6808414 | Val - AUC : 0.9641619 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 486] Train - loss : 7.6484568 | Val - AUC : 0.9641595 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 487] Train - loss : 7.6073199 | Val - AUC : 0.9641541 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 488] Train - loss : 7.6562276 | Val - AUC : 0.9641578 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 489] Train - loss : 7.6877726 | Val - AUC : 0.9641535 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 490] Train - loss : 7.5557625 | Val - AUC : 0.964152 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 491] Train - loss : 7.6274556 | Val - AUC : 0.9641593 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 492] Train - loss : 7.6099286 | Val - AUC : 0.9641623 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 493] Train - loss : 7.8306097 | Val - AUC : 0.9641655 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 494] Train - loss : 7.6819542 | Val - AUC : 0.9641562 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 495] Train - loss : 7.544993 | Val - AUC : 0.9641536 | Best AUC : 0.9661934 (epoch : 62)
# ...
# [Epoch 836] Train - loss : 7.4716 | Val - AUC : 0.9639515 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 837] Train - loss : 7.5028636 | Val - AUC : 0.9639619 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 838] Train - loss : 7.3622544 | Val - AUC : 0.9639532 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 839] Train - loss : 7.5885492 | Val - AUC : 0.9639472 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 840] Train - loss : 7.3679463 | Val - AUC : 0.9639442 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 841] Train - loss : 7.2510287 | Val - AUC : 0.9639505 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 842] Train - loss : 7.3916274 | Val - AUC : 0.9639537 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 843] Train - loss : 7.6062851 | Val - AUC : 0.9639624 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 844] Train - loss : 7.4594176 | Val - AUC : 0.9639584 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 845] Train - loss : 7.4874375 | Val - AUC : 0.9639679 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 846] Train - loss : 7.3985153 | Val - AUC : 0.9639563 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 847] Train - loss : 7.4401985 | Val - AUC : 0.9639646 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 848] Train - loss : 7.3160695 | Val - AUC : 0.9639609 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 849] Train - loss : 7.3921849 | Val - AUC : 0.9639608 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 850] Train - loss : 7.4033307 | Val - AUC : 0.9639576 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 851] Train - loss : 7.4033504 | Val - AUC : 0.9639514 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 852] Train - loss : 7.4008359 | Val - AUC : 0.9639521 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 853] Train - loss : 7.3530935 | Val - AUC : 0.9639517 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 854] Train - loss : 7.3469772 | Val - AUC : 0.9639513 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 855] Train - loss : 7.5012329 | Val - AUC : 0.9639459 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 856] Train - loss : 7.4570447 | Val - AUC : 0.9639489 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 857] Train - loss : 7.4322656 | Val - AUC : 0.9639513 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 858] Train - loss : 7.3445102 | Val - AUC : 0.9639562 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 859] Train - loss : 7.4991798 | Val - AUC : 0.9639545 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 860] Train - loss : 7.3318612 | Val - AUC : 0.9639645 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 861] Train - loss : 7.3690694 | Val - AUC : 0.9639598 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 862] Train - loss : 7.4115861 | Val - AUC : 0.9639551 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 863] Train - loss : 7.3396436 | Val - AUC : 0.9639556 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 864] Train - loss : 7.4317296 | Val - AUC : 0.9639544 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 865] Train - loss : 7.2571113 | Val - AUC : 0.9639496 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 866] Train - loss : 7.4972139 | Val - AUC : 0.9639581 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 867] Train - loss : 7.5158195 | Val - AUC : 0.9639559 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 868] Train - loss : 7.3724542 | Val - AUC : 0.9639601 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 869] Train - loss : 7.3592984 | Val - AUC : 0.9639631 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 870] Train - loss : 7.3926487 | Val - AUC : 0.9639616 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 871] Train - loss : 7.5359532 | Val - AUC : 0.9639577 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 872] Train - loss : 7.5369153 | Val - AUC : 0.9639571 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 873] Train - loss : 7.4607772 | Val - AUC : 0.9639645 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 874] Train - loss : 7.4818842 | Val - AUC : 0.9639602 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 875] Train - loss : 7.5018939 | Val - AUC : 0.9639682 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 876] Train - loss : 7.5009148 | Val - AUC : 0.9639675 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 877] Train - loss : 7.4336057 | Val - AUC : 0.9639693 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 878] Train - loss : 7.4845731 | Val - AUC : 0.9639801 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 879] Train - loss : 7.3238742 | Val - AUC : 0.9639763 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 880] Train - loss : 7.2922846 | Val - AUC : 0.9639771 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 881] Train - loss : 7.3497812 | Val - AUC : 0.963973 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 882] Train - loss : 7.3882961 | Val - AUC : 0.9639573 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 883] Train - loss : 7.4134403 | Val - AUC : 0.9639612 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 884] Train - loss : 7.3370356 | Val - AUC : 0.9639625 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 885] Train - loss : 7.2753308 | Val - AUC : 0.9639625 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 886] Train - loss : 7.4204906 | Val - AUC : 0.9639654 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 887] Train - loss : 7.4940408 | Val - AUC : 0.9639717 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 888] Train - loss : 7.3974064 | Val - AUC : 0.9639707 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 889] Train - loss : 7.4009557 | Val - AUC : 0.963967 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 890] Train - loss : 7.483248 | Val - AUC : 0.9639718 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 891] Train - loss : 7.5333346 | Val - AUC : 0.9639742 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 892] Train - loss : 7.3938059 | Val - AUC : 0.9639752 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 893] Train - loss : 7.4917488 | Val - AUC : 0.9639765 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 894] Train - loss : 7.426792 | Val - AUC : 0.9639717 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 895] Train - loss : 7.4757115 | Val - AUC : 0.9639751 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 896] Train - loss : 7.4024264 | Val - AUC : 0.9639832 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 897] Train - loss : 7.4422836 | Val - AUC : 0.9639724 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 898] Train - loss : 7.3745113 | Val - AUC : 0.9639799 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 899] Train - loss : 7.4613311 | Val - AUC : 0.9639713 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 900] Train - loss : 7.4384558 | Val - AUC : 0.9639746 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 901] Train - loss : 7.320476 | Val - AUC : 0.9639694 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 902] Train - loss : 7.416434 | Val - AUC : 0.9639822 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 903] Train - loss : 7.306377 | Val - AUC : 0.9639796 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 904] Train - loss : 7.3479151 | Val - AUC : 0.9639803 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 905] Train - loss : 7.4888088 | Val - AUC : 0.9639715 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 906] Train - loss : 7.3627999 | Val - AUC : 0.9639711 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 907] Train - loss : 7.3517116 | Val - AUC : 0.9639721 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 908] Train - loss : 7.2902027 | Val - AUC : 0.9639828 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 909] Train - loss : 7.3301466 | Val - AUC : 0.9639808 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 910] Train - loss : 7.3658326 | Val - AUC : 0.9639843 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 911] Train - loss : 7.3756244 | Val - AUC : 0.9639887 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 912] Train - loss : 7.4569602 | Val - AUC : 0.9639857 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 913] Train - loss : 7.3499716 | Val - AUC : 0.9639852 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 914] Train - loss : 7.4082276 | Val - AUC : 0.9639813 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 915] Train - loss : 7.4253212 | Val - AUC : 0.9639913 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 916] Train - loss : 7.2741811 | Val - AUC : 0.9639877 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 917] Train - loss : 7.3680835 | Val - AUC : 0.9639903 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 918] Train - loss : 7.3830199 | Val - AUC : 0.963982 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 919] Train - loss : 7.3845631 | Val - AUC : 0.9639694 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 920] Train - loss : 7.4699701 | Val - AUC : 0.9639862 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 921] Train - loss : 7.3409729 | Val - AUC : 0.963976 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 922] Train - loss : 7.4270316 | Val - AUC : 0.9639838 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 923] Train - loss : 7.2666998 | Val - AUC : 0.9639837 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 924] Train - loss : 7.2866195 | Val - AUC : 0.9639822 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 925] Train - loss : 7.4125029 | Val - AUC : 0.9639914 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 926] Train - loss : 7.3553929 | Val - AUC : 0.9639875 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 927] Train - loss : 7.4473352 | Val - AUC : 0.9639909 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 928] Train - loss : 7.2909259 | Val - AUC : 0.9639845 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 929] Train - loss : 7.5032244 | Val - AUC : 0.9639783 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 930] Train - loss : 7.391692 | Val - AUC : 0.9639843 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 931] Train - loss : 7.3067106 | Val - AUC : 0.9639864 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 932] Train - loss : 7.3938625 | Val - AUC : 0.963987 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 933] Train - loss : 7.4284539 | Val - AUC : 0.9639864 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 934] Train - loss : 7.3129677 | Val - AUC : 0.9639911 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 935] Train - loss : 7.2884022 | Val - AUC : 0.9639993 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 936] Train - loss : 7.4882661 | Val - AUC : 0.9639954 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 937] Train - loss : 7.3826725 | Val - AUC : 0.9639938 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 938] Train - loss : 7.4818946 | Val - AUC : 0.9639895 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 939] Train - loss : 7.4595213 | Val - AUC : 0.9639926 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 940] Train - loss : 7.3852833 | Val - AUC : 0.9639926 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 941] Train - loss : 7.4200054 | Val - AUC : 0.9639893 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 942] Train - loss : 7.6119584 | Val - AUC : 0.9639969 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 943] Train - loss : 7.2869676 | Val - AUC : 0.9639818 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 944] Train - loss : 7.2996089 | Val - AUC : 0.9639927 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 945] Train - loss : 7.3443823 | Val - AUC : 0.9639927 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 946] Train - loss : 7.3859477 | Val - AUC : 0.9639901 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 947] Train - loss : 7.5127084 | Val - AUC : 0.9639951 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 948] Train - loss : 7.457838 | Val - AUC : 0.9639914 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 949] Train - loss : 7.4552093 | Val - AUC : 0.9639902 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 950] Train - loss : 7.3733777 | Val - AUC : 0.9639946 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 951] Train - loss : 7.4145771 | Val - AUC : 0.9639977 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 952] Train - loss : 7.3702595 | Val - AUC : 0.9639898 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 953] Train - loss : 7.3963049 | Val - AUC : 0.9640042 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 954] Train - loss : 7.2337489 | Val - AUC : 0.9640094 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 955] Train - loss : 7.3744016 | Val - AUC : 0.9640104 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 956] Train - loss : 7.5607351 | Val - AUC : 0.9640138 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 957] Train - loss : 7.2109851 | Val - AUC : 0.9640107 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 958] Train - loss : 7.4749685 | Val - AUC : 0.9640131 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 959] Train - loss : 7.273909 | Val - AUC : 0.9640094 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 960] Train - loss : 7.5007862 | Val - AUC : 0.9640143 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 961] Train - loss : 7.4081266 | Val - AUC : 0.964012 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 962] Train - loss : 7.3116981 | Val - AUC : 0.96401 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 963] Train - loss : 7.4551923 | Val - AUC : 0.9640166 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 964] Train - loss : 7.4837973 | Val - AUC : 0.9640184 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 965] Train - loss : 7.3500829 | Val - AUC : 0.9640264 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 966] Train - loss : 7.4397168 | Val - AUC : 0.9640258 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 967] Train - loss : 7.3116199 | Val - AUC : 0.9640266 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 968] Train - loss : 7.4219446 | Val - AUC : 0.9640192 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 969] Train - loss : 7.2727483 | Val - AUC : 0.9640247 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 970] Train - loss : 7.2438735 | Val - AUC : 0.9640298 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 971] Train - loss : 7.2751168 | Val - AUC : 0.9640335 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 972] Train - loss : 7.4162236 | Val - AUC : 0.964036 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 973] Train - loss : 7.5186011 | Val - AUC : 0.9640238 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 974] Train - loss : 7.3342492 | Val - AUC : 0.9640321 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 975] Train - loss : 7.3385983 | Val - AUC : 0.9640255 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 976] Train - loss : 7.273292 | Val - AUC : 0.9640249 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 977] Train - loss : 7.3102751 | Val - AUC : 0.9640255 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 978] Train - loss : 7.2753382 | Val - AUC : 0.9640256 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 979] Train - loss : 7.2844916 | Val - AUC : 0.9640265 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 980] Train - loss : 7.4559908 | Val - AUC : 0.9640345 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 981] Train - loss : 7.4441873 | Val - AUC : 0.9640328 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 982] Train - loss : 7.2252576 | Val - AUC : 0.964033 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 983] Train - loss : 7.3747941 | Val - AUC : 0.964035 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 984] Train - loss : 7.4287857 | Val - AUC : 0.964034 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 985] Train - loss : 7.300795 | Val - AUC : 0.9640385 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 986] Train - loss : 7.3398637 | Val - AUC : 0.9640371 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 987] Train - loss : 7.330361 | Val - AUC : 0.9640325 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 988] Train - loss : 7.4765092 | Val - AUC : 0.9640328 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 989] Train - loss : 7.4274109 | Val - AUC : 0.9640344 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 990] Train - loss : 7.3766375 | Val - AUC : 0.9640371 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 991] Train - loss : 7.2655399 | Val - AUC : 0.9640324 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 992] Train - loss : 7.4050955 | Val - AUC : 0.9640309 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 993] Train - loss : 7.2694618 | Val - AUC : 0.9640459 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 994] Train - loss : 7.3273019 | Val - AUC : 0.9640533 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 995] Train - loss : 7.4781072 | Val - AUC : 0.9640374 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 996] Train - loss : 7.3121211 | Val - AUC : 0.9640413 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 997] Train - loss : 7.3652746 | Val - AUC : 0.9640562 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 998] Train - loss : 7.2841056 | Val - AUC : 0.9640516 | Best AUC : 0.9661934 (epoch : 62)
# [Epoch 999] Train - loss : 7.3204694 | Val - AUC : 0.9640518 | Best AUC : 0.9661934 (epoch : 62)
# [2020-12-17 20:33:28,813][INFO][base.py:96] Succeed to load best model, device: 'cpu'

# %%
best_latent_data_list = result_dict["val_result_dict_list"][62]["latent_data_list"]
abnormal_label_list = [abnormal_label.item() for x, y, abnormal_label in dataset_factory.test_dataset]

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

pca = PCA(n_components=2)

pca.fit(best_latent_data_list)
pca_best_latent_data_list = pca.transform(best_latent_data_list)

pca_normal_latent_data_list = [
    pca_best_latent_data for pca_best_latent_data, abnormal_label in 
    zip(pca_best_latent_data_list, abnormal_label_list) if abnormal_label == 0
]
pca_abnormal_latent_data_list = [
    pca_best_latent_data for pca_best_latent_data, abnormal_label in
    zip(pca_best_latent_data_list, abnormal_label_list) if abnormal_label == 1
]

# %%
fig = plt.figure(figsize=(15, 15))

plt.scatter(
    x=list(map(lambda data: data[0], pca_normal_latent_data_list)),
    y=list(map(lambda data: data[1], pca_normal_latent_data_list)),
    label="Normal",
    color="blue",
    alpha=0.3
)
plt.scatter(
    x=list(map(lambda data: data[0], pca_abnormal_latent_data_list)),
    y=list(map(lambda data: data[1], pca_abnormal_latent_data_list)),
    label="Abormal",
    color="red",
    alpha=0.3
)

plt.xlim(-2, 2)
plt.ylim(-2, 2)

font_size = 15

plt.xlabel("PC1", fontsize=font_size)
plt.ylabel("PC2", fontsize=font_size)
plt.xticks(fontsize=font_size)
plt.yticks(fontsize=font_size)
plt.legend(fontsize=font_size)

plt.savefig("./plot/oesae_margin10_latent_2d.png")

plt.show()

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

pca = PCA(n_components=3)

pca.fit(best_latent_data_list)
pca_best_latent_data_list = pca.transform(best_latent_data_list)

pca_normal_latent_data_list = [
    pca_best_latent_data for pca_best_latent_data, abnormal_label in 
    zip(pca_best_latent_data_list, abnormal_label_list) if abnormal_label == 0
]
pca_abnormal_latent_data_list = [
    pca_best_latent_data for pca_best_latent_data, abnormal_label in
    zip(pca_best_latent_data_list, abnormal_label_list) if abnormal_label == 1
]

# %%
fig = plt.figure(figsize=(15, 15))
ax = fig.gca(projection='3d')

ax.scatter(
    list(map(lambda data: data[0], pca_normal_latent_data_list)),
    list(map(lambda data: data[1], pca_normal_latent_data_list)),
    list(map(lambda data: data[2], pca_normal_latent_data_list)),
    label="Normal",
    color="blue",
    alpha=0.3
)
ax.scatter(
    list(map(lambda data: data[0], pca_abnormal_latent_data_list)),
    list(map(lambda data: data[1], pca_abnormal_latent_data_list)),
    list(map(lambda data: data[2], pca_abnormal_latent_data_list)),
    label="Abormal",
    color="red",
    alpha=0.3
)


ax.set_xlim(-2, 2)
ax.set_ylim(-2, 2)
ax.set_zlim(-2, 2)

font_size = 12

ax.set_xlabel("PC1", fontsize=font_size)
ax.set_ylabel("PC2", fontsize=font_size)
ax.set_zlabel("PC3", fontsize=font_size)
ax.tick_params(axis="x", labelsize=font_size)
ax.tick_params(axis="y", labelsize=font_size)
ax.tick_params(axis="z", labelsize=font_size)
ax.legend(fontsize=font_size)

ax.view_init(elev=10., azim=300)

# ax.view_init(elev=10., azim=310)
plt.savefig("./plot/oesae_margin10_latent_3d.png")

plt.show()

# %%
best_latent_data_list = result_dict["val_result_dict_list"][-1]["latent_data_list"]
abnormal_label_list = [abnormal_label.item() for x, y, abnormal_label in dataset_factory.test_dataset]

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

pca = PCA(n_components=2)

pca.fit(best_latent_data_list)
pca_best_latent_data_list = pca.transform(best_latent_data_list)

pca_normal_latent_data_list = [
    pca_best_latent_data for pca_best_latent_data, abnormal_label in 
    zip(pca_best_latent_data_list, abnormal_label_list) if abnormal_label == 0
]
pca_abnormal_latent_data_list = [
    pca_best_latent_data for pca_best_latent_data, abnormal_label in
    zip(pca_best_latent_data_list, abnormal_label_list) if abnormal_label == 1
]

# %%
fig = plt.figure(figsize=(15, 15))

plt.scatter(
    x=list(map(lambda data: data[0], pca_normal_latent_data_list)),
    y=list(map(lambda data: data[1], pca_normal_latent_data_list)),
    label="Normal",
    color="blue",
    alpha=0.3
)
plt.scatter(
    x=list(map(lambda data: data[0], pca_abnormal_latent_data_list)),
    y=list(map(lambda data: data[1], pca_abnormal_latent_data_list)),
    label="Abormal",
    color="red",
    alpha=0.3
)
plt.legend()

plt.show()

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

pca = PCA(n_components=3)

pca.fit(best_latent_data_list)
pca_best_latent_data_list = pca.transform(best_latent_data_list)

pca_normal_latent_data_list = [
    pca_best_latent_data for pca_best_latent_data, abnormal_label in 
    zip(pca_best_latent_data_list, abnormal_label_list) if abnormal_label == 0
]
pca_abnormal_latent_data_list = [
    pca_best_latent_data for pca_best_latent_data, abnormal_label in
    zip(pca_best_latent_data_list, abnormal_label_list) if abnormal_label == 1
]

# %%
fig = plt.figure(figsize=(15, 15))
ax = fig.gca(projection='3d')

ax.scatter(
    list(map(lambda data: data[0], pca_normal_latent_data_list)),
    list(map(lambda data: data[1], pca_normal_latent_data_list)),
    list(map(lambda data: data[2], pca_normal_latent_data_list)),
    label="Normal",
    color="blue",
    alpha=0.3
)
ax.scatter(
    list(map(lambda data: data[0], pca_abnormal_latent_data_list)),
    list(map(lambda data: data[1], pca_abnormal_latent_data_list)),
    list(map(lambda data: data[2], pca_abnormal_latent_data_list)),
    label="Abormal",
    color="red",
    alpha=0.3
)


ax.set_xlim(-2, 2)
ax.set_ylim(-2, 2)
ax.set_zlim(-2, 2)

ax.view_init(elev=10., azim=310)
# ax.view_init(elev=10., azim=40)
ax.legend()

plt.show()
