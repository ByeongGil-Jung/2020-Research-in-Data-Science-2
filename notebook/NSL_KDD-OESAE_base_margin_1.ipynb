# %%
import os
import pathlib
import sys

default_dir_path = str(pathlib.Path(os.getcwd()).parent.absolute())

sys.path.append(default_dir_path)

from properties import ApplicationProperties
# Out:
# [2020-12-17 15:28:21,972][INFO][properties.py:22] Complete to apply the random seed, RANDOM_SEED : 777

# %%
from torch import optim
from torch.nn import functional as F
import torch

from dataset.factory import DatasetFactory
from dataset.nsl_kdd_dataset import NSLKDDDataFrameFactory, NSLKDDDataset
from domain.criterion import Criterion
from domain.hyperparameters import Hyperparameters
from domain.metadata import ModelFileMetadata
from logger import logger
from model.factory import ModelFactory
from trainer.base import TrainerBase
from trainer.factory import TrainerFactory

# %%
from sklearn import preprocessing
from sklearn.metrics import roc_curve, auc
from sklearn.model_selection import train_test_split
from torch import nn, optim
from torch.utils.data import Dataset, DataLoader
import numpy as np
import pandas as pd
import tqdm.notebook as tqdm

# %%
device = "cpu"
data_name = "nsl_kdd_outlier"
model_name = "oesae_margin1"
n_epoch = 1000

# %%
dataset_factory = DatasetFactory.create(data_name=data_name)
# Out:
# [2020-12-17 15:28:23,384][INFO][nsl_kdd_dataset.py:98] Success to load dataset dataframe : train
# [2020-12-17 15:28:23,481][INFO][nsl_kdd_dataset.py:98] Success to load dataset dataframe : test
# [2020-12-17 15:28:24,082][INFO][nsl_kdd_dataset.py:110] Success to load dataset dataframe : entire
# [2020-12-17 15:28:24,764][INFO][nsl_kdd_dataset.py:164] Entire data size : 148517
# [2020-12-17 15:28:24,767][INFO][nsl_kdd_dataset.py:165] Normal data size : 77054
# [2020-12-17 15:28:24,769][INFO][nsl_kdd_dataset.py:166] Abnormal data size : 7146
# [2020-12-17 15:28:24,771][INFO][nsl_kdd_dataset.py:167] Outlier data size : 7146
# [2020-12-17 15:28:24,773][INFO][nsl_kdd_dataset.py:168] Normal test data size : 7146
# [2020-12-17 15:28:24,776][INFO][nsl_kdd_dataset.py:169] Training data size : 69908
# [2020-12-17 15:28:24,778][INFO][nsl_kdd_dataset.py:170] Test data size : 14292
# [2020-12-17 15:28:25,092][INFO][factory.py:109] Success to fit data with scaling
# [2020-12-17 15:28:25,257][INFO][factory.py:118] Success to transform data with scaling
# [2020-12-17 15:28:25,268][INFO][factory.py:153] Data selected : 'nsl_kdd_outlier'

# %%
train_dataloader, outlier_dataloader = dataset_factory.train_dataloader
val_dataloader = dataset_factory.val_dataloader

# %%
class AE(nn.Module):
    
    def __init__(self, input_size):  # 117
        super(AE, self).__init__()
        self.encoder_1 = nn.Sequential(
            nn.Linear(in_features=input_size, out_features=64, bias=True),
            nn.Tanh(),
            nn.Linear(in_features=64, out_features=32, bias=True),
            nn.Tanh(),
            nn.Linear(in_features=32, out_features=16, bias=True),
            nn.Tanh()
        )
        self.decoder_1 = nn.Sequential(
            nn.Linear(in_features=16, out_features=32, bias=True),
            nn.Tanh(),
            nn.Linear(in_features=32, out_features=64, bias=True),
            nn.Tanh(),
            nn.Linear(in_features=64, out_features=input_size, bias=True),
            nn.Tanh()
        )
        
        self.he_init_weight()
        
    def forward(self, x):
        z = self.encoder_1(x)
        x_hat = self.decoder_1(z)
        return x_hat, z
    
    def he_init_weight(self):
        for module in self.modules():
            if isinstance(module, nn.Conv2d):
                nn.init.kaiming_normal_(module.weight.data)
            elif isinstance(module, nn.Linear):
                nn.init.kaiming_normal_(module.weight.data)
            elif isinstance(module, nn.ConvTranspose2d):
                nn.init.kaiming_normal_(module.weight.data)

# %%
from copy import deepcopy
import pickle
import time

from sklearn.metrics import roc_curve, auc
import torch

from domain.criterion import Criterion
from trainer.base import TrainerBase

time.time()


class OESAETrainer(TrainerBase):

    def __init__(self, model, model_file_metadata, train_loader, outlier_loader, val_loader, test_loader, hyperparameters,
                 tqdm_env='script'):
        super(OESAETrainer, self).__init__(model, model_file_metadata, train_loader, val_loader, test_loader,
                                        hyperparameters, tqdm_env)
        self.outlier_loader = outlier_loader

    def train(self):
        self.model.train()

        train_result_dict_list = list()
        val_result_dict_list = list()

        best_loss = 999999
        best_auc = 0
        best_loss_epoch = 0
        best_auc_epoch = 0

        # Set hyperparameters
        optimizer_cls = self.hyperparameters.optimizer_cls
        lr = self.hyperparameters.lr
        weight_decay = self.hyperparameters.weight_decay
        n_epoch = self.hyperparameters.n_epoch
        train_criterion = self.hyperparameters.train_criterion
        val_criterion = self.hyperparameters.val_criterion
        lambda_ = self.hyperparameters.lambda_
        margin = self.hyperparameters.margin
        device = self.hyperparameters.device

        optimizer = optimizer_cls(self.model.parameters(), lr=lr, weight_decay=weight_decay)

        for epoch in self.tqdm.tqdm(range(n_epoch)):
            total_loss = 0
            n_batch = 0

            for i, ((data_batch, label_batch, abnormal_label_batch), (outlier_data_batch, outlier_label_batch, outlier_abnormal_label_batch)) in enumerate(zip(self.train_loader, self.outlier_loader)):
                entire_data_batch = torch.cat([data_batch, outlier_data_batch], dim=0)
                entire_data_batch = entire_data_batch.to(device)

                # Optimization
                optimizer.zero_grad()
                pred_data_batch, latent_data_batch = self.model(entire_data_batch)

                in_pred_data_batch = pred_data_batch[:len(data_batch)]
                out_pred_data_batch = pred_data_batch[len(data_batch):]

                in_latent_data_batch = latent_data_batch[:len(data_batch)]
                out_latent_data_batch = latent_data_batch[len(data_batch):]

                if in_latent_data_batch.shape != out_latent_data_batch.shape:
                    continue

                mse_loss = val_criterion(data_batch, in_pred_data_batch, in_latent_data_batch, lambda_)
                triple_margin_loss = train_criterion(
                    anchor=torch.zeros(size=in_latent_data_batch.shape),
                    positive=in_latent_data_batch,
                    negative=out_latent_data_batch,
                    margin=margin
                )
                loss = mse_loss + triple_margin_loss

                loss.backward()
                optimizer.step()

                total_loss += loss.item()
                n_batch += 1

            current_loss = total_loss / n_batch

            train_result_dict = dict(
                loss=current_loss
            )
            val_result_dict = self.validate()

            # Early stopping
            if val_result_dict['loss'] < best_loss:
                best_loss = val_result_dict['loss']
                best_loss_epoch = epoch
                # self.best_model_state_dict = deepcopy(self.model.state_dict())

            if best_auc < val_result_dict['auc']:
                best_auc = val_result_dict['auc']
                best_auc_epoch = epoch
                self.best_model = deepcopy(self.model.state_dict())

            # Print
            print(
                f"[Epoch {epoch}] "
                f"Train - loss : {round(train_result_dict['loss'], 7)} | "
                f"Val - AUC : {round(val_result_dict['auc'], 7)} | "
                f"Best AUC : {round(best_auc, 7)} (epoch : {best_auc_epoch})"
            )

            # Save Model & Record dictW
            record_dict = dict(
                train_result_dict=train_result_dict,
                val_result_dict=val_result_dict
            )

            self.save_model(epoch=epoch)
            self.save_record(record=record_dict, epoch=epoch)

            train_result_dict_list.append(train_result_dict)
            val_result_dict_list.append(val_result_dict)

        # Save last result
        entire_record_dict = dict(
            train_result_dict_list=train_result_dict_list,
            val_result_dict_list=val_result_dict_list
        )
        torch.save(self.best_model, self.model_file_metadata.get_best_model_file_path())

        # Save entire_record_dict
        with open(self.model_file_metadata.get_entire_record_file_path(), "wb") as f:
            pickle.dump(entire_record_dict, f, protocol=pickle.HIGHEST_PROTOCOL)

        # Load best model
        self.load_best_model()

        return entire_record_dict

    def validate(self):
        self.model.eval()

        total_loss = 0
        n_batch = 0

        latent_data_list = list()
        reconstructino_error_list = list()
        abnormal_label_list = list()

        # Set hyperparameters
        device = self.hyperparameters.device
        val_criterion = self.hyperparameters.val_criterion
        lambda_ = self.hyperparameters.lambda_

        for i, (data_batch, label_batch, abnormal_label_batch) in enumerate(self.val_loader):
            data_batch = data_batch.to(device)
            abnormal_label_batch = abnormal_label_batch.to(device)

            with torch.no_grad():
                pred_data_batch, latent_data_batch = self.model(data_batch)
                loss = val_criterion(data_batch, pred_data_batch, latent_data_batch, lambda_).item()
                reconstruction_error_batch = Criterion.reconstruction_error(x=data_batch, x_hat=pred_data_batch)

            latent_data_list.append(latent_data_batch)
            reconstructino_error_list.append(reconstruction_error_batch)
            abnormal_label_list.append(abnormal_label_batch)

            total_loss += loss
            n_batch += 1

        latent_data_list = torch.cat(latent_data_list).cpu().numpy()
        reconstruction_error_list = torch.cat(reconstructino_error_list).cpu().numpy()
        abnormal_label_list = torch.cat(abnormal_label_list).cpu().numpy()

        fpr, tpr, thresholds = roc_curve(abnormal_label_list, reconstruction_error_list)
        auc_value = auc(fpr, tpr)

        current_loss = total_loss / n_batch

        return dict(loss=current_loss, auc=auc_value, latent_data_list=latent_data_list)

# %%
ae_model = AE(input_size=118)

# %%
ae_model.to(device)
# Out:
# AE(
#   (encoder_1): Sequential(
#     (0): Linear(in_features=118, out_features=64, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=64, out_features=32, bias=True)
#     (3): Tanh()
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): Tanh()
#   )
#   (decoder_1): Sequential(
#     (0): Linear(in_features=16, out_features=32, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=32, out_features=64, bias=True)
#     (3): Tanh()
#     (4): Linear(in_features=64, out_features=118, bias=True)
#     (5): Tanh()
#   )
# )

# %%
trainer = OESAETrainer(
    model=ae_model,
    model_file_metadata=ModelFileMetadata(model_name=model_name),
    train_loader=train_dataloader,
    val_loader=val_dataloader,
    outlier_loader=outlier_dataloader,
    test_loader=dataset_factory.test_dataloader,
    hyperparameters=Hyperparameters(
        optimizer_cls=optim.Adadelta,
        train_criterion=Criterion.triple_margin_loss,
        val_criterion=Criterion.sae_loss,
        lambda_=10,
        margin=1,
        n_epoch=n_epoch,
        lr=1e-3,
        weight_decay=0,
        device=device
    ),
    tqdm_env="jupyter"
)
# Out:
# [2020-12-17 15:28:25,433][INFO][base.py:40] Model set to 'cpu'

# %%
# Adadelta (tanh, lambda 10)
result_dict = trainer.train()
# Out:
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# [Epoch 0] Train - loss : 3.2216164 | Val - AUC : 0.964627 | Best AUC : 0.964627 (epoch : 0)
# [Epoch 1] Train - loss : 3.080236 | Val - AUC : 0.9648171 | Best AUC : 0.9648171 (epoch : 1)
# [Epoch 2] Train - loss : 3.0248733 | Val - AUC : 0.9648789 | Best AUC : 0.9648789 (epoch : 2)
# [Epoch 3] Train - loss : 2.900608 | Val - AUC : 0.9648783 | Best AUC : 0.9648789 (epoch : 2)
# [Epoch 4] Train - loss : 2.9132248 | Val - AUC : 0.9648686 | Best AUC : 0.9648789 (epoch : 2)
# [Epoch 5] Train - loss : 2.6016626 | Val - AUC : 0.9648552 | Best AUC : 0.9648789 (epoch : 2)
# [Epoch 6] Train - loss : 2.5704771 | Val - AUC : 0.9648626 | Best AUC : 0.9648789 (epoch : 2)
# [Epoch 7] Train - loss : 2.5681287 | Val - AUC : 0.9648984 | Best AUC : 0.9648984 (epoch : 7)
# [Epoch 8] Train - loss : 2.3223571 | Val - AUC : 0.9649341 | Best AUC : 0.9649341 (epoch : 8)
# [Epoch 9] Train - loss : 2.2344767 | Val - AUC : 0.9649681 | Best AUC : 0.9649681 (epoch : 9)
# [Epoch 10] Train - loss : 2.4268358 | Val - AUC : 0.9650106 | Best AUC : 0.9650106 (epoch : 10)
# [Epoch 11] Train - loss : 2.2677474 | Val - AUC : 0.9650614 | Best AUC : 0.9650614 (epoch : 11)
# [Epoch 12] Train - loss : 2.1468181 | Val - AUC : 0.9651273 | Best AUC : 0.9651273 (epoch : 12)
# [Epoch 13] Train - loss : 2.1523836 | Val - AUC : 0.9651673 | Best AUC : 0.9651673 (epoch : 13)
# [Epoch 14] Train - loss : 2.006847 | Val - AUC : 0.9652116 | Best AUC : 0.9652116 (epoch : 14)
# [Epoch 15] Train - loss : 1.9832033 | Val - AUC : 0.965247 | Best AUC : 0.965247 (epoch : 15)
# [Epoch 16] Train - loss : 1.9625561 | Val - AUC : 0.9652874 | Best AUC : 0.9652874 (epoch : 16)
# [Epoch 17] Train - loss : 1.9571599 | Val - AUC : 0.9653207 | Best AUC : 0.9653207 (epoch : 17)
# [Epoch 18] Train - loss : 2.0059067 | Val - AUC : 0.9653571 | Best AUC : 0.9653571 (epoch : 18)
# [Epoch 19] Train - loss : 1.8389322 | Val - AUC : 0.965387 | Best AUC : 0.965387 (epoch : 19)
# [Epoch 20] Train - loss : 1.8662174 | Val - AUC : 0.965422 | Best AUC : 0.965422 (epoch : 20)
# [Epoch 21] Train - loss : 1.82301 | Val - AUC : 0.9654501 | Best AUC : 0.9654501 (epoch : 21)
# [Epoch 22] Train - loss : 1.7442203 | Val - AUC : 0.9654814 | Best AUC : 0.9654814 (epoch : 22)
# [Epoch 23] Train - loss : 1.9207615 | Val - AUC : 0.9655032 | Best AUC : 0.9655032 (epoch : 23)
# [Epoch 24] Train - loss : 1.9738047 | Val - AUC : 0.9655244 | Best AUC : 0.9655244 (epoch : 24)
# [Epoch 25] Train - loss : 1.6418807 | Val - AUC : 0.9655552 | Best AUC : 0.9655552 (epoch : 25)
# [Epoch 26] Train - loss : 1.6634119 | Val - AUC : 0.9655841 | Best AUC : 0.9655841 (epoch : 26)
# [Epoch 27] Train - loss : 1.7662646 | Val - AUC : 0.96561 | Best AUC : 0.96561 (epoch : 27)
# [Epoch 28] Train - loss : 1.812202 | Val - AUC : 0.9656437 | Best AUC : 0.9656437 (epoch : 28)
# [Epoch 29] Train - loss : 1.7537896 | Val - AUC : 0.9656698 | Best AUC : 0.9656698 (epoch : 29)
# [Epoch 30] Train - loss : 1.7301505 | Val - AUC : 0.9656939 | Best AUC : 0.9656939 (epoch : 30)
# [Epoch 31] Train - loss : 1.6446609 | Val - AUC : 0.9657282 | Best AUC : 0.9657282 (epoch : 31)
# [Epoch 32] Train - loss : 1.5063578 | Val - AUC : 0.9657508 | Best AUC : 0.9657508 (epoch : 32)
# [Epoch 33] Train - loss : 1.6397665 | Val - AUC : 0.9657811 | Best AUC : 0.9657811 (epoch : 33)
# [Epoch 34] Train - loss : 1.6630575 | Val - AUC : 0.9658149 | Best AUC : 0.9658149 (epoch : 34)
# [Epoch 35] Train - loss : 1.4232855 | Val - AUC : 0.9658363 | Best AUC : 0.9658363 (epoch : 35)
# [Epoch 36] Train - loss : 1.6184789 | Val - AUC : 0.9658666 | Best AUC : 0.9658666 (epoch : 36)
# [Epoch 37] Train - loss : 1.573224 | Val - AUC : 0.9658932 | Best AUC : 0.9658932 (epoch : 37)
# [Epoch 38] Train - loss : 1.5145346 | Val - AUC : 0.9659118 | Best AUC : 0.9659118 (epoch : 38)
# [Epoch 39] Train - loss : 1.6548571 | Val - AUC : 0.9659358 | Best AUC : 0.9659358 (epoch : 39)
# [Epoch 40] Train - loss : 1.396768 | Val - AUC : 0.9659613 | Best AUC : 0.9659613 (epoch : 40)
# [Epoch 41] Train - loss : 1.4117014 | Val - AUC : 0.9659854 | Best AUC : 0.9659854 (epoch : 41)
# [Epoch 42] Train - loss : 1.6034699 | Val - AUC : 0.9660004 | Best AUC : 0.9660004 (epoch : 42)
# [Epoch 43] Train - loss : 1.4659071 | Val - AUC : 0.9660216 | Best AUC : 0.9660216 (epoch : 43)
# [Epoch 44] Train - loss : 1.443496 | Val - AUC : 0.9660457 | Best AUC : 0.9660457 (epoch : 44)
# [Epoch 45] Train - loss : 1.4086807 | Val - AUC : 0.9660698 | Best AUC : 0.9660698 (epoch : 45)
# [Epoch 46] Train - loss : 1.5022684 | Val - AUC : 0.9660858 | Best AUC : 0.9660858 (epoch : 46)
# [Epoch 47] Train - loss : 1.5174792 | Val - AUC : 0.9661025 | Best AUC : 0.9661025 (epoch : 47)
# [Epoch 48] Train - loss : 1.6956245 | Val - AUC : 0.9661213 | Best AUC : 0.9661213 (epoch : 48)
# [Epoch 49] Train - loss : 1.379759 | Val - AUC : 0.9661438 | Best AUC : 0.9661438 (epoch : 49)
# [Epoch 50] Train - loss : 1.4654192 | Val - AUC : 0.9661578 | Best AUC : 0.9661578 (epoch : 50)
# [Epoch 51] Train - loss : 1.468203 | Val - AUC : 0.9661724 | Best AUC : 0.9661724 (epoch : 51)
# [Epoch 52] Train - loss : 1.3909506 | Val - AUC : 0.9661848 | Best AUC : 0.9661848 (epoch : 52)
# [Epoch 53] Train - loss : 1.490683 | Val - AUC : 0.9661936 | Best AUC : 0.9661936 (epoch : 53)
# [Epoch 54] Train - loss : 1.5308622 | Val - AUC : 0.9662127 | Best AUC : 0.9662127 (epoch : 54)
# [Epoch 55] Train - loss : 1.3156771 | Val - AUC : 0.9662264 | Best AUC : 0.9662264 (epoch : 55)
# [Epoch 56] Train - loss : 1.2204544 | Val - AUC : 0.9662385 | Best AUC : 0.9662385 (epoch : 56)
# [Epoch 57] Train - loss : 1.3431999 | Val - AUC : 0.9662526 | Best AUC : 0.9662526 (epoch : 57)
# [Epoch 58] Train - loss : 1.3555034 | Val - AUC : 0.9662633 | Best AUC : 0.9662633 (epoch : 58)
# [Epoch 59] Train - loss : 1.2985433 | Val - AUC : 0.9662807 | Best AUC : 0.9662807 (epoch : 59)
# [Epoch 60] Train - loss : 1.2511313 | Val - AUC : 0.9662914 | Best AUC : 0.9662914 (epoch : 60)
# [Epoch 61] Train - loss : 1.2906167 | Val - AUC : 0.9663023 | Best AUC : 0.9663023 (epoch : 61)
# [Epoch 62] Train - loss : 1.3442209 | Val - AUC : 0.9663153 | Best AUC : 0.9663153 (epoch : 62)
# [Epoch 63] Train - loss : 1.3608518 | Val - AUC : 0.9663229 | Best AUC : 0.9663229 (epoch : 63)
# [Epoch 64] Train - loss : 1.3543506 | Val - AUC : 0.9663398 | Best AUC : 0.9663398 (epoch : 64)
# [Epoch 65] Train - loss : 1.3043697 | Val - AUC : 0.966345 | Best AUC : 0.966345 (epoch : 65)
# [Epoch 66] Train - loss : 1.2131814 | Val - AUC : 0.9663573 | Best AUC : 0.9663573 (epoch : 66)
# [Epoch 67] Train - loss : 1.3711053 | Val - AUC : 0.9663605 | Best AUC : 0.9663605 (epoch : 67)
# [Epoch 68] Train - loss : 1.2459068 | Val - AUC : 0.96637 | Best AUC : 0.96637 (epoch : 68)
# [Epoch 69] Train - loss : 1.2081089 | Val - AUC : 0.9663735 | Best AUC : 0.9663735 (epoch : 69)
# [Epoch 70] Train - loss : 1.2665246 | Val - AUC : 0.9663736 | Best AUC : 0.9663736 (epoch : 70)
# [Epoch 71] Train - loss : 1.3381592 | Val - AUC : 0.9663834 | Best AUC : 0.9663834 (epoch : 71)
# [Epoch 72] Train - loss : 1.1034931 | Val - AUC : 0.9663917 | Best AUC : 0.9663917 (epoch : 72)
# [Epoch 73] Train - loss : 1.2823838 | Val - AUC : 0.9664006 | Best AUC : 0.9664006 (epoch : 73)
# [Epoch 74] Train - loss : 1.1919917 | Val - AUC : 0.9664066 | Best AUC : 0.9664066 (epoch : 74)
# [Epoch 75] Train - loss : 1.4020213 | Val - AUC : 0.9664072 | Best AUC : 0.9664072 (epoch : 75)
# [Epoch 76] Train - loss : 1.299181 | Val - AUC : 0.9664167 | Best AUC : 0.9664167 (epoch : 76)
# [Epoch 77] Train - loss : 1.3615498 | Val - AUC : 0.9664188 | Best AUC : 0.9664188 (epoch : 77)
# [Epoch 78] Train - loss : 1.3070129 | Val - AUC : 0.966426 | Best AUC : 0.966426 (epoch : 78)
# [Epoch 79] Train - loss : 1.2473593 | Val - AUC : 0.9664344 | Best AUC : 0.9664344 (epoch : 79)
# [Epoch 80] Train - loss : 1.2430733 | Val - AUC : 0.9664361 | Best AUC : 0.9664361 (epoch : 80)
# [Epoch 81] Train - loss : 1.3306217 | Val - AUC : 0.9664459 | Best AUC : 0.9664459 (epoch : 81)
# [Epoch 82] Train - loss : 1.2671944 | Val - AUC : 0.9664514 | Best AUC : 0.9664514 (epoch : 82)
# [Epoch 83] Train - loss : 1.1417863 | Val - AUC : 0.9664484 | Best AUC : 0.9664514 (epoch : 82)
# [Epoch 84] Train - loss : 1.3197354 | Val - AUC : 0.9664545 | Best AUC : 0.9664545 (epoch : 84)
# [Epoch 85] Train - loss : 1.0953359 | Val - AUC : 0.9664556 | Best AUC : 0.9664556 (epoch : 85)
# [Epoch 86] Train - loss : 1.3666739 | Val - AUC : 0.9664609 | Best AUC : 0.9664609 (epoch : 86)
# [Epoch 87] Train - loss : 1.3391279 | Val - AUC : 0.9664621 | Best AUC : 0.9664621 (epoch : 87)
# [Epoch 88] Train - loss : 1.2311056 | Val - AUC : 0.9664637 | Best AUC : 0.9664637 (epoch : 88)
# [Epoch 89] Train - loss : 1.1384087 | Val - AUC : 0.9664685 | Best AUC : 0.9664685 (epoch : 89)
# [Epoch 90] Train - loss : 1.2852623 | Val - AUC : 0.9664707 | Best AUC : 0.9664707 (epoch : 90)
# [Epoch 91] Train - loss : 1.2265045 | Val - AUC : 0.9664703 | Best AUC : 0.9664707 (epoch : 90)
# [Epoch 92] Train - loss : 1.2697965 | Val - AUC : 0.9664751 | Best AUC : 0.9664751 (epoch : 92)
# [Epoch 93] Train - loss : 1.213651 | Val - AUC : 0.9664718 | Best AUC : 0.9664751 (epoch : 92)
# [Epoch 94] Train - loss : 1.2036778 | Val - AUC : 0.9664796 | Best AUC : 0.9664796 (epoch : 94)
# [Epoch 95] Train - loss : 1.1759813 | Val - AUC : 0.9664892 | Best AUC : 0.9664892 (epoch : 95)
# [Epoch 96] Train - loss : 1.0478192 | Val - AUC : 0.9664911 | Best AUC : 0.9664911 (epoch : 96)
# [Epoch 97] Train - loss : 1.0894826 | Val - AUC : 0.9664867 | Best AUC : 0.9664911 (epoch : 96)
# [Epoch 98] Train - loss : 1.0711139 | Val - AUC : 0.9664845 | Best AUC : 0.9664911 (epoch : 96)
# [Epoch 99] Train - loss : 1.0817002 | Val - AUC : 0.9664881 | Best AUC : 0.9664911 (epoch : 96)
# [Epoch 100] Train - loss : 0.9785622 | Val - AUC : 0.9664849 | Best AUC : 0.9664911 (epoch : 96)
# [Epoch 101] Train - loss : 1.4501543 | Val - AUC : 0.966482 | Best AUC : 0.9664911 (epoch : 96)
# [Epoch 102] Train - loss : 1.0780491 | Val - AUC : 0.9664855 | Best AUC : 0.9664911 (epoch : 96)
# [Epoch 103] Train - loss : 1.0854795 | Val - AUC : 0.9664876 | Best AUC : 0.9664911 (epoch : 96)
# [Epoch 104] Train - loss : 1.0551257 | Val - AUC : 0.9664856 | Best AUC : 0.9664911 (epoch : 96)
# [Epoch 105] Train - loss : 1.0727146 | Val - AUC : 0.9664819 | Best AUC : 0.9664911 (epoch : 96)
# [Epoch 106] Train - loss : 1.0856997 | Val - AUC : 0.9664888 | Best AUC : 0.9664911 (epoch : 96)
# [Epoch 107] Train - loss : 0.9537088 | Val - AUC : 0.9664806 | Best AUC : 0.9664911 (epoch : 96)
# [Epoch 108] Train - loss : 1.1657453 | Val - AUC : 0.9664849 | Best AUC : 0.9664911 (epoch : 96)
# [Epoch 109] Train - loss : 0.9509513 | Val - AUC : 0.9664761 | Best AUC : 0.9664911 (epoch : 96)
# [Epoch 110] Train - loss : 1.0333864 | Val - AUC : 0.9664737 | Best AUC : 0.9664911 (epoch : 96)
# [Epoch 111] Train - loss : 1.1650971 | Val - AUC : 0.9664708 | Best AUC : 0.9664911 (epoch : 96)
# [Epoch 112] Train - loss : 1.1017121 | Val - AUC : 0.9664649 | Best AUC : 0.9664911 (epoch : 96)
# [Epoch 113] Train - loss : 1.0281101 | Val - AUC : 0.9664615 | Best AUC : 0.9664911 (epoch : 96)
# [Epoch 114] Train - loss : 1.01382 | Val - AUC : 0.9664624 | Best AUC : 0.9664911 (epoch : 96)
# [Epoch 115] Train - loss : 1.0217903 | Val - AUC : 0.9664596 | Best AUC : 0.9664911 (epoch : 96)
# [Epoch 116] Train - loss : 1.2127535 | Val - AUC : 0.966462 | Best AUC : 0.9664911 (epoch : 96)
# [Epoch 117] Train - loss : 1.0715522 | Val - AUC : 0.9664616 | Best AUC : 0.9664911 (epoch : 96)
# [Epoch 118] Train - loss : 1.1117836 | Val - AUC : 0.9664588 | Best AUC : 0.9664911 (epoch : 96)
# [Epoch 119] Train - loss : 1.0827658 | Val - AUC : 0.9664585 | Best AUC : 0.9664911 (epoch : 96)
# [Epoch 120] Train - loss : 0.9214519 | Val - AUC : 0.9664585 | Best AUC : 0.9664911 (epoch : 96)
# [Epoch 121] Train - loss : 1.0482094 | Val - AUC : 0.9664544 | Best AUC : 0.9664911 (epoch : 96)
# [Epoch 122] Train - loss : 1.0261823 | Val - AUC : 0.9664548 | Best AUC : 0.9664911 (epoch : 96)
# [Epoch 123] Train - loss : 1.0328102 | Val - AUC : 0.9664527 | Best AUC : 0.9664911 (epoch : 96)
# [Epoch 124] Train - loss : 1.0709093 | Val - AUC : 0.9664567 | Best AUC : 0.9664911 (epoch : 96)
# [Epoch 125] Train - loss : 1.0075828 | Val - AUC : 0.9664516 | Best AUC : 0.9664911 (epoch : 96)
# [Epoch 126] Train - loss : 1.1283645 | Val - AUC : 0.9664547 | Best AUC : 0.9664911 (epoch : 96)
# [Epoch 127] Train - loss : 0.914202 | Val - AUC : 0.9664594 | Best AUC : 0.9664911 (epoch : 96)
# [Epoch 128] Train - loss : 0.9432007 | Val - AUC : 0.9664604 | Best AUC : 0.9664911 (epoch : 96)
# [Epoch 129] Train - loss : 1.0487744 | Val - AUC : 0.9664552 | Best AUC : 0.9664911 (epoch : 96)
# [Epoch 130] Train - loss : 1.1497334 | Val - AUC : 0.9664525 | Best AUC : 0.9664911 (epoch : 96)
# [Epoch 131] Train - loss : 1.1011313 | Val - AUC : 0.9664524 | Best AUC : 0.9664911 (epoch : 96)
# [Epoch 132] Train - loss : 0.931073 | Val - AUC : 0.9664536 | Best AUC : 0.9664911 (epoch : 96)
# [Epoch 133] Train - loss : 1.0427367 | Val - AUC : 0.9664573 | Best AUC : 0.9664911 (epoch : 96)
# [Epoch 134] Train - loss : 1.0374714 | Val - AUC : 0.9664561 | Best AUC : 0.9664911 (epoch : 96)
# [Epoch 135] Train - loss : 1.0599247 | Val - AUC : 0.9664578 | Best AUC : 0.9664911 (epoch : 96)
# [Epoch 136] Train - loss : 0.9077974 | Val - AUC : 0.966447 | Best AUC : 0.9664911 (epoch : 96)
# [Epoch 137] Train - loss : 1.0336054 | Val - AUC : 0.9664525 | Best AUC : 0.9664911 (epoch : 96)
# [Epoch 138] Train - loss : 1.1104205 | Val - AUC : 0.9664507 | Best AUC : 0.9664911 (epoch : 96)
# [Epoch 139] Train - loss : 1.0467882 | Val - AUC : 0.9664486 | Best AUC : 0.9664911 (epoch : 96)
# [Epoch 140] Train - loss : 1.0651159 | Val - AUC : 0.9664487 | Best AUC : 0.9664911 (epoch : 96)
# [Epoch 141] Train - loss : 1.1127713 | Val - AUC : 0.9664438 | Best AUC : 0.9664911 (epoch : 96)
# [Epoch 142] Train - loss : 0.8532362 | Val - AUC : 0.9664454 | Best AUC : 0.9664911 (epoch : 96)
# [Epoch 143] Train - loss : 0.9112516 | Val - AUC : 0.9664401 | Best AUC : 0.9664911 (epoch : 96)
# [Epoch 144] Train - loss : 1.0198285 | Val - AUC : 0.9664396 | Best AUC : 0.9664911 (epoch : 96)
# [Epoch 145] Train - loss : 0.9633466 | Val - AUC : 0.9664488 | Best AUC : 0.9664911 (epoch : 96)
# [Epoch 146] Train - loss : 1.13273 | Val - AUC : 0.9664409 | Best AUC : 0.9664911 (epoch : 96)
# [Epoch 147] Train - loss : 0.9284447 | Val - AUC : 0.9664441 | Best AUC : 0.9664911 (epoch : 96)
# [Epoch 148] Train - loss : 1.0714745 | Val - AUC : 0.9664505 | Best AUC : 0.9664911 (epoch : 96)
# [Epoch 149] Train - loss : 0.9585057 | Val - AUC : 0.966448 | Best AUC : 0.9664911 (epoch : 96)
# [Epoch 150] Train - loss : 0.9539668 | Val - AUC : 0.9664539 | Best AUC : 0.9664911 (epoch : 96)
# [Epoch 151] Train - loss : 0.8145115 | Val - AUC : 0.9664516 | Best AUC : 0.9664911 (epoch : 96)
# [Epoch 152] Train - loss : 0.9231687 | Val - AUC : 0.9664503 | Best AUC : 0.9664911 (epoch : 96)
# [Epoch 153] Train - loss : 0.9654563 | Val - AUC : 0.9664484 | Best AUC : 0.9664911 (epoch : 96)
# [Epoch 154] Train - loss : 1.113097 | Val - AUC : 0.9664577 | Best AUC : 0.9664911 (epoch : 96)
# [Epoch 155] Train - loss : 0.9876974 | Val - AUC : 0.966463 | Best AUC : 0.9664911 (epoch : 96)
# [Epoch 156] Train - loss : 0.9886539 | Val - AUC : 0.9664586 | Best AUC : 0.9664911 (epoch : 96)
# [Epoch 157] Train - loss : 0.9760751 | Val - AUC : 0.9664597 | Best AUC : 0.9664911 (epoch : 96)
# [Epoch 158] Train - loss : 0.9757333 | Val - AUC : 0.9664628 | Best AUC : 0.9664911 (epoch : 96)
# [Epoch 159] Train - loss : 0.9530895 | Val - AUC : 0.9664679 | Best AUC : 0.9664911 (epoch : 96)
# [Epoch 160] Train - loss : 1.0230951 | Val - AUC : 0.966466 | Best AUC : 0.9664911 (epoch : 96)
# [Epoch 161] Train - loss : 0.903434 | Val - AUC : 0.9664692 | Best AUC : 0.9664911 (epoch : 96)
# [Epoch 162] Train - loss : 0.9716948 | Val - AUC : 0.9664765 | Best AUC : 0.9664911 (epoch : 96)
# [Epoch 163] Train - loss : 1.0886018 | Val - AUC : 0.9664798 | Best AUC : 0.9664911 (epoch : 96)
# [Epoch 164] Train - loss : 0.8758782 | Val - AUC : 0.966477 | Best AUC : 0.9664911 (epoch : 96)
# [Epoch 165] Train - loss : 0.8935781 | Val - AUC : 0.9664772 | Best AUC : 0.9664911 (epoch : 96)
# [Epoch 166] Train - loss : 0.881619 | Val - AUC : 0.9664794 | Best AUC : 0.9664911 (epoch : 96)
# [Epoch 167] Train - loss : 0.883246 | Val - AUC : 0.9664823 | Best AUC : 0.9664911 (epoch : 96)
# [Epoch 168] Train - loss : 0.915026 | Val - AUC : 0.9664791 | Best AUC : 0.9664911 (epoch : 96)
# [Epoch 169] Train - loss : 1.0031851 | Val - AUC : 0.9664833 | Best AUC : 0.9664911 (epoch : 96)
# [Epoch 170] Train - loss : 0.9466211 | Val - AUC : 0.9664869 | Best AUC : 0.9664911 (epoch : 96)
# [Epoch 171] Train - loss : 1.0504923 | Val - AUC : 0.9664837 | Best AUC : 0.9664911 (epoch : 96)
# [Epoch 172] Train - loss : 0.9600876 | Val - AUC : 0.9664774 | Best AUC : 0.9664911 (epoch : 96)
# [Epoch 173] Train - loss : 0.9131926 | Val - AUC : 0.9664795 | Best AUC : 0.9664911 (epoch : 96)
# [Epoch 174] Train - loss : 0.9958235 | Val - AUC : 0.9664742 | Best AUC : 0.9664911 (epoch : 96)
# [Epoch 175] Train - loss : 0.8624697 | Val - AUC : 0.966474 | Best AUC : 0.9664911 (epoch : 96)
# [Epoch 176] Train - loss : 0.8575446 | Val - AUC : 0.9664768 | Best AUC : 0.9664911 (epoch : 96)
# [Epoch 177] Train - loss : 0.9008698 | Val - AUC : 0.9664807 | Best AUC : 0.9664911 (epoch : 96)
# [Epoch 178] Train - loss : 0.7920953 | Val - AUC : 0.9664847 | Best AUC : 0.9664911 (epoch : 96)
# [Epoch 179] Train - loss : 0.9063611 | Val - AUC : 0.9664754 | Best AUC : 0.9664911 (epoch : 96)
# [Epoch 180] Train - loss : 0.9116565 | Val - AUC : 0.966473 | Best AUC : 0.9664911 (epoch : 96)
# [Epoch 181] Train - loss : 0.9672808 | Val - AUC : 0.9664799 | Best AUC : 0.9664911 (epoch : 96)
# [Epoch 182] Train - loss : 1.0181748 | Val - AUC : 0.9664849 | Best AUC : 0.9664911 (epoch : 96)
# [Epoch 183] Train - loss : 0.9809171 | Val - AUC : 0.9664869 | Best AUC : 0.9664911 (epoch : 96)
# [Epoch 184] Train - loss : 0.9472859 | Val - AUC : 0.966489 | Best AUC : 0.9664911 (epoch : 96)
# [Epoch 185] Train - loss : 1.0784332 | Val - AUC : 0.9664862 | Best AUC : 0.9664911 (epoch : 96)
# [Epoch 186] Train - loss : 1.1621606 | Val - AUC : 0.9664833 | Best AUC : 0.9664911 (epoch : 96)
# [Epoch 187] Train - loss : 0.86382 | Val - AUC : 0.966483 | Best AUC : 0.9664911 (epoch : 96)
# [Epoch 188] Train - loss : 0.8839661 | Val - AUC : 0.9664891 | Best AUC : 0.9664911 (epoch : 96)
# [Epoch 189] Train - loss : 0.9006645 | Val - AUC : 0.9664913 | Best AUC : 0.9664913 (epoch : 189)
# [Epoch 190] Train - loss : 1.0197175 | Val - AUC : 0.9664903 | Best AUC : 0.9664913 (epoch : 189)
# [Epoch 191] Train - loss : 1.140977 | Val - AUC : 0.9664948 | Best AUC : 0.9664948 (epoch : 191)
# [Epoch 192] Train - loss : 0.9712614 | Val - AUC : 0.9664988 | Best AUC : 0.9664988 (epoch : 192)
# [Epoch 193] Train - loss : 0.9582766 | Val - AUC : 0.9664936 | Best AUC : 0.9664988 (epoch : 192)
# [Epoch 194] Train - loss : 0.9710778 | Val - AUC : 0.9664972 | Best AUC : 0.9664988 (epoch : 192)
# [Epoch 195] Train - loss : 0.9223588 | Val - AUC : 0.9665022 | Best AUC : 0.9665022 (epoch : 195)
# [Epoch 196] Train - loss : 0.8483153 | Val - AUC : 0.9665009 | Best AUC : 0.9665022 (epoch : 195)
# [Epoch 197] Train - loss : 1.119452 | Val - AUC : 0.966508 | Best AUC : 0.966508 (epoch : 197)
# [Epoch 198] Train - loss : 0.7987967 | Val - AUC : 0.9665068 | Best AUC : 0.966508 (epoch : 197)
# [Epoch 199] Train - loss : 0.8012476 | Val - AUC : 0.9665039 | Best AUC : 0.966508 (epoch : 197)
# [Epoch 200] Train - loss : 1.0917345 | Val - AUC : 0.9665092 | Best AUC : 0.9665092 (epoch : 200)
# [Epoch 201] Train - loss : 0.9301733 | Val - AUC : 0.9665105 | Best AUC : 0.9665105 (epoch : 201)
# [Epoch 202] Train - loss : 0.8417315 | Val - AUC : 0.966509 | Best AUC : 0.9665105 (epoch : 201)
# [Epoch 203] Train - loss : 0.8945298 | Val - AUC : 0.9665138 | Best AUC : 0.9665138 (epoch : 203)
# [Epoch 204] Train - loss : 0.9115221 | Val - AUC : 0.966514 | Best AUC : 0.966514 (epoch : 204)
# [Epoch 205] Train - loss : 0.9618344 | Val - AUC : 0.9665187 | Best AUC : 0.9665187 (epoch : 205)
# [Epoch 206] Train - loss : 0.8455883 | Val - AUC : 0.9665176 | Best AUC : 0.9665187 (epoch : 205)
# [Epoch 207] Train - loss : 0.8177702 | Val - AUC : 0.966515 | Best AUC : 0.9665187 (epoch : 205)
# [Epoch 208] Train - loss : 0.8003469 | Val - AUC : 0.9665178 | Best AUC : 0.9665187 (epoch : 205)
# [Epoch 209] Train - loss : 1.0157104 | Val - AUC : 0.966513 | Best AUC : 0.9665187 (epoch : 205)
# [Epoch 210] Train - loss : 1.1149296 | Val - AUC : 0.9665177 | Best AUC : 0.9665187 (epoch : 205)
# [Epoch 211] Train - loss : 0.8650778 | Val - AUC : 0.9665224 | Best AUC : 0.9665224 (epoch : 211)
# [Epoch 212] Train - loss : 0.8900055 | Val - AUC : 0.9665239 | Best AUC : 0.9665239 (epoch : 212)
# [Epoch 213] Train - loss : 0.941308 | Val - AUC : 0.9665219 | Best AUC : 0.9665239 (epoch : 212)
# [Epoch 214] Train - loss : 1.0642353 | Val - AUC : 0.9665295 | Best AUC : 0.9665295 (epoch : 214)
# [Epoch 215] Train - loss : 0.8133662 | Val - AUC : 0.9665221 | Best AUC : 0.9665295 (epoch : 214)
# [Epoch 216] Train - loss : 1.1562947 | Val - AUC : 0.9665217 | Best AUC : 0.9665295 (epoch : 214)
# [Epoch 217] Train - loss : 0.8861802 | Val - AUC : 0.9665197 | Best AUC : 0.9665295 (epoch : 214)
# [Epoch 218] Train - loss : 0.8897511 | Val - AUC : 0.9665238 | Best AUC : 0.9665295 (epoch : 214)
# [Epoch 219] Train - loss : 0.8857839 | Val - AUC : 0.9665234 | Best AUC : 0.9665295 (epoch : 214)
# [Epoch 220] Train - loss : 0.9313576 | Val - AUC : 0.9665199 | Best AUC : 0.9665295 (epoch : 214)
# [Epoch 221] Train - loss : 0.7867966 | Val - AUC : 0.966522 | Best AUC : 0.9665295 (epoch : 214)
# [Epoch 222] Train - loss : 0.8663325 | Val - AUC : 0.9665239 | Best AUC : 0.9665295 (epoch : 214)
# [Epoch 223] Train - loss : 0.7886219 | Val - AUC : 0.9665192 | Best AUC : 0.9665295 (epoch : 214)
# [Epoch 224] Train - loss : 1.0757631 | Val - AUC : 0.966528 | Best AUC : 0.9665295 (epoch : 214)
# [Epoch 225] Train - loss : 0.9162916 | Val - AUC : 0.9665305 | Best AUC : 0.9665305 (epoch : 225)
# [Epoch 226] Train - loss : 0.8648191 | Val - AUC : 0.9665254 | Best AUC : 0.9665305 (epoch : 225)
# [Epoch 227] Train - loss : 0.8709199 | Val - AUC : 0.9665252 | Best AUC : 0.9665305 (epoch : 225)
# [Epoch 228] Train - loss : 1.1513418 | Val - AUC : 0.9665305 | Best AUC : 0.9665305 (epoch : 225)
# [Epoch 229] Train - loss : 0.7497036 | Val - AUC : 0.9665344 | Best AUC : 0.9665344 (epoch : 229)
# [Epoch 230] Train - loss : 0.9755773 | Val - AUC : 0.9665279 | Best AUC : 0.9665344 (epoch : 229)
# [Epoch 231] Train - loss : 0.9155178 | Val - AUC : 0.9665337 | Best AUC : 0.9665344 (epoch : 229)
# [Epoch 232] Train - loss : 1.0221706 | Val - AUC : 0.9665287 | Best AUC : 0.9665344 (epoch : 229)
# [Epoch 233] Train - loss : 0.864225 | Val - AUC : 0.9665326 | Best AUC : 0.9665344 (epoch : 229)
# [Epoch 234] Train - loss : 0.8645392 | Val - AUC : 0.9665353 | Best AUC : 0.9665353 (epoch : 234)
# [Epoch 235] Train - loss : 0.8431839 | Val - AUC : 0.9665365 | Best AUC : 0.9665365 (epoch : 235)
# [Epoch 236] Train - loss : 0.8382525 | Val - AUC : 0.9665312 | Best AUC : 0.9665365 (epoch : 235)
# [Epoch 237] Train - loss : 0.9830923 | Val - AUC : 0.9665312 | Best AUC : 0.9665365 (epoch : 235)
# [Epoch 238] Train - loss : 0.8621683 | Val - AUC : 0.966536 | Best AUC : 0.9665365 (epoch : 235)
# [Epoch 239] Train - loss : 0.8797267 | Val - AUC : 0.9665318 | Best AUC : 0.9665365 (epoch : 235)
# [Epoch 240] Train - loss : 1.0712465 | Val - AUC : 0.9665326 | Best AUC : 0.9665365 (epoch : 235)
# [Epoch 241] Train - loss : 0.862604 | Val - AUC : 0.9665368 | Best AUC : 0.9665368 (epoch : 241)
# [Epoch 242] Train - loss : 0.8175616 | Val - AUC : 0.9665355 | Best AUC : 0.9665368 (epoch : 241)
# [Epoch 243] Train - loss : 0.8902073 | Val - AUC : 0.9665426 | Best AUC : 0.9665426 (epoch : 243)
# [Epoch 244] Train - loss : 0.9160781 | Val - AUC : 0.9665439 | Best AUC : 0.9665439 (epoch : 244)
# [Epoch 245] Train - loss : 0.9761896 | Val - AUC : 0.9665437 | Best AUC : 0.9665439 (epoch : 244)
# [Epoch 246] Train - loss : 0.9439234 | Val - AUC : 0.9665459 | Best AUC : 0.9665459 (epoch : 246)
# [Epoch 247] Train - loss : 0.9415024 | Val - AUC : 0.966548 | Best AUC : 0.966548 (epoch : 247)
# [Epoch 248] Train - loss : 0.8200634 | Val - AUC : 0.9665466 | Best AUC : 0.966548 (epoch : 247)
# [Epoch 249] Train - loss : 0.8377452 | Val - AUC : 0.9665502 | Best AUC : 0.9665502 (epoch : 249)
# [Epoch 250] Train - loss : 0.8959939 | Val - AUC : 0.9665511 | Best AUC : 0.9665511 (epoch : 250)
# [Epoch 251] Train - loss : 0.9391441 | Val - AUC : 0.9665542 | Best AUC : 0.9665542 (epoch : 251)
# [Epoch 252] Train - loss : 0.8236251 | Val - AUC : 0.9665588 | Best AUC : 0.9665588 (epoch : 252)
# [Epoch 253] Train - loss : 0.7844007 | Val - AUC : 0.966559 | Best AUC : 0.966559 (epoch : 253)
# [Epoch 254] Train - loss : 1.095103 | Val - AUC : 0.9665634 | Best AUC : 0.9665634 (epoch : 254)
# [Epoch 255] Train - loss : 1.0277844 | Val - AUC : 0.9665572 | Best AUC : 0.9665634 (epoch : 254)
# [Epoch 256] Train - loss : 0.7978126 | Val - AUC : 0.9665598 | Best AUC : 0.9665634 (epoch : 254)
# [Epoch 257] Train - loss : 0.7665014 | Val - AUC : 0.9665641 | Best AUC : 0.9665641 (epoch : 257)
# [Epoch 258] Train - loss : 0.9805794 | Val - AUC : 0.9665727 | Best AUC : 0.9665727 (epoch : 258)
# [Epoch 259] Train - loss : 0.8832784 | Val - AUC : 0.9665732 | Best AUC : 0.9665732 (epoch : 259)
# [Epoch 260] Train - loss : 0.7552845 | Val - AUC : 0.9665767 | Best AUC : 0.9665767 (epoch : 260)
# [Epoch 261] Train - loss : 0.8116864 | Val - AUC : 0.9665728 | Best AUC : 0.9665767 (epoch : 260)
# [Epoch 262] Train - loss : 0.8033145 | Val - AUC : 0.9665757 | Best AUC : 0.9665767 (epoch : 260)
# [Epoch 263] Train - loss : 0.7727534 | Val - AUC : 0.9665823 | Best AUC : 0.9665823 (epoch : 263)
# [Epoch 264] Train - loss : 0.8837766 | Val - AUC : 0.9665827 | Best AUC : 0.9665827 (epoch : 264)
# [Epoch 265] Train - loss : 0.7806012 | Val - AUC : 0.966585 | Best AUC : 0.966585 (epoch : 265)
# [Epoch 266] Train - loss : 0.7133722 | Val - AUC : 0.9665778 | Best AUC : 0.966585 (epoch : 265)
# [Epoch 267] Train - loss : 0.7546135 | Val - AUC : 0.9665807 | Best AUC : 0.966585 (epoch : 265)
# [Epoch 268] Train - loss : 0.8551897 | Val - AUC : 0.9665883 | Best AUC : 0.9665883 (epoch : 268)
# [Epoch 269] Train - loss : 0.7913706 | Val - AUC : 0.9665875 | Best AUC : 0.9665883 (epoch : 268)
# [Epoch 270] Train - loss : 0.8901833 | Val - AUC : 0.9665882 | Best AUC : 0.9665883 (epoch : 268)
# [Epoch 271] Train - loss : 1.0001414 | Val - AUC : 0.9665885 | Best AUC : 0.9665885 (epoch : 271)
# [Epoch 272] Train - loss : 0.7559755 | Val - AUC : 0.9665849 | Best AUC : 0.9665885 (epoch : 271)
# [Epoch 273] Train - loss : 0.836555 | Val - AUC : 0.9665905 | Best AUC : 0.9665905 (epoch : 273)
# [Epoch 274] Train - loss : 0.8273973 | Val - AUC : 0.9665905 | Best AUC : 0.9665905 (epoch : 274)
# [Epoch 275] Train - loss : 0.8720491 | Val - AUC : 0.9665908 | Best AUC : 0.9665908 (epoch : 275)
# [Epoch 276] Train - loss : 0.8995013 | Val - AUC : 0.9665918 | Best AUC : 0.9665918 (epoch : 276)
# [Epoch 277] Train - loss : 0.9506115 | Val - AUC : 0.9665923 | Best AUC : 0.9665923 (epoch : 277)
# [Epoch 278] Train - loss : 0.8691525 | Val - AUC : 0.9666 | Best AUC : 0.9666 (epoch : 278)
# [Epoch 279] Train - loss : 1.1096965 | Val - AUC : 0.9665998 | Best AUC : 0.9666 (epoch : 278)
# [Epoch 280] Train - loss : 0.9303305 | Val - AUC : 0.9666032 | Best AUC : 0.9666032 (epoch : 280)
# [Epoch 281] Train - loss : 0.741033 | Val - AUC : 0.9666098 | Best AUC : 0.9666098 (epoch : 281)
# [Epoch 282] Train - loss : 0.8288911 | Val - AUC : 0.9666145 | Best AUC : 0.9666145 (epoch : 282)
# [Epoch 283] Train - loss : 0.7637146 | Val - AUC : 0.966611 | Best AUC : 0.9666145 (epoch : 282)
# [Epoch 284] Train - loss : 0.9187886 | Val - AUC : 0.9666172 | Best AUC : 0.9666172 (epoch : 284)
# [Epoch 285] Train - loss : 0.8268655 | Val - AUC : 0.9666162 | Best AUC : 0.9666172 (epoch : 284)
# [Epoch 286] Train - loss : 0.7511938 | Val - AUC : 0.9666151 | Best AUC : 0.9666172 (epoch : 284)
# [Epoch 287] Train - loss : 0.9285858 | Val - AUC : 0.9666208 | Best AUC : 0.9666208 (epoch : 287)
# [Epoch 288] Train - loss : 0.8762677 | Val - AUC : 0.966623 | Best AUC : 0.966623 (epoch : 288)
# [Epoch 289] Train - loss : 1.11654 | Val - AUC : 0.9666222 | Best AUC : 0.966623 (epoch : 288)
# [Epoch 290] Train - loss : 0.9721473 | Val - AUC : 0.9666243 | Best AUC : 0.9666243 (epoch : 290)
# [Epoch 291] Train - loss : 0.8169649 | Val - AUC : 0.9666308 | Best AUC : 0.9666308 (epoch : 291)
# [Epoch 292] Train - loss : 0.8079742 | Val - AUC : 0.9666287 | Best AUC : 0.9666308 (epoch : 291)
# [Epoch 293] Train - loss : 0.9437035 | Val - AUC : 0.9666335 | Best AUC : 0.9666335 (epoch : 293)
# [Epoch 294] Train - loss : 1.0770939 | Val - AUC : 0.9666339 | Best AUC : 0.9666339 (epoch : 294)
# [Epoch 295] Train - loss : 0.844777 | Val - AUC : 0.9666371 | Best AUC : 0.9666371 (epoch : 295)
# [Epoch 296] Train - loss : 0.8500692 | Val - AUC : 0.9666412 | Best AUC : 0.9666412 (epoch : 296)
# [Epoch 297] Train - loss : 0.7778899 | Val - AUC : 0.9666408 | Best AUC : 0.9666412 (epoch : 296)
# [Epoch 298] Train - loss : 0.7776817 | Val - AUC : 0.966644 | Best AUC : 0.966644 (epoch : 298)
# [Epoch 299] Train - loss : 0.7470322 | Val - AUC : 0.9666412 | Best AUC : 0.966644 (epoch : 298)
# [Epoch 300] Train - loss : 0.7151845 | Val - AUC : 0.9666412 | Best AUC : 0.966644 (epoch : 298)
# [Epoch 301] Train - loss : 0.7704219 | Val - AUC : 0.9666485 | Best AUC : 0.9666485 (epoch : 301)
# [Epoch 302] Train - loss : 0.7820043 | Val - AUC : 0.9666497 | Best AUC : 0.9666497 (epoch : 302)
# [Epoch 303] Train - loss : 0.9294648 | Val - AUC : 0.9666518 | Best AUC : 0.9666518 (epoch : 303)
# [Epoch 304] Train - loss : 0.7676059 | Val - AUC : 0.9666554 | Best AUC : 0.9666554 (epoch : 304)
# [Epoch 305] Train - loss : 0.7536338 | Val - AUC : 0.966654 | Best AUC : 0.9666554 (epoch : 304)
# [Epoch 306] Train - loss : 0.7477533 | Val - AUC : 0.966654 | Best AUC : 0.9666554 (epoch : 304)
# [Epoch 307] Train - loss : 0.7580593 | Val - AUC : 0.9666609 | Best AUC : 0.9666609 (epoch : 307)
# [Epoch 308] Train - loss : 0.9581534 | Val - AUC : 0.9666674 | Best AUC : 0.9666674 (epoch : 308)
# [Epoch 309] Train - loss : 0.837123 | Val - AUC : 0.9666672 | Best AUC : 0.9666674 (epoch : 308)
# [Epoch 310] Train - loss : 0.7993912 | Val - AUC : 0.9666669 | Best AUC : 0.9666674 (epoch : 308)
# [Epoch 311] Train - loss : 0.7586331 | Val - AUC : 0.9666681 | Best AUC : 0.9666681 (epoch : 311)
# [Epoch 312] Train - loss : 0.8763184 | Val - AUC : 0.9666675 | Best AUC : 0.9666681 (epoch : 311)
# [Epoch 313] Train - loss : 0.7034699 | Val - AUC : 0.9666691 | Best AUC : 0.9666691 (epoch : 313)
# [Epoch 314] Train - loss : 0.7523255 | Val - AUC : 0.9666704 | Best AUC : 0.9666704 (epoch : 314)
# [Epoch 315] Train - loss : 0.7370667 | Val - AUC : 0.9666701 | Best AUC : 0.9666704 (epoch : 314)
# [Epoch 316] Train - loss : 0.8001551 | Val - AUC : 0.9666788 | Best AUC : 0.9666788 (epoch : 316)
# [Epoch 317] Train - loss : 0.7104867 | Val - AUC : 0.9666783 | Best AUC : 0.9666788 (epoch : 316)
# [Epoch 318] Train - loss : 0.900222 | Val - AUC : 0.9666772 | Best AUC : 0.9666788 (epoch : 316)
# [Epoch 319] Train - loss : 0.792127 | Val - AUC : 0.9666838 | Best AUC : 0.9666838 (epoch : 319)
# [Epoch 320] Train - loss : 0.8859907 | Val - AUC : 0.966685 | Best AUC : 0.966685 (epoch : 320)
# [Epoch 321] Train - loss : 0.7828529 | Val - AUC : 0.9666867 | Best AUC : 0.9666867 (epoch : 321)
# [Epoch 322] Train - loss : 0.9570101 | Val - AUC : 0.9666869 | Best AUC : 0.9666869 (epoch : 322)
# [Epoch 323] Train - loss : 1.0024909 | Val - AUC : 0.9666879 | Best AUC : 0.9666879 (epoch : 323)
# [Epoch 324] Train - loss : 0.6947846 | Val - AUC : 0.9666907 | Best AUC : 0.9666907 (epoch : 324)
# [Epoch 325] Train - loss : 0.9050653 | Val - AUC : 0.9666935 | Best AUC : 0.9666935 (epoch : 325)
# [Epoch 326] Train - loss : 0.7550401 | Val - AUC : 0.966702 | Best AUC : 0.966702 (epoch : 326)
# [Epoch 327] Train - loss : 1.0164728 | Val - AUC : 0.9667017 | Best AUC : 0.966702 (epoch : 326)
# [Epoch 328] Train - loss : 0.7829569 | Val - AUC : 0.966702 | Best AUC : 0.966702 (epoch : 328)
# [Epoch 329] Train - loss : 0.7766991 | Val - AUC : 0.9667047 | Best AUC : 0.9667047 (epoch : 329)
# [Epoch 330] Train - loss : 0.8824373 | Val - AUC : 0.9667054 | Best AUC : 0.9667054 (epoch : 330)
# [Epoch 331] Train - loss : 0.7965958 | Val - AUC : 0.9667122 | Best AUC : 0.9667122 (epoch : 331)
# [Epoch 332] Train - loss : 0.7942702 | Val - AUC : 0.9667156 | Best AUC : 0.9667156 (epoch : 332)
# [Epoch 333] Train - loss : 0.7755026 | Val - AUC : 0.9667132 | Best AUC : 0.9667156 (epoch : 332)
# [Epoch 334] Train - loss : 0.8578142 | Val - AUC : 0.9667077 | Best AUC : 0.9667156 (epoch : 332)
# [Epoch 335] Train - loss : 0.9324763 | Val - AUC : 0.9667115 | Best AUC : 0.9667156 (epoch : 332)
# [Epoch 336] Train - loss : 0.7090117 | Val - AUC : 0.966715 | Best AUC : 0.9667156 (epoch : 332)
# [Epoch 337] Train - loss : 0.808041 | Val - AUC : 0.9667154 | Best AUC : 0.9667156 (epoch : 332)
# [Epoch 338] Train - loss : 0.7466811 | Val - AUC : 0.9667199 | Best AUC : 0.9667199 (epoch : 338)
# [Epoch 339] Train - loss : 0.7264657 | Val - AUC : 0.9667221 | Best AUC : 0.9667221 (epoch : 339)
# [Epoch 340] Train - loss : 0.7585159 | Val - AUC : 0.9667283 | Best AUC : 0.9667283 (epoch : 340)
# [Epoch 341] Train - loss : 0.7623233 | Val - AUC : 0.966731 | Best AUC : 0.966731 (epoch : 341)
# [Epoch 342] Train - loss : 0.7125389 | Val - AUC : 0.9667302 | Best AUC : 0.966731 (epoch : 341)
# [Epoch 343] Train - loss : 0.7939678 | Val - AUC : 0.9667306 | Best AUC : 0.966731 (epoch : 341)
# [Epoch 344] Train - loss : 0.755521 | Val - AUC : 0.9667246 | Best AUC : 0.966731 (epoch : 341)
# [Epoch 345] Train - loss : 0.8710867 | Val - AUC : 0.9667296 | Best AUC : 0.966731 (epoch : 341)
# [Epoch 346] Train - loss : 0.8161764 | Val - AUC : 0.9667361 | Best AUC : 0.9667361 (epoch : 346)
# [Epoch 347] Train - loss : 0.7276682 | Val - AUC : 0.9667452 | Best AUC : 0.9667452 (epoch : 347)
# [Epoch 348] Train - loss : 0.9221955 | Val - AUC : 0.9667469 | Best AUC : 0.9667469 (epoch : 348)
# [Epoch 349] Train - loss : 0.7936085 | Val - AUC : 0.9667403 | Best AUC : 0.9667469 (epoch : 348)
# [Epoch 350] Train - loss : 0.8229682 | Val - AUC : 0.9667477 | Best AUC : 0.9667477 (epoch : 350)
# [Epoch 351] Train - loss : 0.7403793 | Val - AUC : 0.966758 | Best AUC : 0.966758 (epoch : 351)
# [Epoch 352] Train - loss : 0.7347178 | Val - AUC : 0.9667565 | Best AUC : 0.966758 (epoch : 351)
# [Epoch 353] Train - loss : 0.8060445 | Val - AUC : 0.9667601 | Best AUC : 0.9667601 (epoch : 353)
# [Epoch 354] Train - loss : 0.8335597 | Val - AUC : 0.9667572 | Best AUC : 0.9667601 (epoch : 353)
# [Epoch 355] Train - loss : 0.783528 | Val - AUC : 0.966764 | Best AUC : 0.966764 (epoch : 355)
# [Epoch 356] Train - loss : 0.7614538 | Val - AUC : 0.966765 | Best AUC : 0.966765 (epoch : 356)
# [Epoch 357] Train - loss : 0.7295044 | Val - AUC : 0.9667626 | Best AUC : 0.966765 (epoch : 356)
# [Epoch 358] Train - loss : 0.9306248 | Val - AUC : 0.9667632 | Best AUC : 0.966765 (epoch : 356)
# [Epoch 359] Train - loss : 0.7295579 | Val - AUC : 0.9667685 | Best AUC : 0.9667685 (epoch : 359)
# [Epoch 360] Train - loss : 1.0280179 | Val - AUC : 0.9667738 | Best AUC : 0.9667738 (epoch : 360)
# [Epoch 361] Train - loss : 0.7336673 | Val - AUC : 0.9667699 | Best AUC : 0.9667738 (epoch : 360)
# [Epoch 362] Train - loss : 0.8161086 | Val - AUC : 0.9667784 | Best AUC : 0.9667784 (epoch : 362)
# [Epoch 363] Train - loss : 0.8147288 | Val - AUC : 0.9667777 | Best AUC : 0.9667784 (epoch : 362)
# [Epoch 364] Train - loss : 0.7727805 | Val - AUC : 0.9667899 | Best AUC : 0.9667899 (epoch : 364)
# [Epoch 365] Train - loss : 0.7850116 | Val - AUC : 0.9667869 | Best AUC : 0.9667899 (epoch : 364)
# [Epoch 366] Train - loss : 0.7825127 | Val - AUC : 0.9667885 | Best AUC : 0.9667899 (epoch : 364)
# [Epoch 367] Train - loss : 0.6542134 | Val - AUC : 0.9667938 | Best AUC : 0.9667938 (epoch : 367)
# [Epoch 368] Train - loss : 0.6814438 | Val - AUC : 0.9667915 | Best AUC : 0.9667938 (epoch : 367)
# [Epoch 369] Train - loss : 0.7336084 | Val - AUC : 0.9667942 | Best AUC : 0.9667942 (epoch : 369)
# [Epoch 370] Train - loss : 0.6974558 | Val - AUC : 0.9667949 | Best AUC : 0.9667949 (epoch : 370)
# [Epoch 371] Train - loss : 0.790478 | Val - AUC : 0.9668037 | Best AUC : 0.9668037 (epoch : 371)
# [Epoch 372] Train - loss : 0.7496222 | Val - AUC : 0.9668132 | Best AUC : 0.9668132 (epoch : 372)
# [Epoch 373] Train - loss : 0.6187014 | Val - AUC : 0.9668132 | Best AUC : 0.9668132 (epoch : 373)
# [Epoch 374] Train - loss : 0.7440577 | Val - AUC : 0.9668151 | Best AUC : 0.9668151 (epoch : 374)
# [Epoch 375] Train - loss : 0.8485096 | Val - AUC : 0.9668153 | Best AUC : 0.9668153 (epoch : 375)
# [Epoch 376] Train - loss : 0.6727643 | Val - AUC : 0.966818 | Best AUC : 0.966818 (epoch : 376)
# [Epoch 377] Train - loss : 0.8005793 | Val - AUC : 0.9668214 | Best AUC : 0.9668214 (epoch : 377)
# [Epoch 378] Train - loss : 0.8074534 | Val - AUC : 0.96682 | Best AUC : 0.9668214 (epoch : 377)
# [Epoch 379] Train - loss : 0.8153473 | Val - AUC : 0.966829 | Best AUC : 0.966829 (epoch : 379)
# [Epoch 380] Train - loss : 0.8826344 | Val - AUC : 0.9668301 | Best AUC : 0.9668301 (epoch : 380)
# [Epoch 381] Train - loss : 0.8323378 | Val - AUC : 0.9668343 | Best AUC : 0.9668343 (epoch : 381)
# [Epoch 382] Train - loss : 0.8150194 | Val - AUC : 0.966834 | Best AUC : 0.9668343 (epoch : 381)
# [Epoch 383] Train - loss : 0.7689203 | Val - AUC : 0.9668397 | Best AUC : 0.9668397 (epoch : 383)
# [Epoch 384] Train - loss : 0.7751058 | Val - AUC : 0.9668388 | Best AUC : 0.9668397 (epoch : 383)
# [Epoch 385] Train - loss : 0.7898162 | Val - AUC : 0.9668406 | Best AUC : 0.9668406 (epoch : 385)
# [Epoch 386] Train - loss : 0.8526246 | Val - AUC : 0.9668508 | Best AUC : 0.9668508 (epoch : 386)
# [Epoch 387] Train - loss : 0.8307752 | Val - AUC : 0.9668506 | Best AUC : 0.9668508 (epoch : 386)
# [Epoch 388] Train - loss : 0.881842 | Val - AUC : 0.9668512 | Best AUC : 0.9668512 (epoch : 388)
# [Epoch 389] Train - loss : 0.9243914 | Val - AUC : 0.9668542 | Best AUC : 0.9668542 (epoch : 389)
# [Epoch 390] Train - loss : 0.6960243 | Val - AUC : 0.9668552 | Best AUC : 0.9668552 (epoch : 390)
# [Epoch 391] Train - loss : 0.9230552 | Val - AUC : 0.9668575 | Best AUC : 0.9668575 (epoch : 391)
# [Epoch 392] Train - loss : 0.7689603 | Val - AUC : 0.9668613 | Best AUC : 0.9668613 (epoch : 392)
# [Epoch 393] Train - loss : 0.7349112 | Val - AUC : 0.9668618 | Best AUC : 0.9668618 (epoch : 393)
# [Epoch 394] Train - loss : 0.777751 | Val - AUC : 0.966863 | Best AUC : 0.966863 (epoch : 394)
# [Epoch 395] Train - loss : 0.8250482 | Val - AUC : 0.9668716 | Best AUC : 0.9668716 (epoch : 395)
# [Epoch 396] Train - loss : 0.7490581 | Val - AUC : 0.9668709 | Best AUC : 0.9668716 (epoch : 395)
# [Epoch 397] Train - loss : 0.9700538 | Val - AUC : 0.966879 | Best AUC : 0.966879 (epoch : 397)
# [Epoch 398] Train - loss : 0.7297467 | Val - AUC : 0.9668785 | Best AUC : 0.966879 (epoch : 397)
# [Epoch 399] Train - loss : 0.8008615 | Val - AUC : 0.9668788 | Best AUC : 0.966879 (epoch : 397)
# [Epoch 400] Train - loss : 0.8913097 | Val - AUC : 0.9668757 | Best AUC : 0.966879 (epoch : 397)
# [Epoch 401] Train - loss : 0.7235078 | Val - AUC : 0.9668755 | Best AUC : 0.966879 (epoch : 397)
# [Epoch 402] Train - loss : 0.6498338 | Val - AUC : 0.9668798 | Best AUC : 0.9668798 (epoch : 402)
# [Epoch 403] Train - loss : 0.8239371 | Val - AUC : 0.9668915 | Best AUC : 0.9668915 (epoch : 403)
# [Epoch 404] Train - loss : 0.7595548 | Val - AUC : 0.9668896 | Best AUC : 0.9668915 (epoch : 403)
# [Epoch 405] Train - loss : 0.794978 | Val - AUC : 0.9668915 | Best AUC : 0.9668915 (epoch : 403)
# [Epoch 406] Train - loss : 0.7990421 | Val - AUC : 0.9668952 | Best AUC : 0.9668952 (epoch : 406)
# [Epoch 407] Train - loss : 0.9695558 | Val - AUC : 0.9669042 | Best AUC : 0.9669042 (epoch : 407)
# [Epoch 408] Train - loss : 0.6727625 | Val - AUC : 0.9669053 | Best AUC : 0.9669053 (epoch : 408)
# [Epoch 409] Train - loss : 0.7711506 | Val - AUC : 0.9669023 | Best AUC : 0.9669053 (epoch : 408)
# [Epoch 410] Train - loss : 0.7943852 | Val - AUC : 0.9669071 | Best AUC : 0.9669071 (epoch : 410)
# [Epoch 411] Train - loss : 0.7261372 | Val - AUC : 0.9669055 | Best AUC : 0.9669071 (epoch : 410)
# [Epoch 412] Train - loss : 0.8296736 | Val - AUC : 0.9669146 | Best AUC : 0.9669146 (epoch : 412)
# [Epoch 413] Train - loss : 0.7523166 | Val - AUC : 0.9669166 | Best AUC : 0.9669166 (epoch : 413)
# [Epoch 414] Train - loss : 0.7445517 | Val - AUC : 0.9669178 | Best AUC : 0.9669178 (epoch : 414)
# [Epoch 415] Train - loss : 0.7642914 | Val - AUC : 0.9669257 | Best AUC : 0.9669257 (epoch : 415)
# [Epoch 416] Train - loss : 0.7190335 | Val - AUC : 0.9669245 | Best AUC : 0.9669257 (epoch : 415)
# [Epoch 417] Train - loss : 0.851565 | Val - AUC : 0.9669319 | Best AUC : 0.9669319 (epoch : 417)
# [Epoch 418] Train - loss : 0.7632417 | Val - AUC : 0.9669318 | Best AUC : 0.9669319 (epoch : 417)
# [Epoch 419] Train - loss : 0.7156121 | Val - AUC : 0.9669303 | Best AUC : 0.9669319 (epoch : 417)
# [Epoch 420] Train - loss : 0.9353366 | Val - AUC : 0.9669377 | Best AUC : 0.9669377 (epoch : 420)
# [Epoch 421] Train - loss : 0.7975926 | Val - AUC : 0.9669321 | Best AUC : 0.9669377 (epoch : 420)
# [Epoch 422] Train - loss : 0.8269447 | Val - AUC : 0.9669373 | Best AUC : 0.9669377 (epoch : 420)
# [Epoch 423] Train - loss : 0.7673029 | Val - AUC : 0.9669348 | Best AUC : 0.9669377 (epoch : 420)
# [Epoch 424] Train - loss : 0.8086187 | Val - AUC : 0.966938 | Best AUC : 0.966938 (epoch : 424)
# [Epoch 425] Train - loss : 0.7657559 | Val - AUC : 0.9669546 | Best AUC : 0.9669546 (epoch : 425)
# [Epoch 426] Train - loss : 0.822447 | Val - AUC : 0.9669506 | Best AUC : 0.9669546 (epoch : 425)
# [Epoch 427] Train - loss : 0.9127588 | Val - AUC : 0.9669546 | Best AUC : 0.9669546 (epoch : 425)
# [Epoch 428] Train - loss : 0.7359846 | Val - AUC : 0.9669576 | Best AUC : 0.9669576 (epoch : 428)
# [Epoch 429] Train - loss : 0.8249637 | Val - AUC : 0.9669531 | Best AUC : 0.9669576 (epoch : 428)
# [Epoch 430] Train - loss : 0.6402078 | Val - AUC : 0.966962 | Best AUC : 0.966962 (epoch : 430)
# [Epoch 431] Train - loss : 0.7539528 | Val - AUC : 0.9669619 | Best AUC : 0.966962 (epoch : 430)
# [Epoch 432] Train - loss : 0.7782037 | Val - AUC : 0.9669654 | Best AUC : 0.9669654 (epoch : 432)
# [Epoch 433] Train - loss : 0.8840604 | Val - AUC : 0.966971 | Best AUC : 0.966971 (epoch : 433)
# [Epoch 434] Train - loss : 0.8780786 | Val - AUC : 0.966965 | Best AUC : 0.966971 (epoch : 433)
# [Epoch 435] Train - loss : 0.6975033 | Val - AUC : 0.96697 | Best AUC : 0.966971 (epoch : 433)
# [Epoch 436] Train - loss : 0.8062674 | Val - AUC : 0.9669681 | Best AUC : 0.966971 (epoch : 433)
# [Epoch 437] Train - loss : 0.8454132 | Val - AUC : 0.9669701 | Best AUC : 0.966971 (epoch : 433)
# [Epoch 438] Train - loss : 0.7880364 | Val - AUC : 0.9669768 | Best AUC : 0.9669768 (epoch : 438)
# [Epoch 439] Train - loss : 0.839204 | Val - AUC : 0.9669852 | Best AUC : 0.9669852 (epoch : 439)
# [Epoch 440] Train - loss : 0.7147726 | Val - AUC : 0.966984 | Best AUC : 0.9669852 (epoch : 439)
# [Epoch 441] Train - loss : 0.7131776 | Val - AUC : 0.9669804 | Best AUC : 0.9669852 (epoch : 439)
# [Epoch 442] Train - loss : 0.7531731 | Val - AUC : 0.9669881 | Best AUC : 0.9669881 (epoch : 442)
# [Epoch 443] Train - loss : 0.7179425 | Val - AUC : 0.9669978 | Best AUC : 0.9669978 (epoch : 443)
# [Epoch 444] Train - loss : 0.8958501 | Val - AUC : 0.9670013 | Best AUC : 0.9670013 (epoch : 444)
# [Epoch 445] Train - loss : 0.8474146 | Val - AUC : 0.9670039 | Best AUC : 0.9670039 (epoch : 445)
# [Epoch 446] Train - loss : 0.8961223 | Val - AUC : 0.9670094 | Best AUC : 0.9670094 (epoch : 446)
# [Epoch 447] Train - loss : 0.6305434 | Val - AUC : 0.9670155 | Best AUC : 0.9670155 (epoch : 447)
# [Epoch 448] Train - loss : 0.8281015 | Val - AUC : 0.967017 | Best AUC : 0.967017 (epoch : 448)
# [Epoch 449] Train - loss : 0.7335935 | Val - AUC : 0.9670217 | Best AUC : 0.9670217 (epoch : 449)
# [Epoch 450] Train - loss : 0.6615044 | Val - AUC : 0.9670196 | Best AUC : 0.9670217 (epoch : 449)
# [Epoch 451] Train - loss : 0.6027 | Val - AUC : 0.9670245 | Best AUC : 0.9670245 (epoch : 451)
# [Epoch 452] Train - loss : 0.8170905 | Val - AUC : 0.9670192 | Best AUC : 0.9670245 (epoch : 451)
# [Epoch 453] Train - loss : 0.7706588 | Val - AUC : 0.9670193 | Best AUC : 0.9670245 (epoch : 451)
# [Epoch 454] Train - loss : 0.74154 | Val - AUC : 0.9670305 | Best AUC : 0.9670305 (epoch : 454)
# [Epoch 455] Train - loss : 0.8332889 | Val - AUC : 0.9670407 | Best AUC : 0.9670407 (epoch : 455)
# [Epoch 456] Train - loss : 0.7105726 | Val - AUC : 0.9670412 | Best AUC : 0.9670412 (epoch : 456)
# [Epoch 457] Train - loss : 0.7827456 | Val - AUC : 0.9670416 | Best AUC : 0.9670416 (epoch : 457)
# [Epoch 458] Train - loss : 0.7774294 | Val - AUC : 0.9670428 | Best AUC : 0.9670428 (epoch : 458)
# [Epoch 459] Train - loss : 0.887309 | Val - AUC : 0.9670515 | Best AUC : 0.9670515 (epoch : 459)
# [Epoch 460] Train - loss : 0.7414023 | Val - AUC : 0.9670495 | Best AUC : 0.9670515 (epoch : 459)
# [Epoch 461] Train - loss : 0.6854012 | Val - AUC : 0.9670534 | Best AUC : 0.9670534 (epoch : 461)
# [Epoch 462] Train - loss : 0.6858034 | Val - AUC : 0.9670539 | Best AUC : 0.9670539 (epoch : 462)
# [Epoch 463] Train - loss : 0.8108572 | Val - AUC : 0.9670558 | Best AUC : 0.9670558 (epoch : 463)
# [Epoch 464] Train - loss : 0.7789927 | Val - AUC : 0.967063 | Best AUC : 0.967063 (epoch : 464)
# [Epoch 465] Train - loss : 0.744058 | Val - AUC : 0.9670556 | Best AUC : 0.967063 (epoch : 464)
# [Epoch 466] Train - loss : 0.889736 | Val - AUC : 0.9670661 | Best AUC : 0.9670661 (epoch : 466)
# [Epoch 467] Train - loss : 0.9665817 | Val - AUC : 0.9670683 | Best AUC : 0.9670683 (epoch : 467)
# [Epoch 468] Train - loss : 0.6135252 | Val - AUC : 0.9670733 | Best AUC : 0.9670733 (epoch : 468)
# [Epoch 469] Train - loss : 0.6684386 | Val - AUC : 0.9670656 | Best AUC : 0.9670733 (epoch : 468)
# [Epoch 470] Train - loss : 0.7223525 | Val - AUC : 0.9670715 | Best AUC : 0.9670733 (epoch : 468)
# [Epoch 471] Train - loss : 0.7656058 | Val - AUC : 0.9670736 | Best AUC : 0.9670736 (epoch : 471)
# [Epoch 472] Train - loss : 0.7875712 | Val - AUC : 0.9670754 | Best AUC : 0.9670754 (epoch : 472)
# [Epoch 473] Train - loss : 0.8457595 | Val - AUC : 0.9670731 | Best AUC : 0.9670754 (epoch : 472)
# [Epoch 474] Train - loss : 0.8155007 | Val - AUC : 0.967078 | Best AUC : 0.967078 (epoch : 474)
# [Epoch 475] Train - loss : 0.7430663 | Val - AUC : 0.9670828 | Best AUC : 0.9670828 (epoch : 475)
# [Epoch 476] Train - loss : 0.7185817 | Val - AUC : 0.9670921 | Best AUC : 0.9670921 (epoch : 476)
# [Epoch 477] Train - loss : 0.7442737 | Val - AUC : 0.9670927 | Best AUC : 0.9670927 (epoch : 477)
# [Epoch 478] Train - loss : 0.6326683 | Val - AUC : 0.9671009 | Best AUC : 0.9671009 (epoch : 478)
# [Epoch 479] Train - loss : 0.8683301 | Val - AUC : 0.9671018 | Best AUC : 0.9671018 (epoch : 479)
# [Epoch 480] Train - loss : 0.8802127 | Val - AUC : 0.9671075 | Best AUC : 0.9671075 (epoch : 480)
# [Epoch 481] Train - loss : 0.8021327 | Val - AUC : 0.96711 | Best AUC : 0.96711 (epoch : 481)
# [Epoch 482] Train - loss : 0.786414 | Val - AUC : 0.9671158 | Best AUC : 0.9671158 (epoch : 482)
# [Epoch 483] Train - loss : 0.7227265 | Val - AUC : 0.9671185 | Best AUC : 0.9671185 (epoch : 483)
# [Epoch 484] Train - loss : 0.7235619 | Val - AUC : 0.9671206 | Best AUC : 0.9671206 (epoch : 484)
# [Epoch 485] Train - loss : 0.8097374 | Val - AUC : 0.9671209 | Best AUC : 0.9671209 (epoch : 485)
# [Epoch 486] Train - loss : 0.7715391 | Val - AUC : 0.9671253 | Best AUC : 0.9671253 (epoch : 486)
# [Epoch 487] Train - loss : 0.7112731 | Val - AUC : 0.9671325 | Best AUC : 0.9671325 (epoch : 487)
# [Epoch 488] Train - loss : 0.7640506 | Val - AUC : 0.9671339 | Best AUC : 0.9671339 (epoch : 488)
# [Epoch 489] Train - loss : 0.809383 | Val - AUC : 0.9671306 | Best AUC : 0.9671339 (epoch : 488)
# [Epoch 490] Train - loss : 0.6916302 | Val - AUC : 0.9671423 | Best AUC : 0.9671423 (epoch : 490)
# [Epoch 491] Train - loss : 0.7318 | Val - AUC : 0.9671492 | Best AUC : 0.9671492 (epoch : 491)
# [Epoch 492] Train - loss : 0.7412717 | Val - AUC : 0.9671518 | Best AUC : 0.9671518 (epoch : 492)
# [Epoch 493] Train - loss : 0.9541178 | Val - AUC : 0.9671549 | Best AUC : 0.9671549 (epoch : 493)
# ...
# [Epoch 837] Train - loss : 0.7821572 | Val - AUC : 0.9686653 | Best AUC : 0.9686653 (epoch : 837)
# [Epoch 838] Train - loss : 0.6264397 | Val - AUC : 0.9686677 | Best AUC : 0.9686677 (epoch : 838)
# [Epoch 839] Train - loss : 0.8588955 | Val - AUC : 0.9686592 | Best AUC : 0.9686677 (epoch : 838)
# [Epoch 840] Train - loss : 0.6378795 | Val - AUC : 0.9686694 | Best AUC : 0.9686694 (epoch : 840)
# [Epoch 841] Train - loss : 0.5369843 | Val - AUC : 0.9686735 | Best AUC : 0.9686735 (epoch : 841)
# [Epoch 842] Train - loss : 0.6557827 | Val - AUC : 0.968676 | Best AUC : 0.968676 (epoch : 842)
# [Epoch 843] Train - loss : 0.8605043 | Val - AUC : 0.9686844 | Best AUC : 0.9686844 (epoch : 843)
# [Epoch 844] Train - loss : 0.7498123 | Val - AUC : 0.9686772 | Best AUC : 0.9686844 (epoch : 843)
# [Epoch 845] Train - loss : 0.7366295 | Val - AUC : 0.9686836 | Best AUC : 0.9686844 (epoch : 843)
# [Epoch 846] Train - loss : 0.6573993 | Val - AUC : 0.9686891 | Best AUC : 0.9686891 (epoch : 846)
# [Epoch 847] Train - loss : 0.7287596 | Val - AUC : 0.968685 | Best AUC : 0.9686891 (epoch : 846)
# [Epoch 848] Train - loss : 0.5979397 | Val - AUC : 0.9686945 | Best AUC : 0.9686945 (epoch : 848)
# [Epoch 849] Train - loss : 0.643968 | Val - AUC : 0.968694 | Best AUC : 0.9686945 (epoch : 848)
# [Epoch 850] Train - loss : 0.6873346 | Val - AUC : 0.9686977 | Best AUC : 0.9686977 (epoch : 850)
# [Epoch 851] Train - loss : 0.6673266 | Val - AUC : 0.9686997 | Best AUC : 0.9686997 (epoch : 851)
# [Epoch 852] Train - loss : 0.6910551 | Val - AUC : 0.9687007 | Best AUC : 0.9687007 (epoch : 852)
# [Epoch 853] Train - loss : 0.6230791 | Val - AUC : 0.9686983 | Best AUC : 0.9687007 (epoch : 852)
# [Epoch 854] Train - loss : 0.6149972 | Val - AUC : 0.9687033 | Best AUC : 0.9687033 (epoch : 854)
# [Epoch 855] Train - loss : 0.7830121 | Val - AUC : 0.9687048 | Best AUC : 0.9687048 (epoch : 855)
# [Epoch 856] Train - loss : 0.743973 | Val - AUC : 0.9687078 | Best AUC : 0.9687078 (epoch : 856)
# [Epoch 857] Train - loss : 0.6818154 | Val - AUC : 0.9687086 | Best AUC : 0.9687086 (epoch : 857)
# [Epoch 858] Train - loss : 0.6205988 | Val - AUC : 0.9687093 | Best AUC : 0.9687093 (epoch : 858)
# [Epoch 859] Train - loss : 0.7721802 | Val - AUC : 0.9687096 | Best AUC : 0.9687096 (epoch : 859)
# [Epoch 860] Train - loss : 0.6040819 | Val - AUC : 0.9687169 | Best AUC : 0.9687169 (epoch : 860)
# [Epoch 861] Train - loss : 0.634043 | Val - AUC : 0.9687094 | Best AUC : 0.9687169 (epoch : 860)
# [Epoch 862] Train - loss : 0.68702 | Val - AUC : 0.9687194 | Best AUC : 0.9687194 (epoch : 862)
# [Epoch 863] Train - loss : 0.6145606 | Val - AUC : 0.9687206 | Best AUC : 0.9687206 (epoch : 863)
# [Epoch 864] Train - loss : 0.7116243 | Val - AUC : 0.9687283 | Best AUC : 0.9687283 (epoch : 864)
# [Epoch 865] Train - loss : 0.5303182 | Val - AUC : 0.968727 | Best AUC : 0.9687283 (epoch : 864)
# [Epoch 866] Train - loss : 0.7802458 | Val - AUC : 0.9687331 | Best AUC : 0.9687331 (epoch : 866)
# [Epoch 867] Train - loss : 0.7769495 | Val - AUC : 0.9687373 | Best AUC : 0.9687373 (epoch : 867)
# [Epoch 868] Train - loss : 0.6542801 | Val - AUC : 0.9687384 | Best AUC : 0.9687384 (epoch : 868)
# [Epoch 869] Train - loss : 0.6205939 | Val - AUC : 0.9687393 | Best AUC : 0.9687393 (epoch : 869)
# [Epoch 870] Train - loss : 0.6606487 | Val - AUC : 0.9687403 | Best AUC : 0.9687403 (epoch : 870)
# [Epoch 871] Train - loss : 0.796629 | Val - AUC : 0.9687426 | Best AUC : 0.9687426 (epoch : 871)
# [Epoch 872] Train - loss : 0.8001712 | Val - AUC : 0.9687359 | Best AUC : 0.9687426 (epoch : 871)
# [Epoch 873] Train - loss : 0.7366296 | Val - AUC : 0.9687391 | Best AUC : 0.9687426 (epoch : 871)
# [Epoch 874] Train - loss : 0.7606937 | Val - AUC : 0.9687426 | Best AUC : 0.9687426 (epoch : 874)
# [Epoch 875] Train - loss : 0.7940581 | Val - AUC : 0.9687475 | Best AUC : 0.9687475 (epoch : 875)
# [Epoch 876] Train - loss : 0.7760816 | Val - AUC : 0.9687544 | Best AUC : 0.9687544 (epoch : 876)
# [Epoch 877] Train - loss : 0.7128529 | Val - AUC : 0.9687503 | Best AUC : 0.9687544 (epoch : 876)
# [Epoch 878] Train - loss : 0.7566566 | Val - AUC : 0.9687587 | Best AUC : 0.9687587 (epoch : 878)
# [Epoch 879] Train - loss : 0.592951 | Val - AUC : 0.9687607 | Best AUC : 0.9687607 (epoch : 879)
# [Epoch 880] Train - loss : 0.5907508 | Val - AUC : 0.9687583 | Best AUC : 0.9687607 (epoch : 879)
# [Epoch 881] Train - loss : 0.6157233 | Val - AUC : 0.9687665 | Best AUC : 0.9687665 (epoch : 881)
# [Epoch 882] Train - loss : 0.6715726 | Val - AUC : 0.9687628 | Best AUC : 0.9687665 (epoch : 881)
# [Epoch 883] Train - loss : 0.6709716 | Val - AUC : 0.9687605 | Best AUC : 0.9687665 (epoch : 881)
# [Epoch 884] Train - loss : 0.6375518 | Val - AUC : 0.9687613 | Best AUC : 0.9687665 (epoch : 881)
# [Epoch 885] Train - loss : 0.5673063 | Val - AUC : 0.9687697 | Best AUC : 0.9687697 (epoch : 885)
# [Epoch 886] Train - loss : 0.7030531 | Val - AUC : 0.9687613 | Best AUC : 0.9687697 (epoch : 885)
# [Epoch 887] Train - loss : 0.7673282 | Val - AUC : 0.9687714 | Best AUC : 0.9687714 (epoch : 887)
# [Epoch 888] Train - loss : 0.6879184 | Val - AUC : 0.968784 | Best AUC : 0.968784 (epoch : 888)
# [Epoch 889] Train - loss : 0.6783722 | Val - AUC : 0.9687843 | Best AUC : 0.9687843 (epoch : 889)
# [Epoch 890] Train - loss : 0.7531263 | Val - AUC : 0.9687835 | Best AUC : 0.9687843 (epoch : 889)
# [Epoch 891] Train - loss : 0.806253 | Val - AUC : 0.9687832 | Best AUC : 0.9687843 (epoch : 889)
# [Epoch 892] Train - loss : 0.6804324 | Val - AUC : 0.9687908 | Best AUC : 0.9687908 (epoch : 892)
# [Epoch 893] Train - loss : 0.7512515 | Val - AUC : 0.9687873 | Best AUC : 0.9687908 (epoch : 892)
# [Epoch 894] Train - loss : 0.6979487 | Val - AUC : 0.968793 | Best AUC : 0.968793 (epoch : 894)
# [Epoch 895] Train - loss : 0.7521824 | Val - AUC : 0.9687905 | Best AUC : 0.968793 (epoch : 894)
# [Epoch 896] Train - loss : 0.6647837 | Val - AUC : 0.9687882 | Best AUC : 0.968793 (epoch : 894)
# [Epoch 897] Train - loss : 0.7217789 | Val - AUC : 0.9687856 | Best AUC : 0.968793 (epoch : 894)
# [Epoch 898] Train - loss : 0.6505071 | Val - AUC : 0.9687943 | Best AUC : 0.9687943 (epoch : 898)
# [Epoch 899] Train - loss : 0.7499611 | Val - AUC : 0.9688 | Best AUC : 0.9688 (epoch : 899)
# [Epoch 900] Train - loss : 0.7160171 | Val - AUC : 0.9687994 | Best AUC : 0.9688 (epoch : 899)
# [Epoch 901] Train - loss : 0.6162625 | Val - AUC : 0.9688053 | Best AUC : 0.9688053 (epoch : 901)
# [Epoch 902] Train - loss : 0.6973895 | Val - AUC : 0.9688091 | Best AUC : 0.9688091 (epoch : 902)
# [Epoch 903] Train - loss : 0.6036652 | Val - AUC : 0.9688067 | Best AUC : 0.9688091 (epoch : 902)
# [Epoch 904] Train - loss : 0.6278322 | Val - AUC : 0.9688017 | Best AUC : 0.9688091 (epoch : 902)
# [Epoch 905] Train - loss : 0.7644184 | Val - AUC : 0.9688102 | Best AUC : 0.9688102 (epoch : 905)
# [Epoch 906] Train - loss : 0.6491933 | Val - AUC : 0.9688167 | Best AUC : 0.9688167 (epoch : 906)
# [Epoch 907] Train - loss : 0.6340585 | Val - AUC : 0.9688112 | Best AUC : 0.9688167 (epoch : 906)
# [Epoch 908] Train - loss : 0.5812553 | Val - AUC : 0.9688226 | Best AUC : 0.9688226 (epoch : 908)
# [Epoch 909] Train - loss : 0.6391585 | Val - AUC : 0.9688214 | Best AUC : 0.9688226 (epoch : 908)
# [Epoch 910] Train - loss : 0.6514736 | Val - AUC : 0.9688294 | Best AUC : 0.9688294 (epoch : 910)
# [Epoch 911] Train - loss : 0.6547203 | Val - AUC : 0.9688346 | Best AUC : 0.9688346 (epoch : 911)
# [Epoch 912] Train - loss : 0.7620289 | Val - AUC : 0.9688371 | Best AUC : 0.9688371 (epoch : 912)
# [Epoch 913] Train - loss : 0.6400033 | Val - AUC : 0.9688307 | Best AUC : 0.9688371 (epoch : 912)
# [Epoch 914] Train - loss : 0.7013807 | Val - AUC : 0.9688342 | Best AUC : 0.9688371 (epoch : 912)
# [Epoch 915] Train - loss : 0.7258197 | Val - AUC : 0.9688403 | Best AUC : 0.9688403 (epoch : 915)
# [Epoch 916] Train - loss : 0.5720181 | Val - AUC : 0.968844 | Best AUC : 0.968844 (epoch : 916)
# [Epoch 917] Train - loss : 0.6586446 | Val - AUC : 0.968847 | Best AUC : 0.968847 (epoch : 917)
# [Epoch 918] Train - loss : 0.6429056 | Val - AUC : 0.9688449 | Best AUC : 0.968847 (epoch : 917)
# [Epoch 919] Train - loss : 0.6392846 | Val - AUC : 0.9688416 | Best AUC : 0.968847 (epoch : 917)
# [Epoch 920] Train - loss : 0.7685771 | Val - AUC : 0.9688469 | Best AUC : 0.968847 (epoch : 917)
# [Epoch 921] Train - loss : 0.6294875 | Val - AUC : 0.9688501 | Best AUC : 0.9688501 (epoch : 921)
# [Epoch 922] Train - loss : 0.6966077 | Val - AUC : 0.9688442 | Best AUC : 0.9688501 (epoch : 921)
# [Epoch 923] Train - loss : 0.5666024 | Val - AUC : 0.9688507 | Best AUC : 0.9688507 (epoch : 923)
# [Epoch 924] Train - loss : 0.5702274 | Val - AUC : 0.968858 | Best AUC : 0.968858 (epoch : 924)
# [Epoch 925] Train - loss : 0.7015076 | Val - AUC : 0.9688606 | Best AUC : 0.9688606 (epoch : 925)
# [Epoch 926] Train - loss : 0.6393251 | Val - AUC : 0.9688646 | Best AUC : 0.9688646 (epoch : 926)
# [Epoch 927] Train - loss : 0.7359833 | Val - AUC : 0.9688573 | Best AUC : 0.9688646 (epoch : 926)
# [Epoch 928] Train - loss : 0.6049789 | Val - AUC : 0.9688552 | Best AUC : 0.9688646 (epoch : 926)
# [Epoch 929] Train - loss : 0.811498 | Val - AUC : 0.9688592 | Best AUC : 0.9688646 (epoch : 926)
# [Epoch 930] Train - loss : 0.6748329 | Val - AUC : 0.9688653 | Best AUC : 0.9688653 (epoch : 930)
# [Epoch 931] Train - loss : 0.6062252 | Val - AUC : 0.9688637 | Best AUC : 0.9688653 (epoch : 930)
# [Epoch 932] Train - loss : 0.6749604 | Val - AUC : 0.9688674 | Best AUC : 0.9688674 (epoch : 932)
# [Epoch 933] Train - loss : 0.7170825 | Val - AUC : 0.9688724 | Best AUC : 0.9688724 (epoch : 933)
# [Epoch 934] Train - loss : 0.6229378 | Val - AUC : 0.9688733 | Best AUC : 0.9688733 (epoch : 934)
# [Epoch 935] Train - loss : 0.5876758 | Val - AUC : 0.9688766 | Best AUC : 0.9688766 (epoch : 935)
# [Epoch 936] Train - loss : 0.7690057 | Val - AUC : 0.968879 | Best AUC : 0.968879 (epoch : 936)
# [Epoch 937] Train - loss : 0.6616418 | Val - AUC : 0.9688783 | Best AUC : 0.968879 (epoch : 936)
# [Epoch 938] Train - loss : 0.7792366 | Val - AUC : 0.96888 | Best AUC : 0.96888 (epoch : 938)
# [Epoch 939] Train - loss : 0.7436255 | Val - AUC : 0.9688879 | Best AUC : 0.9688879 (epoch : 939)
# [Epoch 940] Train - loss : 0.6665348 | Val - AUC : 0.9688792 | Best AUC : 0.9688879 (epoch : 939)
# [Epoch 941] Train - loss : 0.7111174 | Val - AUC : 0.9688855 | Best AUC : 0.9688879 (epoch : 939)
# [Epoch 942] Train - loss : 0.8886284 | Val - AUC : 0.9688913 | Best AUC : 0.9688913 (epoch : 942)
# [Epoch 943] Train - loss : 0.5841228 | Val - AUC : 0.9688847 | Best AUC : 0.9688913 (epoch : 942)
# [Epoch 944] Train - loss : 0.6056814 | Val - AUC : 0.9688941 | Best AUC : 0.9688941 (epoch : 944)
# [Epoch 945] Train - loss : 0.6278513 | Val - AUC : 0.9688933 | Best AUC : 0.9688941 (epoch : 944)
# [Epoch 946] Train - loss : 0.6633009 | Val - AUC : 0.9688962 | Best AUC : 0.9688962 (epoch : 946)
# [Epoch 947] Train - loss : 0.795431 | Val - AUC : 0.968897 | Best AUC : 0.968897 (epoch : 947)
# [Epoch 948] Train - loss : 0.7469849 | Val - AUC : 0.9689072 | Best AUC : 0.9689072 (epoch : 948)
# [Epoch 949] Train - loss : 0.7645951 | Val - AUC : 0.9689041 | Best AUC : 0.9689072 (epoch : 948)
# [Epoch 950] Train - loss : 0.6666772 | Val - AUC : 0.9689007 | Best AUC : 0.9689072 (epoch : 948)
# [Epoch 951] Train - loss : 0.7077282 | Val - AUC : 0.9689046 | Best AUC : 0.9689072 (epoch : 948)
# [Epoch 952] Train - loss : 0.673666 | Val - AUC : 0.9689045 | Best AUC : 0.9689072 (epoch : 948)
# [Epoch 953] Train - loss : 0.6821064 | Val - AUC : 0.9689118 | Best AUC : 0.9689118 (epoch : 953)
# [Epoch 954] Train - loss : 0.5520817 | Val - AUC : 0.9689242 | Best AUC : 0.9689242 (epoch : 954)
# [Epoch 955] Train - loss : 0.6782705 | Val - AUC : 0.9689184 | Best AUC : 0.9689242 (epoch : 954)
# [Epoch 956] Train - loss : 0.8547055 | Val - AUC : 0.9689204 | Best AUC : 0.9689242 (epoch : 954)
# [Epoch 957] Train - loss : 0.5284978 | Val - AUC : 0.9689276 | Best AUC : 0.9689276 (epoch : 957)
# [Epoch 958] Train - loss : 0.7669061 | Val - AUC : 0.9689272 | Best AUC : 0.9689276 (epoch : 957)
# [Epoch 959] Train - loss : 0.5890451 | Val - AUC : 0.9689291 | Best AUC : 0.9689291 (epoch : 959)
# [Epoch 960] Train - loss : 0.7865897 | Val - AUC : 0.9689265 | Best AUC : 0.9689291 (epoch : 959)
# [Epoch 961] Train - loss : 0.6911431 | Val - AUC : 0.9689266 | Best AUC : 0.9689291 (epoch : 959)
# [Epoch 962] Train - loss : 0.6070659 | Val - AUC : 0.9689333 | Best AUC : 0.9689333 (epoch : 962)
# [Epoch 963] Train - loss : 0.7764728 | Val - AUC : 0.9689338 | Best AUC : 0.9689338 (epoch : 963)
# [Epoch 964] Train - loss : 0.7737359 | Val - AUC : 0.9689379 | Best AUC : 0.9689379 (epoch : 964)
# [Epoch 965] Train - loss : 0.6682127 | Val - AUC : 0.968943 | Best AUC : 0.968943 (epoch : 965)
# [Epoch 966] Train - loss : 0.7374538 | Val - AUC : 0.968942 | Best AUC : 0.968943 (epoch : 965)
# [Epoch 967] Train - loss : 0.6273 | Val - AUC : 0.9689439 | Best AUC : 0.9689439 (epoch : 967)
# [Epoch 968] Train - loss : 0.7114577 | Val - AUC : 0.9689382 | Best AUC : 0.9689439 (epoch : 967)
# [Epoch 969] Train - loss : 0.5703451 | Val - AUC : 0.9689464 | Best AUC : 0.9689464 (epoch : 969)
# [Epoch 970] Train - loss : 0.5386954 | Val - AUC : 0.9689478 | Best AUC : 0.9689478 (epoch : 970)
# [Epoch 971] Train - loss : 0.5930197 | Val - AUC : 0.9689524 | Best AUC : 0.9689524 (epoch : 971)
# [Epoch 972] Train - loss : 0.7260615 | Val - AUC : 0.9689528 | Best AUC : 0.9689528 (epoch : 972)
# [Epoch 973] Train - loss : 0.8276111 | Val - AUC : 0.9689544 | Best AUC : 0.9689544 (epoch : 973)
# [Epoch 974] Train - loss : 0.619974 | Val - AUC : 0.9689583 | Best AUC : 0.9689583 (epoch : 974)
# [Epoch 975] Train - loss : 0.6457795 | Val - AUC : 0.9689609 | Best AUC : 0.9689609 (epoch : 975)
# [Epoch 976] Train - loss : 0.5675525 | Val - AUC : 0.968962 | Best AUC : 0.968962 (epoch : 976)
# [Epoch 977] Train - loss : 0.6229861 | Val - AUC : 0.9689641 | Best AUC : 0.9689641 (epoch : 977)
# [Epoch 978] Train - loss : 0.5919978 | Val - AUC : 0.9689603 | Best AUC : 0.9689641 (epoch : 977)
# [Epoch 979] Train - loss : 0.5848171 | Val - AUC : 0.9689623 | Best AUC : 0.9689641 (epoch : 977)
# [Epoch 980] Train - loss : 0.735753 | Val - AUC : 0.9689576 | Best AUC : 0.9689641 (epoch : 977)
# [Epoch 981] Train - loss : 0.7282882 | Val - AUC : 0.9689635 | Best AUC : 0.9689641 (epoch : 977)
# [Epoch 982] Train - loss : 0.5365488 | Val - AUC : 0.9689601 | Best AUC : 0.9689641 (epoch : 977)
# [Epoch 983] Train - loss : 0.6673821 | Val - AUC : 0.968965 | Best AUC : 0.968965 (epoch : 983)
# [Epoch 984] Train - loss : 0.7167525 | Val - AUC : 0.9689573 | Best AUC : 0.968965 (epoch : 983)
# [Epoch 985] Train - loss : 0.6193586 | Val - AUC : 0.9689673 | Best AUC : 0.9689673 (epoch : 985)
# [Epoch 986] Train - loss : 0.6348459 | Val - AUC : 0.968962 | Best AUC : 0.9689673 (epoch : 985)
# [Epoch 987] Train - loss : 0.6456121 | Val - AUC : 0.9689614 | Best AUC : 0.9689673 (epoch : 985)
# [Epoch 988] Train - loss : 0.7782824 | Val - AUC : 0.9689734 | Best AUC : 0.9689734 (epoch : 988)
# [Epoch 989] Train - loss : 0.7087957 | Val - AUC : 0.9689714 | Best AUC : 0.9689734 (epoch : 988)
# [Epoch 990] Train - loss : 0.6730657 | Val - AUC : 0.968971 | Best AUC : 0.9689734 (epoch : 988)
# [Epoch 991] Train - loss : 0.5620201 | Val - AUC : 0.9689689 | Best AUC : 0.9689734 (epoch : 988)
# [Epoch 992] Train - loss : 0.7110484 | Val - AUC : 0.9689735 | Best AUC : 0.9689735 (epoch : 992)
# [Epoch 993] Train - loss : 0.5896585 | Val - AUC : 0.9689857 | Best AUC : 0.9689857 (epoch : 993)
# [Epoch 994] Train - loss : 0.6331264 | Val - AUC : 0.9689894 | Best AUC : 0.9689894 (epoch : 994)
# [Epoch 995] Train - loss : 0.7457891 | Val - AUC : 0.9689855 | Best AUC : 0.9689894 (epoch : 994)
# [Epoch 996] Train - loss : 0.6246932 | Val - AUC : 0.9689824 | Best AUC : 0.9689894 (epoch : 994)
# [Epoch 997] Train - loss : 0.7020268 | Val - AUC : 0.9689882 | Best AUC : 0.9689894 (epoch : 994)
# [Epoch 998] Train - loss : 0.5945956 | Val - AUC : 0.9689922 | Best AUC : 0.9689922 (epoch : 998)
# [Epoch 999] Train - loss : 0.6238796 | Val - AUC : 0.9689872 | Best AUC : 0.9689922 (epoch : 998)
# [2020-12-17 21:19:04,681][INFO][base.py:96] Succeed to load best model, device: 'cpu'

# %%
best_latent_data_list = result_dict["val_result_dict_list"][998]["latent_data_list"]
abnormal_label_list = [abnormal_label.item() for x, y, abnormal_label in dataset_factory.test_dataset]

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

pca = PCA(n_components=2)

pca.fit(best_latent_data_list)
pca_best_latent_data_list = pca.transform(best_latent_data_list)

pca_normal_latent_data_list = [
    pca_best_latent_data for pca_best_latent_data, abnormal_label in 
    zip(pca_best_latent_data_list, abnormal_label_list) if abnormal_label == 0
]
pca_abnormal_latent_data_list = [
    pca_best_latent_data for pca_best_latent_data, abnormal_label in
    zip(pca_best_latent_data_list, abnormal_label_list) if abnormal_label == 1
]

# %%
fig = plt.figure(figsize=(15, 15))

plt.scatter(
    x=list(map(lambda data: data[0], pca_normal_latent_data_list)),
    y=list(map(lambda data: data[1], pca_normal_latent_data_list)),
    label="Normal",
    color="blue",
    alpha=0.3
)
plt.scatter(
    x=list(map(lambda data: data[0], pca_abnormal_latent_data_list)),
    y=list(map(lambda data: data[1], pca_abnormal_latent_data_list)),
    label="Abormal",
    color="red",
    alpha=0.3
)

plt.xlim(-2, 2)
plt.ylim(-2, 2)

font_size = 15

plt.xlabel("PC1", fontsize=font_size)
plt.ylabel("PC2", fontsize=font_size)
plt.xticks(fontsize=font_size)
plt.yticks(fontsize=font_size)
plt.legend(fontsize=font_size)

plt.savefig("./plot/oesae_margin1_latent_2d.png")
plt.show()

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

pca = PCA(n_components=3)

pca.fit(best_latent_data_list)
pca_best_latent_data_list = pca.transform(best_latent_data_list)

pca_normal_latent_data_list = [
    pca_best_latent_data for pca_best_latent_data, abnormal_label in 
    zip(pca_best_latent_data_list, abnormal_label_list) if abnormal_label == 0
]
pca_abnormal_latent_data_list = [
    pca_best_latent_data for pca_best_latent_data, abnormal_label in
    zip(pca_best_latent_data_list, abnormal_label_list) if abnormal_label == 1
]

# %%
fig = plt.figure(figsize=(15, 15))
ax = fig.gca(projection='3d')

ax.scatter(
    list(map(lambda data: data[0], pca_normal_latent_data_list)),
    list(map(lambda data: data[1], pca_normal_latent_data_list)),
    list(map(lambda data: data[2], pca_normal_latent_data_list)),
    label="Normal",
    color="blue",
    alpha=0.3
)
ax.scatter(
    list(map(lambda data: data[0], pca_abnormal_latent_data_list)),
    list(map(lambda data: data[1], pca_abnormal_latent_data_list)),
    list(map(lambda data: data[2], pca_abnormal_latent_data_list)),
    label="Abormal",
    color="red",
    alpha=0.3
)

ax.set_xlim(-2, 2)
ax.set_ylim(-2, 2)
ax.set_zlim(-2, 2)

font_size = 12

ax.set_xlabel("PC1", fontsize=font_size)
ax.set_ylabel("PC2", fontsize=font_size)
ax.set_zlabel("PC3", fontsize=font_size)
ax.tick_params(axis="x", labelsize=font_size)
ax.tick_params(axis="y", labelsize=font_size)
ax.tick_params(axis="z", labelsize=font_size)
ax.legend(fontsize=font_size)

ax.view_init(elev=10., azim=240)

# ax.view_init(elev=10., azim=310)
plt.savefig("./plot/oesae_margin1_latent_3d.png")

plt.show()

# %%
best_latent_data_list = result_dict["val_result_dict_list"][3]["latent_data_list"]
abnormal_label_list = [abnormal_label.item() for x, y, abnormal_label in dataset_factory.test_dataset]

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

pca = PCA(n_components=2)

pca.fit(best_latent_data_list)
pca_best_latent_data_list = pca.transform(best_latent_data_list)

pca_normal_latent_data_list = [
    pca_best_latent_data for pca_best_latent_data, abnormal_label in 
    zip(pca_best_latent_data_list, abnormal_label_list) if abnormal_label == 0
]
pca_abnormal_latent_data_list = [
    pca_best_latent_data for pca_best_latent_data, abnormal_label in
    zip(pca_best_latent_data_list, abnormal_label_list) if abnormal_label == 1
]

# %%
fig = plt.figure(figsize=(15, 15))

plt.scatter(
    x=list(map(lambda data: data[0], pca_normal_latent_data_list)),
    y=list(map(lambda data: data[1], pca_normal_latent_data_list)),
    label="Normal",
    color="blue",
    alpha=0.3
)
plt.scatter(
    x=list(map(lambda data: data[0], pca_abnormal_latent_data_list)),
    y=list(map(lambda data: data[1], pca_abnormal_latent_data_list)),
    label="Abormal",
    color="red",
    alpha=0.3
)

plt.xlim(-2, 2)
plt.ylim(-2, 2)

font_size = 15

plt.xlabel("PC1", fontsize=font_size)
plt.ylabel("PC2", fontsize=font_size)
plt.xticks(fontsize=font_size)
plt.yticks(fontsize=font_size)
plt.legend(fontsize=font_size)

plt.savefig("./plot/oesae_margin1_latent_change_1.png")
plt.show()

# %%
best_latent_data_list = result_dict["val_result_dict_list"][75]["latent_data_list"]
abnormal_label_list = [abnormal_label.item() for x, y, abnormal_label in dataset_factory.test_dataset]

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

pca = PCA(n_components=2)

pca.fit(best_latent_data_list)
pca_best_latent_data_list = pca.transform(best_latent_data_list)

pca_normal_latent_data_list = [
    pca_best_latent_data for pca_best_latent_data, abnormal_label in 
    zip(pca_best_latent_data_list, abnormal_label_list) if abnormal_label == 0
]
pca_abnormal_latent_data_list = [
    pca_best_latent_data for pca_best_latent_data, abnormal_label in
    zip(pca_best_latent_data_list, abnormal_label_list) if abnormal_label == 1
]

# %%
fig = plt.figure(figsize=(15, 15))

plt.scatter(
    x=list(map(lambda data: data[0], pca_normal_latent_data_list)),
    y=list(map(lambda data: data[1], pca_normal_latent_data_list)),
    label="Normal",
    color="blue",
    alpha=0.3
)
plt.scatter(
    x=list(map(lambda data: data[0], pca_abnormal_latent_data_list)),
    y=list(map(lambda data: data[1], pca_abnormal_latent_data_list)),
    label="Abormal",
    color="red",
    alpha=0.3
)

plt.xlim(-2, 2)
plt.ylim(-2, 2)

font_size = 15

plt.xlabel("PC1", fontsize=font_size)
plt.ylabel("PC2", fontsize=font_size)
plt.xticks(fontsize=font_size)
plt.yticks(fontsize=font_size)
plt.legend(fontsize=font_size)

plt.savefig("./plot/oesae_margin1_latent_change_2.png")
plt.show()

# %%
best_latent_data_list = result_dict["val_result_dict_list"][998]["latent_data_list"]
abnormal_label_list = [abnormal_label.item() for x, y, abnormal_label in dataset_factory.test_dataset]

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

pca = PCA(n_components=2)

pca.fit(best_latent_data_list)
pca_best_latent_data_list = pca.transform(best_latent_data_list)

pca_normal_latent_data_list = [
    pca_best_latent_data for pca_best_latent_data, abnormal_label in 
    zip(pca_best_latent_data_list, abnormal_label_list) if abnormal_label == 0
]
pca_abnormal_latent_data_list = [
    pca_best_latent_data for pca_best_latent_data, abnormal_label in
    zip(pca_best_latent_data_list, abnormal_label_list) if abnormal_label == 1
]

# %%
fig = plt.figure(figsize=(15, 15))

plt.scatter(
    x=list(map(lambda data: data[0], pca_normal_latent_data_list)),
    y=list(map(lambda data: data[1], pca_normal_latent_data_list)),
    label="Normal",
    color="blue",
    alpha=0.3
)
plt.scatter(
    x=list(map(lambda data: data[0], pca_abnormal_latent_data_list)),
    y=list(map(lambda data: data[1], pca_abnormal_latent_data_list)),
    label="Abormal",
    color="red",
    alpha=0.3
)

plt.xlim(-2, 2)
plt.ylim(-2, 2)

font_size = 15

plt.xlabel("PC1", fontsize=font_size)
plt.ylabel("PC2", fontsize=font_size)
plt.xticks(fontsize=font_size)
plt.yticks(fontsize=font_size)
plt.legend(fontsize=font_size)

plt.savefig("./plot/oesae_margin1_latent_change_3.png")
plt.show()

# %%
best_latent_data_list = result_dict["val_result_dict_list"][-1]["latent_data_list"]
abnormal_label_list = [abnormal_label.item() for x, y, abnormal_label in dataset_factory.test_dataset]

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

pca = PCA(n_components=2)

pca.fit(best_latent_data_list)
pca_best_latent_data_list = pca.transform(best_latent_data_list)

pca_normal_latent_data_list = [
    pca_best_latent_data for pca_best_latent_data, abnormal_label in 
    zip(pca_best_latent_data_list, abnormal_label_list) if abnormal_label == 0
]
pca_abnormal_latent_data_list = [
    pca_best_latent_data for pca_best_latent_data, abnormal_label in
    zip(pca_best_latent_data_list, abnormal_label_list) if abnormal_label == 1
]

# %%
fig = plt.figure(figsize=(15, 15))

plt.scatter(
    x=list(map(lambda data: data[0], pca_normal_latent_data_list)),
    y=list(map(lambda data: data[1], pca_normal_latent_data_list)),
    label="Normal",
    color="blue",
    alpha=0.3
)
plt.scatter(
    x=list(map(lambda data: data[0], pca_abnormal_latent_data_list)),
    y=list(map(lambda data: data[1], pca_abnormal_latent_data_list)),
    label="Abormal",
    color="red",
    alpha=0.3
)
plt.legend()

plt.show()

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

pca = PCA(n_components=3)

pca.fit(best_latent_data_list)
pca_best_latent_data_list = pca.transform(best_latent_data_list)

pca_normal_latent_data_list = [
    pca_best_latent_data for pca_best_latent_data, abnormal_label in 
    zip(pca_best_latent_data_list, abnormal_label_list) if abnormal_label == 0
]
pca_abnormal_latent_data_list = [
    pca_best_latent_data for pca_best_latent_data, abnormal_label in
    zip(pca_best_latent_data_list, abnormal_label_list) if abnormal_label == 1
]

# %%
fig = plt.figure(figsize=(15, 15))
ax = fig.gca(projection='3d')

ax.scatter(
    list(map(lambda data: data[0], pca_normal_latent_data_list)),
    list(map(lambda data: data[1], pca_normal_latent_data_list)),
    list(map(lambda data: data[2], pca_normal_latent_data_list)),
    label="Normal",
    color="blue",
    alpha=0.3
)
ax.scatter(
    list(map(lambda data: data[0], pca_abnormal_latent_data_list)),
    list(map(lambda data: data[1], pca_abnormal_latent_data_list)),
    list(map(lambda data: data[2], pca_abnormal_latent_data_list)),
    label="Abormal",
    color="red",
    alpha=0.3
)


ax.set_xlim(-2, 2)
ax.set_ylim(-2, 2)
ax.set_zlim(-2, 2)

ax.view_init(elev=10., azim=60)
# ax.view_init(elev=10., azim=40)
ax.legend()

plt.show()
