# %%
import os
import pathlib
import sys

default_dir_path = str(pathlib.Path(os.getcwd()).parent.absolute())

sys.path.append(default_dir_path)

from properties import ApplicationProperties
# Out:
# [2020-12-17 15:35:50,560][INFO][properties.py:22] Complete to apply the random seed, RANDOM_SEED : 777

# %%
from torch import optim
from torch.nn import functional as F
import torch

from dataset.factory import DatasetFactory
from dataset.nsl_kdd_dataset import NSLKDDDataFrameFactory, NSLKDDDataset
from domain.criterion import Criterion
from domain.hyperparameters import Hyperparameters
from domain.metadata import ModelFileMetadata
from logger import logger
from model.factory import ModelFactory
from trainer.base import TrainerBase
from trainer.factory import TrainerFactory

# %%
from sklearn import preprocessing
from sklearn.metrics import roc_curve, auc
from sklearn.model_selection import train_test_split
from torch import nn, optim
from torch.utils.data import Dataset, DataLoader
import numpy as np
import pandas as pd
import tqdm.notebook as tqdm

# %%
device = "cpu"
data_name = "nsl_kdd_outlier"
model_name = "oesae_margin001"
n_epoch = 1000

# %%
dataset_factory = DatasetFactory.create(data_name=data_name)
# Out:
# [2020-12-17 15:35:58,091][INFO][nsl_kdd_dataset.py:98] Success to load dataset dataframe : train
# [2020-12-17 15:35:58,274][INFO][nsl_kdd_dataset.py:98] Success to load dataset dataframe : test
# [2020-12-17 15:35:58,765][INFO][nsl_kdd_dataset.py:110] Success to load dataset dataframe : entire
# [2020-12-17 15:36:02,272][INFO][nsl_kdd_dataset.py:164] Entire data size : 148517
# [2020-12-17 15:36:02,276][INFO][nsl_kdd_dataset.py:165] Normal data size : 77054
# [2020-12-17 15:36:02,278][INFO][nsl_kdd_dataset.py:166] Abnormal data size : 7146
# [2020-12-17 15:36:02,281][INFO][nsl_kdd_dataset.py:167] Outlier data size : 7146
# [2020-12-17 15:36:02,283][INFO][nsl_kdd_dataset.py:168] Normal test data size : 7146
# [2020-12-17 15:36:02,285][INFO][nsl_kdd_dataset.py:169] Training data size : 69908
# [2020-12-17 15:36:02,286][INFO][nsl_kdd_dataset.py:170] Test data size : 14292
# [2020-12-17 15:36:04,196][INFO][factory.py:109] Success to fit data with scaling
# [2020-12-17 15:36:05,190][INFO][factory.py:118] Success to transform data with scaling
# [2020-12-17 15:36:05,191][INFO][factory.py:153] Data selected : 'nsl_kdd_outlier'

# %%
train_dataloader, outlier_dataloader = dataset_factory.train_dataloader
val_dataloader = dataset_factory.val_dataloader

# %%
class AE(nn.Module):
    
    def __init__(self, input_size):  # 117
        super(AE, self).__init__()
        self.encoder_1 = nn.Sequential(
            nn.Linear(in_features=input_size, out_features=64, bias=True),
            nn.Tanh(),
            nn.Linear(in_features=64, out_features=32, bias=True),
            nn.Tanh(),
            nn.Linear(in_features=32, out_features=16, bias=True),
            nn.Tanh()
        )
        self.decoder_1 = nn.Sequential(
            nn.Linear(in_features=16, out_features=32, bias=True),
            nn.Tanh(),
            nn.Linear(in_features=32, out_features=64, bias=True),
            nn.Tanh(),
            nn.Linear(in_features=64, out_features=input_size, bias=True),
            nn.Tanh()
        )
        
        self.he_init_weight()
        
    def forward(self, x):
        z = self.encoder_1(x)
        x_hat = self.decoder_1(z)
        return x_hat, z
    
    def he_init_weight(self):
        for module in self.modules():
            if isinstance(module, nn.Conv2d):
                nn.init.kaiming_normal_(module.weight.data)
            elif isinstance(module, nn.Linear):
                nn.init.kaiming_normal_(module.weight.data)
            elif isinstance(module, nn.ConvTranspose2d):
                nn.init.kaiming_normal_(module.weight.data)

# %%
from copy import deepcopy
import pickle
import time

from sklearn.metrics import roc_curve, auc
import torch

from domain.criterion import Criterion
from trainer.base import TrainerBase

time.time()


class OESAETrainer(TrainerBase):

    def __init__(self, model, model_file_metadata, train_loader, outlier_loader, val_loader, test_loader, hyperparameters,
                 tqdm_env='script'):
        super(OESAETrainer, self).__init__(model, model_file_metadata, train_loader, val_loader, test_loader,
                                        hyperparameters, tqdm_env)
        self.outlier_loader = outlier_loader

    def train(self):
        self.model.train()

        train_result_dict_list = list()
        val_result_dict_list = list()

        best_loss = 999999
        best_auc = 0
        best_loss_epoch = 0
        best_auc_epoch = 0

        # Set hyperparameters
        optimizer_cls = self.hyperparameters.optimizer_cls
        lr = self.hyperparameters.lr
        weight_decay = self.hyperparameters.weight_decay
        n_epoch = self.hyperparameters.n_epoch
        train_criterion = self.hyperparameters.train_criterion
        val_criterion = self.hyperparameters.val_criterion
        lambda_ = self.hyperparameters.lambda_
        margin = self.hyperparameters.margin
        device = self.hyperparameters.device

        optimizer = optimizer_cls(self.model.parameters(), lr=lr, weight_decay=weight_decay)

        for epoch in self.tqdm.tqdm(range(n_epoch)):
            total_loss = 0
            n_batch = 0

            for i, ((data_batch, label_batch, abnormal_label_batch), (outlier_data_batch, outlier_label_batch, outlier_abnormal_label_batch)) in enumerate(zip(self.train_loader, self.outlier_loader)):
                entire_data_batch = torch.cat([data_batch, outlier_data_batch], dim=0)
                entire_data_batch = entire_data_batch.to(device)

                # Optimization
                optimizer.zero_grad()
                pred_data_batch, latent_data_batch = self.model(entire_data_batch)

                in_pred_data_batch = pred_data_batch[:len(data_batch)]
                out_pred_data_batch = pred_data_batch[len(data_batch):]

                in_latent_data_batch = latent_data_batch[:len(data_batch)]
                out_latent_data_batch = latent_data_batch[len(data_batch):]

                if in_latent_data_batch.shape != out_latent_data_batch.shape:
                    continue

                mse_loss = val_criterion(data_batch, in_pred_data_batch, in_latent_data_batch, lambda_)
                triple_margin_loss = train_criterion(
                    anchor=torch.zeros(size=in_latent_data_batch.shape),
                    positive=in_latent_data_batch,
                    negative=out_latent_data_batch,
                    margin=margin
                )
                loss = mse_loss + triple_margin_loss

                loss.backward()
                optimizer.step()

                total_loss += loss.item()
                n_batch += 1

            current_loss = total_loss / n_batch

            train_result_dict = dict(
                loss=current_loss
            )
            val_result_dict = self.validate()

            # Early stopping
            if val_result_dict['loss'] < best_loss:
                best_loss = val_result_dict['loss']
                best_loss_epoch = epoch
                # self.best_model_state_dict = deepcopy(self.model.state_dict())

            if best_auc < val_result_dict['auc']:
                best_auc = val_result_dict['auc']
                best_auc_epoch = epoch
                self.best_model = deepcopy(self.model.state_dict())

            # Print
            print(
                f"[Epoch {epoch}] "
                f"Train - loss : {round(train_result_dict['loss'], 7)} | "
                f"Val - AUC : {round(val_result_dict['auc'], 7)} | "
                f"Best AUC : {round(best_auc, 7)} (epoch : {best_auc_epoch})"
            )

            # Save Model & Record dictW
            record_dict = dict(
                train_result_dict=train_result_dict,
                val_result_dict=val_result_dict
            )

            self.save_model(epoch=epoch)
            self.save_record(record=record_dict, epoch=epoch)

            train_result_dict_list.append(train_result_dict)
            val_result_dict_list.append(val_result_dict)

        # Save last result
        entire_record_dict = dict(
            train_result_dict_list=train_result_dict_list,
            val_result_dict_list=val_result_dict_list
        )
        torch.save(self.best_model, self.model_file_metadata.get_best_model_file_path())

        # Save entire_record_dict
        with open(self.model_file_metadata.get_entire_record_file_path(), "wb") as f:
            pickle.dump(entire_record_dict, f, protocol=pickle.HIGHEST_PROTOCOL)

        # Load best model
        self.load_best_model()

        return entire_record_dict

    def validate(self):
        self.model.eval()

        total_loss = 0
        n_batch = 0

        latent_data_list = list()
        reconstructino_error_list = list()
        abnormal_label_list = list()

        # Set hyperparameters
        device = self.hyperparameters.device
        val_criterion = self.hyperparameters.val_criterion
        lambda_ = self.hyperparameters.lambda_

        for i, (data_batch, label_batch, abnormal_label_batch) in enumerate(self.val_loader):
            data_batch = data_batch.to(device)
            abnormal_label_batch = abnormal_label_batch.to(device)

            with torch.no_grad():
                pred_data_batch, latent_data_batch = self.model(data_batch)
                loss = val_criterion(data_batch, pred_data_batch, latent_data_batch, lambda_).item()
                reconstruction_error_batch = Criterion.reconstruction_error(x=data_batch, x_hat=pred_data_batch)

            latent_data_list.append(latent_data_batch)
            reconstructino_error_list.append(reconstruction_error_batch)
            abnormal_label_list.append(abnormal_label_batch)

            total_loss += loss
            n_batch += 1

        latent_data_list = torch.cat(latent_data_list).cpu().numpy()
        reconstruction_error_list = torch.cat(reconstructino_error_list).cpu().numpy()
        abnormal_label_list = torch.cat(abnormal_label_list).cpu().numpy()

        fpr, tpr, thresholds = roc_curve(abnormal_label_list, reconstruction_error_list)
        auc_value = auc(fpr, tpr)

        current_loss = total_loss / n_batch

        return dict(loss=current_loss, auc=auc_value, latent_data_list=latent_data_list)

# %%
ae_model = AE(input_size=118)

# %%
ae_model.to(device)
# Out:
# AE(
#   (encoder_1): Sequential(
#     (0): Linear(in_features=118, out_features=64, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=64, out_features=32, bias=True)
#     (3): Tanh()
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): Tanh()
#   )
#   (decoder_1): Sequential(
#     (0): Linear(in_features=16, out_features=32, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=32, out_features=64, bias=True)
#     (3): Tanh()
#     (4): Linear(in_features=64, out_features=118, bias=True)
#     (5): Tanh()
#   )
# )

# %%
trainer = OESAETrainer(
    model=ae_model,
    model_file_metadata=ModelFileMetadata(model_name=model_name),
    train_loader=train_dataloader,
    val_loader=val_dataloader,
    outlier_loader=outlier_dataloader,
    test_loader=dataset_factory.test_dataloader,
    hyperparameters=Hyperparameters(
        optimizer_cls=optim.Adadelta,
        train_criterion=Criterion.triple_margin_loss,
        val_criterion=Criterion.sae_loss,
        lambda_=10,
        margin=0.01,
        n_epoch=n_epoch,
        lr=1e-3,
        weight_decay=0,
        device=device
    ),
    tqdm_env="jupyter"
)
# Out:
# [2020-12-17 15:36:05,734][INFO][base.py:40] Model set to 'cpu'

# %%
# Adadelta (tanh, lambda 10)
result_dict = trainer.train()
# Out:
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# [Epoch 0] Train - loss : 2.8472201 | Val - AUC : 0.9646262 | Best AUC : 0.9646262 (epoch : 0)
# [Epoch 1] Train - loss : 2.7360142 | Val - AUC : 0.9647952 | Best AUC : 0.9647952 (epoch : 1)
# [Epoch 2] Train - loss : 2.7055426 | Val - AUC : 0.9648355 | Best AUC : 0.9648355 (epoch : 2)
# [Epoch 3] Train - loss : 2.6133313 | Val - AUC : 0.9648161 | Best AUC : 0.9648355 (epoch : 2)
# [Epoch 4] Train - loss : 2.6411167 | Val - AUC : 0.9647953 | Best AUC : 0.9648355 (epoch : 2)
# [Epoch 5] Train - loss : 2.3434568 | Val - AUC : 0.9647808 | Best AUC : 0.9648355 (epoch : 2)
# [Epoch 6] Train - loss : 2.3258682 | Val - AUC : 0.9647969 | Best AUC : 0.9648355 (epoch : 2)
# [Epoch 7] Train - loss : 2.3299471 | Val - AUC : 0.9648437 | Best AUC : 0.9648437 (epoch : 7)
# [Epoch 8] Train - loss : 2.0962317 | Val - AUC : 0.9648966 | Best AUC : 0.9648966 (epoch : 8)
# [Epoch 9] Train - loss : 2.0124451 | Val - AUC : 0.9649406 | Best AUC : 0.9649406 (epoch : 9)
# [Epoch 10] Train - loss : 2.2163765 | Val - AUC : 0.9649891 | Best AUC : 0.9649891 (epoch : 10)
# [Epoch 11] Train - loss : 2.0596945 | Val - AUC : 0.9650396 | Best AUC : 0.9650396 (epoch : 11)
# [Epoch 12] Train - loss : 1.9519122 | Val - AUC : 0.9651057 | Best AUC : 0.9651057 (epoch : 12)
# [Epoch 13] Train - loss : 1.9549335 | Val - AUC : 0.9651463 | Best AUC : 0.9651463 (epoch : 13)
# [Epoch 14] Train - loss : 1.8163778 | Val - AUC : 0.9651875 | Best AUC : 0.9651875 (epoch : 14)
# [Epoch 15] Train - loss : 1.8025111 | Val - AUC : 0.9652188 | Best AUC : 0.9652188 (epoch : 15)
# [Epoch 16] Train - loss : 1.7850414 | Val - AUC : 0.9652571 | Best AUC : 0.9652571 (epoch : 16)
# [Epoch 17] Train - loss : 1.7813189 | Val - AUC : 0.9652877 | Best AUC : 0.9652877 (epoch : 17)
# [Epoch 18] Train - loss : 1.8368566 | Val - AUC : 0.9653187 | Best AUC : 0.9653187 (epoch : 18)
# [Epoch 19] Train - loss : 1.6693071 | Val - AUC : 0.9653454 | Best AUC : 0.9653454 (epoch : 19)
# [Epoch 20] Train - loss : 1.6971599 | Val - AUC : 0.9653782 | Best AUC : 0.9653782 (epoch : 20)
# [Epoch 21] Train - loss : 1.6596655 | Val - AUC : 0.9654018 | Best AUC : 0.9654018 (epoch : 21)
# [Epoch 22] Train - loss : 1.5824347 | Val - AUC : 0.9654334 | Best AUC : 0.9654334 (epoch : 22)
# [Epoch 23] Train - loss : 1.7623541 | Val - AUC : 0.9654532 | Best AUC : 0.9654532 (epoch : 23)
# [Epoch 24] Train - loss : 1.8151455 | Val - AUC : 0.9654733 | Best AUC : 0.9654733 (epoch : 24)
# [Epoch 25] Train - loss : 1.4866922 | Val - AUC : 0.9655073 | Best AUC : 0.9655073 (epoch : 25)
# [Epoch 26] Train - loss : 1.5097302 | Val - AUC : 0.9655358 | Best AUC : 0.9655358 (epoch : 26)
# [Epoch 27] Train - loss : 1.6169805 | Val - AUC : 0.9655626 | Best AUC : 0.9655626 (epoch : 27)
# [Epoch 28] Train - loss : 1.659119 | Val - AUC : 0.9655939 | Best AUC : 0.9655939 (epoch : 28)
# [Epoch 29] Train - loss : 1.6026039 | Val - AUC : 0.9656182 | Best AUC : 0.9656182 (epoch : 29)
# [Epoch 30] Train - loss : 1.589772 | Val - AUC : 0.9656434 | Best AUC : 0.9656434 (epoch : 30)
# [Epoch 31] Train - loss : 1.4964966 | Val - AUC : 0.9656754 | Best AUC : 0.9656754 (epoch : 31)
# [Epoch 32] Train - loss : 1.3668222 | Val - AUC : 0.9656929 | Best AUC : 0.9656929 (epoch : 32)
# [Epoch 33] Train - loss : 1.4986948 | Val - AUC : 0.9657205 | Best AUC : 0.9657205 (epoch : 33)
# [Epoch 34] Train - loss : 1.5188242 | Val - AUC : 0.9657486 | Best AUC : 0.9657486 (epoch : 34)
# [Epoch 35] Train - loss : 1.2873136 | Val - AUC : 0.9657636 | Best AUC : 0.9657636 (epoch : 35)
# [Epoch 36] Train - loss : 1.4837792 | Val - AUC : 0.9657898 | Best AUC : 0.9657898 (epoch : 36)
# [Epoch 37] Train - loss : 1.4349566 | Val - AUC : 0.9658111 | Best AUC : 0.9658111 (epoch : 37)
# [Epoch 38] Train - loss : 1.3844597 | Val - AUC : 0.9658273 | Best AUC : 0.9658273 (epoch : 38)
# [Epoch 39] Train - loss : 1.5180241 | Val - AUC : 0.9658505 | Best AUC : 0.9658505 (epoch : 39)
# [Epoch 40] Train - loss : 1.2653072 | Val - AUC : 0.9658681 | Best AUC : 0.9658681 (epoch : 40)
# [Epoch 41] Train - loss : 1.2822611 | Val - AUC : 0.9658862 | Best AUC : 0.9658862 (epoch : 41)
# [Epoch 42] Train - loss : 1.4715774 | Val - AUC : 0.9658984 | Best AUC : 0.9658984 (epoch : 42)
# [Epoch 43] Train - loss : 1.3388344 | Val - AUC : 0.9659161 | Best AUC : 0.9659161 (epoch : 43)
# [Epoch 44] Train - loss : 1.315322 | Val - AUC : 0.9659408 | Best AUC : 0.9659408 (epoch : 44)
# [Epoch 45] Train - loss : 1.2799708 | Val - AUC : 0.9659645 | Best AUC : 0.9659645 (epoch : 45)
# [Epoch 46] Train - loss : 1.3780215 | Val - AUC : 0.9659784 | Best AUC : 0.9659784 (epoch : 46)
# [Epoch 47] Train - loss : 1.3933142 | Val - AUC : 0.9659919 | Best AUC : 0.9659919 (epoch : 47)
# [Epoch 48] Train - loss : 1.5716067 | Val - AUC : 0.9660112 | Best AUC : 0.9660112 (epoch : 48)
# [Epoch 49] Train - loss : 1.2591342 | Val - AUC : 0.9660316 | Best AUC : 0.9660316 (epoch : 49)
# [Epoch 50] Train - loss : 1.3440618 | Val - AUC : 0.9660467 | Best AUC : 0.9660467 (epoch : 50)
# [Epoch 51] Train - loss : 1.3452377 | Val - AUC : 0.9660612 | Best AUC : 0.9660612 (epoch : 51)
# [Epoch 52] Train - loss : 1.2726629 | Val - AUC : 0.9660759 | Best AUC : 0.9660759 (epoch : 52)
# [Epoch 53] Train - loss : 1.3697325 | Val - AUC : 0.9660853 | Best AUC : 0.9660853 (epoch : 53)
# [Epoch 54] Train - loss : 1.4136162 | Val - AUC : 0.9661063 | Best AUC : 0.9661063 (epoch : 54)
# [Epoch 55] Train - loss : 1.1957929 | Val - AUC : 0.9661189 | Best AUC : 0.9661189 (epoch : 55)
# [Epoch 56] Train - loss : 1.1042462 | Val - AUC : 0.9661335 | Best AUC : 0.9661335 (epoch : 56)
# [Epoch 57] Train - loss : 1.2336032 | Val - AUC : 0.9661498 | Best AUC : 0.9661498 (epoch : 57)
# [Epoch 58] Train - loss : 1.2410472 | Val - AUC : 0.9661597 | Best AUC : 0.9661597 (epoch : 58)
# [Epoch 59] Train - loss : 1.1881873 | Val - AUC : 0.9661762 | Best AUC : 0.9661762 (epoch : 59)
# [Epoch 60] Train - loss : 1.1376641 | Val - AUC : 0.9661855 | Best AUC : 0.9661855 (epoch : 60)
# [Epoch 61] Train - loss : 1.1793998 | Val - AUC : 0.9661977 | Best AUC : 0.9661977 (epoch : 61)
# [Epoch 62] Train - loss : 1.2299826 | Val - AUC : 0.9662111 | Best AUC : 0.9662111 (epoch : 62)
# [Epoch 63] Train - loss : 1.2476692 | Val - AUC : 0.9662155 | Best AUC : 0.9662155 (epoch : 63)
# [Epoch 64] Train - loss : 1.2422677 | Val - AUC : 0.9662336 | Best AUC : 0.9662336 (epoch : 64)
# [Epoch 65] Train - loss : 1.1961215 | Val - AUC : 0.9662396 | Best AUC : 0.9662396 (epoch : 65)
# [Epoch 66] Train - loss : 1.1014391 | Val - AUC : 0.9662564 | Best AUC : 0.9662564 (epoch : 66)
# [Epoch 67] Train - loss : 1.2578522 | Val - AUC : 0.9662598 | Best AUC : 0.9662598 (epoch : 67)
# [Epoch 68] Train - loss : 1.1383194 | Val - AUC : 0.96627 | Best AUC : 0.96627 (epoch : 68)
# [Epoch 69] Train - loss : 1.099128 | Val - AUC : 0.9662762 | Best AUC : 0.9662762 (epoch : 69)
# [Epoch 70] Train - loss : 1.1596355 | Val - AUC : 0.966281 | Best AUC : 0.966281 (epoch : 70)
# [Epoch 71] Train - loss : 1.2289925 | Val - AUC : 0.9662962 | Best AUC : 0.9662962 (epoch : 71)
# [Epoch 72] Train - loss : 0.9975068 | Val - AUC : 0.9663045 | Best AUC : 0.9663045 (epoch : 72)
# [Epoch 73] Train - loss : 1.1720625 | Val - AUC : 0.9663143 | Best AUC : 0.9663143 (epoch : 73)
# [Epoch 74] Train - loss : 1.0845216 | Val - AUC : 0.9663214 | Best AUC : 0.9663214 (epoch : 74)
# [Epoch 75] Train - loss : 1.2969113 | Val - AUC : 0.9663265 | Best AUC : 0.9663265 (epoch : 75)
# [Epoch 76] Train - loss : 1.1971919 | Val - AUC : 0.9663341 | Best AUC : 0.9663341 (epoch : 76)
# [Epoch 77] Train - loss : 1.2613011 | Val - AUC : 0.966339 | Best AUC : 0.966339 (epoch : 77)
# [Epoch 78] Train - loss : 1.2084034 | Val - AUC : 0.9663439 | Best AUC : 0.9663439 (epoch : 78)
# [Epoch 79] Train - loss : 1.144611 | Val - AUC : 0.9663524 | Best AUC : 0.9663524 (epoch : 79)
# [Epoch 80] Train - loss : 1.1438054 | Val - AUC : 0.9663547 | Best AUC : 0.9663547 (epoch : 80)
# [Epoch 81] Train - loss : 1.2304249 | Val - AUC : 0.9663648 | Best AUC : 0.9663648 (epoch : 81)
# [Epoch 82] Train - loss : 1.1672214 | Val - AUC : 0.9663739 | Best AUC : 0.9663739 (epoch : 82)
# [Epoch 83] Train - loss : 1.0402481 | Val - AUC : 0.9663792 | Best AUC : 0.9663792 (epoch : 83)
# [Epoch 84] Train - loss : 1.2154174 | Val - AUC : 0.9663832 | Best AUC : 0.9663832 (epoch : 84)
# [Epoch 85] Train - loss : 0.9937724 | Val - AUC : 0.9663846 | Best AUC : 0.9663846 (epoch : 85)
# [Epoch 86] Train - loss : 1.2693271 | Val - AUC : 0.9663909 | Best AUC : 0.9663909 (epoch : 86)
# [Epoch 87] Train - loss : 1.2362033 | Val - AUC : 0.9663948 | Best AUC : 0.9663948 (epoch : 87)
# [Epoch 88] Train - loss : 1.1298051 | Val - AUC : 0.9663979 | Best AUC : 0.9663979 (epoch : 88)
# [Epoch 89] Train - loss : 1.0427334 | Val - AUC : 0.9664023 | Best AUC : 0.9664023 (epoch : 89)
# [Epoch 90] Train - loss : 1.181445 | Val - AUC : 0.9664045 | Best AUC : 0.9664045 (epoch : 90)
# [Epoch 91] Train - loss : 1.1241183 | Val - AUC : 0.9664049 | Best AUC : 0.9664049 (epoch : 91)
# [Epoch 92] Train - loss : 1.1670041 | Val - AUC : 0.96641 | Best AUC : 0.96641 (epoch : 92)
# [Epoch 93] Train - loss : 1.1140809 | Val - AUC : 0.9664064 | Best AUC : 0.96641 (epoch : 92)
# [Epoch 94] Train - loss : 1.1027196 | Val - AUC : 0.966417 | Best AUC : 0.966417 (epoch : 94)
# [Epoch 95] Train - loss : 1.0781502 | Val - AUC : 0.9664239 | Best AUC : 0.9664239 (epoch : 95)
# [Epoch 96] Train - loss : 0.9552856 | Val - AUC : 0.9664237 | Best AUC : 0.9664239 (epoch : 95)
# [Epoch 97] Train - loss : 0.9908289 | Val - AUC : 0.9664227 | Best AUC : 0.9664239 (epoch : 95)
# [Epoch 98] Train - loss : 0.9740991 | Val - AUC : 0.9664222 | Best AUC : 0.9664239 (epoch : 95)
# [Epoch 99] Train - loss : 0.9817861 | Val - AUC : 0.9664259 | Best AUC : 0.9664259 (epoch : 99)
# [Epoch 100] Train - loss : 0.8857101 | Val - AUC : 0.9664244 | Best AUC : 0.9664259 (epoch : 99)
# [Epoch 101] Train - loss : 1.3526808 | Val - AUC : 0.9664258 | Best AUC : 0.9664259 (epoch : 99)
# [Epoch 102] Train - loss : 0.9820508 | Val - AUC : 0.9664332 | Best AUC : 0.9664332 (epoch : 102)
# [Epoch 103] Train - loss : 0.992556 | Val - AUC : 0.9664361 | Best AUC : 0.9664361 (epoch : 103)
# [Epoch 104] Train - loss : 0.9608419 | Val - AUC : 0.9664384 | Best AUC : 0.9664384 (epoch : 104)
# [Epoch 105] Train - loss : 0.9778244 | Val - AUC : 0.9664404 | Best AUC : 0.9664404 (epoch : 105)
# [Epoch 106] Train - loss : 0.9887847 | Val - AUC : 0.9664465 | Best AUC : 0.9664465 (epoch : 106)
# [Epoch 107] Train - loss : 0.8613536 | Val - AUC : 0.9664418 | Best AUC : 0.9664465 (epoch : 106)
# [Epoch 108] Train - loss : 1.0728322 | Val - AUC : 0.9664468 | Best AUC : 0.9664468 (epoch : 108)
# [Epoch 109] Train - loss : 0.8578214 | Val - AUC : 0.9664412 | Best AUC : 0.9664468 (epoch : 108)
# [Epoch 110] Train - loss : 0.9368771 | Val - AUC : 0.9664437 | Best AUC : 0.9664468 (epoch : 108)
# [Epoch 111] Train - loss : 1.068932 | Val - AUC : 0.9664462 | Best AUC : 0.9664468 (epoch : 108)
# [Epoch 112] Train - loss : 1.0079107 | Val - AUC : 0.9664396 | Best AUC : 0.9664468 (epoch : 108)
# [Epoch 113] Train - loss : 0.9368014 | Val - AUC : 0.9664391 | Best AUC : 0.9664468 (epoch : 108)
# [Epoch 114] Train - loss : 0.9231012 | Val - AUC : 0.9664443 | Best AUC : 0.9664468 (epoch : 108)
# [Epoch 115] Train - loss : 0.9290556 | Val - AUC : 0.9664401 | Best AUC : 0.9664468 (epoch : 108)
# [Epoch 116] Train - loss : 1.1228444 | Val - AUC : 0.9664471 | Best AUC : 0.9664471 (epoch : 116)
# [Epoch 117] Train - loss : 0.9743362 | Val - AUC : 0.9664478 | Best AUC : 0.9664478 (epoch : 117)
# [Epoch 118] Train - loss : 1.0184372 | Val - AUC : 0.9664443 | Best AUC : 0.9664478 (epoch : 117)
# [Epoch 119] Train - loss : 0.9863104 | Val - AUC : 0.9664447 | Best AUC : 0.9664478 (epoch : 117)
# [Epoch 120] Train - loss : 0.8309869 | Val - AUC : 0.9664428 | Best AUC : 0.9664478 (epoch : 117)
# [Epoch 121] Train - loss : 0.9582965 | Val - AUC : 0.9664411 | Best AUC : 0.9664478 (epoch : 117)
# [Epoch 122] Train - loss : 0.9380443 | Val - AUC : 0.9664443 | Best AUC : 0.9664478 (epoch : 117)
# [Epoch 123] Train - loss : 0.9450237 | Val - AUC : 0.9664404 | Best AUC : 0.9664478 (epoch : 117)
# [Epoch 124] Train - loss : 0.9804203 | Val - AUC : 0.9664409 | Best AUC : 0.9664478 (epoch : 117)
# [Epoch 125] Train - loss : 0.9141097 | Val - AUC : 0.9664419 | Best AUC : 0.9664478 (epoch : 117)
# [Epoch 126] Train - loss : 1.0406702 | Val - AUC : 0.9664466 | Best AUC : 0.9664478 (epoch : 117)
# [Epoch 127] Train - loss : 0.8248109 | Val - AUC : 0.966453 | Best AUC : 0.966453 (epoch : 127)
# [Epoch 128] Train - loss : 0.8538346 | Val - AUC : 0.966453 | Best AUC : 0.966453 (epoch : 128)
# [Epoch 129] Train - loss : 0.9590714 | Val - AUC : 0.9664503 | Best AUC : 0.966453 (epoch : 128)
# [Epoch 130] Train - loss : 1.0574417 | Val - AUC : 0.9664511 | Best AUC : 0.966453 (epoch : 128)
# [Epoch 131] Train - loss : 1.0112705 | Val - AUC : 0.9664534 | Best AUC : 0.9664534 (epoch : 131)
# [Epoch 132] Train - loss : 0.8408251 | Val - AUC : 0.9664588 | Best AUC : 0.9664588 (epoch : 132)
# [Epoch 133] Train - loss : 0.9548504 | Val - AUC : 0.9664603 | Best AUC : 0.9664603 (epoch : 133)
# [Epoch 134] Train - loss : 0.9499026 | Val - AUC : 0.9664604 | Best AUC : 0.9664604 (epoch : 134)
# [Epoch 135] Train - loss : 0.9724264 | Val - AUC : 0.9664643 | Best AUC : 0.9664643 (epoch : 135)
# [Epoch 136] Train - loss : 0.8182754 | Val - AUC : 0.96646 | Best AUC : 0.9664643 (epoch : 135)
# [Epoch 137] Train - loss : 0.9445289 | Val - AUC : 0.9664637 | Best AUC : 0.9664643 (epoch : 135)
# [Epoch 138] Train - loss : 1.0206525 | Val - AUC : 0.9664658 | Best AUC : 0.9664658 (epoch : 138)
# [Epoch 139] Train - loss : 0.9599771 | Val - AUC : 0.9664665 | Best AUC : 0.9664665 (epoch : 139)
# [Epoch 140] Train - loss : 0.9752634 | Val - AUC : 0.9664714 | Best AUC : 0.9664714 (epoch : 140)
# [Epoch 141] Train - loss : 1.0210004 | Val - AUC : 0.9664674 | Best AUC : 0.9664714 (epoch : 140)
# [Epoch 142] Train - loss : 0.7651284 | Val - AUC : 0.9664704 | Best AUC : 0.9664714 (epoch : 140)
# [Epoch 143] Train - loss : 0.8224562 | Val - AUC : 0.9664745 | Best AUC : 0.9664745 (epoch : 143)
# [Epoch 144] Train - loss : 0.9319091 | Val - AUC : 0.96648 | Best AUC : 0.96648 (epoch : 144)
# [Epoch 145] Train - loss : 0.8771034 | Val - AUC : 0.9664879 | Best AUC : 0.9664879 (epoch : 145)
# [Epoch 146] Train - loss : 1.0475454 | Val - AUC : 0.9664815 | Best AUC : 0.9664879 (epoch : 145)
# [Epoch 147] Train - loss : 0.8414372 | Val - AUC : 0.9664883 | Best AUC : 0.9664883 (epoch : 147)
# [Epoch 148] Train - loss : 0.9831463 | Val - AUC : 0.9664971 | Best AUC : 0.9664971 (epoch : 148)
# [Epoch 149] Train - loss : 0.8687008 | Val - AUC : 0.9664992 | Best AUC : 0.9664992 (epoch : 149)
# [Epoch 150] Train - loss : 0.8673039 | Val - AUC : 0.9665091 | Best AUC : 0.9665091 (epoch : 150)
# [Epoch 151] Train - loss : 0.7302404 | Val - AUC : 0.9665076 | Best AUC : 0.9665091 (epoch : 150)
# [Epoch 152] Train - loss : 0.8349874 | Val - AUC : 0.9665076 | Best AUC : 0.9665091 (epoch : 150)
# [Epoch 153] Train - loss : 0.8812621 | Val - AUC : 0.9665086 | Best AUC : 0.9665091 (epoch : 150)
# [Epoch 154] Train - loss : 1.0237329 | Val - AUC : 0.9665134 | Best AUC : 0.9665134 (epoch : 154)
# [Epoch 155] Train - loss : 0.9020893 | Val - AUC : 0.9665153 | Best AUC : 0.9665153 (epoch : 155)
# [Epoch 156] Train - loss : 0.9064193 | Val - AUC : 0.966516 | Best AUC : 0.966516 (epoch : 156)
# [Epoch 157] Train - loss : 0.888155 | Val - AUC : 0.9665112 | Best AUC : 0.966516 (epoch : 156)
# [Epoch 158] Train - loss : 0.8904793 | Val - AUC : 0.9665123 | Best AUC : 0.966516 (epoch : 156)
# [Epoch 159] Train - loss : 0.8651201 | Val - AUC : 0.9665208 | Best AUC : 0.9665208 (epoch : 159)
# [Epoch 160] Train - loss : 0.9392868 | Val - AUC : 0.9665161 | Best AUC : 0.9665208 (epoch : 159)
# [Epoch 161] Train - loss : 0.8172973 | Val - AUC : 0.9665212 | Best AUC : 0.9665212 (epoch : 161)
# [Epoch 162] Train - loss : 0.8853439 | Val - AUC : 0.9665307 | Best AUC : 0.9665307 (epoch : 162)
# [Epoch 163] Train - loss : 1.0050954 | Val - AUC : 0.9665308 | Best AUC : 0.9665308 (epoch : 163)
# [Epoch 164] Train - loss : 0.7913097 | Val - AUC : 0.9665272 | Best AUC : 0.9665308 (epoch : 163)
# [Epoch 165] Train - loss : 0.8074732 | Val - AUC : 0.9665321 | Best AUC : 0.9665321 (epoch : 165)
# [Epoch 166] Train - loss : 0.7957059 | Val - AUC : 0.966535 | Best AUC : 0.966535 (epoch : 166)
# [Epoch 167] Train - loss : 0.7998189 | Val - AUC : 0.9665414 | Best AUC : 0.9665414 (epoch : 167)
# [Epoch 168] Train - loss : 0.8320015 | Val - AUC : 0.9665405 | Best AUC : 0.9665414 (epoch : 167)
# [Epoch 169] Train - loss : 0.9186493 | Val - AUC : 0.9665442 | Best AUC : 0.9665442 (epoch : 169)
# [Epoch 170] Train - loss : 0.8615793 | Val - AUC : 0.9665461 | Best AUC : 0.9665461 (epoch : 170)
# [Epoch 171] Train - loss : 0.9665774 | Val - AUC : 0.966545 | Best AUC : 0.9665461 (epoch : 170)
# [Epoch 172] Train - loss : 0.8743763 | Val - AUC : 0.9665397 | Best AUC : 0.9665461 (epoch : 170)
# [Epoch 173] Train - loss : 0.8293329 | Val - AUC : 0.9665391 | Best AUC : 0.9665461 (epoch : 170)
# [Epoch 174] Train - loss : 0.9115017 | Val - AUC : 0.9665389 | Best AUC : 0.9665461 (epoch : 170)
# [Epoch 175] Train - loss : 0.7805453 | Val - AUC : 0.9665407 | Best AUC : 0.9665461 (epoch : 170)
# [Epoch 176] Train - loss : 0.7710451 | Val - AUC : 0.9665467 | Best AUC : 0.9665467 (epoch : 176)
# [Epoch 177] Train - loss : 0.8184096 | Val - AUC : 0.9665499 | Best AUC : 0.9665499 (epoch : 177)
# [Epoch 178] Train - loss : 0.7112261 | Val - AUC : 0.966553 | Best AUC : 0.966553 (epoch : 178)
# [Epoch 179] Train - loss : 0.8255946 | Val - AUC : 0.9665529 | Best AUC : 0.966553 (epoch : 178)
# [Epoch 180] Train - loss : 0.827759 | Val - AUC : 0.9665532 | Best AUC : 0.9665532 (epoch : 180)
# [Epoch 181] Train - loss : 0.8829396 | Val - AUC : 0.9665593 | Best AUC : 0.9665593 (epoch : 181)
# [Epoch 182] Train - loss : 0.9360827 | Val - AUC : 0.9665621 | Best AUC : 0.9665621 (epoch : 182)
# [Epoch 183] Train - loss : 0.8975188 | Val - AUC : 0.9665689 | Best AUC : 0.9665689 (epoch : 183)
# [Epoch 184] Train - loss : 0.8654934 | Val - AUC : 0.9665663 | Best AUC : 0.9665689 (epoch : 183)
# [Epoch 185] Train - loss : 0.9940933 | Val - AUC : 0.9665661 | Best AUC : 0.9665689 (epoch : 183)
# [Epoch 186] Train - loss : 1.0772732 | Val - AUC : 0.9665629 | Best AUC : 0.9665689 (epoch : 183)
# [Epoch 187] Train - loss : 0.7842313 | Val - AUC : 0.9665657 | Best AUC : 0.9665689 (epoch : 183)
# [Epoch 188] Train - loss : 0.8017855 | Val - AUC : 0.9665697 | Best AUC : 0.9665697 (epoch : 188)
# [Epoch 189] Train - loss : 0.8144631 | Val - AUC : 0.9665664 | Best AUC : 0.9665697 (epoch : 188)
# [Epoch 190] Train - loss : 0.936491 | Val - AUC : 0.9665659 | Best AUC : 0.9665697 (epoch : 188)
# [Epoch 191] Train - loss : 1.0554566 | Val - AUC : 0.9665719 | Best AUC : 0.9665719 (epoch : 191)
# [Epoch 192] Train - loss : 0.8896028 | Val - AUC : 0.9665726 | Best AUC : 0.9665726 (epoch : 192)
# [Epoch 193] Train - loss : 0.876182 | Val - AUC : 0.9665687 | Best AUC : 0.9665726 (epoch : 192)
# [Epoch 194] Train - loss : 0.8895457 | Val - AUC : 0.9665713 | Best AUC : 0.9665726 (epoch : 192)
# [Epoch 195] Train - loss : 0.8443048 | Val - AUC : 0.9665728 | Best AUC : 0.9665728 (epoch : 195)
# [Epoch 196] Train - loss : 0.7690297 | Val - AUC : 0.9665737 | Best AUC : 0.9665737 (epoch : 196)
# [Epoch 197] Train - loss : 1.0375084 | Val - AUC : 0.9665731 | Best AUC : 0.9665737 (epoch : 196)
# [Epoch 198] Train - loss : 0.717068 | Val - AUC : 0.9665748 | Best AUC : 0.9665748 (epoch : 198)
# [Epoch 199] Train - loss : 0.7198801 | Val - AUC : 0.9665713 | Best AUC : 0.9665748 (epoch : 198)
# [Epoch 200] Train - loss : 1.0108082 | Val - AUC : 0.966578 | Best AUC : 0.966578 (epoch : 200)
# [Epoch 201] Train - loss : 0.8497727 | Val - AUC : 0.9665788 | Best AUC : 0.9665788 (epoch : 201)
# [Epoch 202] Train - loss : 0.7599174 | Val - AUC : 0.9665803 | Best AUC : 0.9665803 (epoch : 202)
# [Epoch 203] Train - loss : 0.8132835 | Val - AUC : 0.9665876 | Best AUC : 0.9665876 (epoch : 203)
# [Epoch 204] Train - loss : 0.8342109 | Val - AUC : 0.9665862 | Best AUC : 0.9665876 (epoch : 203)
# [Epoch 205] Train - loss : 0.8822016 | Val - AUC : 0.9665871 | Best AUC : 0.9665876 (epoch : 203)
# [Epoch 206] Train - loss : 0.7662591 | Val - AUC : 0.9665869 | Best AUC : 0.9665876 (epoch : 203)
# [Epoch 207] Train - loss : 0.7397707 | Val - AUC : 0.9665876 | Best AUC : 0.9665876 (epoch : 207)
# [Epoch 208] Train - loss : 0.7220407 | Val - AUC : 0.9665834 | Best AUC : 0.9665876 (epoch : 207)
# [Epoch 209] Train - loss : 0.9346811 | Val - AUC : 0.9665805 | Best AUC : 0.9665876 (epoch : 207)
# [Epoch 210] Train - loss : 1.0300273 | Val - AUC : 0.9665813 | Best AUC : 0.9665876 (epoch : 207)
# [Epoch 211] Train - loss : 0.7834072 | Val - AUC : 0.9665861 | Best AUC : 0.9665876 (epoch : 207)
# [Epoch 212] Train - loss : 0.8051432 | Val - AUC : 0.9665879 | Best AUC : 0.9665879 (epoch : 212)
# [Epoch 213] Train - loss : 0.862323 | Val - AUC : 0.9665857 | Best AUC : 0.9665879 (epoch : 212)
# [Epoch 214] Train - loss : 0.9845922 | Val - AUC : 0.9665906 | Best AUC : 0.9665906 (epoch : 214)
# [Epoch 215] Train - loss : 0.733957 | Val - AUC : 0.9665863 | Best AUC : 0.9665906 (epoch : 214)
# [Epoch 216] Train - loss : 1.0758582 | Val - AUC : 0.9665889 | Best AUC : 0.9665906 (epoch : 214)
# [Epoch 217] Train - loss : 0.8044695 | Val - AUC : 0.9665848 | Best AUC : 0.9665906 (epoch : 214)
# [Epoch 218] Train - loss : 0.810717 | Val - AUC : 0.966584 | Best AUC : 0.9665906 (epoch : 214)
# [Epoch 219] Train - loss : 0.8063407 | Val - AUC : 0.9665818 | Best AUC : 0.9665906 (epoch : 214)
# [Epoch 220] Train - loss : 0.8496351 | Val - AUC : 0.9665789 | Best AUC : 0.9665906 (epoch : 214)
# [Epoch 221] Train - loss : 0.705473 | Val - AUC : 0.9665777 | Best AUC : 0.9665906 (epoch : 214)
# [Epoch 222] Train - loss : 0.7851445 | Val - AUC : 0.9665822 | Best AUC : 0.9665906 (epoch : 214)
# [Epoch 223] Train - loss : 0.7107608 | Val - AUC : 0.9665733 | Best AUC : 0.9665906 (epoch : 214)
# [Epoch 224] Train - loss : 0.9974668 | Val - AUC : 0.9665774 | Best AUC : 0.9665906 (epoch : 214)
# [Epoch 225] Train - loss : 0.8358113 | Val - AUC : 0.9665792 | Best AUC : 0.9665906 (epoch : 214)
# [Epoch 226] Train - loss : 0.7840924 | Val - AUC : 0.966576 | Best AUC : 0.9665906 (epoch : 214)
# [Epoch 227] Train - loss : 0.7874612 | Val - AUC : 0.9665767 | Best AUC : 0.9665906 (epoch : 214)
# [Epoch 228] Train - loss : 1.07355 | Val - AUC : 0.9665794 | Best AUC : 0.9665906 (epoch : 214)
# [Epoch 229] Train - loss : 0.6753249 | Val - AUC : 0.9665799 | Best AUC : 0.9665906 (epoch : 214)
# [Epoch 230] Train - loss : 0.8974526 | Val - AUC : 0.9665789 | Best AUC : 0.9665906 (epoch : 214)
# [Epoch 231] Train - loss : 0.8384052 | Val - AUC : 0.9665842 | Best AUC : 0.9665906 (epoch : 214)
# [Epoch 232] Train - loss : 0.9448552 | Val - AUC : 0.9665831 | Best AUC : 0.9665906 (epoch : 214)
# [Epoch 233] Train - loss : 0.7827826 | Val - AUC : 0.9665823 | Best AUC : 0.9665906 (epoch : 214)
# [Epoch 234] Train - loss : 0.7873679 | Val - AUC : 0.966584 | Best AUC : 0.9665906 (epoch : 214)
# [Epoch 235] Train - loss : 0.7676905 | Val - AUC : 0.9665824 | Best AUC : 0.9665906 (epoch : 214)
# [Epoch 236] Train - loss : 0.7576268 | Val - AUC : 0.9665796 | Best AUC : 0.9665906 (epoch : 214)
# [Epoch 237] Train - loss : 0.9042794 | Val - AUC : 0.9665785 | Best AUC : 0.9665906 (epoch : 214)
# [Epoch 238] Train - loss : 0.7864417 | Val - AUC : 0.9665797 | Best AUC : 0.9665906 (epoch : 214)
# [Epoch 239] Train - loss : 0.8017025 | Val - AUC : 0.9665782 | Best AUC : 0.9665906 (epoch : 214)
# [Epoch 240] Train - loss : 0.9948344 | Val - AUC : 0.9665748 | Best AUC : 0.9665906 (epoch : 214)
# [Epoch 241] Train - loss : 0.7831506 | Val - AUC : 0.9665755 | Best AUC : 0.9665906 (epoch : 214)
# [Epoch 242] Train - loss : 0.7382767 | Val - AUC : 0.9665767 | Best AUC : 0.9665906 (epoch : 214)
# [Epoch 243] Train - loss : 0.8124158 | Val - AUC : 0.9665796 | Best AUC : 0.9665906 (epoch : 214)
# [Epoch 244] Train - loss : 0.8402005 | Val - AUC : 0.9665763 | Best AUC : 0.9665906 (epoch : 214)
# [Epoch 245] Train - loss : 0.8987745 | Val - AUC : 0.9665763 | Best AUC : 0.9665906 (epoch : 214)
# [Epoch 246] Train - loss : 0.8664957 | Val - AUC : 0.9665766 | Best AUC : 0.9665906 (epoch : 214)
# [Epoch 247] Train - loss : 0.8658944 | Val - AUC : 0.9665794 | Best AUC : 0.9665906 (epoch : 214)
# [Epoch 248] Train - loss : 0.7434416 | Val - AUC : 0.9665803 | Best AUC : 0.9665906 (epoch : 214)
# [Epoch 249] Train - loss : 0.7626061 | Val - AUC : 0.9665844 | Best AUC : 0.9665906 (epoch : 214)
# [Epoch 250] Train - loss : 0.8189633 | Val - AUC : 0.9665817 | Best AUC : 0.9665906 (epoch : 214)
# [Epoch 251] Train - loss : 0.862422 | Val - AUC : 0.9665804 | Best AUC : 0.9665906 (epoch : 214)
# [Epoch 252] Train - loss : 0.7494571 | Val - AUC : 0.9665806 | Best AUC : 0.9665906 (epoch : 214)
# [Epoch 253] Train - loss : 0.7113177 | Val - AUC : 0.9665808 | Best AUC : 0.9665906 (epoch : 214)
# [Epoch 254] Train - loss : 1.018366 | Val - AUC : 0.9665864 | Best AUC : 0.9665906 (epoch : 214)
# [Epoch 255] Train - loss : 0.9542615 | Val - AUC : 0.9665779 | Best AUC : 0.9665906 (epoch : 214)
# [Epoch 256] Train - loss : 0.7243014 | Val - AUC : 0.9665804 | Best AUC : 0.9665906 (epoch : 214)
# [Epoch 257] Train - loss : 0.6925441 | Val - AUC : 0.9665816 | Best AUC : 0.9665906 (epoch : 214)
# [Epoch 258] Train - loss : 0.9057724 | Val - AUC : 0.9665848 | Best AUC : 0.9665906 (epoch : 214)
# [Epoch 259] Train - loss : 0.8071387 | Val - AUC : 0.9665842 | Best AUC : 0.9665906 (epoch : 214)
# [Epoch 260] Train - loss : 0.6835476 | Val - AUC : 0.966587 | Best AUC : 0.9665906 (epoch : 214)
# [Epoch 261] Train - loss : 0.736612 | Val - AUC : 0.966585 | Best AUC : 0.9665906 (epoch : 214)
# [Epoch 262] Train - loss : 0.725584 | Val - AUC : 0.9665838 | Best AUC : 0.9665906 (epoch : 214)
# [Epoch 263] Train - loss : 0.6960273 | Val - AUC : 0.9665854 | Best AUC : 0.9665906 (epoch : 214)
# [Epoch 264] Train - loss : 0.8082635 | Val - AUC : 0.9665831 | Best AUC : 0.9665906 (epoch : 214)
# [Epoch 265] Train - loss : 0.7061937 | Val - AUC : 0.966583 | Best AUC : 0.9665906 (epoch : 214)
# [Epoch 266] Train - loss : 0.6382172 | Val - AUC : 0.9665797 | Best AUC : 0.9665906 (epoch : 214)
# [Epoch 267] Train - loss : 0.6791286 | Val - AUC : 0.9665794 | Best AUC : 0.9665906 (epoch : 214)
# [Epoch 268] Train - loss : 0.7796096 | Val - AUC : 0.9665824 | Best AUC : 0.9665906 (epoch : 214)
# [Epoch 269] Train - loss : 0.717543 | Val - AUC : 0.9665808 | Best AUC : 0.9665906 (epoch : 214)
# [Epoch 270] Train - loss : 0.8168097 | Val - AUC : 0.966581 | Best AUC : 0.9665906 (epoch : 214)
# [Epoch 271] Train - loss : 0.9244335 | Val - AUC : 0.9665814 | Best AUC : 0.9665906 (epoch : 214)
# [Epoch 272] Train - loss : 0.6811434 | Val - AUC : 0.9665772 | Best AUC : 0.9665906 (epoch : 214)
# [Epoch 273] Train - loss : 0.7627488 | Val - AUC : 0.9665841 | Best AUC : 0.9665906 (epoch : 214)
# [Epoch 274] Train - loss : 0.7531194 | Val - AUC : 0.9665796 | Best AUC : 0.9665906 (epoch : 214)
# [Epoch 275] Train - loss : 0.7993947 | Val - AUC : 0.9665807 | Best AUC : 0.9665906 (epoch : 214)
# [Epoch 276] Train - loss : 0.8255565 | Val - AUC : 0.9665841 | Best AUC : 0.9665906 (epoch : 214)
# [Epoch 277] Train - loss : 0.8743522 | Val - AUC : 0.9665832 | Best AUC : 0.9665906 (epoch : 214)
# [Epoch 278] Train - loss : 0.7944521 | Val - AUC : 0.9665841 | Best AUC : 0.9665906 (epoch : 214)
# [Epoch 279] Train - loss : 1.0365841 | Val - AUC : 0.9665826 | Best AUC : 0.9665906 (epoch : 214)
# [Epoch 280] Train - loss : 0.8549158 | Val - AUC : 0.9665835 | Best AUC : 0.9665906 (epoch : 214)
# [Epoch 281] Train - loss : 0.6704936 | Val - AUC : 0.9665864 | Best AUC : 0.9665906 (epoch : 214)
# [Epoch 282] Train - loss : 0.7541405 | Val - AUC : 0.9665904 | Best AUC : 0.9665906 (epoch : 214)
# [Epoch 283] Train - loss : 0.6909573 | Val - AUC : 0.9665872 | Best AUC : 0.9665906 (epoch : 214)
# [Epoch 284] Train - loss : 0.8482423 | Val - AUC : 0.9665877 | Best AUC : 0.9665906 (epoch : 214)
# [Epoch 285] Train - loss : 0.7521535 | Val - AUC : 0.9665866 | Best AUC : 0.9665906 (epoch : 214)
# [Epoch 286] Train - loss : 0.6776691 | Val - AUC : 0.9665865 | Best AUC : 0.9665906 (epoch : 214)
# [Epoch 287] Train - loss : 0.853581 | Val - AUC : 0.9665874 | Best AUC : 0.9665906 (epoch : 214)
# [Epoch 288] Train - loss : 0.8027381 | Val - AUC : 0.9665872 | Best AUC : 0.9665906 (epoch : 214)
# [Epoch 289] Train - loss : 1.0463 | Val - AUC : 0.9665845 | Best AUC : 0.9665906 (epoch : 214)
# [Epoch 290] Train - loss : 0.8979132 | Val - AUC : 0.9665846 | Best AUC : 0.9665906 (epoch : 214)
# [Epoch 291] Train - loss : 0.7434958 | Val - AUC : 0.9665854 | Best AUC : 0.9665906 (epoch : 214)
# [Epoch 292] Train - loss : 0.7331343 | Val - AUC : 0.9665849 | Best AUC : 0.9665906 (epoch : 214)
# [Epoch 293] Train - loss : 0.8716361 | Val - AUC : 0.9665866 | Best AUC : 0.9665906 (epoch : 214)
# [Epoch 294] Train - loss : 1.0033286 | Val - AUC : 0.9665877 | Best AUC : 0.9665906 (epoch : 214)
# [Epoch 295] Train - loss : 0.7722404 | Val - AUC : 0.9665901 | Best AUC : 0.9665906 (epoch : 214)
# [Epoch 296] Train - loss : 0.7821562 | Val - AUC : 0.9665896 | Best AUC : 0.9665906 (epoch : 214)
# [Epoch 297] Train - loss : 0.7056 | Val - AUC : 0.9665888 | Best AUC : 0.9665906 (epoch : 214)
# [Epoch 298] Train - loss : 0.7013844 | Val - AUC : 0.9665913 | Best AUC : 0.9665913 (epoch : 298)
# [Epoch 299] Train - loss : 0.6723172 | Val - AUC : 0.9665852 | Best AUC : 0.9665913 (epoch : 298)
# [Epoch 300] Train - loss : 0.6420571 | Val - AUC : 0.9665891 | Best AUC : 0.9665913 (epoch : 298)
# [Epoch 301] Train - loss : 0.6972185 | Val - AUC : 0.9665933 | Best AUC : 0.9665933 (epoch : 301)
# [Epoch 302] Train - loss : 0.7103774 | Val - AUC : 0.9665911 | Best AUC : 0.9665933 (epoch : 301)
# [Epoch 303] Train - loss : 0.856802 | Val - AUC : 0.9665915 | Best AUC : 0.9665933 (epoch : 301)
# [Epoch 304] Train - loss : 0.6954666 | Val - AUC : 0.966591 | Best AUC : 0.9665933 (epoch : 301)
# [Epoch 305] Train - loss : 0.6809481 | Val - AUC : 0.9665898 | Best AUC : 0.9665933 (epoch : 301)
# [Epoch 306] Train - loss : 0.6766169 | Val - AUC : 0.9665869 | Best AUC : 0.9665933 (epoch : 301)
# [Epoch 307] Train - loss : 0.6873698 | Val - AUC : 0.9665922 | Best AUC : 0.9665933 (epoch : 301)
# [Epoch 308] Train - loss : 0.886116 | Val - AUC : 0.9665917 | Best AUC : 0.9665933 (epoch : 301)
# [Epoch 309] Train - loss : 0.7634659 | Val - AUC : 0.9665937 | Best AUC : 0.9665937 (epoch : 309)
# [Epoch 310] Train - loss : 0.7289518 | Val - AUC : 0.9665944 | Best AUC : 0.9665944 (epoch : 310)
# [Epoch 311] Train - loss : 0.6878955 | Val - AUC : 0.9665922 | Best AUC : 0.9665944 (epoch : 310)
# [Epoch 312] Train - loss : 0.8041962 | Val - AUC : 0.9665898 | Best AUC : 0.9665944 (epoch : 310)
# [Epoch 313] Train - loss : 0.6318519 | Val - AUC : 0.9665862 | Best AUC : 0.9665944 (epoch : 310)
# [Epoch 314] Train - loss : 0.6816776 | Val - AUC : 0.9665892 | Best AUC : 0.9665944 (epoch : 310)
# [Epoch 315] Train - loss : 0.6658061 | Val - AUC : 0.9665943 | Best AUC : 0.9665944 (epoch : 310)
# [Epoch 316] Train - loss : 0.7309236 | Val - AUC : 0.9665972 | Best AUC : 0.9665972 (epoch : 316)
# [Epoch 317] Train - loss : 0.6411677 | Val - AUC : 0.9665986 | Best AUC : 0.9665986 (epoch : 317)
# [Epoch 318] Train - loss : 0.8254071 | Val - AUC : 0.9665986 | Best AUC : 0.9665986 (epoch : 317)
# [Epoch 319] Train - loss : 0.7216545 | Val - AUC : 0.9666019 | Best AUC : 0.9666019 (epoch : 319)
# [Epoch 320] Train - loss : 0.8163135 | Val - AUC : 0.9666022 | Best AUC : 0.9666022 (epoch : 320)
# [Epoch 321] Train - loss : 0.7087834 | Val - AUC : 0.9666011 | Best AUC : 0.9666022 (epoch : 320)
# [Epoch 322] Train - loss : 0.8861646 | Val - AUC : 0.9666023 | Best AUC : 0.9666023 (epoch : 322)
# [Epoch 323] Train - loss : 0.9302824 | Val - AUC : 0.9666022 | Best AUC : 0.9666023 (epoch : 322)
# [Epoch 324] Train - loss : 0.624161 | Val - AUC : 0.966605 | Best AUC : 0.966605 (epoch : 324)
# [Epoch 325] Train - loss : 0.8355483 | Val - AUC : 0.9666018 | Best AUC : 0.966605 (epoch : 324)
# [Epoch 326] Train - loss : 0.6846028 | Val - AUC : 0.9666074 | Best AUC : 0.9666074 (epoch : 326)
# [Epoch 327] Train - loss : 0.9440561 | Val - AUC : 0.9666078 | Best AUC : 0.9666078 (epoch : 327)
# [Epoch 328] Train - loss : 0.7118041 | Val - AUC : 0.9666075 | Best AUC : 0.9666078 (epoch : 327)
# [Epoch 329] Train - loss : 0.7075695 | Val - AUC : 0.9666069 | Best AUC : 0.9666078 (epoch : 327)
# [Epoch 330] Train - loss : 0.8126942 | Val - AUC : 0.9666074 | Best AUC : 0.9666078 (epoch : 327)
# [Epoch 331] Train - loss : 0.7267467 | Val - AUC : 0.966607 | Best AUC : 0.9666078 (epoch : 327)
# [Epoch 332] Train - loss : 0.7236368 | Val - AUC : 0.9666086 | Best AUC : 0.9666086 (epoch : 332)
# [Epoch 333] Train - loss : 0.7045902 | Val - AUC : 0.9666102 | Best AUC : 0.9666102 (epoch : 333)
# [Epoch 334] Train - loss : 0.788358 | Val - AUC : 0.9666064 | Best AUC : 0.9666102 (epoch : 333)
# [Epoch 335] Train - loss : 0.8616357 | Val - AUC : 0.9666087 | Best AUC : 0.9666102 (epoch : 333)
# [Epoch 336] Train - loss : 0.6364682 | Val - AUC : 0.9666031 | Best AUC : 0.9666102 (epoch : 333)
# [Epoch 337] Train - loss : 0.7366758 | Val - AUC : 0.9666033 | Best AUC : 0.9666102 (epoch : 333)
# [Epoch 338] Train - loss : 0.6767141 | Val - AUC : 0.9666109 | Best AUC : 0.9666109 (epoch : 338)
# [Epoch 339] Train - loss : 0.6554131 | Val - AUC : 0.9666133 | Best AUC : 0.9666133 (epoch : 339)
# [Epoch 340] Train - loss : 0.6892063 | Val - AUC : 0.9666161 | Best AUC : 0.9666161 (epoch : 340)
# [Epoch 341] Train - loss : 0.6901786 | Val - AUC : 0.9666171 | Best AUC : 0.9666171 (epoch : 341)
# [Epoch 342] Train - loss : 0.6420714 | Val - AUC : 0.9666165 | Best AUC : 0.9666171 (epoch : 341)
# [Epoch 343] Train - loss : 0.7243299 | Val - AUC : 0.9666152 | Best AUC : 0.9666171 (epoch : 341)
# [Epoch 344] Train - loss : 0.6863855 | Val - AUC : 0.9666114 | Best AUC : 0.9666171 (epoch : 341)
# [Epoch 345] Train - loss : 0.7986776 | Val - AUC : 0.9666133 | Best AUC : 0.9666171 (epoch : 341)
# [Epoch 346] Train - loss : 0.7426093 | Val - AUC : 0.9666147 | Best AUC : 0.9666171 (epoch : 341)
# [Epoch 347] Train - loss : 0.6581026 | Val - AUC : 0.9666199 | Best AUC : 0.9666199 (epoch : 347)
# [Epoch 348] Train - loss : 0.8492012 | Val - AUC : 0.9666188 | Best AUC : 0.9666199 (epoch : 347)
# [Epoch 349] Train - loss : 0.7231723 | Val - AUC : 0.9666139 | Best AUC : 0.9666199 (epoch : 347)
# [Epoch 350] Train - loss : 0.7531993 | Val - AUC : 0.9666196 | Best AUC : 0.9666199 (epoch : 347)
# [Epoch 351] Train - loss : 0.6714855 | Val - AUC : 0.9666242 | Best AUC : 0.9666242 (epoch : 351)
# [Epoch 352] Train - loss : 0.665063 | Val - AUC : 0.9666203 | Best AUC : 0.9666242 (epoch : 351)
# [Epoch 353] Train - loss : 0.7368544 | Val - AUC : 0.9666211 | Best AUC : 0.9666242 (epoch : 351)
# [Epoch 354] Train - loss : 0.7631837 | Val - AUC : 0.9666181 | Best AUC : 0.9666242 (epoch : 351)
# [Epoch 355] Train - loss : 0.713962 | Val - AUC : 0.9666225 | Best AUC : 0.9666242 (epoch : 351)
# [Epoch 356] Train - loss : 0.6944903 | Val - AUC : 0.9666249 | Best AUC : 0.9666249 (epoch : 356)
# [Epoch 357] Train - loss : 0.6603205 | Val - AUC : 0.9666247 | Best AUC : 0.9666249 (epoch : 356)
# [Epoch 358] Train - loss : 0.8603013 | Val - AUC : 0.9666232 | Best AUC : 0.9666249 (epoch : 356)
# [Epoch 359] Train - loss : 0.6624373 | Val - AUC : 0.9666246 | Best AUC : 0.9666249 (epoch : 356)
# [Epoch 360] Train - loss : 0.9625501 | Val - AUC : 0.9666256 | Best AUC : 0.9666256 (epoch : 360)
# [Epoch 361] Train - loss : 0.6583587 | Val - AUC : 0.9666241 | Best AUC : 0.9666256 (epoch : 360)
# [Epoch 362] Train - loss : 0.7475666 | Val - AUC : 0.9666292 | Best AUC : 0.9666292 (epoch : 362)
# [Epoch 363] Train - loss : 0.7457622 | Val - AUC : 0.966627 | Best AUC : 0.9666292 (epoch : 362)
# [Epoch 364] Train - loss : 0.7013168 | Val - AUC : 0.9666364 | Best AUC : 0.9666364 (epoch : 364)
# [Epoch 365] Train - loss : 0.7141763 | Val - AUC : 0.9666335 | Best AUC : 0.9666364 (epoch : 364)
# [Epoch 366] Train - loss : 0.7098817 | Val - AUC : 0.966633 | Best AUC : 0.9666364 (epoch : 364)
# [Epoch 367] Train - loss : 0.583923 | Val - AUC : 0.966634 | Best AUC : 0.9666364 (epoch : 364)
# [Epoch 368] Train - loss : 0.6145682 | Val - AUC : 0.9666319 | Best AUC : 0.9666364 (epoch : 364)
# [Epoch 369] Train - loss : 0.6627667 | Val - AUC : 0.9666301 | Best AUC : 0.9666364 (epoch : 364)
# [Epoch 370] Train - loss : 0.6309019 | Val - AUC : 0.9666334 | Best AUC : 0.9666364 (epoch : 364)
# [Epoch 371] Train - loss : 0.7212359 | Val - AUC : 0.9666372 | Best AUC : 0.9666372 (epoch : 371)
# [Epoch 372] Train - loss : 0.6815639 | Val - AUC : 0.9666409 | Best AUC : 0.9666409 (epoch : 372)
# [Epoch 373] Train - loss : 0.5521277 | Val - AUC : 0.9666407 | Best AUC : 0.9666409 (epoch : 372)
# [Epoch 374] Train - loss : 0.6735481 | Val - AUC : 0.9666405 | Best AUC : 0.9666409 (epoch : 372)
# [Epoch 375] Train - loss : 0.7784116 | Val - AUC : 0.9666403 | Best AUC : 0.9666409 (epoch : 372)
# [Epoch 376] Train - loss : 0.6047176 | Val - AUC : 0.966643 | Best AUC : 0.966643 (epoch : 376)
# [Epoch 377] Train - loss : 0.7338481 | Val - AUC : 0.9666431 | Best AUC : 0.9666431 (epoch : 377)
# [Epoch 378] Train - loss : 0.7383809 | Val - AUC : 0.9666394 | Best AUC : 0.9666431 (epoch : 377)
# [Epoch 379] Train - loss : 0.7495164 | Val - AUC : 0.9666466 | Best AUC : 0.9666466 (epoch : 379)
# [Epoch 380] Train - loss : 0.8131974 | Val - AUC : 0.9666487 | Best AUC : 0.9666487 (epoch : 380)
# [Epoch 381] Train - loss : 0.7629035 | Val - AUC : 0.9666466 | Best AUC : 0.9666487 (epoch : 380)
# [Epoch 382] Train - loss : 0.7449189 | Val - AUC : 0.9666435 | Best AUC : 0.9666487 (epoch : 380)
# [Epoch 383] Train - loss : 0.7028959 | Val - AUC : 0.9666451 | Best AUC : 0.9666487 (epoch : 380)
# [Epoch 384] Train - loss : 0.7059949 | Val - AUC : 0.966645 | Best AUC : 0.9666487 (epoch : 380)
# [Epoch 385] Train - loss : 0.7207084 | Val - AUC : 0.9666438 | Best AUC : 0.9666487 (epoch : 380)
# [Epoch 386] Train - loss : 0.7837413 | Val - AUC : 0.9666505 | Best AUC : 0.9666505 (epoch : 386)
# [Epoch 387] Train - loss : 0.762935 | Val - AUC : 0.9666485 | Best AUC : 0.9666505 (epoch : 386)
# [Epoch 388] Train - loss : 0.8125113 | Val - AUC : 0.9666503 | Best AUC : 0.9666505 (epoch : 386)
# [Epoch 389] Train - loss : 0.8554698 | Val - AUC : 0.9666489 | Best AUC : 0.9666505 (epoch : 386)
# [Epoch 390] Train - loss : 0.6280068 | Val - AUC : 0.9666503 | Best AUC : 0.9666505 (epoch : 386)
# [Epoch 391] Train - loss : 0.8567327 | Val - AUC : 0.9666496 | Best AUC : 0.9666505 (epoch : 386)
# [Epoch 392] Train - loss : 0.699201 | Val - AUC : 0.9666507 | Best AUC : 0.9666507 (epoch : 392)
# [Epoch 393] Train - loss : 0.6664353 | Val - AUC : 0.9666475 | Best AUC : 0.9666507 (epoch : 392)
# [Epoch 394] Train - loss : 0.7110501 | Val - AUC : 0.9666524 | Best AUC : 0.9666524 (epoch : 394)
# [Epoch 395] Train - loss : 0.7554047 | Val - AUC : 0.9666565 | Best AUC : 0.9666565 (epoch : 395)
# [Epoch 396] Train - loss : 0.6823733 | Val - AUC : 0.9666555 | Best AUC : 0.9666565 (epoch : 395)
# [Epoch 397] Train - loss : 0.9018662 | Val - AUC : 0.9666556 | Best AUC : 0.9666565 (epoch : 395)
# [Epoch 398] Train - loss : 0.6611283 | Val - AUC : 0.9666544 | Best AUC : 0.9666565 (epoch : 395)
# [Epoch 399] Train - loss : 0.7341673 | Val - AUC : 0.966652 | Best AUC : 0.9666565 (epoch : 395)
# [Epoch 400] Train - loss : 0.8241614 | Val - AUC : 0.9666506 | Best AUC : 0.9666565 (epoch : 395)
# [Epoch 401] Train - loss : 0.6553199 | Val - AUC : 0.9666498 | Best AUC : 0.9666565 (epoch : 395)
# [Epoch 402] Train - loss : 0.5852224 | Val - AUC : 0.9666555 | Best AUC : 0.9666565 (epoch : 395)
# [Epoch 403] Train - loss : 0.7557041 | Val - AUC : 0.9666602 | Best AUC : 0.9666602 (epoch : 403)
# [Epoch 404] Train - loss : 0.6910237 | Val - AUC : 0.966659 | Best AUC : 0.9666602 (epoch : 403)
# [Epoch 405] Train - loss : 0.7240702 | Val - AUC : 0.966658 | Best AUC : 0.9666602 (epoch : 403)
# [Epoch 406] Train - loss : 0.7344873 | Val - AUC : 0.9666607 | Best AUC : 0.9666607 (epoch : 406)
# [Epoch 407] Train - loss : 0.901676 | Val - AUC : 0.9666617 | Best AUC : 0.9666617 (epoch : 407)
# [Epoch 408] Train - loss : 0.6076312 | Val - AUC : 0.9666619 | Best AUC : 0.9666619 (epoch : 408)
# [Epoch 409] Train - loss : 0.7057585 | Val - AUC : 0.9666606 | Best AUC : 0.9666619 (epoch : 408)
# [Epoch 410] Train - loss : 0.7280496 | Val - AUC : 0.9666583 | Best AUC : 0.9666619 (epoch : 408)
# [Epoch 411] Train - loss : 0.6577501 | Val - AUC : 0.9666574 | Best AUC : 0.9666619 (epoch : 408)
# [Epoch 412] Train - loss : 0.7644814 | Val - AUC : 0.9666616 | Best AUC : 0.9666619 (epoch : 408)
# [Epoch 413] Train - loss : 0.6834237 | Val - AUC : 0.9666577 | Best AUC : 0.9666619 (epoch : 408)
# [Epoch 414] Train - loss : 0.6779314 | Val - AUC : 0.9666589 | Best AUC : 0.9666619 (epoch : 408)
# [Epoch 415] Train - loss : 0.7004716 | Val - AUC : 0.9666615 | Best AUC : 0.9666619 (epoch : 408)
# [Epoch 416] Train - loss : 0.6520477 | Val - AUC : 0.9666587 | Best AUC : 0.9666619 (epoch : 408)
# [Epoch 417] Train - loss : 0.7847998 | Val - AUC : 0.9666611 | Best AUC : 0.9666619 (epoch : 408)
# [Epoch 418] Train - loss : 0.6960463 | Val - AUC : 0.9666611 | Best AUC : 0.9666619 (epoch : 408)
# [Epoch 419] Train - loss : 0.6450149 | Val - AUC : 0.9666611 | Best AUC : 0.9666619 (epoch : 408)
# [Epoch 420] Train - loss : 0.8677512 | Val - AUC : 0.9666663 | Best AUC : 0.9666663 (epoch : 420)
# [Epoch 421] Train - loss : 0.7283956 | Val - AUC : 0.9666584 | Best AUC : 0.9666663 (epoch : 420)
# [Epoch 422] Train - loss : 0.7597187 | Val - AUC : 0.9666605 | Best AUC : 0.9666663 (epoch : 420)
# [Epoch 423] Train - loss : 0.6985899 | Val - AUC : 0.9666588 | Best AUC : 0.9666663 (epoch : 420)
# [Epoch 424] Train - loss : 0.7401575 | Val - AUC : 0.9666596 | Best AUC : 0.9666663 (epoch : 420)
# [Epoch 425] Train - loss : 0.7003031 | Val - AUC : 0.9666632 | Best AUC : 0.9666663 (epoch : 420)
# [Epoch 426] Train - loss : 0.7588436 | Val - AUC : 0.9666595 | Best AUC : 0.9666663 (epoch : 420)
# [Epoch 427] Train - loss : 0.8467252 | Val - AUC : 0.966663 | Best AUC : 0.9666663 (epoch : 420)
# [Epoch 428] Train - loss : 0.6707261 | Val - AUC : 0.9666631 | Best AUC : 0.9666663 (epoch : 420)
# [Epoch 429] Train - loss : 0.7595644 | Val - AUC : 0.9666629 | Best AUC : 0.9666663 (epoch : 420)
# [Epoch 430] Train - loss : 0.5734735 | Val - AUC : 0.9666641 | Best AUC : 0.9666663 (epoch : 420)
# [Epoch 431] Train - loss : 0.6855393 | Val - AUC : 0.9666619 | Best AUC : 0.9666663 (epoch : 420)
# [Epoch 432] Train - loss : 0.7134236 | Val - AUC : 0.9666647 | Best AUC : 0.9666663 (epoch : 420)
# [Epoch 433] Train - loss : 0.8154859 | Val - AUC : 0.9666606 | Best AUC : 0.9666663 (epoch : 420)
# [Epoch 434] Train - loss : 0.8085528 | Val - AUC : 0.9666584 | Best AUC : 0.9666663 (epoch : 420)
# [Epoch 435] Train - loss : 0.6309083 | Val - AUC : 0.9666618 | Best AUC : 0.9666663 (epoch : 420)
# [Epoch 436] Train - loss : 0.7387305 | Val - AUC : 0.9666617 | Best AUC : 0.9666663 (epoch : 420)
# [Epoch 437] Train - loss : 0.7784507 | Val - AUC : 0.9666654 | Best AUC : 0.9666663 (epoch : 420)
# [Epoch 438] Train - loss : 0.7225121 | Val - AUC : 0.9666655 | Best AUC : 0.9666663 (epoch : 420)
# [Epoch 439] Train - loss : 0.7726155 | Val - AUC : 0.9666669 | Best AUC : 0.9666669 (epoch : 439)
# [Epoch 440] Train - loss : 0.6464631 | Val - AUC : 0.9666674 | Best AUC : 0.9666674 (epoch : 440)
# [Epoch 441] Train - loss : 0.6483226 | Val - AUC : 0.9666634 | Best AUC : 0.9666674 (epoch : 440)
# [Epoch 442] Train - loss : 0.6846508 | Val - AUC : 0.9666671 | Best AUC : 0.9666674 (epoch : 440)
# [Epoch 443] Train - loss : 0.6520211 | Val - AUC : 0.966668 | Best AUC : 0.966668 (epoch : 443)
# [Epoch 444] Train - loss : 0.8299116 | Val - AUC : 0.9666681 | Best AUC : 0.9666681 (epoch : 444)
# [Epoch 445] Train - loss : 0.7809711 | Val - AUC : 0.9666687 | Best AUC : 0.9666687 (epoch : 445)
# [Epoch 446] Train - loss : 0.8330852 | Val - AUC : 0.9666705 | Best AUC : 0.9666705 (epoch : 446)
# [Epoch 447] Train - loss : 0.5639086 | Val - AUC : 0.9666748 | Best AUC : 0.9666748 (epoch : 447)
# [Epoch 448] Train - loss : 0.7624286 | Val - AUC : 0.9666755 | Best AUC : 0.9666755 (epoch : 448)
# [Epoch 449] Train - loss : 0.6654231 | Val - AUC : 0.9666797 | Best AUC : 0.9666797 (epoch : 449)
# [Epoch 450] Train - loss : 0.5967956 | Val - AUC : 0.9666723 | Best AUC : 0.9666797 (epoch : 449)
# [Epoch 451] Train - loss : 0.5379416 | Val - AUC : 0.9666731 | Best AUC : 0.9666797 (epoch : 449)
# [Epoch 452] Train - loss : 0.7499568 | Val - AUC : 0.9666709 | Best AUC : 0.9666797 (epoch : 449)
# [Epoch 453] Train - loss : 0.7038479 | Val - AUC : 0.9666697 | Best AUC : 0.9666797 (epoch : 449)
# [Epoch 454] Train - loss : 0.6746976 | Val - AUC : 0.9666721 | Best AUC : 0.9666797 (epoch : 449)
# [Epoch 455] Train - loss : 0.7667309 | Val - AUC : 0.9666747 | Best AUC : 0.9666797 (epoch : 449)
# [Epoch 456] Train - loss : 0.6480982 | Val - AUC : 0.966677 | Best AUC : 0.9666797 (epoch : 449)
# [Epoch 457] Train - loss : 0.718351 | Val - AUC : 0.9666745 | Best AUC : 0.9666797 (epoch : 449)
# [Epoch 458] Train - loss : 0.7097113 | Val - AUC : 0.9666706 | Best AUC : 0.9666797 (epoch : 449)
# [Epoch 459] Train - loss : 0.8199541 | Val - AUC : 0.9666755 | Best AUC : 0.9666797 (epoch : 449)
# [Epoch 460] Train - loss : 0.6747016 | Val - AUC : 0.9666749 | Best AUC : 0.9666797 (epoch : 449)
# [Epoch 461] Train - loss : 0.6175969 | Val - AUC : 0.9666745 | Best AUC : 0.9666797 (epoch : 449)
# [Epoch 462] Train - loss : 0.6235314 | Val - AUC : 0.9666741 | Best AUC : 0.9666797 (epoch : 449)
# [Epoch 463] Train - loss : 0.7441681 | Val - AUC : 0.9666734 | Best AUC : 0.9666797 (epoch : 449)
# [Epoch 464] Train - loss : 0.7114036 | Val - AUC : 0.9666759 | Best AUC : 0.9666797 (epoch : 449)
# [Epoch 465] Train - loss : 0.6775289 | Val - AUC : 0.9666708 | Best AUC : 0.9666797 (epoch : 449)
# [Epoch 466] Train - loss : 0.8229528 | Val - AUC : 0.9666749 | Best AUC : 0.9666797 (epoch : 449)
# [Epoch 467] Train - loss : 0.9009425 | Val - AUC : 0.9666713 | Best AUC : 0.9666797 (epoch : 449)
# [Epoch 468] Train - loss : 0.5480617 | Val - AUC : 0.9666724 | Best AUC : 0.9666797 (epoch : 449)
# [Epoch 469] Train - loss : 0.6042059 | Val - AUC : 0.9666713 | Best AUC : 0.9666797 (epoch : 449)
# [Epoch 470] Train - loss : 0.6538412 | Val - AUC : 0.9666729 | Best AUC : 0.9666797 (epoch : 449)
# [Epoch 471] Train - loss : 0.6995765 | Val - AUC : 0.9666715 | Best AUC : 0.9666797 (epoch : 449)
# [Epoch 472] Train - loss : 0.7227789 | Val - AUC : 0.9666733 | Best AUC : 0.9666797 (epoch : 449)
# [Epoch 473] Train - loss : 0.7803416 | Val - AUC : 0.9666729 | Best AUC : 0.9666797 (epoch : 449)
# [Epoch 474] Train - loss : 0.7467773 | Val - AUC : 0.9666748 | Best AUC : 0.9666797 (epoch : 449)
# [Epoch 475] Train - loss : 0.6797747 | Val - AUC : 0.966671 | Best AUC : 0.9666797 (epoch : 449)
# [Epoch 476] Train - loss : 0.6552811 | Val - AUC : 0.9666736 | Best AUC : 0.9666797 (epoch : 449)
# [Epoch 477] Train - loss : 0.6804895 | Val - AUC : 0.9666735 | Best AUC : 0.9666797 (epoch : 449)
# [Epoch 478] Train - loss : 0.5649983 | Val - AUC : 0.9666738 | Best AUC : 0.9666797 (epoch : 449)
# [Epoch 479] Train - loss : 0.8035608 | Val - AUC : 0.9666765 | Best AUC : 0.9666797 (epoch : 449)
# [Epoch 480] Train - loss : 0.8162116 | Val - AUC : 0.9666791 | Best AUC : 0.9666797 (epoch : 449)
# [Epoch 481] Train - loss : 0.7368825 | Val - AUC : 0.9666797 | Best AUC : 0.9666797 (epoch : 481)
# [Epoch 482] Train - loss : 0.7204342 | Val - AUC : 0.9666812 | Best AUC : 0.9666812 (epoch : 482)
# [Epoch 483] Train - loss : 0.6576165 | Val - AUC : 0.9666767 | Best AUC : 0.9666812 (epoch : 482)
# [Epoch 484] Train - loss : 0.6598832 | Val - AUC : 0.9666784 | Best AUC : 0.9666812 (epoch : 482)
# [Epoch 485] Train - loss : 0.7438779 | Val - AUC : 0.9666814 | Best AUC : 0.9666814 (epoch : 485)
# [Epoch 486] Train - loss : 0.7049144 | Val - AUC : 0.9666801 | Best AUC : 0.9666814 (epoch : 485)
# [Epoch 487] Train - loss : 0.6426841 | Val - AUC : 0.9666798 | Best AUC : 0.9666814 (epoch : 485)
# [Epoch 488] Train - loss : 0.6991753 | Val - AUC : 0.9666811 | Best AUC : 0.9666814 (epoch : 485)
# [Epoch 489] Train - loss : 0.7449083 | Val - AUC : 0.9666829 | Best AUC : 0.9666829 (epoch : 489)
# [Epoch 490] Train - loss : 0.6282271 | Val - AUC : 0.9666813 | Best AUC : 0.9666829 (epoch : 489)
# [Epoch 491] Train - loss : 0.6655846 | Val - AUC : 0.9666803 | Best AUC : 0.9666829 (epoch : 489)
# ...
# [Epoch 838] Train - loss : 0.5715759 | Val - AUC : 0.9669905 | Best AUC : 0.9669905 (epoch : 838)
# [Epoch 839] Train - loss : 0.8038659 | Val - AUC : 0.9669883 | Best AUC : 0.9669905 (epoch : 838)
# [Epoch 840] Train - loss : 0.5828345 | Val - AUC : 0.9669947 | Best AUC : 0.9669947 (epoch : 840)
# [Epoch 841] Train - loss : 0.4825097 | Val - AUC : 0.9669999 | Best AUC : 0.9669999 (epoch : 841)
# [Epoch 842] Train - loss : 0.5999332 | Val - AUC : 0.967 | Best AUC : 0.967 (epoch : 842)
# [Epoch 843] Train - loss : 0.8039087 | Val - AUC : 0.9670043 | Best AUC : 0.9670043 (epoch : 843)
# [Epoch 844] Train - loss : 0.699633 | Val - AUC : 0.9669944 | Best AUC : 0.9670043 (epoch : 843)
# [Epoch 845] Train - loss : 0.6813308 | Val - AUC : 0.9670042 | Best AUC : 0.9670043 (epoch : 843)
# [Epoch 846] Train - loss : 0.5999817 | Val - AUC : 0.9670051 | Best AUC : 0.9670051 (epoch : 846)
# [Epoch 847] Train - loss : 0.6742615 | Val - AUC : 0.9670074 | Best AUC : 0.9670074 (epoch : 847)
# [Epoch 848] Train - loss : 0.5414325 | Val - AUC : 0.9670097 | Best AUC : 0.9670097 (epoch : 848)
# [Epoch 849] Train - loss : 0.5858638 | Val - AUC : 0.9670194 | Best AUC : 0.9670194 (epoch : 849)
# [Epoch 850] Train - loss : 0.6315576 | Val - AUC : 0.9670207 | Best AUC : 0.9670207 (epoch : 850)
# [Epoch 851] Train - loss : 0.6111962 | Val - AUC : 0.9670191 | Best AUC : 0.9670207 (epoch : 850)
# [Epoch 852] Train - loss : 0.6361366 | Val - AUC : 0.9670226 | Best AUC : 0.9670226 (epoch : 852)
# [Epoch 853] Train - loss : 0.566306 | Val - AUC : 0.9670177 | Best AUC : 0.9670226 (epoch : 852)
# [Epoch 854] Train - loss : 0.5585724 | Val - AUC : 0.9670188 | Best AUC : 0.9670226 (epoch : 852)
# [Epoch 855] Train - loss : 0.7302966 | Val - AUC : 0.9670204 | Best AUC : 0.9670226 (epoch : 852)
# [Epoch 856] Train - loss : 0.6883809 | Val - AUC : 0.967024 | Best AUC : 0.967024 (epoch : 856)
# [Epoch 857] Train - loss : 0.6227584 | Val - AUC : 0.9670233 | Best AUC : 0.967024 (epoch : 856)
# [Epoch 858] Train - loss : 0.5640401 | Val - AUC : 0.9670267 | Best AUC : 0.9670267 (epoch : 858)
# [Epoch 859] Train - loss : 0.7140179 | Val - AUC : 0.967031 | Best AUC : 0.967031 (epoch : 859)
# [Epoch 860] Train - loss : 0.5482287 | Val - AUC : 0.9670331 | Best AUC : 0.9670331 (epoch : 860)
# [Epoch 861] Train - loss : 0.575589 | Val - AUC : 0.9670277 | Best AUC : 0.9670331 (epoch : 860)
# [Epoch 862] Train - loss : 0.6294976 | Val - AUC : 0.967033 | Best AUC : 0.9670331 (epoch : 860)
# [Epoch 863] Train - loss : 0.5554206 | Val - AUC : 0.9670324 | Best AUC : 0.9670331 (epoch : 860)
# [Epoch 864] Train - loss : 0.6563301 | Val - AUC : 0.9670406 | Best AUC : 0.9670406 (epoch : 864)
# [Epoch 865] Train - loss : 0.4730173 | Val - AUC : 0.9670354 | Best AUC : 0.9670406 (epoch : 864)
# [Epoch 866] Train - loss : 0.7242002 | Val - AUC : 0.9670378 | Best AUC : 0.9670406 (epoch : 864)
# [Epoch 867] Train - loss : 0.7177951 | Val - AUC : 0.9670422 | Best AUC : 0.9670422 (epoch : 867)
# [Epoch 868] Train - loss : 0.599497 | Val - AUC : 0.9670421 | Best AUC : 0.9670422 (epoch : 867)
# [Epoch 869] Train - loss : 0.5639938 | Val - AUC : 0.9670456 | Best AUC : 0.9670456 (epoch : 869)
# [Epoch 870] Train - loss : 0.6038345 | Val - AUC : 0.967044 | Best AUC : 0.9670456 (epoch : 869)
# [Epoch 871] Train - loss : 0.7399834 | Val - AUC : 0.9670477 | Best AUC : 0.9670477 (epoch : 871)
# [Epoch 872] Train - loss : 0.7462206 | Val - AUC : 0.9670451 | Best AUC : 0.9670477 (epoch : 871)
# [Epoch 873] Train - loss : 0.682311 | Val - AUC : 0.9670464 | Best AUC : 0.9670477 (epoch : 871)
# [Epoch 874] Train - loss : 0.7036943 | Val - AUC : 0.9670466 | Best AUC : 0.9670477 (epoch : 871)
# [Epoch 875] Train - loss : 0.7386011 | Val - AUC : 0.9670484 | Best AUC : 0.9670484 (epoch : 875)
# [Epoch 876] Train - loss : 0.7205344 | Val - AUC : 0.9670535 | Best AUC : 0.9670535 (epoch : 876)
# [Epoch 877] Train - loss : 0.6572265 | Val - AUC : 0.967055 | Best AUC : 0.967055 (epoch : 877)
# [Epoch 878] Train - loss : 0.6991601 | Val - AUC : 0.9670608 | Best AUC : 0.9670608 (epoch : 878)
# [Epoch 879] Train - loss : 0.5377151 | Val - AUC : 0.9670603 | Best AUC : 0.9670608 (epoch : 878)
# [Epoch 880] Train - loss : 0.5379974 | Val - AUC : 0.9670549 | Best AUC : 0.9670608 (epoch : 878)
# [Epoch 881] Train - loss : 0.5595501 | Val - AUC : 0.9670619 | Best AUC : 0.9670619 (epoch : 881)
# [Epoch 882] Train - loss : 0.6159659 | Val - AUC : 0.9670612 | Best AUC : 0.9670619 (epoch : 881)
# [Epoch 883] Train - loss : 0.6126304 | Val - AUC : 0.9670633 | Best AUC : 0.9670633 (epoch : 883)
# [Epoch 884] Train - loss : 0.5841225 | Val - AUC : 0.9670628 | Best AUC : 0.9670633 (epoch : 883)
# [Epoch 885] Train - loss : 0.5133645 | Val - AUC : 0.967066 | Best AUC : 0.967066 (epoch : 885)
# [Epoch 886] Train - loss : 0.6495239 | Val - AUC : 0.9670591 | Best AUC : 0.967066 (epoch : 885)
# [Epoch 887] Train - loss : 0.7106235 | Val - AUC : 0.9670665 | Best AUC : 0.9670665 (epoch : 887)
# [Epoch 888] Train - loss : 0.6336149 | Val - AUC : 0.9670763 | Best AUC : 0.9670763 (epoch : 888)
# [Epoch 889] Train - loss : 0.6234035 | Val - AUC : 0.9670805 | Best AUC : 0.9670805 (epoch : 889)
# [Epoch 890] Train - loss : 0.6973149 | Val - AUC : 0.9670803 | Best AUC : 0.9670805 (epoch : 889)
# [Epoch 891] Train - loss : 0.7494052 | Val - AUC : 0.9670821 | Best AUC : 0.9670821 (epoch : 891)
# [Epoch 892] Train - loss : 0.6278323 | Val - AUC : 0.967082 | Best AUC : 0.9670821 (epoch : 891)
# [Epoch 893] Train - loss : 0.6935317 | Val - AUC : 0.9670793 | Best AUC : 0.9670821 (epoch : 891)
# [Epoch 894] Train - loss : 0.6423411 | Val - AUC : 0.9670804 | Best AUC : 0.9670821 (epoch : 891)
# [Epoch 895] Train - loss : 0.6947945 | Val - AUC : 0.9670767 | Best AUC : 0.9670821 (epoch : 891)
# [Epoch 896] Train - loss : 0.6054681 | Val - AUC : 0.9670758 | Best AUC : 0.9670821 (epoch : 891)
# [Epoch 897] Train - loss : 0.6658898 | Val - AUC : 0.9670748 | Best AUC : 0.9670821 (epoch : 891)
# [Epoch 898] Train - loss : 0.592903 | Val - AUC : 0.9670791 | Best AUC : 0.9670821 (epoch : 891)
# [Epoch 899] Train - loss : 0.6931927 | Val - AUC : 0.9670812 | Best AUC : 0.9670821 (epoch : 891)
# [Epoch 900] Train - loss : 0.660628 | Val - AUC : 0.9670819 | Best AUC : 0.9670821 (epoch : 891)
# [Epoch 901] Train - loss : 0.5633181 | Val - AUC : 0.9670814 | Best AUC : 0.9670821 (epoch : 891)
# [Epoch 902] Train - loss : 0.6435714 | Val - AUC : 0.9670845 | Best AUC : 0.9670845 (epoch : 902)
# [Epoch 903] Train - loss : 0.5508796 | Val - AUC : 0.9670844 | Best AUC : 0.9670845 (epoch : 902)
# [Epoch 904] Train - loss : 0.5729662 | Val - AUC : 0.9670889 | Best AUC : 0.9670889 (epoch : 904)
# [Epoch 905] Train - loss : 0.7092421 | Val - AUC : 0.9670945 | Best AUC : 0.9670945 (epoch : 905)
# [Epoch 906] Train - loss : 0.5940649 | Val - AUC : 0.9670907 | Best AUC : 0.9670945 (epoch : 905)
# [Epoch 907] Train - loss : 0.5797821 | Val - AUC : 0.9670892 | Best AUC : 0.9670945 (epoch : 905)
# [Epoch 908] Train - loss : 0.5283433 | Val - AUC : 0.9670963 | Best AUC : 0.9670963 (epoch : 908)
# [Epoch 909] Train - loss : 0.5856165 | Val - AUC : 0.967094 | Best AUC : 0.9670963 (epoch : 908)
# [Epoch 910] Train - loss : 0.5969241 | Val - AUC : 0.9670981 | Best AUC : 0.9670981 (epoch : 910)
# [Epoch 911] Train - loss : 0.6001266 | Val - AUC : 0.9671024 | Best AUC : 0.9671024 (epoch : 911)
# [Epoch 912] Train - loss : 0.7107929 | Val - AUC : 0.9671069 | Best AUC : 0.9671069 (epoch : 912)
# [Epoch 913] Train - loss : 0.5874771 | Val - AUC : 0.9671055 | Best AUC : 0.9671069 (epoch : 912)
# [Epoch 914] Train - loss : 0.6460077 | Val - AUC : 0.9671041 | Best AUC : 0.9671069 (epoch : 912)
# [Epoch 915] Train - loss : 0.6732648 | Val - AUC : 0.9671071 | Best AUC : 0.9671071 (epoch : 915)
# [Epoch 916] Train - loss : 0.5178782 | Val - AUC : 0.9671118 | Best AUC : 0.9671118 (epoch : 916)
# [Epoch 917] Train - loss : 0.6039416 | Val - AUC : 0.9671075 | Best AUC : 0.9671118 (epoch : 916)
# [Epoch 918] Train - loss : 0.5846158 | Val - AUC : 0.9671079 | Best AUC : 0.9671118 (epoch : 916)
# [Epoch 919] Train - loss : 0.5810388 | Val - AUC : 0.9671034 | Best AUC : 0.9671118 (epoch : 916)
# [Epoch 920] Train - loss : 0.7151653 | Val - AUC : 0.9671082 | Best AUC : 0.9671118 (epoch : 916)
# [Epoch 921] Train - loss : 0.5736628 | Val - AUC : 0.9671062 | Best AUC : 0.9671118 (epoch : 916)
# [Epoch 922] Train - loss : 0.6396669 | Val - AUC : 0.9671039 | Best AUC : 0.9671118 (epoch : 916)
# [Epoch 923] Train - loss : 0.5125872 | Val - AUC : 0.9671075 | Best AUC : 0.9671118 (epoch : 916)
# [Epoch 924] Train - loss : 0.5147226 | Val - AUC : 0.9671124 | Best AUC : 0.9671124 (epoch : 924)
# [Epoch 925] Train - loss : 0.6457698 | Val - AUC : 0.9671126 | Best AUC : 0.9671126 (epoch : 925)
# [Epoch 926] Train - loss : 0.5842085 | Val - AUC : 0.9671206 | Best AUC : 0.9671206 (epoch : 926)
# [Epoch 927] Train - loss : 0.6788792 | Val - AUC : 0.9671144 | Best AUC : 0.9671206 (epoch : 926)
# [Epoch 928] Train - loss : 0.551893 | Val - AUC : 0.9671131 | Best AUC : 0.9671206 (epoch : 926)
# [Epoch 929] Train - loss : 0.7564222 | Val - AUC : 0.9671153 | Best AUC : 0.9671206 (epoch : 926)
# [Epoch 930] Train - loss : 0.6174987 | Val - AUC : 0.9671153 | Best AUC : 0.9671206 (epoch : 926)
# [Epoch 931] Train - loss : 0.5517732 | Val - AUC : 0.9671174 | Best AUC : 0.9671206 (epoch : 926)
# [Epoch 932] Train - loss : 0.6176507 | Val - AUC : 0.9671217 | Best AUC : 0.9671217 (epoch : 932)
# [Epoch 933] Train - loss : 0.6627629 | Val - AUC : 0.9671259 | Best AUC : 0.9671259 (epoch : 933)
# [Epoch 934] Train - loss : 0.5710141 | Val - AUC : 0.9671291 | Best AUC : 0.9671291 (epoch : 934)
# [Epoch 935] Train - loss : 0.5336124 | Val - AUC : 0.9671307 | Best AUC : 0.9671307 (epoch : 935)
# [Epoch 936] Train - loss : 0.7142694 | Val - AUC : 0.96713 | Best AUC : 0.9671307 (epoch : 935)
# [Epoch 937] Train - loss : 0.6067971 | Val - AUC : 0.9671318 | Best AUC : 0.9671318 (epoch : 937)
# [Epoch 938] Train - loss : 0.7265598 | Val - AUC : 0.9671364 | Best AUC : 0.9671364 (epoch : 938)
# [Epoch 939] Train - loss : 0.688142 | Val - AUC : 0.9671384 | Best AUC : 0.9671384 (epoch : 939)
# [Epoch 940] Train - loss : 0.6115067 | Val - AUC : 0.9671351 | Best AUC : 0.9671384 (epoch : 939)
# [Epoch 941] Train - loss : 0.6557216 | Val - AUC : 0.9671416 | Best AUC : 0.9671416 (epoch : 941)
# [Epoch 942] Train - loss : 0.8318971 | Val - AUC : 0.9671398 | Best AUC : 0.9671416 (epoch : 941)
# [Epoch 943] Train - loss : 0.5299676 | Val - AUC : 0.9671425 | Best AUC : 0.9671425 (epoch : 943)
# [Epoch 944] Train - loss : 0.5542821 | Val - AUC : 0.9671428 | Best AUC : 0.9671428 (epoch : 944)
# [Epoch 945] Train - loss : 0.5710987 | Val - AUC : 0.9671426 | Best AUC : 0.9671428 (epoch : 944)
# [Epoch 946] Train - loss : 0.607637 | Val - AUC : 0.9671453 | Best AUC : 0.9671453 (epoch : 946)
# [Epoch 947] Train - loss : 0.7413187 | Val - AUC : 0.967144 | Best AUC : 0.9671453 (epoch : 946)
# [Epoch 948] Train - loss : 0.6903631 | Val - AUC : 0.9671501 | Best AUC : 0.9671501 (epoch : 948)
# [Epoch 949] Train - loss : 0.7117622 | Val - AUC : 0.9671487 | Best AUC : 0.9671501 (epoch : 948)
# [Epoch 950] Train - loss : 0.6123235 | Val - AUC : 0.9671449 | Best AUC : 0.9671501 (epoch : 948)
# [Epoch 951] Train - loss : 0.6519565 | Val - AUC : 0.9671485 | Best AUC : 0.9671501 (epoch : 948)
# [Epoch 952] Train - loss : 0.6191877 | Val - AUC : 0.9671448 | Best AUC : 0.9671501 (epoch : 948)
# [Epoch 953] Train - loss : 0.6281867 | Val - AUC : 0.9671509 | Best AUC : 0.9671509 (epoch : 953)
# [Epoch 954] Train - loss : 0.4996008 | Val - AUC : 0.9671602 | Best AUC : 0.9671602 (epoch : 954)
# [Epoch 955] Train - loss : 0.6249408 | Val - AUC : 0.9671625 | Best AUC : 0.9671625 (epoch : 955)
# [Epoch 956] Train - loss : 0.8001678 | Val - AUC : 0.9671581 | Best AUC : 0.9671625 (epoch : 955)
# [Epoch 957] Train - loss : 0.4759717 | Val - AUC : 0.9671568 | Best AUC : 0.9671625 (epoch : 955)
# [Epoch 958] Train - loss : 0.7135281 | Val - AUC : 0.9671588 | Best AUC : 0.9671625 (epoch : 955)
# [Epoch 959] Train - loss : 0.5373989 | Val - AUC : 0.967157 | Best AUC : 0.9671625 (epoch : 955)
# [Epoch 960] Train - loss : 0.729922 | Val - AUC : 0.9671579 | Best AUC : 0.9671625 (epoch : 955)
# [Epoch 961] Train - loss : 0.6347727 | Val - AUC : 0.967157 | Best AUC : 0.9671625 (epoch : 955)
# [Epoch 962] Train - loss : 0.5525904 | Val - AUC : 0.9671585 | Best AUC : 0.9671625 (epoch : 955)
# [Epoch 963] Train - loss : 0.7229616 | Val - AUC : 0.9671583 | Best AUC : 0.9671625 (epoch : 955)
# [Epoch 964] Train - loss : 0.7194601 | Val - AUC : 0.9671618 | Best AUC : 0.9671625 (epoch : 955)
# [Epoch 965] Train - loss : 0.6157952 | Val - AUC : 0.9671604 | Best AUC : 0.9671625 (epoch : 955)
# [Epoch 966] Train - loss : 0.6835355 | Val - AUC : 0.9671615 | Best AUC : 0.9671625 (epoch : 955)
# [Epoch 967] Train - loss : 0.5749677 | Val - AUC : 0.9671608 | Best AUC : 0.9671625 (epoch : 955)
# [Epoch 968] Train - loss : 0.6575611 | Val - AUC : 0.96716 | Best AUC : 0.9671625 (epoch : 955)
# [Epoch 969] Train - loss : 0.5167708 | Val - AUC : 0.9671699 | Best AUC : 0.9671699 (epoch : 969)
# [Epoch 970] Train - loss : 0.4844601 | Val - AUC : 0.9671725 | Best AUC : 0.9671725 (epoch : 970)
# [Epoch 971] Train - loss : 0.5412915 | Val - AUC : 0.9671728 | Best AUC : 0.9671728 (epoch : 971)
# [Epoch 972] Train - loss : 0.6731658 | Val - AUC : 0.9671743 | Best AUC : 0.9671743 (epoch : 972)
# [Epoch 973] Train - loss : 0.7742829 | Val - AUC : 0.9671705 | Best AUC : 0.9671743 (epoch : 972)
# [Epoch 974] Train - loss : 0.5650647 | Val - AUC : 0.9671691 | Best AUC : 0.9671743 (epoch : 972)
# [Epoch 975] Train - loss : 0.5914985 | Val - AUC : 0.9671729 | Best AUC : 0.9671743 (epoch : 972)
# [Epoch 976] Train - loss : 0.5143926 | Val - AUC : 0.9671751 | Best AUC : 0.9671751 (epoch : 976)
# [Epoch 977] Train - loss : 0.5715021 | Val - AUC : 0.9671705 | Best AUC : 0.9671751 (epoch : 976)
# [Epoch 978] Train - loss : 0.5406532 | Val - AUC : 0.9671748 | Best AUC : 0.9671751 (epoch : 976)
# [Epoch 979] Train - loss : 0.5310501 | Val - AUC : 0.9671798 | Best AUC : 0.9671798 (epoch : 979)
# [Epoch 980] Train - loss : 0.6785056 | Val - AUC : 0.9671764 | Best AUC : 0.9671798 (epoch : 979)
# [Epoch 981] Train - loss : 0.6727351 | Val - AUC : 0.9671736 | Best AUC : 0.9671798 (epoch : 979)
# [Epoch 982] Train - loss : 0.4821391 | Val - AUC : 0.967173 | Best AUC : 0.9671798 (epoch : 979)
# [Epoch 983] Train - loss : 0.6107063 | Val - AUC : 0.9671778 | Best AUC : 0.9671798 (epoch : 979)
# [Epoch 984] Train - loss : 0.6596776 | Val - AUC : 0.9671732 | Best AUC : 0.9671798 (epoch : 979)
# [Epoch 985] Train - loss : 0.5655861 | Val - AUC : 0.9671777 | Best AUC : 0.9671798 (epoch : 979)
# [Epoch 986] Train - loss : 0.5780197 | Val - AUC : 0.9671769 | Best AUC : 0.9671798 (epoch : 979)
# [Epoch 987] Train - loss : 0.5927385 | Val - AUC : 0.9671773 | Best AUC : 0.9671798 (epoch : 979)
# [Epoch 988] Train - loss : 0.7247511 | Val - AUC : 0.9671842 | Best AUC : 0.9671842 (epoch : 988)
# [Epoch 989] Train - loss : 0.6537083 | Val - AUC : 0.9671868 | Best AUC : 0.9671868 (epoch : 989)
# [Epoch 990] Train - loss : 0.6179587 | Val - AUC : 0.9671881 | Best AUC : 0.9671881 (epoch : 990)
# [Epoch 991] Train - loss : 0.5092589 | Val - AUC : 0.967186 | Best AUC : 0.9671881 (epoch : 990)
# [Epoch 992] Train - loss : 0.6561737 | Val - AUC : 0.9671849 | Best AUC : 0.9671881 (epoch : 990)
# [Epoch 993] Train - loss : 0.5361342 | Val - AUC : 0.9671898 | Best AUC : 0.9671898 (epoch : 993)
# [Epoch 994] Train - loss : 0.5797952 | Val - AUC : 0.9671935 | Best AUC : 0.9671935 (epoch : 994)
# [Epoch 995] Train - loss : 0.6871583 | Val - AUC : 0.9671915 | Best AUC : 0.9671935 (epoch : 994)
# [Epoch 996] Train - loss : 0.5696759 | Val - AUC : 0.9671921 | Best AUC : 0.9671935 (epoch : 994)
# [Epoch 997] Train - loss : 0.6521415 | Val - AUC : 0.9671999 | Best AUC : 0.9671999 (epoch : 997)
# [Epoch 998] Train - loss : 0.5405753 | Val - AUC : 0.967195 | Best AUC : 0.9671999 (epoch : 997)
# [Epoch 999] Train - loss : 0.5694922 | Val - AUC : 0.9671944 | Best AUC : 0.9671999 (epoch : 997)
# [2020-12-17 21:35:03,553][INFO][base.py:96] Succeed to load best model, device: 'cpu'

# %%
best_latent_data_list = result_dict["val_result_dict_list"][997]["latent_data_list"]
abnormal_label_list = [abnormal_label.item() for x, y, abnormal_label in dataset_factory.test_dataset]

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

pca = PCA(n_components=2)

pca.fit(best_latent_data_list)
pca_best_latent_data_list = pca.transform(best_latent_data_list)

pca_normal_latent_data_list = [
    pca_best_latent_data for pca_best_latent_data, abnormal_label in 
    zip(pca_best_latent_data_list, abnormal_label_list) if abnormal_label == 0
]
pca_abnormal_latent_data_list = [
    pca_best_latent_data for pca_best_latent_data, abnormal_label in
    zip(pca_best_latent_data_list, abnormal_label_list) if abnormal_label == 1
]

# %%
fig = plt.figure(figsize=(15, 15))

plt.scatter(
    x=list(map(lambda data: data[0], pca_normal_latent_data_list)),
    y=list(map(lambda data: data[1], pca_normal_latent_data_list)),
    label="Normal",
    color="blue",
    alpha=0.3
)
plt.scatter(
    x=list(map(lambda data: data[0], pca_abnormal_latent_data_list)),
    y=list(map(lambda data: data[1], pca_abnormal_latent_data_list)),
    label="Abormal",
    color="red",
    alpha=0.3
)

plt.xlim(-2, 2)
plt.ylim(-2, 2)

font_size = 15

plt.xlabel("PC1", fontsize=font_size)
plt.ylabel("PC2", fontsize=font_size)
plt.xticks(fontsize=font_size)
plt.yticks(fontsize=font_size)
plt.legend(fontsize=font_size)

plt.savefig("./plot/oesae_margin001_latent_2d.png")

plt.show()

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

pca = PCA(n_components=3)

pca.fit(best_latent_data_list)
pca_best_latent_data_list = pca.transform(best_latent_data_list)

pca_normal_latent_data_list = [
    pca_best_latent_data for pca_best_latent_data, abnormal_label in 
    zip(pca_best_latent_data_list, abnormal_label_list) if abnormal_label == 0
]
pca_abnormal_latent_data_list = [
    pca_best_latent_data for pca_best_latent_data, abnormal_label in
    zip(pca_best_latent_data_list, abnormal_label_list) if abnormal_label == 1
]

# %%
fig = plt.figure(figsize=(15, 15))
ax = fig.gca(projection='3d')

ax.scatter(
    list(map(lambda data: data[0], pca_normal_latent_data_list)),
    list(map(lambda data: data[1], pca_normal_latent_data_list)),
    list(map(lambda data: data[2], pca_normal_latent_data_list)),
    label="Normal",
    color="blue",
    alpha=0.3
)
ax.scatter(
    list(map(lambda data: data[0], pca_abnormal_latent_data_list)),
    list(map(lambda data: data[1], pca_abnormal_latent_data_list)),
    list(map(lambda data: data[2], pca_abnormal_latent_data_list)),
    label="Abormal",
    color="red",
    alpha=0.3
)

ax.set_xlim(-2, 2)
ax.set_ylim(-2, 2)
ax.set_zlim(-2, 2)

font_size = 12

ax.set_xlabel("PC1", fontsize=font_size)
ax.set_ylabel("PC2", fontsize=font_size)
ax.set_zlabel("PC3", fontsize=font_size)
ax.tick_params(axis="x", labelsize=font_size)
ax.tick_params(axis="y", labelsize=font_size)
ax.tick_params(axis="z", labelsize=font_size)
ax.legend(fontsize=font_size)


ax.view_init(elev=10., azim=300)

# ax.view_init(elev=10., azim=310)
plt.savefig("./plot/oesae_margin001_latent_3d.png")

plt.show()
