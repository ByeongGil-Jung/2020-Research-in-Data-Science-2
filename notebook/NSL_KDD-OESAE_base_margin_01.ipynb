# %%
import os
import pathlib
import sys

default_dir_path = str(pathlib.Path(os.getcwd()).parent.absolute())

sys.path.append(default_dir_path)

from properties import ApplicationProperties
# Out:
# [2020-12-17 15:35:02,543][INFO][properties.py:22] Complete to apply the random seed, RANDOM_SEED : 777

# %%
from torch import optim
from torch.nn import functional as F
import torch

from dataset.factory import DatasetFactory
from dataset.nsl_kdd_dataset import NSLKDDDataFrameFactory, NSLKDDDataset
from domain.criterion import Criterion
from domain.hyperparameters import Hyperparameters
from domain.metadata import ModelFileMetadata
from logger import logger
from model.factory import ModelFactory
from trainer.base import TrainerBase
from trainer.factory import TrainerFactory

# %%
from sklearn import preprocessing
from sklearn.metrics import roc_curve, auc
from sklearn.model_selection import train_test_split
from torch import nn, optim
from torch.utils.data import Dataset, DataLoader
import numpy as np
import pandas as pd
import tqdm.notebook as tqdm

# %%
device = "cpu"
data_name = "nsl_kdd_outlier"
model_name = "oesae_margin01"
n_epoch = 1000

# %%
dataset_factory = DatasetFactory.create(data_name=data_name)
# Out:
# [2020-12-17 15:35:04,986][INFO][nsl_kdd_dataset.py:98] Success to load dataset dataframe : train
# [2020-12-17 15:35:05,080][INFO][nsl_kdd_dataset.py:98] Success to load dataset dataframe : test
# [2020-12-17 15:35:05,312][INFO][nsl_kdd_dataset.py:110] Success to load dataset dataframe : entire
# [2020-12-17 15:35:06,246][INFO][nsl_kdd_dataset.py:164] Entire data size : 148517
# [2020-12-17 15:35:06,255][INFO][nsl_kdd_dataset.py:165] Normal data size : 77054
# [2020-12-17 15:35:06,258][INFO][nsl_kdd_dataset.py:166] Abnormal data size : 7146
# [2020-12-17 15:35:06,260][INFO][nsl_kdd_dataset.py:167] Outlier data size : 7146
# [2020-12-17 15:35:06,263][INFO][nsl_kdd_dataset.py:168] Normal test data size : 7146
# [2020-12-17 15:35:06,265][INFO][nsl_kdd_dataset.py:169] Training data size : 69908
# [2020-12-17 15:35:06,267][INFO][nsl_kdd_dataset.py:170] Test data size : 14292
# [2020-12-17 15:35:07,045][INFO][factory.py:109] Success to fit data with scaling
# [2020-12-17 15:35:07,430][INFO][factory.py:118] Success to transform data with scaling
# [2020-12-17 15:35:07,450][INFO][factory.py:153] Data selected : 'nsl_kdd_outlier'

# %%
train_dataloader, outlier_dataloader = dataset_factory.train_dataloader
val_dataloader = dataset_factory.val_dataloader

# %%
class AE(nn.Module):
    
    def __init__(self, input_size):  # 117
        super(AE, self).__init__()
        self.encoder_1 = nn.Sequential(
            nn.Linear(in_features=input_size, out_features=64, bias=True),
            nn.Tanh(),
            nn.Linear(in_features=64, out_features=32, bias=True),
            nn.Tanh(),
            nn.Linear(in_features=32, out_features=16, bias=True),
            nn.Tanh()
        )
        self.decoder_1 = nn.Sequential(
            nn.Linear(in_features=16, out_features=32, bias=True),
            nn.Tanh(),
            nn.Linear(in_features=32, out_features=64, bias=True),
            nn.Tanh(),
            nn.Linear(in_features=64, out_features=input_size, bias=True),
            nn.Tanh()
        )
        
        self.he_init_weight()
        
    def forward(self, x):
        z = self.encoder_1(x)
        x_hat = self.decoder_1(z)
        return x_hat, z
    
    def he_init_weight(self):
        for module in self.modules():
            if isinstance(module, nn.Conv2d):
                nn.init.kaiming_normal_(module.weight.data)
            elif isinstance(module, nn.Linear):
                nn.init.kaiming_normal_(module.weight.data)
            elif isinstance(module, nn.ConvTranspose2d):
                nn.init.kaiming_normal_(module.weight.data)

# %%
from copy import deepcopy
import pickle
import time

from sklearn.metrics import roc_curve, auc
import torch

from domain.criterion import Criterion
from trainer.base import TrainerBase

time.time()


class OESAETrainer(TrainerBase):

    def __init__(self, model, model_file_metadata, train_loader, outlier_loader, val_loader, test_loader, hyperparameters,
                 tqdm_env='script'):
        super(OESAETrainer, self).__init__(model, model_file_metadata, train_loader, val_loader, test_loader,
                                        hyperparameters, tqdm_env)
        self.outlier_loader = outlier_loader

    def train(self):
        self.model.train()

        train_result_dict_list = list()
        val_result_dict_list = list()

        best_loss = 999999
        best_auc = 0
        best_loss_epoch = 0
        best_auc_epoch = 0

        # Set hyperparameters
        optimizer_cls = self.hyperparameters.optimizer_cls
        lr = self.hyperparameters.lr
        weight_decay = self.hyperparameters.weight_decay
        n_epoch = self.hyperparameters.n_epoch
        train_criterion = self.hyperparameters.train_criterion
        val_criterion = self.hyperparameters.val_criterion
        lambda_ = self.hyperparameters.lambda_
        margin = self.hyperparameters.margin
        device = self.hyperparameters.device

        optimizer = optimizer_cls(self.model.parameters(), lr=lr, weight_decay=weight_decay)

        for epoch in self.tqdm.tqdm(range(n_epoch)):
            total_loss = 0
            n_batch = 0

            for i, ((data_batch, label_batch, abnormal_label_batch), (outlier_data_batch, outlier_label_batch, outlier_abnormal_label_batch)) in enumerate(zip(self.train_loader, self.outlier_loader)):
                entire_data_batch = torch.cat([data_batch, outlier_data_batch], dim=0)
                entire_data_batch = entire_data_batch.to(device)

                # Optimization
                optimizer.zero_grad()
                pred_data_batch, latent_data_batch = self.model(entire_data_batch)

                in_pred_data_batch = pred_data_batch[:len(data_batch)]
                out_pred_data_batch = pred_data_batch[len(data_batch):]

                in_latent_data_batch = latent_data_batch[:len(data_batch)]
                out_latent_data_batch = latent_data_batch[len(data_batch):]

                if in_latent_data_batch.shape != out_latent_data_batch.shape:
                    continue

                mse_loss = val_criterion(data_batch, in_pred_data_batch, in_latent_data_batch, lambda_)
                triple_margin_loss = train_criterion(
                    anchor=torch.zeros(size=in_latent_data_batch.shape),
                    positive=in_latent_data_batch,
                    negative=out_latent_data_batch,
                    margin=margin
                )
                loss = mse_loss + triple_margin_loss

                loss.backward()
                optimizer.step()

                total_loss += loss.item()
                n_batch += 1

            current_loss = total_loss / n_batch

            train_result_dict = dict(
                loss=current_loss
            )
            val_result_dict = self.validate()

            # Early stopping
            if val_result_dict['loss'] < best_loss:
                best_loss = val_result_dict['loss']
                best_loss_epoch = epoch
                # self.best_model_state_dict = deepcopy(self.model.state_dict())

            if best_auc < val_result_dict['auc']:
                best_auc = val_result_dict['auc']
                best_auc_epoch = epoch
                self.best_model = deepcopy(self.model.state_dict())

            # Print
            print(
                f"[Epoch {epoch}] "
                f"Train - loss : {round(train_result_dict['loss'], 7)} | "
                f"Val - AUC : {round(val_result_dict['auc'], 7)} | "
                f"Best AUC : {round(best_auc, 7)} (epoch : {best_auc_epoch})"
            )

            # Save Model & Record dictW
            record_dict = dict(
                train_result_dict=train_result_dict,
                val_result_dict=val_result_dict
            )

            self.save_model(epoch=epoch)
            self.save_record(record=record_dict, epoch=epoch)

            train_result_dict_list.append(train_result_dict)
            val_result_dict_list.append(val_result_dict)

        # Save last result
        entire_record_dict = dict(
            train_result_dict_list=train_result_dict_list,
            val_result_dict_list=val_result_dict_list
        )
        torch.save(self.best_model, self.model_file_metadata.get_best_model_file_path())

        # Save entire_record_dict
        with open(self.model_file_metadata.get_entire_record_file_path(), "wb") as f:
            pickle.dump(entire_record_dict, f, protocol=pickle.HIGHEST_PROTOCOL)

        # Load best model
        self.load_best_model()

        return entire_record_dict

    def validate(self):
        self.model.eval()

        total_loss = 0
        n_batch = 0

        latent_data_list = list()
        reconstructino_error_list = list()
        abnormal_label_list = list()

        # Set hyperparameters
        device = self.hyperparameters.device
        val_criterion = self.hyperparameters.val_criterion
        lambda_ = self.hyperparameters.lambda_

        for i, (data_batch, label_batch, abnormal_label_batch) in enumerate(self.val_loader):
            data_batch = data_batch.to(device)
            abnormal_label_batch = abnormal_label_batch.to(device)

            with torch.no_grad():
                pred_data_batch, latent_data_batch = self.model(data_batch)
                loss = val_criterion(data_batch, pred_data_batch, latent_data_batch, lambda_).item()
                reconstruction_error_batch = Criterion.reconstruction_error(x=data_batch, x_hat=pred_data_batch)

            latent_data_list.append(latent_data_batch)
            reconstructino_error_list.append(reconstruction_error_batch)
            abnormal_label_list.append(abnormal_label_batch)

            total_loss += loss
            n_batch += 1

        latent_data_list = torch.cat(latent_data_list).cpu().numpy()
        reconstruction_error_list = torch.cat(reconstructino_error_list).cpu().numpy()
        abnormal_label_list = torch.cat(abnormal_label_list).cpu().numpy()

        fpr, tpr, thresholds = roc_curve(abnormal_label_list, reconstruction_error_list)
        auc_value = auc(fpr, tpr)

        current_loss = total_loss / n_batch

        return dict(loss=current_loss, auc=auc_value, latent_data_list=latent_data_list)

# %%
ae_model = AE(input_size=118)

# %%
ae_model.to(device)
# Out:
# AE(
#   (encoder_1): Sequential(
#     (0): Linear(in_features=118, out_features=64, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=64, out_features=32, bias=True)
#     (3): Tanh()
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): Tanh()
#   )
#   (decoder_1): Sequential(
#     (0): Linear(in_features=16, out_features=32, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=32, out_features=64, bias=True)
#     (3): Tanh()
#     (4): Linear(in_features=64, out_features=118, bias=True)
#     (5): Tanh()
#   )
# )

# %%
trainer = OESAETrainer(
    model=ae_model,
    model_file_metadata=ModelFileMetadata(model_name=model_name),
    train_loader=train_dataloader,
    val_loader=val_dataloader,
    outlier_loader=outlier_dataloader,
    test_loader=dataset_factory.test_dataloader,
    hyperparameters=Hyperparameters(
        optimizer_cls=optim.Adadelta,
        train_criterion=Criterion.triple_margin_loss,
        val_criterion=Criterion.sae_loss,
        lambda_=10,
        margin=0.1,
        n_epoch=n_epoch,
        lr=1e-3,
        weight_decay=0,
        device=device
    ),
    tqdm_env="jupyter"
)
# Out:
# [2020-12-17 15:35:07,693][INFO][base.py:40] Model set to 'cpu'

# %%
# Adadelta (tanh, lambda 10)
result_dict = trainer.train()
# Out:
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# [Epoch 0] Train - loss : 2.8607704 | Val - AUC : 0.9646255 | Best AUC : 0.9646255 (epoch : 0)
# [Epoch 1] Train - loss : 2.7491388 | Val - AUC : 0.9647964 | Best AUC : 0.9647964 (epoch : 1)
# [Epoch 2] Train - loss : 2.7186169 | Val - AUC : 0.9648403 | Best AUC : 0.9648403 (epoch : 2)
# [Epoch 3] Train - loss : 2.6257842 | Val - AUC : 0.9648218 | Best AUC : 0.9648403 (epoch : 2)
# [Epoch 4] Train - loss : 2.6534752 | Val - AUC : 0.9648031 | Best AUC : 0.9648403 (epoch : 2)
# [Epoch 5] Train - loss : 2.3552932 | Val - AUC : 0.9647877 | Best AUC : 0.9648403 (epoch : 2)
# [Epoch 6] Train - loss : 2.337949 | Val - AUC : 0.9648032 | Best AUC : 0.9648403 (epoch : 2)
# [Epoch 7] Train - loss : 2.3416492 | Val - AUC : 0.9648492 | Best AUC : 0.9648492 (epoch : 7)
# [Epoch 8] Train - loss : 2.1077103 | Val - AUC : 0.9649006 | Best AUC : 0.9649006 (epoch : 8)
# [Epoch 9] Train - loss : 2.0240086 | Val - AUC : 0.9649442 | Best AUC : 0.9649442 (epoch : 9)
# [Epoch 10] Train - loss : 2.2274636 | Val - AUC : 0.9649916 | Best AUC : 0.9649916 (epoch : 10)
# [Epoch 11] Train - loss : 2.0706445 | Val - AUC : 0.9650417 | Best AUC : 0.9650417 (epoch : 11)
# [Epoch 12] Train - loss : 1.9624125 | Val - AUC : 0.9651076 | Best AUC : 0.9651076 (epoch : 12)
# [Epoch 13] Train - loss : 1.9659041 | Val - AUC : 0.9651483 | Best AUC : 0.9651483 (epoch : 13)
# [Epoch 14] Train - loss : 1.8267684 | Val - AUC : 0.9651904 | Best AUC : 0.9651904 (epoch : 14)
# [Epoch 15] Train - loss : 1.812556 | Val - AUC : 0.9652235 | Best AUC : 0.9652235 (epoch : 15)
# [Epoch 16] Train - loss : 1.7951491 | Val - AUC : 0.9652613 | Best AUC : 0.9652613 (epoch : 16)
# [Epoch 17] Train - loss : 1.7912457 | Val - AUC : 0.9652907 | Best AUC : 0.9652907 (epoch : 17)
# [Epoch 18] Train - loss : 1.8465963 | Val - AUC : 0.9653224 | Best AUC : 0.9653224 (epoch : 18)
# [Epoch 19] Train - loss : 1.6789309 | Val - AUC : 0.9653498 | Best AUC : 0.9653498 (epoch : 19)
# [Epoch 20] Train - loss : 1.7071873 | Val - AUC : 0.9653841 | Best AUC : 0.9653841 (epoch : 20)
# [Epoch 21] Train - loss : 1.6691274 | Val - AUC : 0.9654082 | Best AUC : 0.9654082 (epoch : 21)
# [Epoch 22] Train - loss : 1.5917588 | Val - AUC : 0.9654398 | Best AUC : 0.9654398 (epoch : 22)
# [Epoch 23] Train - loss : 1.7715724 | Val - AUC : 0.9654591 | Best AUC : 0.9654591 (epoch : 23)
# [Epoch 24] Train - loss : 1.8244658 | Val - AUC : 0.9654796 | Best AUC : 0.9654796 (epoch : 24)
# [Epoch 25] Train - loss : 1.4959171 | Val - AUC : 0.9655121 | Best AUC : 0.9655121 (epoch : 25)
# [Epoch 26] Train - loss : 1.5185407 | Val - AUC : 0.9655413 | Best AUC : 0.9655413 (epoch : 26)
# [Epoch 27] Train - loss : 1.6259272 | Val - AUC : 0.9655689 | Best AUC : 0.9655689 (epoch : 27)
# [Epoch 28] Train - loss : 1.6681374 | Val - AUC : 0.9656013 | Best AUC : 0.9656013 (epoch : 28)
# [Epoch 29] Train - loss : 1.6114714 | Val - AUC : 0.9656266 | Best AUC : 0.9656266 (epoch : 29)
# [Epoch 30] Train - loss : 1.5978661 | Val - AUC : 0.9656524 | Best AUC : 0.9656524 (epoch : 30)
# [Epoch 31] Train - loss : 1.505076 | Val - AUC : 0.9656842 | Best AUC : 0.9656842 (epoch : 31)
# [Epoch 32] Train - loss : 1.3749533 | Val - AUC : 0.9657027 | Best AUC : 0.9657027 (epoch : 32)
# [Epoch 33] Train - loss : 1.5068456 | Val - AUC : 0.9657298 | Best AUC : 0.9657298 (epoch : 33)
# [Epoch 34] Train - loss : 1.527175 | Val - AUC : 0.9657591 | Best AUC : 0.9657591 (epoch : 34)
# [Epoch 35] Train - loss : 1.2954036 | Val - AUC : 0.9657754 | Best AUC : 0.9657754 (epoch : 35)
# [Epoch 36] Train - loss : 1.4915489 | Val - AUC : 0.9658016 | Best AUC : 0.9658016 (epoch : 36)
# [Epoch 37] Train - loss : 1.4430121 | Val - AUC : 0.9658236 | Best AUC : 0.9658236 (epoch : 37)
# [Epoch 38] Train - loss : 1.3918037 | Val - AUC : 0.9658397 | Best AUC : 0.9658397 (epoch : 38)
# [Epoch 39] Train - loss : 1.5260108 | Val - AUC : 0.9658628 | Best AUC : 0.9658628 (epoch : 39)
# [Epoch 40] Train - loss : 1.2727343 | Val - AUC : 0.9658815 | Best AUC : 0.9658815 (epoch : 40)
# [Epoch 41] Train - loss : 1.2895842 | Val - AUC : 0.965901 | Best AUC : 0.965901 (epoch : 41)
# [Epoch 42] Train - loss : 1.4790196 | Val - AUC : 0.9659135 | Best AUC : 0.9659135 (epoch : 42)
# [Epoch 43] Train - loss : 1.346025 | Val - AUC : 0.9659301 | Best AUC : 0.9659301 (epoch : 43)
# [Epoch 44] Train - loss : 1.3227093 | Val - AUC : 0.9659555 | Best AUC : 0.9659555 (epoch : 44)
# [Epoch 45] Train - loss : 1.2873199 | Val - AUC : 0.9659782 | Best AUC : 0.9659782 (epoch : 45)
# [Epoch 46] Train - loss : 1.3850364 | Val - AUC : 0.965993 | Best AUC : 0.965993 (epoch : 46)
# [Epoch 47] Train - loss : 1.4005243 | Val - AUC : 0.9660084 | Best AUC : 0.9660084 (epoch : 47)
# [Epoch 48] Train - loss : 1.5787207 | Val - AUC : 0.9660257 | Best AUC : 0.9660257 (epoch : 48)
# [Epoch 49] Train - loss : 1.2657737 | Val - AUC : 0.9660455 | Best AUC : 0.9660455 (epoch : 49)
# [Epoch 50] Train - loss : 1.3509366 | Val - AUC : 0.9660605 | Best AUC : 0.9660605 (epoch : 50)
# [Epoch 51] Train - loss : 1.3521546 | Val - AUC : 0.9660753 | Best AUC : 0.9660753 (epoch : 51)
# [Epoch 52] Train - loss : 1.2792949 | Val - AUC : 0.9660896 | Best AUC : 0.9660896 (epoch : 52)
# [Epoch 53] Train - loss : 1.3766866 | Val - AUC : 0.9661011 | Best AUC : 0.9661011 (epoch : 53)
# [Epoch 54] Train - loss : 1.420421 | Val - AUC : 0.96612 | Best AUC : 0.96612 (epoch : 54)
# [Epoch 55] Train - loss : 1.2023298 | Val - AUC : 0.9661334 | Best AUC : 0.9661334 (epoch : 55)
# [Epoch 56] Train - loss : 1.1107299 | Val - AUC : 0.9661481 | Best AUC : 0.9661481 (epoch : 56)
# [Epoch 57] Train - loss : 1.2398678 | Val - AUC : 0.966163 | Best AUC : 0.966163 (epoch : 57)
# [Epoch 58] Train - loss : 1.2473801 | Val - AUC : 0.9661719 | Best AUC : 0.9661719 (epoch : 58)
# [Epoch 59] Train - loss : 1.1941087 | Val - AUC : 0.9661876 | Best AUC : 0.9661876 (epoch : 59)
# [Epoch 60] Train - loss : 1.1440943 | Val - AUC : 0.9661982 | Best AUC : 0.9661982 (epoch : 60)
# [Epoch 61] Train - loss : 1.1857876 | Val - AUC : 0.96621 | Best AUC : 0.96621 (epoch : 61)
# [Epoch 62] Train - loss : 1.2361961 | Val - AUC : 0.9662228 | Best AUC : 0.9662228 (epoch : 62)
# [Epoch 63] Train - loss : 1.2540852 | Val - AUC : 0.9662291 | Best AUC : 0.9662291 (epoch : 63)
# [Epoch 64] Train - loss : 1.2485503 | Val - AUC : 0.966246 | Best AUC : 0.966246 (epoch : 64)
# [Epoch 65] Train - loss : 1.2021252 | Val - AUC : 0.9662539 | Best AUC : 0.9662539 (epoch : 65)
# [Epoch 66] Train - loss : 1.1077692 | Val - AUC : 0.9662687 | Best AUC : 0.9662687 (epoch : 66)
# [Epoch 67] Train - loss : 1.2642266 | Val - AUC : 0.9662716 | Best AUC : 0.9662716 (epoch : 67)
# [Epoch 68] Train - loss : 1.1441935 | Val - AUC : 0.9662831 | Best AUC : 0.9662831 (epoch : 68)
# [Epoch 69] Train - loss : 1.1050468 | Val - AUC : 0.966287 | Best AUC : 0.966287 (epoch : 69)
# [Epoch 70] Train - loss : 1.165702 | Val - AUC : 0.9662911 | Best AUC : 0.9662911 (epoch : 70)
# [Epoch 71] Train - loss : 1.234924 | Val - AUC : 0.9663064 | Best AUC : 0.9663064 (epoch : 71)
# [Epoch 72] Train - loss : 1.003275 | Val - AUC : 0.9663154 | Best AUC : 0.9663154 (epoch : 72)
# [Epoch 73] Train - loss : 1.1781062 | Val - AUC : 0.9663244 | Best AUC : 0.9663244 (epoch : 73)
# [Epoch 74] Train - loss : 1.0902518 | Val - AUC : 0.9663325 | Best AUC : 0.9663325 (epoch : 74)
# [Epoch 75] Train - loss : 1.3027848 | Val - AUC : 0.9663369 | Best AUC : 0.9663369 (epoch : 75)
# [Epoch 76] Train - loss : 1.2027023 | Val - AUC : 0.966346 | Best AUC : 0.966346 (epoch : 76)
# [Epoch 77] Train - loss : 1.2667684 | Val - AUC : 0.9663488 | Best AUC : 0.9663488 (epoch : 77)
# [Epoch 78] Train - loss : 1.2137277 | Val - AUC : 0.9663542 | Best AUC : 0.9663542 (epoch : 78)
# [Epoch 79] Train - loss : 1.149991 | Val - AUC : 0.9663614 | Best AUC : 0.9663614 (epoch : 79)
# [Epoch 80] Train - loss : 1.1491754 | Val - AUC : 0.9663631 | Best AUC : 0.9663631 (epoch : 80)
# [Epoch 81] Train - loss : 1.2359689 | Val - AUC : 0.9663759 | Best AUC : 0.9663759 (epoch : 81)
# [Epoch 82] Train - loss : 1.1726609 | Val - AUC : 0.9663825 | Best AUC : 0.9663825 (epoch : 82)
# [Epoch 83] Train - loss : 1.0455836 | Val - AUC : 0.9663879 | Best AUC : 0.9663879 (epoch : 83)
# [Epoch 84] Train - loss : 1.2210551 | Val - AUC : 0.9663917 | Best AUC : 0.9663917 (epoch : 84)
# [Epoch 85] Train - loss : 0.9993895 | Val - AUC : 0.9663926 | Best AUC : 0.9663926 (epoch : 85)
# [Epoch 86] Train - loss : 1.2747731 | Val - AUC : 0.9663984 | Best AUC : 0.9663984 (epoch : 86)
# [Epoch 87] Train - loss : 1.2417824 | Val - AUC : 0.9664028 | Best AUC : 0.9664028 (epoch : 87)
# [Epoch 88] Train - loss : 1.1352981 | Val - AUC : 0.9664039 | Best AUC : 0.9664039 (epoch : 88)
# [Epoch 89] Train - loss : 1.0479014 | Val - AUC : 0.9664084 | Best AUC : 0.9664084 (epoch : 89)
# [Epoch 90] Train - loss : 1.1870764 | Val - AUC : 0.9664126 | Best AUC : 0.9664126 (epoch : 90)
# [Epoch 91] Train - loss : 1.1296512 | Val - AUC : 0.9664118 | Best AUC : 0.9664126 (epoch : 90)
# [Epoch 92] Train - loss : 1.1726377 | Val - AUC : 0.9664176 | Best AUC : 0.9664176 (epoch : 92)
# [Epoch 93] Train - loss : 1.1195401 | Val - AUC : 0.9664138 | Best AUC : 0.9664176 (epoch : 92)
# [Epoch 94] Train - loss : 1.1083538 | Val - AUC : 0.9664226 | Best AUC : 0.9664226 (epoch : 94)
# [Epoch 95] Train - loss : 1.0833542 | Val - AUC : 0.9664306 | Best AUC : 0.9664306 (epoch : 95)
# [Epoch 96] Train - loss : 0.9602826 | Val - AUC : 0.9664309 | Best AUC : 0.9664309 (epoch : 96)
# [Epoch 97] Train - loss : 0.9961019 | Val - AUC : 0.9664297 | Best AUC : 0.9664309 (epoch : 96)
# [Epoch 98] Train - loss : 0.9793432 | Val - AUC : 0.9664274 | Best AUC : 0.9664309 (epoch : 96)
# [Epoch 99] Train - loss : 0.9872978 | Val - AUC : 0.9664318 | Best AUC : 0.9664318 (epoch : 99)
# [Epoch 100] Train - loss : 0.89073 | Val - AUC : 0.9664311 | Best AUC : 0.9664318 (epoch : 99)
# [Epoch 101] Train - loss : 1.3580341 | Val - AUC : 0.966431 | Best AUC : 0.9664318 (epoch : 99)
# [Epoch 102] Train - loss : 0.9872547 | Val - AUC : 0.966438 | Best AUC : 0.966438 (epoch : 102)
# [Epoch 103] Train - loss : 0.9973526 | Val - AUC : 0.96644 | Best AUC : 0.96644 (epoch : 103)
# [Epoch 104] Train - loss : 0.9659213 | Val - AUC : 0.9664428 | Best AUC : 0.9664428 (epoch : 104)
# [Epoch 105] Train - loss : 0.9828321 | Val - AUC : 0.966443 | Best AUC : 0.966443 (epoch : 105)
# [Epoch 106] Train - loss : 0.9940267 | Val - AUC : 0.9664484 | Best AUC : 0.9664484 (epoch : 106)
# [Epoch 107] Train - loss : 0.8661275 | Val - AUC : 0.9664436 | Best AUC : 0.9664484 (epoch : 106)
# [Epoch 108] Train - loss : 1.0777588 | Val - AUC : 0.9664489 | Best AUC : 0.9664489 (epoch : 108)
# [Epoch 109] Train - loss : 0.8625956 | Val - AUC : 0.9664431 | Best AUC : 0.9664489 (epoch : 108)
# [Epoch 110] Train - loss : 0.942144 | Val - AUC : 0.9664474 | Best AUC : 0.9664489 (epoch : 108)
# [Epoch 111] Train - loss : 1.0738251 | Val - AUC : 0.9664502 | Best AUC : 0.9664502 (epoch : 111)
# [Epoch 112] Train - loss : 1.012966 | Val - AUC : 0.9664463 | Best AUC : 0.9664502 (epoch : 111)
# [Epoch 113] Train - loss : 0.9419059 | Val - AUC : 0.9664451 | Best AUC : 0.9664502 (epoch : 111)
# [Epoch 114] Train - loss : 0.9280462 | Val - AUC : 0.966446 | Best AUC : 0.9664502 (epoch : 111)
# [Epoch 115] Train - loss : 0.933793 | Val - AUC : 0.9664411 | Best AUC : 0.9664502 (epoch : 111)
# [Epoch 116] Train - loss : 1.1275432 | Val - AUC : 0.9664479 | Best AUC : 0.9664502 (epoch : 111)
# [Epoch 117] Train - loss : 0.9794185 | Val - AUC : 0.9664462 | Best AUC : 0.9664502 (epoch : 111)
# [Epoch 118] Train - loss : 1.0233298 | Val - AUC : 0.9664455 | Best AUC : 0.9664502 (epoch : 111)
# [Epoch 119] Train - loss : 0.9913959 | Val - AUC : 0.9664484 | Best AUC : 0.9664502 (epoch : 111)
# [Epoch 120] Train - loss : 0.8357219 | Val - AUC : 0.9664439 | Best AUC : 0.9664502 (epoch : 111)
# [Epoch 121] Train - loss : 0.9628857 | Val - AUC : 0.9664417 | Best AUC : 0.9664502 (epoch : 111)
# [Epoch 122] Train - loss : 0.9424656 | Val - AUC : 0.9664445 | Best AUC : 0.9664502 (epoch : 111)
# [Epoch 123] Train - loss : 0.9494805 | Val - AUC : 0.9664405 | Best AUC : 0.9664502 (epoch : 111)
# [Epoch 124] Train - loss : 0.9849211 | Val - AUC : 0.9664414 | Best AUC : 0.9664502 (epoch : 111)
# [Epoch 125] Train - loss : 0.9191295 | Val - AUC : 0.9664409 | Best AUC : 0.9664502 (epoch : 111)
# [Epoch 126] Train - loss : 1.0452716 | Val - AUC : 0.9664476 | Best AUC : 0.9664502 (epoch : 111)
# [Epoch 127] Train - loss : 0.829597 | Val - AUC : 0.9664533 | Best AUC : 0.9664533 (epoch : 127)
# [Epoch 128] Train - loss : 0.8583535 | Val - AUC : 0.9664526 | Best AUC : 0.9664533 (epoch : 127)
# [Epoch 129] Train - loss : 0.9637708 | Val - AUC : 0.9664484 | Best AUC : 0.9664533 (epoch : 127)
# [Epoch 130] Train - loss : 1.0622422 | Val - AUC : 0.9664477 | Best AUC : 0.9664533 (epoch : 127)
# [Epoch 131] Train - loss : 1.0160733 | Val - AUC : 0.9664501 | Best AUC : 0.9664533 (epoch : 127)
# [Epoch 132] Train - loss : 0.8455012 | Val - AUC : 0.9664553 | Best AUC : 0.9664553 (epoch : 132)
# [Epoch 133] Train - loss : 0.959418 | Val - AUC : 0.9664562 | Best AUC : 0.9664562 (epoch : 133)
# [Epoch 134] Train - loss : 0.9545366 | Val - AUC : 0.9664566 | Best AUC : 0.9664566 (epoch : 134)
# [Epoch 135] Train - loss : 0.9768404 | Val - AUC : 0.9664598 | Best AUC : 0.9664598 (epoch : 135)
# [Epoch 136] Train - loss : 0.8227597 | Val - AUC : 0.9664549 | Best AUC : 0.9664598 (epoch : 135)
# [Epoch 137] Train - loss : 0.9490894 | Val - AUC : 0.9664577 | Best AUC : 0.9664598 (epoch : 135)
# [Epoch 138] Train - loss : 1.0251817 | Val - AUC : 0.9664583 | Best AUC : 0.9664598 (epoch : 135)
# [Epoch 139] Train - loss : 0.9643822 | Val - AUC : 0.966459 | Best AUC : 0.9664598 (epoch : 135)
# [Epoch 140] Train - loss : 0.9799863 | Val - AUC : 0.9664627 | Best AUC : 0.9664627 (epoch : 140)
# [Epoch 141] Train - loss : 1.0257804 | Val - AUC : 0.9664586 | Best AUC : 0.9664627 (epoch : 140)
# [Epoch 142] Train - loss : 0.7695667 | Val - AUC : 0.9664618 | Best AUC : 0.9664627 (epoch : 140)
# [Epoch 143] Train - loss : 0.8271236 | Val - AUC : 0.9664649 | Best AUC : 0.9664649 (epoch : 143)
# [Epoch 144] Train - loss : 0.9362191 | Val - AUC : 0.9664688 | Best AUC : 0.9664688 (epoch : 144)
# [Epoch 145] Train - loss : 0.8813792 | Val - AUC : 0.9664776 | Best AUC : 0.9664776 (epoch : 145)
# [Epoch 146] Train - loss : 1.0516649 | Val - AUC : 0.9664711 | Best AUC : 0.9664776 (epoch : 145)
# [Epoch 147] Train - loss : 0.8458372 | Val - AUC : 0.9664782 | Best AUC : 0.9664782 (epoch : 147)
# [Epoch 148] Train - loss : 0.9876065 | Val - AUC : 0.9664879 | Best AUC : 0.9664879 (epoch : 148)
# [Epoch 149] Train - loss : 0.8729804 | Val - AUC : 0.9664888 | Best AUC : 0.9664888 (epoch : 149)
# [Epoch 150] Train - loss : 0.8716537 | Val - AUC : 0.9664969 | Best AUC : 0.9664969 (epoch : 150)
# [Epoch 151] Train - loss : 0.7345815 | Val - AUC : 0.9664948 | Best AUC : 0.9664969 (epoch : 150)
# [Epoch 152] Train - loss : 0.8392528 | Val - AUC : 0.9664943 | Best AUC : 0.9664969 (epoch : 150)
# [Epoch 153] Train - loss : 0.8852904 | Val - AUC : 0.9664949 | Best AUC : 0.9664969 (epoch : 150)
# [Epoch 154] Train - loss : 1.0281271 | Val - AUC : 0.966501 | Best AUC : 0.966501 (epoch : 154)
# [Epoch 155] Train - loss : 0.906292 | Val - AUC : 0.9665028 | Best AUC : 0.9665028 (epoch : 155)
# [Epoch 156] Train - loss : 0.9105532 | Val - AUC : 0.9665048 | Best AUC : 0.9665048 (epoch : 156)
# [Epoch 157] Train - loss : 0.8926082 | Val - AUC : 0.9665003 | Best AUC : 0.9665048 (epoch : 156)
# [Epoch 158] Train - loss : 0.894823 | Val - AUC : 0.9665025 | Best AUC : 0.9665048 (epoch : 156)
# [Epoch 159] Train - loss : 0.8694174 | Val - AUC : 0.9665087 | Best AUC : 0.9665087 (epoch : 159)
# [Epoch 160] Train - loss : 0.9434984 | Val - AUC : 0.9665048 | Best AUC : 0.9665087 (epoch : 159)
# [Epoch 161] Train - loss : 0.8216129 | Val - AUC : 0.9665107 | Best AUC : 0.9665107 (epoch : 161)
# [Epoch 162] Train - loss : 0.8895159 | Val - AUC : 0.9665195 | Best AUC : 0.9665195 (epoch : 162)
# [Epoch 163] Train - loss : 1.0091963 | Val - AUC : 0.966519 | Best AUC : 0.9665195 (epoch : 162)
# [Epoch 164] Train - loss : 0.7953336 | Val - AUC : 0.9665165 | Best AUC : 0.9665195 (epoch : 162)
# [Epoch 165] Train - loss : 0.8116941 | Val - AUC : 0.9665197 | Best AUC : 0.9665197 (epoch : 165)
# [Epoch 166] Train - loss : 0.7997584 | Val - AUC : 0.9665221 | Best AUC : 0.9665221 (epoch : 166)
# [Epoch 167] Train - loss : 0.8037089 | Val - AUC : 0.9665285 | Best AUC : 0.9665285 (epoch : 167)
# [Epoch 168] Train - loss : 0.8358256 | Val - AUC : 0.9665282 | Best AUC : 0.9665285 (epoch : 167)
# [Epoch 169] Train - loss : 0.9228187 | Val - AUC : 0.966533 | Best AUC : 0.966533 (epoch : 169)
# [Epoch 170] Train - loss : 0.8656689 | Val - AUC : 0.9665343 | Best AUC : 0.9665343 (epoch : 170)
# [Epoch 171] Train - loss : 0.9706393 | Val - AUC : 0.9665317 | Best AUC : 0.9665343 (epoch : 170)
# [Epoch 172] Train - loss : 0.8785194 | Val - AUC : 0.966526 | Best AUC : 0.9665343 (epoch : 170)
# [Epoch 173] Train - loss : 0.8332999 | Val - AUC : 0.9665255 | Best AUC : 0.9665343 (epoch : 170)
# [Epoch 174] Train - loss : 0.9154217 | Val - AUC : 0.966525 | Best AUC : 0.9665343 (epoch : 170)
# [Epoch 175] Train - loss : 0.7844953 | Val - AUC : 0.9665258 | Best AUC : 0.9665343 (epoch : 170)
# [Epoch 176] Train - loss : 0.775115 | Val - AUC : 0.9665313 | Best AUC : 0.9665343 (epoch : 170)
# [Epoch 177] Train - loss : 0.8223846 | Val - AUC : 0.9665344 | Best AUC : 0.9665344 (epoch : 177)
# [Epoch 178] Train - loss : 0.7151373 | Val - AUC : 0.9665376 | Best AUC : 0.9665376 (epoch : 178)
# [Epoch 179] Train - loss : 0.8294839 | Val - AUC : 0.9665357 | Best AUC : 0.9665376 (epoch : 178)
# [Epoch 180] Train - loss : 0.8319379 | Val - AUC : 0.9665367 | Best AUC : 0.9665376 (epoch : 178)
# [Epoch 181] Train - loss : 0.8869115 | Val - AUC : 0.9665421 | Best AUC : 0.9665421 (epoch : 181)
# [Epoch 182] Train - loss : 0.9399399 | Val - AUC : 0.9665432 | Best AUC : 0.9665432 (epoch : 182)
# [Epoch 183] Train - loss : 0.9014812 | Val - AUC : 0.9665508 | Best AUC : 0.9665508 (epoch : 183)
# [Epoch 184] Train - loss : 0.8694846 | Val - AUC : 0.9665492 | Best AUC : 0.9665508 (epoch : 183)
# [Epoch 185] Train - loss : 0.9980836 | Val - AUC : 0.9665497 | Best AUC : 0.9665508 (epoch : 183)
# [Epoch 186] Train - loss : 1.0813411 | Val - AUC : 0.9665458 | Best AUC : 0.9665508 (epoch : 183)
# [Epoch 187] Train - loss : 0.7878717 | Val - AUC : 0.9665479 | Best AUC : 0.9665508 (epoch : 183)
# [Epoch 188] Train - loss : 0.8055421 | Val - AUC : 0.9665521 | Best AUC : 0.9665521 (epoch : 188)
# [Epoch 189] Train - loss : 0.8185937 | Val - AUC : 0.9665502 | Best AUC : 0.9665521 (epoch : 188)
# [Epoch 190] Train - loss : 0.9404986 | Val - AUC : 0.9665503 | Best AUC : 0.9665521 (epoch : 188)
# [Epoch 191] Train - loss : 1.0596837 | Val - AUC : 0.9665548 | Best AUC : 0.9665548 (epoch : 191)
# [Epoch 192] Train - loss : 0.8934685 | Val - AUC : 0.966556 | Best AUC : 0.966556 (epoch : 192)
# [Epoch 193] Train - loss : 0.8799777 | Val - AUC : 0.9665505 | Best AUC : 0.966556 (epoch : 192)
# [Epoch 194] Train - loss : 0.8934178 | Val - AUC : 0.9665534 | Best AUC : 0.966556 (epoch : 192)
# [Epoch 195] Train - loss : 0.84799 | Val - AUC : 0.966556 | Best AUC : 0.966556 (epoch : 192)
# [Epoch 196] Train - loss : 0.7727048 | Val - AUC : 0.9665566 | Best AUC : 0.9665566 (epoch : 196)
# [Epoch 197] Train - loss : 1.0415398 | Val - AUC : 0.9665568 | Best AUC : 0.9665568 (epoch : 197)
# [Epoch 198] Train - loss : 0.7208934 | Val - AUC : 0.9665593 | Best AUC : 0.9665593 (epoch : 198)
# [Epoch 199] Train - loss : 0.7236136 | Val - AUC : 0.9665553 | Best AUC : 0.9665593 (epoch : 198)
# [Epoch 200] Train - loss : 1.0146085 | Val - AUC : 0.9665612 | Best AUC : 0.9665612 (epoch : 200)
# [Epoch 201] Train - loss : 0.8535726 | Val - AUC : 0.9665615 | Best AUC : 0.9665615 (epoch : 201)
# [Epoch 202] Train - loss : 0.7635948 | Val - AUC : 0.9665635 | Best AUC : 0.9665635 (epoch : 202)
# [Epoch 203] Train - loss : 0.8171838 | Val - AUC : 0.9665695 | Best AUC : 0.9665695 (epoch : 203)
# [Epoch 204] Train - loss : 0.8378373 | Val - AUC : 0.9665698 | Best AUC : 0.9665698 (epoch : 204)
# [Epoch 205] Train - loss : 0.885894 | Val - AUC : 0.9665704 | Best AUC : 0.9665704 (epoch : 205)
# [Epoch 206] Train - loss : 0.7699723 | Val - AUC : 0.9665705 | Best AUC : 0.9665705 (epoch : 206)
# [Epoch 207] Train - loss : 0.7432703 | Val - AUC : 0.9665705 | Best AUC : 0.9665705 (epoch : 207)
# [Epoch 208] Train - loss : 0.7256901 | Val - AUC : 0.966567 | Best AUC : 0.9665705 (epoch : 207)
# [Epoch 209] Train - loss : 0.9383311 | Val - AUC : 0.9665631 | Best AUC : 0.9665705 (epoch : 207)
# [Epoch 210] Train - loss : 1.0340412 | Val - AUC : 0.966564 | Best AUC : 0.9665705 (epoch : 207)
# [Epoch 211] Train - loss : 0.7873811 | Val - AUC : 0.966569 | Best AUC : 0.9665705 (epoch : 207)
# [Epoch 212] Train - loss : 0.8090898 | Val - AUC : 0.9665726 | Best AUC : 0.9665726 (epoch : 212)
# [Epoch 213] Train - loss : 0.8660091 | Val - AUC : 0.9665709 | Best AUC : 0.9665726 (epoch : 212)
# [Epoch 214] Train - loss : 0.9882907 | Val - AUC : 0.9665746 | Best AUC : 0.9665746 (epoch : 214)
# [Epoch 215] Train - loss : 0.7374278 | Val - AUC : 0.9665707 | Best AUC : 0.9665746 (epoch : 214)
# [Epoch 216] Train - loss : 1.079595 | Val - AUC : 0.9665725 | Best AUC : 0.9665746 (epoch : 214)
# [Epoch 217] Train - loss : 0.808305 | Val - AUC : 0.9665679 | Best AUC : 0.9665746 (epoch : 214)
# [Epoch 218] Train - loss : 0.8142531 | Val - AUC : 0.9665675 | Best AUC : 0.9665746 (epoch : 214)
# [Epoch 219] Train - loss : 0.8099649 | Val - AUC : 0.9665647 | Best AUC : 0.9665746 (epoch : 214)
# [Epoch 220] Train - loss : 0.8534046 | Val - AUC : 0.9665597 | Best AUC : 0.9665746 (epoch : 214)
# [Epoch 221] Train - loss : 0.7091922 | Val - AUC : 0.9665592 | Best AUC : 0.9665746 (epoch : 214)
# [Epoch 222] Train - loss : 0.7888707 | Val - AUC : 0.9665617 | Best AUC : 0.9665746 (epoch : 214)
# [Epoch 223] Train - loss : 0.7143764 | Val - AUC : 0.9665536 | Best AUC : 0.9665746 (epoch : 214)
# [Epoch 224] Train - loss : 1.0009807 | Val - AUC : 0.9665592 | Best AUC : 0.9665746 (epoch : 214)
# [Epoch 225] Train - loss : 0.8395413 | Val - AUC : 0.9665594 | Best AUC : 0.9665746 (epoch : 214)
# [Epoch 226] Train - loss : 0.7877464 | Val - AUC : 0.9665566 | Best AUC : 0.9665746 (epoch : 214)
# [Epoch 227] Train - loss : 0.7913993 | Val - AUC : 0.9665568 | Best AUC : 0.9665746 (epoch : 214)
# [Epoch 228] Train - loss : 1.0770312 | Val - AUC : 0.9665592 | Best AUC : 0.9665746 (epoch : 214)
# [Epoch 229] Train - loss : 0.6786759 | Val - AUC : 0.9665578 | Best AUC : 0.9665746 (epoch : 214)
# [Epoch 230] Train - loss : 0.9011791 | Val - AUC : 0.9665561 | Best AUC : 0.9665746 (epoch : 214)
# [Epoch 231] Train - loss : 0.8420082 | Val - AUC : 0.9665606 | Best AUC : 0.9665746 (epoch : 214)
# [Epoch 232] Train - loss : 0.9484472 | Val - AUC : 0.9665602 | Best AUC : 0.9665746 (epoch : 214)
# [Epoch 233] Train - loss : 0.7864614 | Val - AUC : 0.9665591 | Best AUC : 0.9665746 (epoch : 214)
# [Epoch 234] Train - loss : 0.7908463 | Val - AUC : 0.9665605 | Best AUC : 0.9665746 (epoch : 214)
# [Epoch 235] Train - loss : 0.7710572 | Val - AUC : 0.96656 | Best AUC : 0.9665746 (epoch : 214)
# [Epoch 236] Train - loss : 0.7612291 | Val - AUC : 0.966558 | Best AUC : 0.9665746 (epoch : 214)
# [Epoch 237] Train - loss : 0.9080456 | Val - AUC : 0.9665558 | Best AUC : 0.9665746 (epoch : 214)
# [Epoch 238] Train - loss : 0.7899197 | Val - AUC : 0.9665584 | Best AUC : 0.9665746 (epoch : 214)
# [Epoch 239] Train - loss : 0.8053542 | Val - AUC : 0.9665573 | Best AUC : 0.9665746 (epoch : 214)
# [Epoch 240] Train - loss : 0.9984646 | Val - AUC : 0.9665531 | Best AUC : 0.9665746 (epoch : 214)
# [Epoch 241] Train - loss : 0.7867838 | Val - AUC : 0.9665542 | Best AUC : 0.9665746 (epoch : 214)
# [Epoch 242] Train - loss : 0.7420202 | Val - AUC : 0.9665559 | Best AUC : 0.9665746 (epoch : 214)
# [Epoch 243] Train - loss : 0.8158331 | Val - AUC : 0.9665592 | Best AUC : 0.9665746 (epoch : 214)
# [Epoch 244] Train - loss : 0.8436878 | Val - AUC : 0.9665555 | Best AUC : 0.9665746 (epoch : 214)
# [Epoch 245] Train - loss : 0.9022343 | Val - AUC : 0.9665548 | Best AUC : 0.9665746 (epoch : 214)
# [Epoch 246] Train - loss : 0.8700369 | Val - AUC : 0.9665564 | Best AUC : 0.9665746 (epoch : 214)
# [Epoch 247] Train - loss : 0.8694021 | Val - AUC : 0.9665587 | Best AUC : 0.9665746 (epoch : 214)
# [Epoch 248] Train - loss : 0.7470449 | Val - AUC : 0.9665595 | Best AUC : 0.9665746 (epoch : 214)
# [Epoch 249] Train - loss : 0.7659283 | Val - AUC : 0.9665643 | Best AUC : 0.9665746 (epoch : 214)
# [Epoch 250] Train - loss : 0.8224178 | Val - AUC : 0.9665619 | Best AUC : 0.9665746 (epoch : 214)
# [Epoch 251] Train - loss : 0.8658837 | Val - AUC : 0.9665603 | Best AUC : 0.9665746 (epoch : 214)
# [Epoch 252] Train - loss : 0.7527842 | Val - AUC : 0.9665609 | Best AUC : 0.9665746 (epoch : 214)
# [Epoch 253] Train - loss : 0.7147211 | Val - AUC : 0.966562 | Best AUC : 0.9665746 (epoch : 214)
# [Epoch 254] Train - loss : 1.0217362 | Val - AUC : 0.9665677 | Best AUC : 0.9665746 (epoch : 214)
# [Epoch 255] Train - loss : 0.9575497 | Val - AUC : 0.9665588 | Best AUC : 0.9665746 (epoch : 214)
# [Epoch 256] Train - loss : 0.727632 | Val - AUC : 0.9665601 | Best AUC : 0.9665746 (epoch : 214)
# [Epoch 257] Train - loss : 0.6958024 | Val - AUC : 0.9665598 | Best AUC : 0.9665746 (epoch : 214)
# [Epoch 258] Train - loss : 0.9090069 | Val - AUC : 0.966564 | Best AUC : 0.9665746 (epoch : 214)
# [Epoch 259] Train - loss : 0.8105155 | Val - AUC : 0.966563 | Best AUC : 0.9665746 (epoch : 214)
# [Epoch 260] Train - loss : 0.6867191 | Val - AUC : 0.9665656 | Best AUC : 0.9665746 (epoch : 214)
# [Epoch 261] Train - loss : 0.7399442 | Val - AUC : 0.9665632 | Best AUC : 0.9665746 (epoch : 214)
# [Epoch 262] Train - loss : 0.7291514 | Val - AUC : 0.9665625 | Best AUC : 0.9665746 (epoch : 214)
# [Epoch 263] Train - loss : 0.6994529 | Val - AUC : 0.966564 | Best AUC : 0.9665746 (epoch : 214)
# [Epoch 264] Train - loss : 0.8116103 | Val - AUC : 0.9665625 | Best AUC : 0.9665746 (epoch : 214)
# [Epoch 265] Train - loss : 0.7093582 | Val - AUC : 0.9665623 | Best AUC : 0.9665746 (epoch : 214)
# [Epoch 266] Train - loss : 0.6415381 | Val - AUC : 0.9665582 | Best AUC : 0.9665746 (epoch : 214)
# [Epoch 267] Train - loss : 0.6826092 | Val - AUC : 0.9665575 | Best AUC : 0.9665746 (epoch : 214)
# [Epoch 268] Train - loss : 0.7831315 | Val - AUC : 0.966561 | Best AUC : 0.9665746 (epoch : 214)
# [Epoch 269] Train - loss : 0.7208681 | Val - AUC : 0.9665596 | Best AUC : 0.9665746 (epoch : 214)
# [Epoch 270] Train - loss : 0.8199985 | Val - AUC : 0.9665587 | Best AUC : 0.9665746 (epoch : 214)
# [Epoch 271] Train - loss : 0.9278214 | Val - AUC : 0.9665601 | Best AUC : 0.9665746 (epoch : 214)
# [Epoch 272] Train - loss : 0.6846265 | Val - AUC : 0.9665549 | Best AUC : 0.9665746 (epoch : 214)
# [Epoch 273] Train - loss : 0.7659806 | Val - AUC : 0.9665628 | Best AUC : 0.9665746 (epoch : 214)
# [Epoch 274] Train - loss : 0.7563835 | Val - AUC : 0.9665581 | Best AUC : 0.9665746 (epoch : 214)
# [Epoch 275] Train - loss : 0.8026064 | Val - AUC : 0.9665589 | Best AUC : 0.9665746 (epoch : 214)
# [Epoch 276] Train - loss : 0.8289848 | Val - AUC : 0.966561 | Best AUC : 0.9665746 (epoch : 214)
# [Epoch 277] Train - loss : 0.8777678 | Val - AUC : 0.9665599 | Best AUC : 0.9665746 (epoch : 214)
# [Epoch 278] Train - loss : 0.7978646 | Val - AUC : 0.966562 | Best AUC : 0.9665746 (epoch : 214)
# [Epoch 279] Train - loss : 1.0397807 | Val - AUC : 0.9665603 | Best AUC : 0.9665746 (epoch : 214)
# [Epoch 280] Train - loss : 0.8583687 | Val - AUC : 0.9665597 | Best AUC : 0.9665746 (epoch : 214)
# [Epoch 281] Train - loss : 0.673621 | Val - AUC : 0.9665629 | Best AUC : 0.9665746 (epoch : 214)
# [Epoch 282] Train - loss : 0.7575602 | Val - AUC : 0.9665696 | Best AUC : 0.9665746 (epoch : 214)
# [Epoch 283] Train - loss : 0.6939834 | Val - AUC : 0.9665654 | Best AUC : 0.9665746 (epoch : 214)
# [Epoch 284] Train - loss : 0.851316 | Val - AUC : 0.9665662 | Best AUC : 0.9665746 (epoch : 214)
# [Epoch 285] Train - loss : 0.7553472 | Val - AUC : 0.9665647 | Best AUC : 0.9665746 (epoch : 214)
# [Epoch 286] Train - loss : 0.6809292 | Val - AUC : 0.9665651 | Best AUC : 0.9665746 (epoch : 214)
# [Epoch 287] Train - loss : 0.8569517 | Val - AUC : 0.9665672 | Best AUC : 0.9665746 (epoch : 214)
# [Epoch 288] Train - loss : 0.8060776 | Val - AUC : 0.9665667 | Best AUC : 0.9665746 (epoch : 214)
# [Epoch 289] Train - loss : 1.0493141 | Val - AUC : 0.9665638 | Best AUC : 0.9665746 (epoch : 214)
# [Epoch 290] Train - loss : 0.9012527 | Val - AUC : 0.9665639 | Best AUC : 0.9665746 (epoch : 214)
# [Epoch 291] Train - loss : 0.7467471 | Val - AUC : 0.966566 | Best AUC : 0.9665746 (epoch : 214)
# [Epoch 292] Train - loss : 0.7364589 | Val - AUC : 0.966565 | Best AUC : 0.9665746 (epoch : 214)
# [Epoch 293] Train - loss : 0.8748236 | Val - AUC : 0.9665652 | Best AUC : 0.9665746 (epoch : 214)
# [Epoch 294] Train - loss : 1.0066004 | Val - AUC : 0.966567 | Best AUC : 0.9665746 (epoch : 214)
# [Epoch 295] Train - loss : 0.7754872 | Val - AUC : 0.9665692 | Best AUC : 0.9665746 (epoch : 214)
# [Epoch 296] Train - loss : 0.7851133 | Val - AUC : 0.9665695 | Best AUC : 0.9665746 (epoch : 214)
# [Epoch 297] Train - loss : 0.708845 | Val - AUC : 0.9665689 | Best AUC : 0.9665746 (epoch : 214)
# [Epoch 298] Train - loss : 0.7048232 | Val - AUC : 0.9665699 | Best AUC : 0.9665746 (epoch : 214)
# [Epoch 299] Train - loss : 0.675598 | Val - AUC : 0.966565 | Best AUC : 0.9665746 (epoch : 214)
# [Epoch 300] Train - loss : 0.6451993 | Val - AUC : 0.9665667 | Best AUC : 0.9665746 (epoch : 214)
# [Epoch 301] Train - loss : 0.7003074 | Val - AUC : 0.9665718 | Best AUC : 0.9665746 (epoch : 214)
# [Epoch 302] Train - loss : 0.7135226 | Val - AUC : 0.9665702 | Best AUC : 0.9665746 (epoch : 214)
# [Epoch 303] Train - loss : 0.8600151 | Val - AUC : 0.9665709 | Best AUC : 0.9665746 (epoch : 214)
# [Epoch 304] Train - loss : 0.6985879 | Val - AUC : 0.9665698 | Best AUC : 0.9665746 (epoch : 214)
# [Epoch 305] Train - loss : 0.6842352 | Val - AUC : 0.9665671 | Best AUC : 0.9665746 (epoch : 214)
# [Epoch 306] Train - loss : 0.6797187 | Val - AUC : 0.9665644 | Best AUC : 0.9665746 (epoch : 214)
# [Epoch 307] Train - loss : 0.6904883 | Val - AUC : 0.9665703 | Best AUC : 0.9665746 (epoch : 214)
# [Epoch 308] Train - loss : 0.8893018 | Val - AUC : 0.9665704 | Best AUC : 0.9665746 (epoch : 214)
# [Epoch 309] Train - loss : 0.7668075 | Val - AUC : 0.9665743 | Best AUC : 0.9665746 (epoch : 214)
# [Epoch 310] Train - loss : 0.7321462 | Val - AUC : 0.9665733 | Best AUC : 0.9665746 (epoch : 214)
# [Epoch 311] Train - loss : 0.6908856 | Val - AUC : 0.9665716 | Best AUC : 0.9665746 (epoch : 214)
# [Epoch 312] Train - loss : 0.8072786 | Val - AUC : 0.9665695 | Best AUC : 0.9665746 (epoch : 214)
# [Epoch 313] Train - loss : 0.6350487 | Val - AUC : 0.9665659 | Best AUC : 0.9665746 (epoch : 214)
# [Epoch 314] Train - loss : 0.6848025 | Val - AUC : 0.9665686 | Best AUC : 0.9665746 (epoch : 214)
# [Epoch 315] Train - loss : 0.668784 | Val - AUC : 0.966572 | Best AUC : 0.9665746 (epoch : 214)
# [Epoch 316] Train - loss : 0.7338626 | Val - AUC : 0.9665785 | Best AUC : 0.9665785 (epoch : 316)
# [Epoch 317] Train - loss : 0.644168 | Val - AUC : 0.9665787 | Best AUC : 0.9665787 (epoch : 317)
# [Epoch 318] Train - loss : 0.8287079 | Val - AUC : 0.9665787 | Best AUC : 0.9665787 (epoch : 317)
# [Epoch 319] Train - loss : 0.7249321 | Val - AUC : 0.9665828 | Best AUC : 0.9665828 (epoch : 319)
# [Epoch 320] Train - loss : 0.8193916 | Val - AUC : 0.9665828 | Best AUC : 0.9665828 (epoch : 320)
# [Epoch 321] Train - loss : 0.7120714 | Val - AUC : 0.9665822 | Best AUC : 0.9665828 (epoch : 320)
# [Epoch 322] Train - loss : 0.889294 | Val - AUC : 0.9665833 | Best AUC : 0.9665833 (epoch : 322)
# [Epoch 323] Train - loss : 0.9335679 | Val - AUC : 0.9665835 | Best AUC : 0.9665835 (epoch : 323)
# [Epoch 324] Train - loss : 0.6272441 | Val - AUC : 0.9665863 | Best AUC : 0.9665863 (epoch : 324)
# [Epoch 325] Train - loss : 0.838616 | Val - AUC : 0.9665825 | Best AUC : 0.9665863 (epoch : 324)
# [Epoch 326] Train - loss : 0.6876409 | Val - AUC : 0.9665888 | Best AUC : 0.9665888 (epoch : 326)
# [Epoch 327] Train - loss : 0.947371 | Val - AUC : 0.9665897 | Best AUC : 0.9665897 (epoch : 327)
# [Epoch 328] Train - loss : 0.7148359 | Val - AUC : 0.9665908 | Best AUC : 0.9665908 (epoch : 328)
# [Epoch 329] Train - loss : 0.7105457 | Val - AUC : 0.9665911 | Best AUC : 0.9665911 (epoch : 329)
# [Epoch 330] Train - loss : 0.8158096 | Val - AUC : 0.9665919 | Best AUC : 0.9665919 (epoch : 330)
# [Epoch 331] Train - loss : 0.7297842 | Val - AUC : 0.9665913 | Best AUC : 0.9665919 (epoch : 330)
# [Epoch 332] Train - loss : 0.726759 | Val - AUC : 0.9665944 | Best AUC : 0.9665944 (epoch : 332)
# [Epoch 333] Train - loss : 0.7077284 | Val - AUC : 0.9665946 | Best AUC : 0.9665946 (epoch : 333)
# [Epoch 334] Train - loss : 0.7913562 | Val - AUC : 0.966591 | Best AUC : 0.9665946 (epoch : 333)
# [Epoch 335] Train - loss : 0.8647511 | Val - AUC : 0.966591 | Best AUC : 0.9665946 (epoch : 333)
# [Epoch 336] Train - loss : 0.6397752 | Val - AUC : 0.9665883 | Best AUC : 0.9665946 (epoch : 333)
# [Epoch 337] Train - loss : 0.7398483 | Val - AUC : 0.9665878 | Best AUC : 0.9665946 (epoch : 333)
# [Epoch 338] Train - loss : 0.6797702 | Val - AUC : 0.9665951 | Best AUC : 0.9665951 (epoch : 338)
# [Epoch 339] Train - loss : 0.6584836 | Val - AUC : 0.9665996 | Best AUC : 0.9665996 (epoch : 339)
# [Epoch 340] Train - loss : 0.692207 | Val - AUC : 0.9666004 | Best AUC : 0.9666004 (epoch : 340)
# [Epoch 341] Train - loss : 0.6934278 | Val - AUC : 0.9666027 | Best AUC : 0.9666027 (epoch : 341)
# [Epoch 342] Train - loss : 0.6452603 | Val - AUC : 0.9666014 | Best AUC : 0.9666027 (epoch : 341)
# [Epoch 343] Train - loss : 0.7274422 | Val - AUC : 0.9666008 | Best AUC : 0.9666027 (epoch : 341)
# [Epoch 344] Train - loss : 0.6894446 | Val - AUC : 0.9665965 | Best AUC : 0.9666027 (epoch : 341)
# [Epoch 345] Train - loss : 0.8019183 | Val - AUC : 0.9665976 | Best AUC : 0.9666027 (epoch : 341)
# [Epoch 346] Train - loss : 0.7458923 | Val - AUC : 0.9665998 | Best AUC : 0.9666027 (epoch : 341)
# [Epoch 347] Train - loss : 0.6612259 | Val - AUC : 0.9666047 | Best AUC : 0.9666047 (epoch : 347)
# [Epoch 348] Train - loss : 0.8523163 | Val - AUC : 0.966604 | Best AUC : 0.9666047 (epoch : 347)
# [Epoch 349] Train - loss : 0.7263512 | Val - AUC : 0.9665987 | Best AUC : 0.9666047 (epoch : 347)
# [Epoch 350] Train - loss : 0.7563072 | Val - AUC : 0.9666061 | Best AUC : 0.9666061 (epoch : 350)
# [Epoch 351] Train - loss : 0.6746077 | Val - AUC : 0.9666096 | Best AUC : 0.9666096 (epoch : 351)
# [Epoch 352] Train - loss : 0.6680896 | Val - AUC : 0.9666064 | Best AUC : 0.9666096 (epoch : 351)
# [Epoch 353] Train - loss : 0.7397304 | Val - AUC : 0.9666089 | Best AUC : 0.9666096 (epoch : 351)
# [Epoch 354] Train - loss : 0.7664044 | Val - AUC : 0.9666047 | Best AUC : 0.9666096 (epoch : 351)
# [Epoch 355] Train - loss : 0.7170276 | Val - AUC : 0.9666096 | Best AUC : 0.9666096 (epoch : 355)
# [Epoch 356] Train - loss : 0.6975107 | Val - AUC : 0.9666106 | Best AUC : 0.9666106 (epoch : 356)
# [Epoch 357] Train - loss : 0.6633436 | Val - AUC : 0.9666116 | Best AUC : 0.9666116 (epoch : 357)
# [Epoch 358] Train - loss : 0.8634198 | Val - AUC : 0.9666105 | Best AUC : 0.9666116 (epoch : 357)
# [Epoch 359] Train - loss : 0.6654088 | Val - AUC : 0.9666121 | Best AUC : 0.9666121 (epoch : 359)
# [Epoch 360] Train - loss : 0.9655317 | Val - AUC : 0.9666129 | Best AUC : 0.9666129 (epoch : 360)
# [Epoch 361] Train - loss : 0.66163 | Val - AUC : 0.9666113 | Best AUC : 0.9666129 (epoch : 360)
# [Epoch 362] Train - loss : 0.7504579 | Val - AUC : 0.9666166 | Best AUC : 0.9666166 (epoch : 362)
# [Epoch 363] Train - loss : 0.7487791 | Val - AUC : 0.9666156 | Best AUC : 0.9666166 (epoch : 362)
# [Epoch 364] Train - loss : 0.7045816 | Val - AUC : 0.9666258 | Best AUC : 0.9666258 (epoch : 364)
# [Epoch 365] Train - loss : 0.7172399 | Val - AUC : 0.9666226 | Best AUC : 0.9666258 (epoch : 364)
# [Epoch 366] Train - loss : 0.7132894 | Val - AUC : 0.9666232 | Best AUC : 0.9666258 (epoch : 364)
# [Epoch 367] Train - loss : 0.5869433 | Val - AUC : 0.966624 | Best AUC : 0.9666258 (epoch : 364)
# [Epoch 368] Train - loss : 0.6173256 | Val - AUC : 0.966621 | Best AUC : 0.9666258 (epoch : 364)
# [Epoch 369] Train - loss : 0.6659845 | Val - AUC : 0.9666191 | Best AUC : 0.9666258 (epoch : 364)
# [Epoch 370] Train - loss : 0.6337087 | Val - AUC : 0.9666217 | Best AUC : 0.9666258 (epoch : 364)
# [Epoch 371] Train - loss : 0.7243349 | Val - AUC : 0.9666263 | Best AUC : 0.9666263 (epoch : 371)
# [Epoch 372] Train - loss : 0.6845456 | Val - AUC : 0.9666295 | Best AUC : 0.9666295 (epoch : 372)
# [Epoch 373] Train - loss : 0.5551845 | Val - AUC : 0.9666309 | Best AUC : 0.9666309 (epoch : 373)
# [Epoch 374] Train - loss : 0.6764989 | Val - AUC : 0.9666305 | Best AUC : 0.9666309 (epoch : 373)
# [Epoch 375] Train - loss : 0.7814233 | Val - AUC : 0.9666277 | Best AUC : 0.9666309 (epoch : 373)
# [Epoch 376] Train - loss : 0.6076533 | Val - AUC : 0.9666317 | Best AUC : 0.9666317 (epoch : 376)
# [Epoch 377] Train - loss : 0.7368455 | Val - AUC : 0.9666319 | Best AUC : 0.9666319 (epoch : 377)
# [Epoch 378] Train - loss : 0.7416071 | Val - AUC : 0.9666274 | Best AUC : 0.9666319 (epoch : 377)
# [Epoch 379] Train - loss : 0.7524627 | Val - AUC : 0.9666346 | Best AUC : 0.9666346 (epoch : 379)
# [Epoch 380] Train - loss : 0.8161372 | Val - AUC : 0.9666361 | Best AUC : 0.9666361 (epoch : 380)
# [Epoch 381] Train - loss : 0.7660382 | Val - AUC : 0.9666339 | Best AUC : 0.9666361 (epoch : 380)
# [Epoch 382] Train - loss : 0.7480259 | Val - AUC : 0.9666321 | Best AUC : 0.9666361 (epoch : 380)
# [Epoch 383] Train - loss : 0.7058281 | Val - AUC : 0.9666347 | Best AUC : 0.9666361 (epoch : 380)
# [Epoch 384] Train - loss : 0.709089 | Val - AUC : 0.966634 | Best AUC : 0.9666361 (epoch : 380)
# [Epoch 385] Train - loss : 0.7237837 | Val - AUC : 0.9666344 | Best AUC : 0.9666361 (epoch : 380)
# [Epoch 386] Train - loss : 0.7867577 | Val - AUC : 0.9666412 | Best AUC : 0.9666412 (epoch : 386)
# [Epoch 387] Train - loss : 0.7659515 | Val - AUC : 0.9666393 | Best AUC : 0.9666412 (epoch : 386)
# [Epoch 388] Train - loss : 0.8157685 | Val - AUC : 0.9666397 | Best AUC : 0.9666412 (epoch : 386)
# [Epoch 389] Train - loss : 0.8585102 | Val - AUC : 0.9666394 | Best AUC : 0.9666412 (epoch : 386)
# [Epoch 390] Train - loss : 0.6309564 | Val - AUC : 0.9666425 | Best AUC : 0.9666425 (epoch : 390)
# [Epoch 391] Train - loss : 0.8596416 | Val - AUC : 0.96664 | Best AUC : 0.9666425 (epoch : 390)
# [Epoch 392] Train - loss : 0.7022336 | Val - AUC : 0.9666416 | Best AUC : 0.9666425 (epoch : 390)
# [Epoch 393] Train - loss : 0.6693456 | Val - AUC : 0.9666391 | Best AUC : 0.9666425 (epoch : 390)
# [Epoch 394] Train - loss : 0.7139588 | Val - AUC : 0.9666434 | Best AUC : 0.9666434 (epoch : 394)
# [Epoch 395] Train - loss : 0.7584356 | Val - AUC : 0.9666475 | Best AUC : 0.9666475 (epoch : 395)
# [Epoch 396] Train - loss : 0.6852167 | Val - AUC : 0.9666454 | Best AUC : 0.9666475 (epoch : 395)
# [Epoch 397] Train - loss : 0.9050779 | Val - AUC : 0.966648 | Best AUC : 0.966648 (epoch : 397)
# [Epoch 398] Train - loss : 0.664189 | Val - AUC : 0.9666468 | Best AUC : 0.966648 (epoch : 397)
# [Epoch 399] Train - loss : 0.7372866 | Val - AUC : 0.9666431 | Best AUC : 0.966648 (epoch : 397)
# [Epoch 400] Train - loss : 0.8270322 | Val - AUC : 0.9666421 | Best AUC : 0.966648 (epoch : 397)
# [Epoch 401] Train - loss : 0.6583428 | Val - AUC : 0.9666402 | Best AUC : 0.966648 (epoch : 397)
# [Epoch 402] Train - loss : 0.5878984 | Val - AUC : 0.9666462 | Best AUC : 0.966648 (epoch : 397)
# [Epoch 403] Train - loss : 0.7586693 | Val - AUC : 0.9666527 | Best AUC : 0.9666527 (epoch : 403)
# [Epoch 404] Train - loss : 0.6940321 | Val - AUC : 0.9666511 | Best AUC : 0.9666527 (epoch : 403)
# [Epoch 405] Train - loss : 0.7272274 | Val - AUC : 0.9666495 | Best AUC : 0.9666527 (epoch : 403)
# [Epoch 406] Train - loss : 0.7373482 | Val - AUC : 0.9666513 | Best AUC : 0.9666527 (epoch : 403)
# [Epoch 407] Train - loss : 0.9046586 | Val - AUC : 0.9666538 | Best AUC : 0.9666538 (epoch : 407)
# [Epoch 408] Train - loss : 0.6103609 | Val - AUC : 0.9666545 | Best AUC : 0.9666545 (epoch : 408)
# [Epoch 409] Train - loss : 0.7085628 | Val - AUC : 0.9666524 | Best AUC : 0.9666545 (epoch : 408)
# [Epoch 410] Train - loss : 0.7308981 | Val - AUC : 0.9666504 | Best AUC : 0.9666545 (epoch : 408)
# [Epoch 411] Train - loss : 0.6607807 | Val - AUC : 0.9666485 | Best AUC : 0.9666545 (epoch : 408)
# [Epoch 412] Train - loss : 0.7671939 | Val - AUC : 0.966654 | Best AUC : 0.9666545 (epoch : 408)
# [Epoch 413] Train - loss : 0.6864302 | Val - AUC : 0.9666516 | Best AUC : 0.9666545 (epoch : 408)
# [Epoch 414] Train - loss : 0.6809088 | Val - AUC : 0.966653 | Best AUC : 0.9666545 (epoch : 408)
# [Epoch 415] Train - loss : 0.7031766 | Val - AUC : 0.9666557 | Best AUC : 0.9666557 (epoch : 415)
# [Epoch 416] Train - loss : 0.6547788 | Val - AUC : 0.9666531 | Best AUC : 0.9666557 (epoch : 415)
# [Epoch 417] Train - loss : 0.7878347 | Val - AUC : 0.9666545 | Best AUC : 0.9666557 (epoch : 415)
# [Epoch 418] Train - loss : 0.6989434 | Val - AUC : 0.9666545 | Best AUC : 0.9666557 (epoch : 415)
# [Epoch 419] Train - loss : 0.6481475 | Val - AUC : 0.9666538 | Best AUC : 0.9666557 (epoch : 415)
# [Epoch 420] Train - loss : 0.8706241 | Val - AUC : 0.9666577 | Best AUC : 0.9666577 (epoch : 420)
# [Epoch 421] Train - loss : 0.7313813 | Val - AUC : 0.9666492 | Best AUC : 0.9666577 (epoch : 420)
# [Epoch 422] Train - loss : 0.7626081 | Val - AUC : 0.9666505 | Best AUC : 0.9666577 (epoch : 420)
# [Epoch 423] Train - loss : 0.7016731 | Val - AUC : 0.9666494 | Best AUC : 0.9666577 (epoch : 420)
# [Epoch 424] Train - loss : 0.7431636 | Val - AUC : 0.9666504 | Best AUC : 0.9666577 (epoch : 420)
# [Epoch 425] Train - loss : 0.7032707 | Val - AUC : 0.9666571 | Best AUC : 0.9666577 (epoch : 420)
# [Epoch 426] Train - loss : 0.761599 | Val - AUC : 0.966652 | Best AUC : 0.9666577 (epoch : 420)
# [Epoch 427] Train - loss : 0.8496669 | Val - AUC : 0.9666558 | Best AUC : 0.9666577 (epoch : 420)
# [Epoch 428] Train - loss : 0.6735279 | Val - AUC : 0.9666572 | Best AUC : 0.9666577 (epoch : 420)
# [Epoch 429] Train - loss : 0.7622911 | Val - AUC : 0.9666562 | Best AUC : 0.9666577 (epoch : 420)
# [Epoch 430] Train - loss : 0.5763706 | Val - AUC : 0.9666576 | Best AUC : 0.9666577 (epoch : 420)
# [Epoch 431] Train - loss : 0.6886042 | Val - AUC : 0.9666568 | Best AUC : 0.9666577 (epoch : 420)
# [Epoch 432] Train - loss : 0.7163124 | Val - AUC : 0.9666583 | Best AUC : 0.9666583 (epoch : 432)
# [Epoch 433] Train - loss : 0.8184194 | Val - AUC : 0.9666569 | Best AUC : 0.9666583 (epoch : 432)
# [Epoch 434] Train - loss : 0.8116406 | Val - AUC : 0.9666522 | Best AUC : 0.9666583 (epoch : 432)
# [Epoch 435] Train - loss : 0.6338564 | Val - AUC : 0.966656 | Best AUC : 0.9666583 (epoch : 432)
# [Epoch 436] Train - loss : 0.7418961 | Val - AUC : 0.9666558 | Best AUC : 0.9666583 (epoch : 432)
# [Epoch 437] Train - loss : 0.7813339 | Val - AUC : 0.9666599 | Best AUC : 0.9666599 (epoch : 437)
# [Epoch 438] Train - loss : 0.7254173 | Val - AUC : 0.9666606 | Best AUC : 0.9666606 (epoch : 438)
# [Epoch 439] Train - loss : 0.7755891 | Val - AUC : 0.9666621 | Best AUC : 0.9666621 (epoch : 439)
# [Epoch 440] Train - loss : 0.6494892 | Val - AUC : 0.9666618 | Best AUC : 0.9666621 (epoch : 439)
# [Epoch 441] Train - loss : 0.6513149 | Val - AUC : 0.9666573 | Best AUC : 0.9666621 (epoch : 439)
# [Epoch 442] Train - loss : 0.6876213 | Val - AUC : 0.9666615 | Best AUC : 0.9666621 (epoch : 439)
# [Epoch 443] Train - loss : 0.6548099 | Val - AUC : 0.966664 | Best AUC : 0.966664 (epoch : 443)
# [Epoch 444] Train - loss : 0.8327877 | Val - AUC : 0.9666637 | Best AUC : 0.966664 (epoch : 443)
# [Epoch 445] Train - loss : 0.7838727 | Val - AUC : 0.9666629 | Best AUC : 0.966664 (epoch : 443)
# [Epoch 446] Train - loss : 0.8357798 | Val - AUC : 0.9666646 | Best AUC : 0.9666646 (epoch : 446)
# [Epoch 447] Train - loss : 0.5668582 | Val - AUC : 0.9666676 | Best AUC : 0.9666676 (epoch : 447)
# [Epoch 448] Train - loss : 0.7653456 | Val - AUC : 0.9666695 | Best AUC : 0.9666695 (epoch : 448)
# [Epoch 449] Train - loss : 0.6683612 | Val - AUC : 0.9666743 | Best AUC : 0.9666743 (epoch : 449)
# [Epoch 450] Train - loss : 0.5996723 | Val - AUC : 0.9666685 | Best AUC : 0.9666743 (epoch : 449)
# [Epoch 451] Train - loss : 0.5408303 | Val - AUC : 0.9666683 | Best AUC : 0.9666743 (epoch : 449)
# [Epoch 452] Train - loss : 0.7529237 | Val - AUC : 0.9666667 | Best AUC : 0.9666743 (epoch : 449)
# [Epoch 453] Train - loss : 0.7067279 | Val - AUC : 0.9666659 | Best AUC : 0.9666743 (epoch : 449)
# [Epoch 454] Train - loss : 0.6776917 | Val - AUC : 0.9666691 | Best AUC : 0.9666743 (epoch : 449)
# [Epoch 455] Train - loss : 0.7696815 | Val - AUC : 0.9666721 | Best AUC : 0.9666743 (epoch : 449)
# [Epoch 456] Train - loss : 0.6507914 | Val - AUC : 0.9666741 | Best AUC : 0.9666743 (epoch : 449)
# [Epoch 457] Train - loss : 0.7211724 | Val - AUC : 0.9666726 | Best AUC : 0.9666743 (epoch : 449)
# [Epoch 458] Train - loss : 0.7127182 | Val - AUC : 0.9666701 | Best AUC : 0.9666743 (epoch : 449)
# [Epoch 459] Train - loss : 0.8229041 | Val - AUC : 0.9666745 | Best AUC : 0.9666745 (epoch : 459)
# [Epoch 460] Train - loss : 0.6775804 | Val - AUC : 0.9666739 | Best AUC : 0.9666745 (epoch : 459)
# [Epoch 461] Train - loss : 0.6205126 | Val - AUC : 0.9666765 | Best AUC : 0.9666765 (epoch : 461)
# [Epoch 462] Train - loss : 0.6261709 | Val - AUC : 0.9666781 | Best AUC : 0.9666781 (epoch : 462)
# [Epoch 463] Train - loss : 0.7470252 | Val - AUC : 0.9666775 | Best AUC : 0.9666781 (epoch : 462)
# [Epoch 464] Train - loss : 0.7144228 | Val - AUC : 0.9666811 | Best AUC : 0.9666811 (epoch : 464)
# [Epoch 465] Train - loss : 0.6804194 | Val - AUC : 0.9666753 | Best AUC : 0.9666811 (epoch : 464)
# [Epoch 466] Train - loss : 0.8258685 | Val - AUC : 0.9666796 | Best AUC : 0.9666811 (epoch : 464)
# [Epoch 467] Train - loss : 0.9038273 | Val - AUC : 0.9666779 | Best AUC : 0.9666811 (epoch : 464)
# [Epoch 468] Train - loss : 0.5509025 | Val - AUC : 0.9666774 | Best AUC : 0.9666811 (epoch : 464)
# [Epoch 469] Train - loss : 0.6069574 | Val - AUC : 0.9666752 | Best AUC : 0.9666811 (epoch : 464)
# [Epoch 470] Train - loss : 0.6569868 | Val - AUC : 0.9666802 | Best AUC : 0.9666811 (epoch : 464)
# [Epoch 471] Train - loss : 0.7024417 | Val - AUC : 0.9666783 | Best AUC : 0.9666811 (epoch : 464)
# [Epoch 472] Train - loss : 0.7254566 | Val - AUC : 0.9666796 | Best AUC : 0.9666811 (epoch : 464)
# [Epoch 473] Train - loss : 0.7832473 | Val - AUC : 0.966679 | Best AUC : 0.9666811 (epoch : 464)
# [Epoch 474] Train - loss : 0.7497511 | Val - AUC : 0.966683 | Best AUC : 0.966683 (epoch : 474)
# [Epoch 475] Train - loss : 0.6825172 | Val - AUC : 0.9666778 | Best AUC : 0.966683 (epoch : 474)
# [Epoch 476] Train - loss : 0.6580424 | Val - AUC : 0.9666829 | Best AUC : 0.966683 (epoch : 474)
# [Epoch 477] Train - loss : 0.683314 | Val - AUC : 0.9666808 | Best AUC : 0.966683 (epoch : 474)
# [Epoch 478] Train - loss : 0.5680465 | Val - AUC : 0.9666821 | Best AUC : 0.966683 (epoch : 474)
# [Epoch 479] Train - loss : 0.8064741 | Val - AUC : 0.9666849 | Best AUC : 0.9666849 (epoch : 479)
# [Epoch 480] Train - loss : 0.819072 | Val - AUC : 0.9666868 | Best AUC : 0.9666868 (epoch : 480)
# [Epoch 481] Train - loss : 0.7398045 | Val - AUC : 0.9666886 | Best AUC : 0.9666886 (epoch : 481)
# [Epoch 482] Train - loss : 0.7234639 | Val - AUC : 0.9666924 | Best AUC : 0.9666924 (epoch : 482)
# [Epoch 483] Train - loss : 0.6605111 | Val - AUC : 0.9666883 | Best AUC : 0.9666924 (epoch : 482)
# [Epoch 484] Train - loss : 0.6626589 | Val - AUC : 0.966691 | Best AUC : 0.9666924 (epoch : 482)
# [Epoch 485] Train - loss : 0.7467154 | Val - AUC : 0.9666926 | Best AUC : 0.9666926 (epoch : 485)
# [Epoch 486] Train - loss : 0.7079129 | Val - AUC : 0.9666912 | Best AUC : 0.9666926 (epoch : 485)
# [Epoch 487] Train - loss : 0.6456613 | Val - AUC : 0.9666918 | Best AUC : 0.9666926 (epoch : 485)
# [Epoch 488] Train - loss : 0.7020219 | Val - AUC : 0.9666931 | Best AUC : 0.9666931 (epoch : 488)
# [Epoch 489] Train - loss : 0.7476707 | Val - AUC : 0.9666942 | Best AUC : 0.9666942 (epoch : 489)
# [Epoch 490] Train - loss : 0.6310928 | Val - AUC : 0.9666936 | Best AUC : 0.9666942 (epoch : 489)
# [Epoch 491] Train - loss : 0.6685229 | Val - AUC : 0.9666946 | Best AUC : 0.9666946 (epoch : 491)
# ...
# [Epoch 837] Train - loss : 0.7290352 | Val - AUC : 0.9671274 | Best AUC : 0.9671274 (epoch : 837)
# [Epoch 838] Train - loss : 0.5738262 | Val - AUC : 0.9671255 | Best AUC : 0.9671274 (epoch : 837)
# [Epoch 839] Train - loss : 0.8062402 | Val - AUC : 0.9671243 | Best AUC : 0.9671274 (epoch : 837)
# [Epoch 840] Train - loss : 0.5851263 | Val - AUC : 0.9671305 | Best AUC : 0.9671305 (epoch : 840)
# [Epoch 841] Train - loss : 0.4848454 | Val - AUC : 0.9671346 | Best AUC : 0.9671346 (epoch : 841)
# [Epoch 842] Train - loss : 0.6023418 | Val - AUC : 0.9671337 | Best AUC : 0.9671346 (epoch : 841)
# [Epoch 843] Train - loss : 0.8061699 | Val - AUC : 0.9671405 | Best AUC : 0.9671405 (epoch : 843)
# [Epoch 844] Train - loss : 0.7016549 | Val - AUC : 0.9671266 | Best AUC : 0.9671405 (epoch : 843)
# [Epoch 845] Train - loss : 0.6836475 | Val - AUC : 0.9671387 | Best AUC : 0.9671405 (epoch : 843)
# [Epoch 846] Train - loss : 0.6023869 | Val - AUC : 0.9671406 | Best AUC : 0.9671406 (epoch : 846)
# [Epoch 847] Train - loss : 0.6765774 | Val - AUC : 0.9671441 | Best AUC : 0.9671441 (epoch : 847)
# [Epoch 848] Train - loss : 0.5437249 | Val - AUC : 0.9671482 | Best AUC : 0.9671482 (epoch : 848)
# [Epoch 849] Train - loss : 0.5882619 | Val - AUC : 0.9671565 | Best AUC : 0.9671565 (epoch : 849)
# [Epoch 850] Train - loss : 0.6340502 | Val - AUC : 0.9671565 | Best AUC : 0.9671565 (epoch : 850)
# [Epoch 851] Train - loss : 0.6134811 | Val - AUC : 0.967157 | Best AUC : 0.967157 (epoch : 851)
# [Epoch 852] Train - loss : 0.6384904 | Val - AUC : 0.9671588 | Best AUC : 0.9671588 (epoch : 852)
# [Epoch 853] Train - loss : 0.5687836 | Val - AUC : 0.9671564 | Best AUC : 0.9671588 (epoch : 852)
# [Epoch 854] Train - loss : 0.5610304 | Val - AUC : 0.9671579 | Best AUC : 0.9671588 (epoch : 852)
# [Epoch 855] Train - loss : 0.7324302 | Val - AUC : 0.9671596 | Best AUC : 0.9671596 (epoch : 855)
# [Epoch 856] Train - loss : 0.6908535 | Val - AUC : 0.9671635 | Best AUC : 0.9671635 (epoch : 856)
# [Epoch 857] Train - loss : 0.6251735 | Val - AUC : 0.9671623 | Best AUC : 0.9671635 (epoch : 856)
# [Epoch 858] Train - loss : 0.5664068 | Val - AUC : 0.9671654 | Best AUC : 0.9671654 (epoch : 858)
# [Epoch 859] Train - loss : 0.7165005 | Val - AUC : 0.9671701 | Best AUC : 0.9671701 (epoch : 859)
# [Epoch 860] Train - loss : 0.5506552 | Val - AUC : 0.9671715 | Best AUC : 0.9671715 (epoch : 860)
# [Epoch 861] Train - loss : 0.5780462 | Val - AUC : 0.9671669 | Best AUC : 0.9671715 (epoch : 860)
# [Epoch 862] Train - loss : 0.6319475 | Val - AUC : 0.9671722 | Best AUC : 0.9671722 (epoch : 862)
# [Epoch 863] Train - loss : 0.5579401 | Val - AUC : 0.9671731 | Best AUC : 0.9671731 (epoch : 863)
# [Epoch 864] Train - loss : 0.6587427 | Val - AUC : 0.9671799 | Best AUC : 0.9671799 (epoch : 864)
# [Epoch 865] Train - loss : 0.4753201 | Val - AUC : 0.9671738 | Best AUC : 0.9671799 (epoch : 864)
# [Epoch 866] Train - loss : 0.7265763 | Val - AUC : 0.9671773 | Best AUC : 0.9671799 (epoch : 864)
# [Epoch 867] Train - loss : 0.7204863 | Val - AUC : 0.9671814 | Best AUC : 0.9671814 (epoch : 867)
# [Epoch 868] Train - loss : 0.6018595 | Val - AUC : 0.9671816 | Best AUC : 0.9671816 (epoch : 868)
# [Epoch 869] Train - loss : 0.5662736 | Val - AUC : 0.967186 | Best AUC : 0.967186 (epoch : 869)
# [Epoch 870] Train - loss : 0.6061053 | Val - AUC : 0.9671863 | Best AUC : 0.9671863 (epoch : 870)
# [Epoch 871] Train - loss : 0.7422778 | Val - AUC : 0.9671881 | Best AUC : 0.9671881 (epoch : 871)
# [Epoch 872] Train - loss : 0.748396 | Val - AUC : 0.9671854 | Best AUC : 0.9671881 (epoch : 871)
# [Epoch 873] Train - loss : 0.6846303 | Val - AUC : 0.9671873 | Best AUC : 0.9671881 (epoch : 871)
# [Epoch 874] Train - loss : 0.7061162 | Val - AUC : 0.9671881 | Best AUC : 0.9671881 (epoch : 874)
# [Epoch 875] Train - loss : 0.7409841 | Val - AUC : 0.9671886 | Best AUC : 0.9671886 (epoch : 875)
# [Epoch 876] Train - loss : 0.7227999 | Val - AUC : 0.9671954 | Best AUC : 0.9671954 (epoch : 876)
# [Epoch 877] Train - loss : 0.6595792 | Val - AUC : 0.967197 | Best AUC : 0.967197 (epoch : 877)
# [Epoch 878] Train - loss : 0.7015573 | Val - AUC : 0.9672027 | Best AUC : 0.9672027 (epoch : 878)
# [Epoch 879] Train - loss : 0.5399099 | Val - AUC : 0.9672041 | Best AUC : 0.9672041 (epoch : 879)
# [Epoch 880] Train - loss : 0.5400838 | Val - AUC : 0.9671981 | Best AUC : 0.9672041 (epoch : 879)
# [Epoch 881] Train - loss : 0.561863 | Val - AUC : 0.9672058 | Best AUC : 0.9672058 (epoch : 881)
# [Epoch 882] Train - loss : 0.6182655 | Val - AUC : 0.9672037 | Best AUC : 0.9672058 (epoch : 881)
# [Epoch 883] Train - loss : 0.6151531 | Val - AUC : 0.9672072 | Best AUC : 0.9672072 (epoch : 883)
# [Epoch 884] Train - loss : 0.5863667 | Val - AUC : 0.9672077 | Best AUC : 0.9672077 (epoch : 884)
# [Epoch 885] Train - loss : 0.5156123 | Val - AUC : 0.9672098 | Best AUC : 0.9672098 (epoch : 885)
# [Epoch 886] Train - loss : 0.6517219 | Val - AUC : 0.9672023 | Best AUC : 0.9672098 (epoch : 885)
# [Epoch 887] Train - loss : 0.7130364 | Val - AUC : 0.9672108 | Best AUC : 0.9672108 (epoch : 887)
# [Epoch 888] Train - loss : 0.6359286 | Val - AUC : 0.9672206 | Best AUC : 0.9672206 (epoch : 888)
# [Epoch 889] Train - loss : 0.6257673 | Val - AUC : 0.9672264 | Best AUC : 0.9672264 (epoch : 889)
# [Epoch 890] Train - loss : 0.6995536 | Val - AUC : 0.967227 | Best AUC : 0.967227 (epoch : 890)
# [Epoch 891] Train - loss : 0.7517902 | Val - AUC : 0.9672279 | Best AUC : 0.9672279 (epoch : 891)
# [Epoch 892] Train - loss : 0.6299454 | Val - AUC : 0.9672275 | Best AUC : 0.9672279 (epoch : 891)
# [Epoch 893] Train - loss : 0.6958842 | Val - AUC : 0.9672256 | Best AUC : 0.9672279 (epoch : 891)
# [Epoch 894] Train - loss : 0.6447317 | Val - AUC : 0.9672267 | Best AUC : 0.9672279 (epoch : 891)
# [Epoch 895] Train - loss : 0.6971363 | Val - AUC : 0.9672236 | Best AUC : 0.9672279 (epoch : 891)
# [Epoch 896] Train - loss : 0.6079649 | Val - AUC : 0.967222 | Best AUC : 0.9672279 (epoch : 891)
# [Epoch 897] Train - loss : 0.6681196 | Val - AUC : 0.9672226 | Best AUC : 0.9672279 (epoch : 891)
# [Epoch 898] Train - loss : 0.5952211 | Val - AUC : 0.9672268 | Best AUC : 0.9672279 (epoch : 891)
# [Epoch 899] Train - loss : 0.6955565 | Val - AUC : 0.9672288 | Best AUC : 0.9672288 (epoch : 899)
# [Epoch 900] Train - loss : 0.6630004 | Val - AUC : 0.9672276 | Best AUC : 0.9672288 (epoch : 899)
# [Epoch 901] Train - loss : 0.5654789 | Val - AUC : 0.9672272 | Best AUC : 0.9672288 (epoch : 899)
# [Epoch 902] Train - loss : 0.6459183 | Val - AUC : 0.9672313 | Best AUC : 0.9672313 (epoch : 902)
# [Epoch 903] Train - loss : 0.5529893 | Val - AUC : 0.9672296 | Best AUC : 0.9672313 (epoch : 902)
# [Epoch 904] Train - loss : 0.5753373 | Val - AUC : 0.9672334 | Best AUC : 0.9672334 (epoch : 904)
# [Epoch 905] Train - loss : 0.7115624 | Val - AUC : 0.9672406 | Best AUC : 0.9672406 (epoch : 905)
# [Epoch 906] Train - loss : 0.5962402 | Val - AUC : 0.9672362 | Best AUC : 0.9672406 (epoch : 905)
# [Epoch 907] Train - loss : 0.5820779 | Val - AUC : 0.9672359 | Best AUC : 0.9672406 (epoch : 905)
# [Epoch 908] Train - loss : 0.5305015 | Val - AUC : 0.9672419 | Best AUC : 0.9672419 (epoch : 908)
# [Epoch 909] Train - loss : 0.5878247 | Val - AUC : 0.9672397 | Best AUC : 0.9672419 (epoch : 908)
# [Epoch 910] Train - loss : 0.5991525 | Val - AUC : 0.9672449 | Best AUC : 0.9672449 (epoch : 910)
# [Epoch 911] Train - loss : 0.602434 | Val - AUC : 0.9672497 | Best AUC : 0.9672497 (epoch : 911)
# [Epoch 912] Train - loss : 0.71274 | Val - AUC : 0.9672535 | Best AUC : 0.9672535 (epoch : 912)
# [Epoch 913] Train - loss : 0.589541 | Val - AUC : 0.9672509 | Best AUC : 0.9672535 (epoch : 912)
# [Epoch 914] Train - loss : 0.6484263 | Val - AUC : 0.9672498 | Best AUC : 0.9672535 (epoch : 912)
# [Epoch 915] Train - loss : 0.6755367 | Val - AUC : 0.9672537 | Best AUC : 0.9672537 (epoch : 915)
# [Epoch 916] Train - loss : 0.5201656 | Val - AUC : 0.967258 | Best AUC : 0.967258 (epoch : 916)
# [Epoch 917] Train - loss : 0.6063296 | Val - AUC : 0.9672544 | Best AUC : 0.967258 (epoch : 916)
# [Epoch 918] Train - loss : 0.5870092 | Val - AUC : 0.9672551 | Best AUC : 0.967258 (epoch : 916)
# [Epoch 919] Train - loss : 0.5834071 | Val - AUC : 0.967252 | Best AUC : 0.967258 (epoch : 916)
# [Epoch 920] Train - loss : 0.7174196 | Val - AUC : 0.967256 | Best AUC : 0.967258 (epoch : 916)
# [Epoch 921] Train - loss : 0.576131 | Val - AUC : 0.967255 | Best AUC : 0.967258 (epoch : 916)
# [Epoch 922] Train - loss : 0.6420042 | Val - AUC : 0.9672549 | Best AUC : 0.967258 (epoch : 916)
# [Epoch 923] Train - loss : 0.5148116 | Val - AUC : 0.9672599 | Best AUC : 0.9672599 (epoch : 923)
# [Epoch 924] Train - loss : 0.5170638 | Val - AUC : 0.9672645 | Best AUC : 0.9672645 (epoch : 924)
# [Epoch 925] Train - loss : 0.6481769 | Val - AUC : 0.9672664 | Best AUC : 0.9672664 (epoch : 925)
# [Epoch 926] Train - loss : 0.5865733 | Val - AUC : 0.9672709 | Best AUC : 0.9672709 (epoch : 926)
# [Epoch 927] Train - loss : 0.681365 | Val - AUC : 0.9672651 | Best AUC : 0.9672709 (epoch : 926)
# [Epoch 928] Train - loss : 0.5539918 | Val - AUC : 0.9672636 | Best AUC : 0.9672709 (epoch : 926)
# [Epoch 929] Train - loss : 0.7586144 | Val - AUC : 0.9672647 | Best AUC : 0.9672709 (epoch : 926)
# [Epoch 930] Train - loss : 0.6198813 | Val - AUC : 0.9672652 | Best AUC : 0.9672709 (epoch : 926)
# [Epoch 931] Train - loss : 0.5540863 | Val - AUC : 0.9672661 | Best AUC : 0.9672709 (epoch : 926)
# [Epoch 932] Train - loss : 0.6198669 | Val - AUC : 0.9672703 | Best AUC : 0.9672709 (epoch : 926)
# [Epoch 933] Train - loss : 0.6650177 | Val - AUC : 0.9672752 | Best AUC : 0.9672752 (epoch : 933)
# [Epoch 934] Train - loss : 0.573049 | Val - AUC : 0.9672756 | Best AUC : 0.9672756 (epoch : 934)
# [Epoch 935] Train - loss : 0.535811 | Val - AUC : 0.9672768 | Best AUC : 0.9672768 (epoch : 935)
# [Epoch 936] Train - loss : 0.7165328 | Val - AUC : 0.9672781 | Best AUC : 0.9672781 (epoch : 936)
# [Epoch 937] Train - loss : 0.6090488 | Val - AUC : 0.9672786 | Best AUC : 0.9672786 (epoch : 937)
# [Epoch 938] Train - loss : 0.7287718 | Val - AUC : 0.967283 | Best AUC : 0.967283 (epoch : 938)
# [Epoch 939] Train - loss : 0.6904707 | Val - AUC : 0.9672859 | Best AUC : 0.9672859 (epoch : 939)
# [Epoch 940] Train - loss : 0.6137481 | Val - AUC : 0.9672832 | Best AUC : 0.9672859 (epoch : 939)
# [Epoch 941] Train - loss : 0.6579719 | Val - AUC : 0.9672895 | Best AUC : 0.9672895 (epoch : 941)
# [Epoch 942] Train - loss : 0.834242 | Val - AUC : 0.9672896 | Best AUC : 0.9672896 (epoch : 942)
# [Epoch 943] Train - loss : 0.5323025 | Val - AUC : 0.96729 | Best AUC : 0.96729 (epoch : 943)
# [Epoch 944] Train - loss : 0.556394 | Val - AUC : 0.9672924 | Best AUC : 0.9672924 (epoch : 944)
# [Epoch 945] Train - loss : 0.5735079 | Val - AUC : 0.9672918 | Best AUC : 0.9672924 (epoch : 944)
# [Epoch 946] Train - loss : 0.6098717 | Val - AUC : 0.9672944 | Best AUC : 0.9672944 (epoch : 946)
# [Epoch 947] Train - loss : 0.7436031 | Val - AUC : 0.9672932 | Best AUC : 0.9672944 (epoch : 946)
# [Epoch 948] Train - loss : 0.6927458 | Val - AUC : 0.9672995 | Best AUC : 0.9672995 (epoch : 948)
# [Epoch 949] Train - loss : 0.7139922 | Val - AUC : 0.9672984 | Best AUC : 0.9672995 (epoch : 948)
# [Epoch 950] Train - loss : 0.6145281 | Val - AUC : 0.9672956 | Best AUC : 0.9672995 (epoch : 948)
# [Epoch 951] Train - loss : 0.6541962 | Val - AUC : 0.9672997 | Best AUC : 0.9672997 (epoch : 951)
# [Epoch 952] Train - loss : 0.6213711 | Val - AUC : 0.9672979 | Best AUC : 0.9672997 (epoch : 951)
# [Epoch 953] Train - loss : 0.6305272 | Val - AUC : 0.9673033 | Best AUC : 0.9673033 (epoch : 953)
# [Epoch 954] Train - loss : 0.5018395 | Val - AUC : 0.9673096 | Best AUC : 0.9673096 (epoch : 954)
# [Epoch 955] Train - loss : 0.6271587 | Val - AUC : 0.9673106 | Best AUC : 0.9673106 (epoch : 955)
# [Epoch 956] Train - loss : 0.8024376 | Val - AUC : 0.9673084 | Best AUC : 0.9673106 (epoch : 955)
# [Epoch 957] Train - loss : 0.4780741 | Val - AUC : 0.9673071 | Best AUC : 0.9673106 (epoch : 955)
# [Epoch 958] Train - loss : 0.7157762 | Val - AUC : 0.967311 | Best AUC : 0.967311 (epoch : 958)
# [Epoch 959] Train - loss : 0.5395123 | Val - AUC : 0.9673099 | Best AUC : 0.967311 (epoch : 958)
# [Epoch 960] Train - loss : 0.732429 | Val - AUC : 0.9673108 | Best AUC : 0.967311 (epoch : 958)
# [Epoch 961] Train - loss : 0.6371922 | Val - AUC : 0.9673109 | Best AUC : 0.967311 (epoch : 958)
# [Epoch 962] Train - loss : 0.5547811 | Val - AUC : 0.9673121 | Best AUC : 0.9673121 (epoch : 962)
# [Epoch 963] Train - loss : 0.72522 | Val - AUC : 0.9673122 | Best AUC : 0.9673122 (epoch : 963)
# [Epoch 964] Train - loss : 0.7217938 | Val - AUC : 0.9673164 | Best AUC : 0.9673164 (epoch : 964)
# [Epoch 965] Train - loss : 0.6179195 | Val - AUC : 0.9673164 | Best AUC : 0.9673164 (epoch : 964)
# [Epoch 966] Train - loss : 0.6857056 | Val - AUC : 0.9673164 | Best AUC : 0.9673164 (epoch : 964)
# [Epoch 967] Train - loss : 0.5771595 | Val - AUC : 0.9673139 | Best AUC : 0.9673164 (epoch : 964)
# [Epoch 968] Train - loss : 0.6596956 | Val - AUC : 0.9673145 | Best AUC : 0.9673164 (epoch : 964)
# [Epoch 969] Train - loss : 0.5190014 | Val - AUC : 0.9673226 | Best AUC : 0.9673226 (epoch : 969)
# [Epoch 970] Train - loss : 0.486506 | Val - AUC : 0.9673255 | Best AUC : 0.9673255 (epoch : 970)
# [Epoch 971] Train - loss : 0.5434264 | Val - AUC : 0.9673247 | Best AUC : 0.9673255 (epoch : 970)
# [Epoch 972] Train - loss : 0.6753281 | Val - AUC : 0.9673261 | Best AUC : 0.9673261 (epoch : 972)
# [Epoch 973] Train - loss : 0.7765551 | Val - AUC : 0.9673237 | Best AUC : 0.9673261 (epoch : 972)
# [Epoch 974] Train - loss : 0.567306 | Val - AUC : 0.9673238 | Best AUC : 0.9673261 (epoch : 972)
# [Epoch 975] Train - loss : 0.5937732 | Val - AUC : 0.9673268 | Best AUC : 0.9673268 (epoch : 975)
# [Epoch 976] Train - loss : 0.5166654 | Val - AUC : 0.9673285 | Best AUC : 0.9673285 (epoch : 976)
# [Epoch 977] Train - loss : 0.5735654 | Val - AUC : 0.9673262 | Best AUC : 0.9673285 (epoch : 976)
# [Epoch 978] Train - loss : 0.5427772 | Val - AUC : 0.9673298 | Best AUC : 0.9673298 (epoch : 978)
# [Epoch 979] Train - loss : 0.5332785 | Val - AUC : 0.967334 | Best AUC : 0.967334 (epoch : 979)
# [Epoch 980] Train - loss : 0.6808835 | Val - AUC : 0.9673313 | Best AUC : 0.967334 (epoch : 979)
# [Epoch 981] Train - loss : 0.6750379 | Val - AUC : 0.9673304 | Best AUC : 0.967334 (epoch : 979)
# [Epoch 982] Train - loss : 0.4843576 | Val - AUC : 0.967329 | Best AUC : 0.967334 (epoch : 979)
# [Epoch 983] Train - loss : 0.6130418 | Val - AUC : 0.9673348 | Best AUC : 0.9673348 (epoch : 983)
# [Epoch 984] Train - loss : 0.6620415 | Val - AUC : 0.9673267 | Best AUC : 0.9673348 (epoch : 983)
# [Epoch 985] Train - loss : 0.5678694 | Val - AUC : 0.9673346 | Best AUC : 0.9673348 (epoch : 983)
# [Epoch 986] Train - loss : 0.580474 | Val - AUC : 0.9673339 | Best AUC : 0.9673348 (epoch : 983)
# [Epoch 987] Train - loss : 0.5949219 | Val - AUC : 0.9673374 | Best AUC : 0.9673374 (epoch : 987)
# [Epoch 988] Train - loss : 0.7269729 | Val - AUC : 0.9673432 | Best AUC : 0.9673432 (epoch : 988)
# [Epoch 989] Train - loss : 0.6560465 | Val - AUC : 0.967346 | Best AUC : 0.967346 (epoch : 989)
# [Epoch 990] Train - loss : 0.6203294 | Val - AUC : 0.9673479 | Best AUC : 0.9673479 (epoch : 990)
# [Epoch 991] Train - loss : 0.5114736 | Val - AUC : 0.9673448 | Best AUC : 0.9673479 (epoch : 990)
# [Epoch 992] Train - loss : 0.6584475 | Val - AUC : 0.9673465 | Best AUC : 0.9673479 (epoch : 990)
# [Epoch 993] Train - loss : 0.5383783 | Val - AUC : 0.967351 | Best AUC : 0.967351 (epoch : 993)
# [Epoch 994] Train - loss : 0.5819235 | Val - AUC : 0.9673555 | Best AUC : 0.9673555 (epoch : 994)
# [Epoch 995] Train - loss : 0.6895713 | Val - AUC : 0.9673519 | Best AUC : 0.9673555 (epoch : 994)
# [Epoch 996] Train - loss : 0.5719991 | Val - AUC : 0.9673535 | Best AUC : 0.9673555 (epoch : 994)
# [Epoch 997] Train - loss : 0.65428 | Val - AUC : 0.9673597 | Best AUC : 0.9673597 (epoch : 997)
# [Epoch 998] Train - loss : 0.5426873 | Val - AUC : 0.9673562 | Best AUC : 0.9673597 (epoch : 997)
# [Epoch 999] Train - loss : 0.5717098 | Val - AUC : 0.967356 | Best AUC : 0.9673597 (epoch : 997)
# [2020-12-17 21:40:12,669][INFO][base.py:96] Succeed to load best model, device: 'cpu'

# %%
best_latent_data_list = result_dict["val_result_dict_list"][997]["latent_data_list"]
abnormal_label_list = [abnormal_label.item() for x, y, abnormal_label in dataset_factory.test_dataset]

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

pca = PCA(n_components=2)

pca.fit(best_latent_data_list)
pca_best_latent_data_list = pca.transform(best_latent_data_list)

pca_normal_latent_data_list = [
    pca_best_latent_data for pca_best_latent_data, abnormal_label in 
    zip(pca_best_latent_data_list, abnormal_label_list) if abnormal_label == 0
]
pca_abnormal_latent_data_list = [
    pca_best_latent_data for pca_best_latent_data, abnormal_label in
    zip(pca_best_latent_data_list, abnormal_label_list) if abnormal_label == 1
]

# %%
fig = plt.figure(figsize=(15, 15))

plt.scatter(
    x=list(map(lambda data: data[0], pca_normal_latent_data_list)),
    y=list(map(lambda data: data[1], pca_normal_latent_data_list)),
    label="Normal",
    color="blue",
    alpha=0.3
)
plt.scatter(
    x=list(map(lambda data: data[0], pca_abnormal_latent_data_list)),
    y=list(map(lambda data: data[1], pca_abnormal_latent_data_list)),
    label="Abormal",
    color="red",
    alpha=0.3
)
plt.xlim(-2, 2)
plt.ylim(-2, 2)

font_size = 15

plt.xlabel("PC1", fontsize=font_size)
plt.ylabel("PC2", fontsize=font_size)
plt.xticks(fontsize=font_size)
plt.yticks(fontsize=font_size)
plt.legend(fontsize=font_size)

plt.savefig("./plot/oesae_margin01_latent_2d.png")

plt.show()

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

pca = PCA(n_components=3)

pca.fit(best_latent_data_list)
pca_best_latent_data_list = pca.transform(best_latent_data_list)

pca_normal_latent_data_list = [
    pca_best_latent_data for pca_best_latent_data, abnormal_label in 
    zip(pca_best_latent_data_list, abnormal_label_list) if abnormal_label == 0
]
pca_abnormal_latent_data_list = [
    pca_best_latent_data for pca_best_latent_data, abnormal_label in
    zip(pca_best_latent_data_list, abnormal_label_list) if abnormal_label == 1
]

# %%
fig = plt.figure(figsize=(15, 15))
ax = fig.gca(projection='3d')

ax.scatter(
    list(map(lambda data: data[0], pca_normal_latent_data_list)),
    list(map(lambda data: data[1], pca_normal_latent_data_list)),
    list(map(lambda data: data[2], pca_normal_latent_data_list)),
    label="Normal",
    color="blue",
    alpha=0.3
)
ax.scatter(
    list(map(lambda data: data[0], pca_abnormal_latent_data_list)),
    list(map(lambda data: data[1], pca_abnormal_latent_data_list)),
    list(map(lambda data: data[2], pca_abnormal_latent_data_list)),
    label="Abormal",
    color="red",
    alpha=0.3
)

ax.set_xlim(-2, 2)
ax.set_ylim(-2, 2)
ax.set_zlim(-2, 2)

font_size = 12

ax.set_xlabel("PC1", fontsize=font_size)
ax.set_ylabel("PC2", fontsize=font_size)
ax.set_zlabel("PC3", fontsize=font_size)
ax.tick_params(axis="x", labelsize=font_size)
ax.tick_params(axis="y", labelsize=font_size)
ax.tick_params(axis="z", labelsize=font_size)
ax.legend(fontsize=font_size)

ax.view_init(elev=10., azim=300)

# ax.view_init(elev=10., azim=310)
plt.savefig("./plot/oesae_margin01_latent_3d.png")

plt.show()
